# %%
import requests
import bs4
from bs4 import BeautifulSoup
from urllib.parse import urljoin
import pandas as pd

# %%
url_inicial = 'https://link.springer.com/journal/40590/volumes-and-issues'
url_root = 'https://link.springer.com/journal/40590/volumes-and-issues'
r=requests.get(url_inicial)

# %%
soup = BeautifulSoup(r.text, 'html.parser')

# %%
box = soup.find('div', class_='u-text-sans-serif')
volumen=box.findAll('li', class_='c-list-group__item')
vol = [x.find('a').get('href')for x in volumen]
vol=[urljoin(url_root,i) for i in vol]
vol
# Out:
# ['https://link.springer.com/journal/40590/volumes-and-issues/28-3',
#  'https://link.springer.com/journal/40590/volumes-and-issues/28-2',
#  'https://link.springer.com/journal/40590/volumes-and-issues/28-1',
#  'https://link.springer.com/journal/40590/volumes-and-issues/27-3',
#  'https://link.springer.com/journal/40590/volumes-and-issues/27-2',
#  'https://link.springer.com/journal/40590/volumes-and-issues/27-1',
#  'https://link.springer.com/journal/40590/volumes-and-issues/26-3',
#  'https://link.springer.com/journal/40590/volumes-and-issues/26-2',
#  'https://link.springer.com/journal/40590/volumes-and-issues/26-1',
#  'https://link.springer.com/journal/40590/volumes-and-issues/25-3',
#  'https://link.springer.com/journal/40590/volumes-and-issues/25-2',
#  'https://link.springer.com/journal/40590/volumes-and-issues/25-1',
#  'https://link.springer.com/journal/40590/volumes-and-issues/24-2',
#  'https://link.springer.com/journal/40590/volumes-and-issues/24-1',
# ...

# %%
vol2 =[]
for i in vol: 
    url_inicial1=i 
    r1 = requests.get(url_inicial1)
    soup1 = BeautifulSoup(r1.text, 'html.parser')
    box1 = soup1.find('ol', class_='app-volumes-and-issues__article-list c-list-group c-list-group--lg c-list-group--bordered') 
    volumen1=box1.findAll('li', class_='c-list-group__item')
    vol1 = [x.find('a').get('href')for x in volumen1]
    vol2+=vol1

# %%
vol2
# Out:
# ['https://link.springer.com/article/10.1007/s40590-022-00463-2',
#  'https://link.springer.com/article/10.1007/s40590-022-00460-5',
#  'https://link.springer.com/article/10.1007/s40590-022-00459-y',
#  'https://link.springer.com/article/10.1007/s40590-022-00462-3',
#  'https://link.springer.com/article/10.1007/s40590-022-00461-4',
#  'https://link.springer.com/article/10.1007/s40590-022-00464-1',
#  'https://link.springer.com/article/10.1007/s40590-022-00457-0',
#  'https://link.springer.com/article/10.1007/s40590-022-00458-z',
#  'https://link.springer.com/article/10.1007/s40590-022-00454-3',
#  'https://link.springer.com/article/10.1007/s40590-022-00447-2',
#  'https://link.springer.com/article/10.1007/s40590-022-00455-2',
#  'https://link.springer.com/article/10.1007/s40590-022-00453-4',
#  'https://link.springer.com/article/10.1007/s40590-022-00452-5',
#  'https://link.springer.com/article/10.1007/s40590-022-00451-6',
# ...

# %%
def get_url_items(sopa,url):
    soup1 = BeautifulSoup(r1.text, 'html.parser')
    box1 = soup1.find('ol', class_='app-volumes-and-issues__article-list c-list-group c-list-group--lg c-list-group--bordered') 
    volumen1=box1.findAll('li', class_='c-list-group__item')
    vol1 = [x.find('a').get('href')for x in volumen1]
    return vol2

# %%
links_items=[]
i=0
while i<1:
    i+=1
    print(f'Estoy en la pagina {url_inicial}')
    r_pag=requests.get(url_inicial)
    s_p=BeautifulSoup(r_pag.text,'html.parser')
    links=get_url_items(s_p, url_inicial)
    links_items.append(links)
# Out:
# Estoy en la pagina https://link.springer.com/journal/40590/volumes-and-issues

# %%
list_scraper=[]
for i in links_items:
    for j in i:
        list_scraper.append(j)
len(list_scraper)
# Out:
# 458

# %%
uno=list_scraper[0]
r_item=requests.get(uno)
s_item=BeautifulSoup(r_item.text, 'html.parser')

# %%
#funcion para iniciar el escraper de cada libro
def scraper_book(url):
    content_book={}
    r=requests.get(url)
    tire='Boletín de la Sociedad Matemática Mexicana'
    a='I. Físico Matemáticas y Ciencias de la Tierra'
    tem='Mathematics'
    s_item=BeautifulSoup(r.text,'html.parser')
    #titulo de revista
    try:
        titulo=tire
        content_book['Titulo Revista']=tire
    except AttributeError:
        content_book['Titulo Revista']=None
    #area
    try:
        area=a
        content_book['Area']=a
    except AttributeError:
        content_book['Area']=None
    #tematica
    try:
        tema=tem
        content_book['Tematica']=tem
    except AttributeError:
        content_book['Tematica']=None
    #titulo articulo
    try:
        titu=s_item.find('h1', class_='c-article-title').get_text(strip=True)
        content_book['Titulo Articulo']=titu
    except AttributeError:
        content_book['Titulo Articulo']=None
    #resumen
    try:
        resu=s_item.find('section', class_='item abstract').get_text(strip=True)
        content_book['Resumen']=resu.replace("Resumen","")
    except AttributeError:
        content_book['Resumen']=None
    #abstract
    try:
        abst=s_item.find('div', class_='c-article-section__content').get_text(strip=True)
        content_book['Abstract']=abst.replace("Abstract","")
    except AttributeError:
        content_book['Abstract']=None
    #Link incial
    try:
        linkart=url
        content_book['Link Articulo']=linkart
    except AttributeError:
        content_book['Link Articulo']=None
    #link articulo
    try:
        link=s_item.find('span', class_='u-text-sm').get('href')
        content_book['Link PDF']=link#urljoin(url_root, link)
    except AttributeError:
        content_book['Link PDF']=None
    return content_book

# %%
list_scraper=list_scraper[0:458]
datos_book=[]
for idx, i in enumerate(list_scraper):
    print(f'estas escrapeando la pag {idx}')
    datos_book.append(scraper_book(i))
# Out:
# estas escrapeando la pag 0
# estas escrapeando la pag 1
# estas escrapeando la pag 2
# estas escrapeando la pag 3
# estas escrapeando la pag 4
# estas escrapeando la pag 5
# estas escrapeando la pag 6
# estas escrapeando la pag 7
# estas escrapeando la pag 8
# estas escrapeando la pag 9
# estas escrapeando la pag 10
# estas escrapeando la pag 11
# estas escrapeando la pag 12
# estas escrapeando la pag 13
# estas escrapeando la pag 14
# estas escrapeando la pag 15
# estas escrapeando la pag 16
# estas escrapeando la pag 17
# estas escrapeando la pag 18
# estas escrapeando la pag 19
# estas escrapeando la pag 20
# estas escrapeando la pag 21
# estas escrapeando la pag 22
# estas escrapeando la pag 23
# estas escrapeando la pag 24
# estas escrapeando la pag 25
# estas escrapeando la pag 26
# estas escrapeando la pag 27
# estas escrapeando la pag 28
# estas escrapeando la pag 29
# estas escrapeando la pag 30
# estas escrapeando la pag 31
# estas escrapeando la pag 32
# ...

# %%
df_catalogo=pd.DataFrame(datos_book)
df_catalogo
# Out:
#                                  Titulo Revista  \
# 0    Boletín de la Sociedad Matemática Mexicana
# 1    Boletín de la Sociedad Matemática Mexicana
# 2    Boletín de la Sociedad Matemática Mexicana
# 3    Boletín de la Sociedad Matemática Mexicana
# 4    Boletín de la Sociedad Matemática Mexicana
# ..                                          ...
# 453  Boletín de la Sociedad Matemática Mexicana
# 454  Boletín de la Sociedad Matemática Mexicana
# 455  Boletín de la Sociedad Matemática Mexicana
# 456  Boletín de la Sociedad Matemática Mexicana
# 457  Boletín de la Sociedad Matemática Mexicana
#
#                                               Area     Tematica  \
# 0    I. Físico Matemáticas y Ciencias de la Tierra  Mathematics
# 1    I. Físico Matemáticas y Ciencias de la Tierra  Mathematics
# 2    I. Físico Matemáticas y Ciencias de la Tierra  Mathematics
# 3    I. Físico Matemáticas y Ciencias de la Tierra  Mathematics
# ...

# %%
df_catalogo.to_csv('Revista213.csv', index=False)
