# %%
import requests
import bs4
from bs4 import BeautifulSoup
from urllib.parse import urljoin
import pandas as pd

# %%
url_inicial = 'http://revistamedica.imss.gob.mx/numero_actual'
url_root = 'http://revistamedica.imss.gob.mx/numero_actual'
r=requests.get(url_inicial)

# %%
soup = BeautifulSoup(r.text, 'html.parser')

# %%
box = soup.find('div', class_='region region-content')
volumen=box.findAll('div', class_='row text-justify')
vol = [x.find('a').get('href')for x in volumen]
vol=[urljoin(url_root,i) for i in vol]
vol
# Out:
# ['http://revistamedica.imss.gob.mx/editorial/index.php/revista_medica/article/view/4627',
#  'http://revistamedica.imss.gob.mx/editorial/index.php/revista_medica/article/view/4245',
#  'http://revistamedica.imss.gob.mx/editorial/index.php/revista_medica/article/view/4409',
#  'http://revistamedica.imss.gob.mx/editorial/index.php/revista_medica/article/view/4425',
#  'http://revistamedica.imss.gob.mx/editorial/index.php/revista_medica/article/view/4446',
#  'http://revistamedica.imss.gob.mx/editorial/index.php/revista_medica/article/view/4478',
#  'http://revistamedica.imss.gob.mx/editorial/index.php/revista_medica/article/view/4487',
#  'http://revistamedica.imss.gob.mx/editorial/index.php/revista_medica/article/view/4494',
#  'http://revistamedica.imss.gob.mx/editorial/index.php/revista_medica/article/view/4523',
#  'http://revistamedica.imss.gob.mx/editorial/index.php/revista_medica/article/view/4532',
#  'http://revistamedica.imss.gob.mx/editorial/index.php/revista_medica/article/view/4546',
#  'http://revistamedica.imss.gob.mx/editorial/index.php/revista_medica/article/view/4547',
#  'http://revistamedica.imss.gob.mx/editorial/index.php/revista_medica/article/view/4567',
#  'http://revistamedica.imss.gob.mx/editorial/index.php/revista_medica/article/view/4575',
#  'http://revistamedica.imss.gob.mx/editorial/index.php/revista_medica/article/view/4472',
#  'http://revistamedica.imss.gob.mx/editorial/index.php/revista_medica/article/view/4484',
#  'http://revistamedica.imss.gob.mx/editorial/index.php/revista_medica/article/view/4497']

# %%
def get_url_items(sopa, url): 
    box = soup.find('div', class_='region region-content')
    volumen=box.findAll('div', class_='row text-justify')
    vol = [x.find('a').get('href')for x in volumen]
    vol=[urljoin(url_root,i) for i in vol]
    return vol

# %%
links_items=[]
i=0
while i<1:
    i+=1
    print(f'Estoy en la pagina {url_inicial}')
    r_pag=requests.get(url_inicial)
    s_p=BeautifulSoup(r_pag.text,'html.parser')
    links=get_url_items(s_p, url_inicial)
    links_items.append(links)
# Out:
# Estoy en la pagina http://revistamedica.imss.gob.mx/numero_actual

# %%
list_scraper=[]
for i in links_items:
    for j in i:
        list_scraper.append(j)
len(list_scraper)
# Out:
# 17

# %%
uno=list_scraper[0]
r_item=requests.get(uno)
s_item=BeautifulSoup(r_item.text, 'html.parser')

# %%
#funcion para iniciar el escraper de cada libro
def scraper_book(url):
    content_book={}
    r=requests.get(url)
    tire='Revista Médica del Instituto Mexicano del Seguro Social'
    a='III. Medicina y Ciencias de la Salud'
    tem='Medicina Experimental, Clínica, Epidemiología, Sistemas y Servicios de Salud, Educación Médica, Historia y Filosofía de la Medicina, Ciencias Sociales y Salud, ética Médica'
    url='http://revistamedica.imss.gob.mx/'
    s_item=BeautifulSoup(r.text,'html.parser')
    #titulo de revista
    try:
        titulo=tire
        content_book['Titulo de revista']=tire
    except AttributeError:
        content_book['Titulo de revista']=None
    #area
    try:
        area=a
        content_book['Área']=a
    except AttributeError:
        content_book['Área']=None
    #tematica
    try:
        tema=tem
        content_book['Temática']=tem
    except AttributeError:
        content_book['Temática']=None
    #titulo libro
    try:
        titu=s_item.find('div', id='articleTitle').get_text(strip=True)
        content_book['Titulo del libro']=titu
    except AttributeError:
        content_book['Titulo del libro']=None
    #resumen
    try:
        resu=s_item.find('p').get_text(strip=True)
        content_book['Resumen']=resu
    except AttributeError:
        content_book['Resumen']=None
    #Link incial
    try:
        inicial=url
        content_book['Link inicial']=url
    except AttributeError:
        content_book['Link inicial']=None
    #link articulo
    try:
        link=s_item.find('a', class_='file').get('href')
        content_book['Link articulo']=urljoin(url_root, link)
    except AttributeError:
        content_book['Link articulo']=None
    return content_book

# %%
list_scraper=list_scraper[0:17]
datos_book=[]
for idx, i in enumerate(list_scraper):
    print(f'estas escrapeando la pag {idx}')
    datos_book.append(scraper_book(i))
# Out:
# estas escrapeando la pag 0
# estas escrapeando la pag 1
# estas escrapeando la pag 2
# estas escrapeando la pag 3
# estas escrapeando la pag 4
# estas escrapeando la pag 5
# estas escrapeando la pag 6
# estas escrapeando la pag 7
# estas escrapeando la pag 8
# estas escrapeando la pag 9
# estas escrapeando la pag 10
# estas escrapeando la pag 11
# estas escrapeando la pag 12
# estas escrapeando la pag 13
# estas escrapeando la pag 14
# estas escrapeando la pag 15
# estas escrapeando la pag 16

# %%
df_catalogo=pd.DataFrame(datos_book)
df_catalogo
# Out:
#                                     Titulo de revista  \
# 0   Revista Médica del Instituto Mexicano del Segu...
# 1   Revista Médica del Instituto Mexicano del Segu...
# 2   Revista Médica del Instituto Mexicano del Segu...
# 3   Revista Médica del Instituto Mexicano del Segu...
# 4   Revista Médica del Instituto Mexicano del Segu...
# 5   Revista Médica del Instituto Mexicano del Segu...
# 6   Revista Médica del Instituto Mexicano del Segu...
# 7   Revista Médica del Instituto Mexicano del Segu...
# 8   Revista Médica del Instituto Mexicano del Segu...
# 9   Revista Médica del Instituto Mexicano del Segu...
# 10  Revista Médica del Instituto Mexicano del Segu...
# 11  Revista Médica del Instituto Mexicano del Segu...
# 12  Revista Médica del Instituto Mexicano del Segu...
# 13  Revista Médica del Instituto Mexicano del Segu...
# 14  Revista Médica del Instituto Mexicano del Segu...
# 15  Revista Médica del Instituto Mexicano del Segu...
# 16  Revista Médica del Instituto Mexicano del Segu...
#
#                                     Área  \
# 0   III. Medicina y Ciencias de la Salud
# 1   III. Medicina y Ciencias de la Salud
# 2   III. Medicina y Ciencias de la Salud
# 3   III. Medicina y Ciencias de la Salud
# 4   III. Medicina y Ciencias de la Salud
# 5   III. Medicina y Ciencias de la Salud
# 6   III. Medicina y Ciencias de la Salud
# 7   III. Medicina y Ciencias de la Salud
# 8   III. Medicina y Ciencias de la Salud
# 9   III. Medicina y Ciencias de la Salud
# 10  III. Medicina y Ciencias de la Salud
# 11  III. Medicina y Ciencias de la Salud
# 12  III. Medicina y Ciencias de la Salud
# 13  III. Medicina y Ciencias de la Salud
# 14  III. Medicina y Ciencias de la Salud
# 15  III. Medicina y Ciencias de la Salud
# 16  III. Medicina y Ciencias de la Salud
#
#                                              Temática  \
# 0   Medicina Experimental, Clínica, Epidemiología,...
# 1   Medicina Experimental, Clínica, Epidemiología,...
# 2   Medicina Experimental, Clínica, Epidemiología,...
# 3   Medicina Experimental, Clínica, Epidemiología,...
# 4   Medicina Experimental, Clínica, Epidemiología,...
# 5   Medicina Experimental, Clínica, Epidemiología,...
# 6   Medicina Experimental, Clínica, Epidemiología,...
# 7   Medicina Experimental, Clínica, Epidemiología,...
# 8   Medicina Experimental, Clínica, Epidemiología,...
# 9   Medicina Experimental, Clínica, Epidemiología,...
# 10  Medicina Experimental, Clínica, Epidemiología,...
# 11  Medicina Experimental, Clínica, Epidemiología,...
# 12  Medicina Experimental, Clínica, Epidemiología,...
# 13  Medicina Experimental, Clínica, Epidemiología,...
# 14  Medicina Experimental, Clínica, Epidemiología,...
# 15  Medicina Experimental, Clínica, Epidemiología,...
# 16  Medicina Experimental, Clínica, Epidemiología,...
#
#                                      Titulo del libro  \
# 0   La variabilidad genética en la asociación escl...
# 1   Variabilidad de la hemoglobina y hematocrito d...
# 2   ESTADO ACTUAL DE RESISTENCIA ANTIMICROBIANA EN...
# 3   Perfil clínico-epidemiológico de pacientes con...
# 4   Una intervención educativa sobre lactancia mat...
# 5   Sintomatología cardiorrespiratoria y neuromusc...
# 6   Reinserción laboral en trabajadores con incapa...
# 7   Factores asociados a recurrencia de infeccione...
# 8   Actividad física, perfil bioquímico y somatomé...
# 9   Estrategia de  “follow up” en la gestión de la...
# 10  Influencia de factores de riesgo sobre mortali...
# 11  Diferencia sodio-cloro como predictor pronosti...
# 12  Predicción de mortalidad en COVID-19. Comparac...
# 13  Incidencia de COVID-19 en trabajadores de salu...
# 14  Enfermedad de Kimura simulando neoplasia prima...
# 15  Anomalía de Ebstein tipo B: un caso de espectr...
# 16  Paciente con síndrome de Good y COVID-19. Repo...
#
#                                               Resumen  \
# 0   La Esclerosis Múltiple es la enfermedad neurod...
# 1
# 2   Introducción:Hoy en día la resistencia bacteri...
# 3   Introducción:La Paralisis periodica tirotóxica...
# 4
# 5   Introducción:La enfermedad por coronavirus 201...
# 6   Introducción:Las lesiones de mano derivadas de...
# 7
# 8   Introducción:Durante la contengencia por COVID...
# 9   Introducción:En los países con economías emerg...
# 10  Antecedentes:Los principales factores de riesg...
# 11  ANTECEDENTES: La hipercloremia se ha asociado ...
# 12  Introducción:el pronóstico y mortalidad en pac...
# 13
# 14  Introducción:La enfermedad de Kimura es un des...
# 15                                            Resumen
# 16                                            Resumen
#
#                          Link inicial  \
# 0   http://revistamedica.imss.gob.mx/
# 1   http://revistamedica.imss.gob.mx/
# 2   http://revistamedica.imss.gob.mx/
# 3   http://revistamedica.imss.gob.mx/
# 4   http://revistamedica.imss.gob.mx/
# 5   http://revistamedica.imss.gob.mx/
# 6   http://revistamedica.imss.gob.mx/
# 7   http://revistamedica.imss.gob.mx/
# 8   http://revistamedica.imss.gob.mx/
# 9   http://revistamedica.imss.gob.mx/
# 10  http://revistamedica.imss.gob.mx/
# 11  http://revistamedica.imss.gob.mx/
# 12  http://revistamedica.imss.gob.mx/
# 13  http://revistamedica.imss.gob.mx/
# 14  http://revistamedica.imss.gob.mx/
# 15  http://revistamedica.imss.gob.mx/
# 16  http://revistamedica.imss.gob.mx/
#
#                                         Link articulo
# 0   http://revistamedica.imss.gob.mx/editorial/ind...
# 1   http://revistamedica.imss.gob.mx/editorial/ind...
# 2   http://revistamedica.imss.gob.mx/editorial/ind...
# 3   http://revistamedica.imss.gob.mx/editorial/ind...
# 4   http://revistamedica.imss.gob.mx/editorial/ind...
# 5   http://revistamedica.imss.gob.mx/editorial/ind...
# 6   http://revistamedica.imss.gob.mx/editorial/ind...
# 7   http://revistamedica.imss.gob.mx/editorial/ind...
# 8   http://revistamedica.imss.gob.mx/editorial/ind...
# 9   http://revistamedica.imss.gob.mx/editorial/ind...
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15                                               None
# 16                                               None

# %%
df_catalogo.to_csv('Revista87.csv', index=False)
