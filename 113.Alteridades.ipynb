# %%
import requests
import bs4
from bs4 import BeautifulSoup
from urllib.parse import urljoin
import pandas as pd

# %%
url_inicial = 'https://alteridades.izt.uam.mx/index.php/Alte/issue/archive'
url_root = 'https://alteridades.izt.uam.mx/index.php/Alte/issue/archive'
r=requests.get(url_inicial)

# %%
soup = BeautifulSoup(r.text, 'html.parser')

# %%
lista_articulo = soup.find_all('div', style='float: left; width: 100%;')
links_libros = [x.find('a').get('href') for x in lista_articulo]
links_libros = [urljoin (url_root, i) for i in links_libros]
links_libros
# Out:
# ['https://alteridades.izt.uam.mx/index.php/Alte/issue/view/69',
#  'https://alteridades.izt.uam.mx/index.php/Alte/issue/view/68',
#  'https://alteridades.izt.uam.mx/index.php/Alte/issue/view/66',
#  'https://alteridades.izt.uam.mx/index.php/Alte/issue/view/64',
#  'https://alteridades.izt.uam.mx/index.php/Alte/issue/view/62',
#  'https://alteridades.izt.uam.mx/index.php/Alte/issue/view/60',
#  'https://alteridades.izt.uam.mx/index.php/Alte/issue/view/56',
#  'https://alteridades.izt.uam.mx/index.php/Alte/issue/view/57',
#  'https://alteridades.izt.uam.mx/index.php/Alte/issue/view/54',
#  'https://alteridades.izt.uam.mx/index.php/Alte/issue/view/53',
#  'https://alteridades.izt.uam.mx/index.php/Alte/issue/view/7',
#  'https://alteridades.izt.uam.mx/index.php/Alte/issue/view/9',
#  'https://alteridades.izt.uam.mx/index.php/Alte/issue/view/11',
#  'https://alteridades.izt.uam.mx/index.php/Alte/issue/view/13',
#  'https://alteridades.izt.uam.mx/index.php/Alte/issue/view/15',
#  'https://alteridades.izt.uam.mx/index.php/Alte/issue/view/17',
#  'https://alteridades.izt.uam.mx/index.php/Alte/issue/view/19',
#  'https://alteridades.izt.uam.mx/index.php/Alte/issue/view/21',
#  'https://alteridades.izt.uam.mx/index.php/Alte/issue/view/23',
#  'https://alteridades.izt.uam.mx/index.php/Alte/issue/view/25',
#  'https://alteridades.izt.uam.mx/index.php/Alte/issue/view/27',
#  'https://alteridades.izt.uam.mx/index.php/Alte/issue/view/29',
#  'https://alteridades.izt.uam.mx/index.php/Alte/issue/view/31',
#  'https://alteridades.izt.uam.mx/index.php/Alte/issue/view/33',
#  'https://alteridades.izt.uam.mx/index.php/Alte/issue/view/35',
#  'https://alteridades.izt.uam.mx/index.php/Alte/issue/view/37',
#  'https://alteridades.izt.uam.mx/index.php/Alte/issue/view/39',
#  'https://alteridades.izt.uam.mx/index.php/Alte/issue/view/41',
#  'https://alteridades.izt.uam.mx/index.php/Alte/issue/view/43',
#  'https://alteridades.izt.uam.mx/index.php/Alte/issue/view/45',
#  'https://alteridades.izt.uam.mx/index.php/Alte/issue/view/47',
#  'https://alteridades.izt.uam.mx/index.php/Alte/issue/view/49']

# %%
def get_url_items(soup,url):
    lista_articulo = soup.find_all('div', style='float: left; width: 100%;')
    links_libros = [x.find('a').get('href') for x in lista_articulo]
    links_libros = [urljoin (url_root, i) for i in links_libros]
    return links_libros

# %%
links_items=[]
i=0
while i<1:
    i+=1
    print(f'Estoy en la pagina {url_inicial}')
    r_pag=requests.get(url_inicial)
    s_p=BeautifulSoup(r_pag.text,'html.parser')
    links=get_url_items(s_p, url_inicial)
    links_items.append(links)
# Out:
# Estoy en la pagina https://alteridades.izt.uam.mx/index.php/Alte/issue/archive

# %%
list_scraper=[]
for i in links_items:
    for j in i:
        list_scraper.append(j)
len(list_scraper)
# Out:
# 32

# %%
uno=list_scraper[0]
r_item=requests.get(uno)
s_item=BeautifulSoup(r_item.text, 'html.parser')

# %%
#funcion para iniciar el escraper de cada libro
def scraper_book(url):
    content_book={}
    r=requests.get(url)
    tire='Alteridades'
    a='V. Ciencias Sociales'
    tem='Antropología Social y Etnología'
    url='http://alteridades.izt.uam.mx'
    s_item=BeautifulSoup(r.text,'html.parser')
    #titulo de revista
    try:
        titulo=tire
        content_book['Titulo de revista']=tire
    except AttributeError:
        content_book['Titulo de revista']=None
    #area
    try:
        area=a
        content_book['Área']=a
    except AttributeError:
        content_book['Área']=None
    #tematica
    try:
        tema=tem
        content_book['Temática']=tem
    except AttributeError:
        content_book['Temática']=None
    #titulo libro
    try:
        titu=s_item.find('h3').get_text(strip=True)
        content_book['Titulo del libro']=titu
    except AttributeError:
        content_book['Titulo del libro']=None
    #resumen
    try:
        resu=s_item.find('a', class_='cover').get_text(strip=True)
        content_book['Resumen']=resu
    except AttributeError:
        content_book['Resumen']=None
    #Link incial
    try:
        inicial=url
        content_book['Link inicial']=url
    except AttributeError:
        content_book['Link inicial']=None
    #link articulo
    try:
        link=s_item.find('a', class_='file').get('href')
        content_book['Link articulo']=urljoin(url_root, link)
    except AttributeError:
        content_book['Link articulo']=None
    return content_book

# %%
list_scraper=list_scraper[0:32]
datos_book=[]
for idx, i in enumerate(list_scraper):
    print(f'estas escrapeando la pag {idx}')
    datos_book.append(scraper_book(i))
# Out:
# estas escrapeando la pag 0
# estas escrapeando la pag 1
# estas escrapeando la pag 2
# estas escrapeando la pag 3
# estas escrapeando la pag 4
# estas escrapeando la pag 5
# estas escrapeando la pag 6
# estas escrapeando la pag 7
# estas escrapeando la pag 8
# estas escrapeando la pag 9
# estas escrapeando la pag 10
# estas escrapeando la pag 11
# estas escrapeando la pag 12
# estas escrapeando la pag 13
# estas escrapeando la pag 14
# estas escrapeando la pag 15
# estas escrapeando la pag 16
# estas escrapeando la pag 17
# estas escrapeando la pag 18
# estas escrapeando la pag 19
# estas escrapeando la pag 20
# estas escrapeando la pag 21
# estas escrapeando la pag 22
# estas escrapeando la pag 23
# estas escrapeando la pag 24
# estas escrapeando la pag 25
# estas escrapeando la pag 26
# estas escrapeando la pag 27
# estas escrapeando la pag 28
# estas escrapeando la pag 29
# estas escrapeando la pag 30
# estas escrapeando la pag 31

# %%
df_catalogo=pd.DataFrame(datos_book)
df_catalogo
# Out:
#    Titulo de revista                  Área                         Temática  \
# 0        Alteridades  V. Ciencias Sociales  Antropología Social y Etnología
# 1        Alteridades  V. Ciencias Sociales  Antropología Social y Etnología
# 2        Alteridades  V. Ciencias Sociales  Antropología Social y Etnología
# 3        Alteridades  V. Ciencias Sociales  Antropología Social y Etnología
# 4        Alteridades  V. Ciencias Sociales  Antropología Social y Etnología
# 5        Alteridades  V. Ciencias Sociales  Antropología Social y Etnología
# 6        Alteridades  V. Ciencias Sociales  Antropología Social y Etnología
# 7        Alteridades  V. Ciencias Sociales  Antropología Social y Etnología
# 8        Alteridades  V. Ciencias Sociales  Antropología Social y Etnología
# 9        Alteridades  V. Ciencias Sociales  Antropología Social y Etnología
# 10       Alteridades  V. Ciencias Sociales  Antropología Social y Etnología
# 11       Alteridades  V. Ciencias Sociales  Antropología Social y Etnología
# 12       Alteridades  V. Ciencias Sociales  Antropología Social y Etnología
# 13       Alteridades  V. Ciencias Sociales  Antropología Social y Etnología
# 14       Alteridades  V. Ciencias Sociales  Antropología Social y Etnología
# 15       Alteridades  V. Ciencias Sociales  Antropología Social y Etnología
# 16       Alteridades  V. Ciencias Sociales  Antropología Social y Etnología
# 17       Alteridades  V. Ciencias Sociales  Antropología Social y Etnología
# 18       Alteridades  V. Ciencias Sociales  Antropología Social y Etnología
# 19       Alteridades  V. Ciencias Sociales  Antropología Social y Etnología
# 20       Alteridades  V. Ciencias Sociales  Antropología Social y Etnología
# 21       Alteridades  V. Ciencias Sociales  Antropología Social y Etnología
# 22       Alteridades  V. Ciencias Sociales  Antropología Social y Etnología
# 23       Alteridades  V. Ciencias Sociales  Antropología Social y Etnología
# 24       Alteridades  V. Ciencias Sociales  Antropología Social y Etnología
# 25       Alteridades  V. Ciencias Sociales  Antropología Social y Etnología
# 26       Alteridades  V. Ciencias Sociales  Antropología Social y Etnología
# 27       Alteridades  V. Ciencias Sociales  Antropología Social y Etnología
# 28       Alteridades  V. Ciencias Sociales  Antropología Social y Etnología
# 29       Alteridades  V. Ciencias Sociales  Antropología Social y Etnología
# 30       Alteridades  V. Ciencias Sociales  Antropología Social y Etnología
# 31       Alteridades  V. Ciencias Sociales  Antropología Social y Etnología
#
#                                      Titulo del libro Resumen  \
# 0   Antropología de la (in)seguridad: experiencias...    None
# 1   Epistemologías antropológicas en contextos de ...    None
# 2                Política cultural, crisis y COVID 19    None
# 3                 Antropología, violencia y emociones    None
# 4   Entre fronteras. Ciudadanía, migración e ident...    None
# 5   Presencias de lo insólito: estudios del perfor...    None
# 6                    Movilidades y experiencia urbana    None
# 7   La ciudad transnacional comparada: aportes teó...    None
# 8                          Antropología y performance    None
# 9   Cambios urbanos globales, prácticas de resiste...    None
# 10              Consumos culturales en América Latina    None
# 11                          Jóvenes en América Latina    None
# 12                     Investigaciones antropológicas    None
# 13                      Género, cultura y procreación    None
# 14                      Laboratorio de Cultura Urbana    None
# 15                   Clases medias y espacios urbanos    None
# 16                      Antropología de las creencias    None
# 17                       Fronteras, limites y frentes    None
# 18                   La desigualdad en América Latina    None
# 19              Local y global en la ciudad de México    None
# 20                  Tiempos y espacios del parentesco    None
# 21  Miradas antropológicas ante una realidad compleja    None
# 22                                           Rituales    None
# 23         Antropología de los movimientos religiosos    None
# 24    El patrimonio cultural. Estudios contemporáneos    None
# 25    Estado nacional, autodeterminación y autonomías    None
# 26                        Antropología de la curación    None
# 27  Derechos humanos lingüísticos en sociedades mu...    None
# 28                Sobre el conocimiento antropológico    None
# 29                     Antropologías latinoamericanas    None
# 30                Reacomodos y construcción de presas    None
# 31                                          Identidad    None
#
#                      Link inicial  \
# 0   http://alteridades.izt.uam.mx
# 1   http://alteridades.izt.uam.mx
# 2   http://alteridades.izt.uam.mx
# 3   http://alteridades.izt.uam.mx
# 4   http://alteridades.izt.uam.mx
# 5   http://alteridades.izt.uam.mx
# 6   http://alteridades.izt.uam.mx
# 7   http://alteridades.izt.uam.mx
# 8   http://alteridades.izt.uam.mx
# 9   http://alteridades.izt.uam.mx
# 10  http://alteridades.izt.uam.mx
# 11  http://alteridades.izt.uam.mx
# 12  http://alteridades.izt.uam.mx
# 13  http://alteridades.izt.uam.mx
# 14  http://alteridades.izt.uam.mx
# 15  http://alteridades.izt.uam.mx
# 16  http://alteridades.izt.uam.mx
# 17  http://alteridades.izt.uam.mx
# 18  http://alteridades.izt.uam.mx
# 19  http://alteridades.izt.uam.mx
# 20  http://alteridades.izt.uam.mx
# 21  http://alteridades.izt.uam.mx
# 22  http://alteridades.izt.uam.mx
# 23  http://alteridades.izt.uam.mx
# 24  http://alteridades.izt.uam.mx
# 25  http://alteridades.izt.uam.mx
# 26  http://alteridades.izt.uam.mx
# 27  http://alteridades.izt.uam.mx
# 28  http://alteridades.izt.uam.mx
# 29  http://alteridades.izt.uam.mx
# 30  http://alteridades.izt.uam.mx
# 31  http://alteridades.izt.uam.mx
#
#                                         Link articulo
# 0   https://alteridades.izt.uam.mx/index.php/Alte/...
# 1   https://alteridades.izt.uam.mx/index.php/Alte/...
# 2   https://alteridades.izt.uam.mx/index.php/Alte/...
# 3   https://alteridades.izt.uam.mx/index.php/Alte/...
# 4   https://alteridades.izt.uam.mx/index.php/Alte/...
# 5   https://alteridades.izt.uam.mx/index.php/Alte/...
# 6   https://alteridades.izt.uam.mx/index.php/Alte/...
# 7   https://alteridades.izt.uam.mx/index.php/Alte/...
# 8   https://alteridades.izt.uam.mx/index.php/Alte/...
# 9   https://alteridades.izt.uam.mx/index.php/Alte/...
# 10  https://alteridades.izt.uam.mx/index.php/Alte/...
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15                                               None
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20                                               None
# 21                                               None
# 22                                               None
# 23                                               None
# 24                                               None
# 25                                               None
# 26                                               None
# 27                                               None
# 28                                               None
# 29                                               None
# 30                                               None
# 31                                               None

# %%
df_catalogo.to_csv('Revista113.csv', index=False)
