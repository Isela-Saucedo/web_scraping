# %%
import requests
import bs4
from bs4 import BeautifulSoup
from urllib.parse import urljoin
import pandas as pd

# %%
url_inicial = 'https://mastozoologiamexicana.com/ojs/index.php/theryanotes/issue/archive'
url_root = 'https://mastozoologiamexicana.com/ojs/index.php/theryanotes/issue/archive'
r=requests.get(url_inicial)

# %%
soup = BeautifulSoup(r.text, 'html.parser')

# %%
box = soup.find('ul', class_='issues_archive')
volumen=box.findAll('div', class_='obj_issue_summary')
vol = [x.find('a').get('href')for x in volumen]
vol
# Out:
# ['https://mastozoologiamexicana.com/ojs/index.php/theryanotes/issue/view/13',
#  'https://mastozoologiamexicana.com/ojs/index.php/theryanotes/issue/view/12',
#  'https://mastozoologiamexicana.com/ojs/index.php/theryanotes/issue/view/8',
#  'https://mastozoologiamexicana.com/ojs/index.php/theryanotes/issue/view/7',
#  'https://mastozoologiamexicana.com/ojs/index.php/theryanotes/issue/view/6',
#  'https://mastozoologiamexicana.com/ojs/index.php/theryanotes/issue/view/5',
#  'https://mastozoologiamexicana.com/ojs/index.php/theryanotes/issue/view/4',
#  'https://mastozoologiamexicana.com/ojs/index.php/theryanotes/issue/view/1']

# %%
vol2 =[]
for i in vol: 
    url_inicial1=i 
    r1 = requests.get(url_inicial1)
    soup1 = BeautifulSoup(r1.text, 'html.parser')
    box1 = soup1.find('ul', class_='cmp_article_list articles') 
    volumen1=box1.findAll('div', class_='obj_article_summary')
    vol1 = [x.find('a').get('href')for x in volumen1]
    vol2+=vol1

# %%
vol2
# Out:
# ['https://mastozoologiamexicana.com/ojs/index.php/theryanotes/article/view/236',
#  'https://mastozoologiamexicana.com/ojs/index.php/theryanotes/article/view/122',
#  'https://mastozoologiamexicana.com/ojs/index.php/theryanotes/article/view/145',
#  'https://mastozoologiamexicana.com/ojs/index.php/theryanotes/article/view/161',
#  'https://mastozoologiamexicana.com/ojs/index.php/theryanotes/article/view/177',
#  'https://mastozoologiamexicana.com/ojs/index.php/theryanotes/article/view/185',
#  'https://mastozoologiamexicana.com/ojs/index.php/theryanotes/article/view/148',
#  'https://mastozoologiamexicana.com/ojs/index.php/theryanotes/article/view/149',
#  'https://mastozoologiamexicana.com/ojs/index.php/theryanotes/article/view/160',
#  'https://mastozoologiamexicana.com/ojs/index.php/theryanotes/article/view/171',
#  'https://mastozoologiamexicana.com/ojs/index.php/theryanotes/article/view/202',
#  'https://mastozoologiamexicana.com/ojs/index.php/theryanotes/article/view/125',
#  'https://mastozoologiamexicana.com/ojs/index.php/theryanotes/article/view/121',
#  'https://mastozoologiamexicana.com/ojs/index.php/theryanotes/article/view/73',
#  'https://mastozoologiamexicana.com/ojs/index.php/theryanotes/article/view/129',
#  'https://mastozoologiamexicana.com/ojs/index.php/theryanotes/article/view/141',
#  'https://mastozoologiamexicana.com/ojs/index.php/theryanotes/article/view/120',
#  'https://mastozoologiamexicana.com/ojs/index.php/theryanotes/article/view/131',
#  'https://mastozoologiamexicana.com/ojs/index.php/theryanotes/article/view/137',
#  'https://mastozoologiamexicana.com/ojs/index.php/theryanotes/article/view/130',
#  'https://mastozoologiamexicana.com/ojs/index.php/theryanotes/article/view/139',
#  'https://mastozoologiamexicana.com/ojs/index.php/theryanotes/article/view/140',
#  'https://mastozoologiamexicana.com/ojs/index.php/theryanotes/article/view/124',
#  'https://mastozoologiamexicana.com/ojs/index.php/theryanotes/article/view/134',
#  'https://mastozoologiamexicana.com/ojs/index.php/theryanotes/article/view/98',
#  'https://mastozoologiamexicana.com/ojs/index.php/theryanotes/article/view/104',
#  'https://mastozoologiamexicana.com/ojs/index.php/theryanotes/article/view/89',
#  'https://mastozoologiamexicana.com/ojs/index.php/theryanotes/article/view/6',
#  'https://mastozoologiamexicana.com/ojs/index.php/theryanotes/article/view/112',
#  'https://mastozoologiamexicana.com/ojs/index.php/theryanotes/article/view/97',
#  'https://mastozoologiamexicana.com/ojs/index.php/theryanotes/article/view/117',
#  'https://mastozoologiamexicana.com/ojs/index.php/theryanotes/article/view/84',
#  'https://mastozoologiamexicana.com/ojs/index.php/theryanotes/article/view/76',
#  'https://mastozoologiamexicana.com/ojs/index.php/theryanotes/article/view/103',
#  'https://mastozoologiamexicana.com/ojs/index.php/theryanotes/article/view/83',
#  'https://mastozoologiamexicana.com/ojs/index.php/theryanotes/article/view/74',
#  'https://mastozoologiamexicana.com/ojs/index.php/theryanotes/article/view/90',
#  'https://mastozoologiamexicana.com/ojs/index.php/theryanotes/article/view/87',
#  'https://mastozoologiamexicana.com/ojs/index.php/theryanotes/article/view/65',
#  'https://mastozoologiamexicana.com/ojs/index.php/theryanotes/article/view/46',
#  'https://mastozoologiamexicana.com/ojs/index.php/theryanotes/article/view/16',
#  'https://mastozoologiamexicana.com/ojs/index.php/theryanotes/article/view/51',
#  'https://mastozoologiamexicana.com/ojs/index.php/theryanotes/article/view/82',
#  'https://mastozoologiamexicana.com/ojs/index.php/theryanotes/article/view/100',
#  'https://mastozoologiamexicana.com/ojs/index.php/theryanotes/article/view/53',
#  'https://mastozoologiamexicana.com/ojs/index.php/theryanotes/article/view/27',
#  'https://mastozoologiamexicana.com/ojs/index.php/theryanotes/article/view/71',
#  'https://mastozoologiamexicana.com/ojs/index.php/theryanotes/article/view/40',
#  'https://mastozoologiamexicana.com/ojs/index.php/theryanotes/article/view/63',
#  'https://mastozoologiamexicana.com/ojs/index.php/theryanotes/article/view/78',
#  'https://mastozoologiamexicana.com/ojs/index.php/theryanotes/article/view/77',
#  'https://mastozoologiamexicana.com/ojs/index.php/theryanotes/article/view/88',
#  'https://mastozoologiamexicana.com/ojs/index.php/theryanotes/article/view/34',
#  'https://mastozoologiamexicana.com/ojs/index.php/theryanotes/article/view/39',
#  'https://mastozoologiamexicana.com/ojs/index.php/theryanotes/article/view/14',
#  'https://mastozoologiamexicana.com/ojs/index.php/theryanotes/article/view/25',
#  'https://mastozoologiamexicana.com/ojs/index.php/theryanotes/article/view/7',
#  'https://mastozoologiamexicana.com/ojs/index.php/theryanotes/article/view/24',
#  'https://mastozoologiamexicana.com/ojs/index.php/theryanotes/article/view/35',
#  'https://mastozoologiamexicana.com/ojs/index.php/theryanotes/article/view/43',
#  'https://mastozoologiamexicana.com/ojs/index.php/theryanotes/article/view/29',
#  'https://mastozoologiamexicana.com/ojs/index.php/theryanotes/article/view/54',
#  'https://mastozoologiamexicana.com/ojs/index.php/theryanotes/article/view/44',
#  'https://mastozoologiamexicana.com/ojs/index.php/theryanotes/article/view/8',
#  'https://mastozoologiamexicana.com/ojs/index.php/theryanotes/article/view/9',
#  'https://mastozoologiamexicana.com/ojs/index.php/theryanotes/article/view/10',
#  'https://mastozoologiamexicana.com/ojs/index.php/theryanotes/article/view/20',
#  'https://mastozoologiamexicana.com/ojs/index.php/theryanotes/article/view/19',
#  'https://mastozoologiamexicana.com/ojs/index.php/theryanotes/article/view/21']

# %%
def get_url_items(sopa,url):
    box1 = soup1.find('ul', class_='cmp_article_list articles')
    volumen1=box1.findAll('div', class_='obj_article_summary')
    vol1 = [x.find('a').get('href')for x in volumen1]
    return vol2

# %%
links_items=[]
i=0
while i<1:
    i+=1
    print(f'Estoy en la pagina {url_inicial}')
    r_pag=requests.get(url_inicial)
    s_p=BeautifulSoup(r_pag.text,'html.parser')
    links=get_url_items(s_p, url_inicial)
    links_items.append(links) 
    next_a=s_p.select('li.next > a')
    if not next_a or not next_a[0].get('href'):
        break
# Out:
# Estoy en la pagina https://mastozoologiamexicana.com/ojs/index.php/theryanotes/issue/archive

# %%
list_scraper=[]
for i in links_items:
    for j in i:
        list_scraper.append(j)
len(list_scraper)
# Out:
# 69

# %%
uno=list_scraper[0]
r_item=requests.get(uno)
s_item=BeautifulSoup(r_item.text, 'html.parser')

# %%
#funcion para iniciar el escraper de cada libro
def scraper_book(url):
    content_book={}
    r=requests.get(url)
    tire='Therya'
    a='II. Biología y Química'
    tem='Mamíferos'
    s_item=BeautifulSoup(r.text,'html.parser')
 #titulo de revista
    try:
        titulo=tire
        content_book['Titulo Revista']=tire
    except AttributeError:
        content_book['Titulo Revista']=None
    #area
    try:
        area=a
        content_book['Area']=a
    except AttributeError:
        content_book['Area']=None
    #tematica
    try:
        tema=tem
        content_book['Tematica']=tem
    except AttributeError:
        content_book['Tematica']=None
    #titulo articulo
    try:
        titu=s_item.find('h1', class_='page_title').get_text(strip=True)
        content_book['Titulo Articulo']=titu
    except AttributeError:
        content_book['Titulo Articulo']=None
    #resumen
    try:
        resu=s_item.find('div', class_='item abstract').find('p').get_text(strip=True)
        content_book['Resumen']=resu
    except AttributeError:
        content_book['Resumen']=None
    #abstract
    try:
        abst=s_item.find('div', class_='item cover_image').get_text(strip=True)
        content_book['Abstract']=abst
    except AttributeError:
        content_book['Abstract']=None
    #Link incial
    try:
        linkart=url
        content_book['Link Articulo']=linkart
    except AttributeError:
        content_book['Link Articulo']=None
    #link articulo
    try:
        link=s_item.find('a', class_='obj_galley_link pdf').get('href')
        content_book['Link PDF']=urljoin(url_root, link)
    except AttributeError:
        content_book['Link PDF']=None
    return content_book

# %%
list_scraper=list_scraper[0:69]
datos_book=[]
for idx, i in enumerate(list_scraper):
    print(f'estas escrapeando la pag {idx}')
    datos_book.append(scraper_book(i))
# Out:
# estas escrapeando la pag 0
# estas escrapeando la pag 1
# estas escrapeando la pag 2
# estas escrapeando la pag 3
# estas escrapeando la pag 4
# estas escrapeando la pag 5
# estas escrapeando la pag 6
# estas escrapeando la pag 7
# estas escrapeando la pag 8
# estas escrapeando la pag 9
# estas escrapeando la pag 10
# estas escrapeando la pag 11
# estas escrapeando la pag 12
# estas escrapeando la pag 13
# estas escrapeando la pag 14
# estas escrapeando la pag 15
# estas escrapeando la pag 16
# estas escrapeando la pag 17
# estas escrapeando la pag 18
# estas escrapeando la pag 19
# estas escrapeando la pag 20
# estas escrapeando la pag 21
# estas escrapeando la pag 22
# estas escrapeando la pag 23
# estas escrapeando la pag 24
# estas escrapeando la pag 25
# estas escrapeando la pag 26
# estas escrapeando la pag 27
# estas escrapeando la pag 28
# estas escrapeando la pag 29
# estas escrapeando la pag 30
# estas escrapeando la pag 31
# estas escrapeando la pag 32
# estas escrapeando la pag 33
# estas escrapeando la pag 34
# estas escrapeando la pag 35
# estas escrapeando la pag 36
# estas escrapeando la pag 37
# estas escrapeando la pag 38
# estas escrapeando la pag 39
# estas escrapeando la pag 40
# estas escrapeando la pag 41
# estas escrapeando la pag 42
# estas escrapeando la pag 43
# estas escrapeando la pag 44
# estas escrapeando la pag 45
# estas escrapeando la pag 46
# estas escrapeando la pag 47
# estas escrapeando la pag 48
# estas escrapeando la pag 49
# estas escrapeando la pag 50
# estas escrapeando la pag 51
# estas escrapeando la pag 52
# estas escrapeando la pag 53
# estas escrapeando la pag 54
# estas escrapeando la pag 55
# estas escrapeando la pag 56
# estas escrapeando la pag 57
# estas escrapeando la pag 58
# estas escrapeando la pag 59
# estas escrapeando la pag 60
# estas escrapeando la pag 61
# estas escrapeando la pag 62
# estas escrapeando la pag 63
# estas escrapeando la pag 64
# estas escrapeando la pag 65
# estas escrapeando la pag 66
# estas escrapeando la pag 67
# estas escrapeando la pag 68

# %%
df_catalogo=pd.DataFrame(datos_book)
df_catalogo
# Out:
#    Titulo Revista                    Area   Tematica  \
# 0          Therya  II. Biología y Química  Mamíferos
# 1          Therya  II. Biología y Química  Mamíferos
# 2          Therya  II. Biología y Química  Mamíferos
# 3          Therya  II. Biología y Química  Mamíferos
# 4          Therya  II. Biología y Química  Mamíferos
# ..            ...                     ...        ...
# 64         Therya  II. Biología y Química  Mamíferos
# 65         Therya  II. Biología y Química  Mamíferos
# 66         Therya  II. Biología y Química  Mamíferos
# 67         Therya  II. Biología y Química  Mamíferos
# 68         Therya  II. Biología y Química  Mamíferos
#
#                                       Titulo Articulo  \
# 0       Wildlife crossings and road impact on mammals
# 1   Rediscovery of the Tamaulipas white-sided jack...
# 2   Dispersal of Hoffmannia excelsa (Rubiaceae) by...
# 3   First record of leucism in the volcano rabbit ...
# 4   Albinism in a wild Caribbean night monkey (Aot...
# ..                                                ...
# 64  Xenomys nelsoni predation by the snake Sentico...
# 65  Morelet’s crocodile predation by jaguar in the...
# 66  Interaction between Ground Squirrels with ratt...
# 67      New record in the diet of Philander andersoni
# 68  Ocelot (Leopardus pardalis) potential predatio...
#
#                                               Resumen Abstract  \
# 0   Las carreteras son esenciales en el crecimient...
# 1   La liebre de flancos blancos de Tamaulipas,Lep...
# 2   En esta nota reportamos el consumo del fruto y...
# 3   El leucismo es la pérdida total o parcial de l...
# 4   El albinismo es el resultado de la ausencia co...
# ..                                                ...      ...
# 64  Las selvas secas albergan un gran número de e...
# 65  Panthera oncaes el felino más grande de Amér...
# 66  La depredación de ardillas terrestres por ser...
# 67  Las especies de marsupiales de la familia Dide...
# 68  La zorra gris (Urocyon cinereoargenteus) es co...
#
#                                         Link Articulo  \
# 0   https://mastozoologiamexicana.com/ojs/index.ph...
# 1   https://mastozoologiamexicana.com/ojs/index.ph...
# 2   https://mastozoologiamexicana.com/ojs/index.ph...
# 3   https://mastozoologiamexicana.com/ojs/index.ph...
# 4   https://mastozoologiamexicana.com/ojs/index.ph...
# ..                                                ...
# 64  https://mastozoologiamexicana.com/ojs/index.ph...
# 65  https://mastozoologiamexicana.com/ojs/index.ph...
# 66  https://mastozoologiamexicana.com/ojs/index.ph...
# 67  https://mastozoologiamexicana.com/ojs/index.ph...
# 68  https://mastozoologiamexicana.com/ojs/index.ph...
#
#                                              Link PDF
# 0   https://mastozoologiamexicana.com/ojs/index.ph...
# 1   https://mastozoologiamexicana.com/ojs/index.ph...
# 2   https://mastozoologiamexicana.com/ojs/index.ph...
# 3   https://mastozoologiamexicana.com/ojs/index.ph...
# 4   https://mastozoologiamexicana.com/ojs/index.ph...
# ..                                                ...
# 64  https://mastozoologiamexicana.com/ojs/index.ph...
# 65  https://mastozoologiamexicana.com/ojs/index.ph...
# 66  https://mastozoologiamexicana.com/ojs/index.ph...
# 67  https://mastozoologiamexicana.com/ojs/index.ph...
# 68  https://mastozoologiamexicana.com/ojs/index.ph...
#
# [69 rows x 8 columns]

# %%
df_catalogo.to_csv('Revista39.csv', index=False)
