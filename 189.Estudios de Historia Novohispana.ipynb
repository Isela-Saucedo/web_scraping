# %%
import requests
import bs4
from bs4 import BeautifulSoup
from urllib.parse import urljoin
import pandas as pd

# %%
url_inicial = 'https://novohispana.historicas.unam.mx/index.php/ehn/issue/archive/3'
url_root = 'https://novohispana.historicas.unam.mx/index.php/ehn/issue/archive/3'
r=requests.get(url_inicial)

# %%
soup = BeautifulSoup(r.text, 'html.parser')

# %%
lista_articulo = soup.find_all('div', class_='obj_issue_summary')
links_libros = [x.find('a').get('href') for x in lista_articulo]
links_libros = [urljoin (url_root, i) for i in links_libros]
links_libros
# Out:
# ['https://novohispana.historicas.unam.mx/index.php/ehn/issue/view/281',
#  'https://novohispana.historicas.unam.mx/index.php/ehn/issue/view/280',
#  'https://novohispana.historicas.unam.mx/index.php/ehn/issue/view/279',
#  'https://novohispana.historicas.unam.mx/index.php/ehn/issue/view/278',
#  'https://novohispana.historicas.unam.mx/index.php/ehn/issue/view/277',
#  'https://novohispana.historicas.unam.mx/index.php/ehn/issue/view/276',
#  'https://novohispana.historicas.unam.mx/index.php/ehn/issue/view/275',
#  'https://novohispana.historicas.unam.mx/index.php/ehn/issue/view/274',
#  'https://novohispana.historicas.unam.mx/index.php/ehn/issue/view/273',
#  'https://novohispana.historicas.unam.mx/index.php/ehn/issue/view/272',
#  'https://novohispana.historicas.unam.mx/index.php/ehn/issue/view/271',
#  'https://novohispana.historicas.unam.mx/index.php/ehn/issue/view/270',
#  'https://novohispana.historicas.unam.mx/index.php/ehn/issue/view/269',
# ...

# %%
def get_url_items(soup,url):
    lista_articulo = soup.find_all('div', class_='obj_issue_summary')
    links_libros = [x.find('a').get('href') for x in lista_articulo]
    links_libros = [urljoin (url_root, i) for i in links_libros]
    return links_libros

# %%
links_items=[]
i=0
while i<1:
    i+=1
    print(f'Estoy en la pagina {url_inicial}')
    r_pag=requests.get(url_inicial)
    s_p=BeautifulSoup(r_pag.text,'html.parser')
    links=get_url_items(s_p, url_inicial)
    links_items.append(links)
# Out:
# Estoy en la pagina https://novohispana.historicas.unam.mx/index.php/ehn/issue/archive/3

# %%
list_scraper=[]
for i in links_items:
    for j in i:
        list_scraper.append(j)
len(list_scraper)
# Out:
# 16

# %%
uno=list_scraper[0]
r_item=requests.get(uno)
s_item=BeautifulSoup(r_item.text, 'html.parser')

# %%
#funcion para iniciar el escraper de cada libro
def scraper_book(url):
    content_book={}
    r=requests.get(url)
    tire='Estudios de Historia Novohispana'
    a='IV. Humanidades y Ciencias de la Conducta'
    tem='Historia por épocas / Historia Moderna'
    url='https://novohispana.historicas.unam.mx/index.php/ehn'
    s_item=BeautifulSoup(r.text,'html.parser')
    #titulo de revista
    try:
        titulo=tire
        content_book['Titulo de revista']=tire
    except AttributeError:
        content_book['Titulo de revista']=None
    #area
    try:
        area=a
        content_book['Área']=a
    except AttributeError:
        content_book['Área']=None
    #tematica
    try:
        tema=tem
        content_book['Temática']=tem
    except AttributeError:
        content_book['Temática']=None
    #titulo libro
    try:
        titu=s_item.find('h2', class_='title').get_text(strip=True)
        content_book['Titulo del libro']=titu
    except AttributeError:
        content_book['Titulo del libro']=None
    #resumen
    try:
        resu=s_item.find('a', class_='cover').get_text(strip=True)
        content_book['Resumen']=resu
    except AttributeError:
        content_book['Resumen']=None
    #Link incial
    try:
        inicial=url
        content_book['Link inicial']=url
    except AttributeError:
        content_book['Link inicial']=None
    #link articulo
    try:
        link=s_item.find('a', class_='obj_galley_link pdf').get('href')
        content_book['Link articulo']=urljoin(url_root, link)
    except AttributeError:
        content_book['Link articulo']=None
    return content_book

# %%
list_scraper=list_scraper[0:24]
datos_book=[]
for idx, i in enumerate(list_scraper):
    print(f'estas escrapeando la pag {idx}')
    datos_book.append(scraper_book(i))
# Out:
# estas escrapeando la pag 0
# estas escrapeando la pag 1
# estas escrapeando la pag 2
# estas escrapeando la pag 3
# estas escrapeando la pag 4
# estas escrapeando la pag 5
# estas escrapeando la pag 6
# estas escrapeando la pag 7
# estas escrapeando la pag 8
# estas escrapeando la pag 9
# estas escrapeando la pag 10
# estas escrapeando la pag 11
# estas escrapeando la pag 12
# estas escrapeando la pag 13
# estas escrapeando la pag 14
# estas escrapeando la pag 15

# %%
df_catalogo=pd.DataFrame(datos_book)
df_catalogo
# Out:
#                    Titulo de revista  \
# 0   Estudios de Historia Novohispana
# 1   Estudios de Historia Novohispana
# 2   Estudios de Historia Novohispana
# 3   Estudios de Historia Novohispana
# 4   Estudios de Historia Novohispana
# 5   Estudios de Historia Novohispana
# 6   Estudios de Historia Novohispana
# 7   Estudios de Historia Novohispana
# 8   Estudios de Historia Novohispana
# 9   Estudios de Historia Novohispana
# 10  Estudios de Historia Novohispana
# 11  Estudios de Historia Novohispana
# 12  Estudios de Historia Novohispana
# 13  Estudios de Historia Novohispana
# 14  Estudios de Historia Novohispana
# 15  Estudios de Historia Novohispana
#
#                                          Área  \
# 0   IV. Humanidades y Ciencias de la Conducta
# 1   IV. Humanidades y Ciencias de la Conducta
# 2   IV. Humanidades y Ciencias de la Conducta
# 3   IV. Humanidades y Ciencias de la Conducta
# 4   IV. Humanidades y Ciencias de la Conducta
# ...

# %%
df_catalogo.to_csv('Revista189.03.csv', index=False)
