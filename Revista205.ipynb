# %%
import requests
import bs4
from bs4 import BeautifulSoup
from urllib.parse import urljoin
import pandas as pd

# %%
url_inicial = 'https://argumentos.xoc.uam.mx/index.php/argumentos/issue/archive'
url_root = 'https://argumentos.xoc.uam.mx/index.php/argumentos/issue/archive'
r=requests.get(url_inicial)

# %%
soup = BeautifulSoup(r.text, 'html.parser')

# %%
box = soup.find('ul', class_='issues_archive')
volumen=box.findAll('div', class_='obj_issue_summary')
vol = [x.find('a').get('href')for x in volumen]
vol=[urljoin(url_root,i) for i in vol]
vol
# Out:
# ['https://argumentos.xoc.uam.mx/index.php/argumentos/issue/view/94',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/issue/view/93',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/issue/view/92',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/issue/view/91',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/issue/view/90',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/issue/view/89',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/issue/view/88',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/issue/view/argumentos91',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/issue/view/argumentos90',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/issue/view/85',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/issue/view/84',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/issue/view/83',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/issue/view/Numero%20completo',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/issue/view/2',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/issue/view/3',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/issue/view/4',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/issue/view/5',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/issue/view/6',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/issue/view/7',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/issue/view/8',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/issue/view/9',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/issue/view/10',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/issue/view/11',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/issue/view/12',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/issue/view/13']

# %%
vol2 =[]
for i in vol: 
    url_inicial1=i 
    r1 = requests.get(url_inicial1)
    soup1 = BeautifulSoup(r1.text, 'html.parser')
    box1 = soup1.find('div', class_='sections') 
    volumen1=box1.findAll('div', class_='obj_article_summary')
    vol1 = [x.find('a').get('href')for x in volumen1]
    vol2+=vol1

# %%
vol2
# Out:
# ['https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1313',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1291',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1292',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1293',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1294',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1295',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1296',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1297',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1298',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1299',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1300',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1301',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1302',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1303',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1304',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1305',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1306',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1307',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1308',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1309',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1310',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1311',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1283',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1278',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1279',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1280',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1263',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1264',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1265',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1266',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1267',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1268',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1271',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1272',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1116',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1117',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1281',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1282',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1284',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1273',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1247',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1248',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1249',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1250',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1251',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1252',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1254',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1253',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1255',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1256',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1257',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1258',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1259',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1261',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1260',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1262',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1275',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1274',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1285',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1232',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1233',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1073',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1077',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1101',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1234',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1225',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1069',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1227',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1226',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1228',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1235',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1237',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1286',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1221',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1222',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1075',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1164',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1143',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1142',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1148',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1070',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1074',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1138',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1140',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1149',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1076',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1128',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1173',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1174',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1223',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1224',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1192',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1193',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1198',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1131',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1145',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1165',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1166',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1167',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1130',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1168',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1169',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1134',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1135',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1146',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1170',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1180',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1197',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1196',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1158',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1159',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1067',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1141',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1147',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1157',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1152',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1136',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1144',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1133',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1151',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1153',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1150',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1154',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1156',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1102',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1103',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1104',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1105',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1106',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1107',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1108',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1109',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1110',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1114',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1111',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1083',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1088',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1089',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1090',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1091',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1092',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1093',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1094',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1095',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1096',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1097',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1098',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1099',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1113',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1050',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1051',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1052',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1053',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1054',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1055',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1056',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1057',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1058',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1059',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1060',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1061',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1062',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1063',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1064',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1065',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1124',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1039',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1040',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1041',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1042',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1043',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1044',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1045',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1046',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1047',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1048',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1049',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1125',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1027',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1028',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1029',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1030',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1031',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1032',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1033',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1034',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1035',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1036',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1037',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1038',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1120',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/2',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/3',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/10',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/9',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/8',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/7',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/6',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/5',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/4',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/11',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/12',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/13',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/14',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/15',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/1122',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/16',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/17',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/18',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/19',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/20',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/21',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/22',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/23',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/24',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/25',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/26',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/27',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/28',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/29',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/30',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/31',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/32',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/33',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/34',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/35',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/36',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/37',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/38',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/39',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/40',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/41',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/42',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/43',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/44',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/45',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/61',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/46',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/47',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/48',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/49',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/50',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/51',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/52',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/53',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/54',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/55',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/56',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/57',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/58',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/59',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/60',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/62',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/63',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/64',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/65',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/66',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/67',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/68',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/69',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/70',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/71',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/72',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/73',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/74',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/75',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/76',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/77',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/78',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/79',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/80',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/81',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/82',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/83',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/84',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/85',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/86',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/87',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/88',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/89',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/90',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/91',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/92',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/93',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/94',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/95',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/96',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/97',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/98',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/99',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/100',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/102',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/101',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/103',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/104',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/105',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/106',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/107',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/108',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/109',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/110',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/111',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/112',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/113',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/114',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/116',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/115',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/117',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/118',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/119',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/120',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/121',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/122',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/123',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/124',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/126',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/125',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/127',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/128',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/129',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/130',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/131',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/132',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/133',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/134',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/135',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/136',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/137',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/138',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/139',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/141',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/140',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/142',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/143',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/144',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/145',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/146',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/147',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/148',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/149',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/150',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/151',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/152',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/153',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/154',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/156',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/155',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/157',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/158',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/159',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/160',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/161',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/162',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/163',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/164',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/165',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/166',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/167',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/169',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/168',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/170',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/171',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/172',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/173',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/174',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/175',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/176',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/177',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/178',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/179',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/180',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/181',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/182',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/183',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/184',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/article/view/185']

# %%
def get_url_items(sopa,url):
    box1 = soup1.find('div', class_='sections') 
    volumen1=box1.findAll('div', class_='obj_article_summary')
    vol1 = [x.find('a').get('href')for x in volumen1]
    return vol2

# %%
links_items=[]
i=0
while i<1:
    i+=1
    print(f'Estoy en la pagina {url_inicial}')
    r_pag=requests.get(url_inicial)
    s_p=BeautifulSoup(r_pag.text,'html.parser')
    links=get_url_items(s_p, url_inicial)
    links_items.append(links)
# Out:
# Estoy en la pagina https://argumentos.xoc.uam.mx/index.php/argumentos/issue/archive

# %%
list_scraper=[]
for i in links_items:
    for j in i:
        list_scraper.append(j)
len(list_scraper)
# Out:
# 377

# %%
uno=list_scraper[0]
r_item=requests.get(uno)
s_item=BeautifulSoup(r_item.text, 'html.parser')

# %%
#funcion para iniciar el escraper de cada libro
def scraper_book(url):
    content_book={}
    r=requests.get(url)
    tire='Argumentos'
    a='V. Ciencias Sociales'
    tem='Social Sciences'
    s_item=BeautifulSoup(r.text,'html.parser')
    #titulo de revista
    try:
        titulo=tire
        content_book['Titulo Revista']=tire
    except AttributeError:
        content_book['Titulo Revista']=None
    #area
    try:
        area=a
        content_book['Area']=a
    except AttributeError:
        content_book['Area']=None
    #tematica
    try:
        tema=tem
        content_book['Tematica']=tem
    except AttributeError:
        content_book['Tematica']=None
    #titulo articulo
    try:
        titu=s_item.find('h1', class_='page_title').get_text(strip=True)
        content_book['Titulo Articulo']=titu
    except AttributeError:
        content_book['Titulo Articulo']=None
    #resumen
    try:
        resu=s_item.find('div', class_='item abstract').get_text(strip=True)
        content_book['Resumen']=resu.replace("Resumen","")
    except AttributeError:
        content_book['Resumen']=None
    #abstract
    try:
        abst=s_item.find('div', id='item cover_image').get_text(strip=True)
        content_book['Abstract']=abst
    except AttributeError:
        content_book['Abstract']=None
    #Link incial
    try:
        linkart=url
        content_book['Link Articulo']=linkart
    except AttributeError:
        content_book['Link Articulo']=None
    #link articulo
    try:
        link=s_item.find('a', class_='obj_galley_link pdf').get('href')
        content_book['Link PDF']=urljoin(url_root, link)
    except AttributeError:
        content_book['Link PDF']=None
    return content_book

# %%
list_scraper=list_scraper[0:377]
datos_book=[]
for idx, i in enumerate(list_scraper):
    print(f'estas escrapeando la pag {idx}')
    datos_book.append(scraper_book(i))
# Out:
# estas escrapeando la pag 0
# estas escrapeando la pag 1
# estas escrapeando la pag 2
# estas escrapeando la pag 3
# estas escrapeando la pag 4
# estas escrapeando la pag 5
# estas escrapeando la pag 6
# estas escrapeando la pag 7
# estas escrapeando la pag 8
# estas escrapeando la pag 9
# estas escrapeando la pag 10
# estas escrapeando la pag 11
# estas escrapeando la pag 12
# estas escrapeando la pag 13
# estas escrapeando la pag 14
# estas escrapeando la pag 15
# estas escrapeando la pag 16
# estas escrapeando la pag 17
# estas escrapeando la pag 18
# estas escrapeando la pag 19
# estas escrapeando la pag 20
# estas escrapeando la pag 21
# estas escrapeando la pag 22
# estas escrapeando la pag 23
# estas escrapeando la pag 24
# estas escrapeando la pag 25
# estas escrapeando la pag 26
# estas escrapeando la pag 27
# estas escrapeando la pag 28
# estas escrapeando la pag 29
# estas escrapeando la pag 30
# estas escrapeando la pag 31
# estas escrapeando la pag 32
# estas escrapeando la pag 33
# estas escrapeando la pag 34
# estas escrapeando la pag 35
# estas escrapeando la pag 36
# estas escrapeando la pag 37
# estas escrapeando la pag 38
# estas escrapeando la pag 39
# estas escrapeando la pag 40
# estas escrapeando la pag 41
# estas escrapeando la pag 42
# estas escrapeando la pag 43
# estas escrapeando la pag 44
# estas escrapeando la pag 45
# estas escrapeando la pag 46
# estas escrapeando la pag 47
# estas escrapeando la pag 48
# estas escrapeando la pag 49
# estas escrapeando la pag 50
# estas escrapeando la pag 51
# estas escrapeando la pag 52
# estas escrapeando la pag 53
# estas escrapeando la pag 54
# estas escrapeando la pag 55
# estas escrapeando la pag 56
# estas escrapeando la pag 57
# estas escrapeando la pag 58
# estas escrapeando la pag 59
# estas escrapeando la pag 60
# estas escrapeando la pag 61
# estas escrapeando la pag 62
# estas escrapeando la pag 63
# estas escrapeando la pag 64
# estas escrapeando la pag 65
# estas escrapeando la pag 66
# estas escrapeando la pag 67
# estas escrapeando la pag 68
# estas escrapeando la pag 69
# estas escrapeando la pag 70
# estas escrapeando la pag 71
# estas escrapeando la pag 72
# estas escrapeando la pag 73
# estas escrapeando la pag 74
# estas escrapeando la pag 75
# estas escrapeando la pag 76
# estas escrapeando la pag 77
# estas escrapeando la pag 78
# estas escrapeando la pag 79
# estas escrapeando la pag 80
# estas escrapeando la pag 81
# estas escrapeando la pag 82
# estas escrapeando la pag 83
# estas escrapeando la pag 84
# estas escrapeando la pag 85
# estas escrapeando la pag 86
# estas escrapeando la pag 87
# estas escrapeando la pag 88
# estas escrapeando la pag 89
# estas escrapeando la pag 90
# estas escrapeando la pag 91
# estas escrapeando la pag 92
# estas escrapeando la pag 93
# estas escrapeando la pag 94
# estas escrapeando la pag 95
# estas escrapeando la pag 96
# estas escrapeando la pag 97
# estas escrapeando la pag 98
# estas escrapeando la pag 99
# estas escrapeando la pag 100
# estas escrapeando la pag 101
# estas escrapeando la pag 102
# estas escrapeando la pag 103
# estas escrapeando la pag 104
# estas escrapeando la pag 105
# estas escrapeando la pag 106
# estas escrapeando la pag 107
# estas escrapeando la pag 108
# estas escrapeando la pag 109
# estas escrapeando la pag 110
# estas escrapeando la pag 111
# estas escrapeando la pag 112
# estas escrapeando la pag 113
# estas escrapeando la pag 114
# estas escrapeando la pag 115
# estas escrapeando la pag 116
# estas escrapeando la pag 117
# estas escrapeando la pag 118
# estas escrapeando la pag 119
# estas escrapeando la pag 120
# estas escrapeando la pag 121
# estas escrapeando la pag 122
# estas escrapeando la pag 123
# estas escrapeando la pag 124
# estas escrapeando la pag 125
# estas escrapeando la pag 126
# estas escrapeando la pag 127
# estas escrapeando la pag 128
# estas escrapeando la pag 129
# estas escrapeando la pag 130
# estas escrapeando la pag 131
# estas escrapeando la pag 132
# estas escrapeando la pag 133
# estas escrapeando la pag 134
# estas escrapeando la pag 135
# estas escrapeando la pag 136
# estas escrapeando la pag 137
# estas escrapeando la pag 138
# estas escrapeando la pag 139
# estas escrapeando la pag 140
# estas escrapeando la pag 141
# estas escrapeando la pag 142
# estas escrapeando la pag 143
# estas escrapeando la pag 144
# estas escrapeando la pag 145
# estas escrapeando la pag 146
# estas escrapeando la pag 147
# estas escrapeando la pag 148
# estas escrapeando la pag 149
# estas escrapeando la pag 150
# estas escrapeando la pag 151
# estas escrapeando la pag 152
# estas escrapeando la pag 153
# estas escrapeando la pag 154
# estas escrapeando la pag 155
# estas escrapeando la pag 156
# estas escrapeando la pag 157
# estas escrapeando la pag 158
# estas escrapeando la pag 159
# estas escrapeando la pag 160
# estas escrapeando la pag 161
# estas escrapeando la pag 162
# estas escrapeando la pag 163
# estas escrapeando la pag 164
# estas escrapeando la pag 165
# estas escrapeando la pag 166
# estas escrapeando la pag 167
# estas escrapeando la pag 168
# estas escrapeando la pag 169
# estas escrapeando la pag 170
# estas escrapeando la pag 171
# estas escrapeando la pag 172
# estas escrapeando la pag 173
# estas escrapeando la pag 174
# estas escrapeando la pag 175
# estas escrapeando la pag 176
# estas escrapeando la pag 177
# estas escrapeando la pag 178
# estas escrapeando la pag 179
# estas escrapeando la pag 180
# estas escrapeando la pag 181
# estas escrapeando la pag 182
# estas escrapeando la pag 183
# estas escrapeando la pag 184
# estas escrapeando la pag 185
# estas escrapeando la pag 186
# estas escrapeando la pag 187
# estas escrapeando la pag 188
# estas escrapeando la pag 189
# estas escrapeando la pag 190
# estas escrapeando la pag 191
# estas escrapeando la pag 192
# estas escrapeando la pag 193
# estas escrapeando la pag 194
# estas escrapeando la pag 195
# estas escrapeando la pag 196
# estas escrapeando la pag 197
# estas escrapeando la pag 198
# estas escrapeando la pag 199
# estas escrapeando la pag 200
# estas escrapeando la pag 201
# estas escrapeando la pag 202
# estas escrapeando la pag 203
# estas escrapeando la pag 204
# estas escrapeando la pag 205
# estas escrapeando la pag 206
# estas escrapeando la pag 207
# estas escrapeando la pag 208
# estas escrapeando la pag 209
# estas escrapeando la pag 210
# estas escrapeando la pag 211
# estas escrapeando la pag 212
# estas escrapeando la pag 213
# estas escrapeando la pag 214
# estas escrapeando la pag 215
# estas escrapeando la pag 216
# estas escrapeando la pag 217
# estas escrapeando la pag 218
# estas escrapeando la pag 219
# estas escrapeando la pag 220
# estas escrapeando la pag 221
# estas escrapeando la pag 222
# estas escrapeando la pag 223
# estas escrapeando la pag 224
# estas escrapeando la pag 225
# estas escrapeando la pag 226
# estas escrapeando la pag 227
# estas escrapeando la pag 228
# estas escrapeando la pag 229
# estas escrapeando la pag 230
# estas escrapeando la pag 231
# estas escrapeando la pag 232
# estas escrapeando la pag 233
# estas escrapeando la pag 234
# estas escrapeando la pag 235
# estas escrapeando la pag 236
# estas escrapeando la pag 237
# estas escrapeando la pag 238
# estas escrapeando la pag 239
# estas escrapeando la pag 240
# estas escrapeando la pag 241
# estas escrapeando la pag 242
# estas escrapeando la pag 243
# estas escrapeando la pag 244
# estas escrapeando la pag 245
# estas escrapeando la pag 246
# estas escrapeando la pag 247
# estas escrapeando la pag 248
# estas escrapeando la pag 249
# estas escrapeando la pag 250
# estas escrapeando la pag 251
# estas escrapeando la pag 252
# estas escrapeando la pag 253
# estas escrapeando la pag 254
# estas escrapeando la pag 255
# estas escrapeando la pag 256
# estas escrapeando la pag 257
# estas escrapeando la pag 258
# estas escrapeando la pag 259
# estas escrapeando la pag 260
# estas escrapeando la pag 261
# estas escrapeando la pag 262
# estas escrapeando la pag 263
# estas escrapeando la pag 264
# estas escrapeando la pag 265
# estas escrapeando la pag 266
# estas escrapeando la pag 267
# estas escrapeando la pag 268
# estas escrapeando la pag 269
# estas escrapeando la pag 270
# estas escrapeando la pag 271
# estas escrapeando la pag 272
# estas escrapeando la pag 273
# estas escrapeando la pag 274
# estas escrapeando la pag 275
# estas escrapeando la pag 276
# estas escrapeando la pag 277
# estas escrapeando la pag 278
# estas escrapeando la pag 279
# estas escrapeando la pag 280
# estas escrapeando la pag 281
# estas escrapeando la pag 282
# estas escrapeando la pag 283
# estas escrapeando la pag 284
# estas escrapeando la pag 285
# estas escrapeando la pag 286
# estas escrapeando la pag 287
# estas escrapeando la pag 288
# estas escrapeando la pag 289
# estas escrapeando la pag 290
# estas escrapeando la pag 291
# estas escrapeando la pag 292
# estas escrapeando la pag 293
# estas escrapeando la pag 294
# estas escrapeando la pag 295
# estas escrapeando la pag 296
# estas escrapeando la pag 297
# estas escrapeando la pag 298
# estas escrapeando la pag 299
# estas escrapeando la pag 300
# estas escrapeando la pag 301
# estas escrapeando la pag 302
# estas escrapeando la pag 303
# estas escrapeando la pag 304
# estas escrapeando la pag 305
# estas escrapeando la pag 306
# estas escrapeando la pag 307
# estas escrapeando la pag 308
# estas escrapeando la pag 309
# estas escrapeando la pag 310
# estas escrapeando la pag 311
# estas escrapeando la pag 312
# estas escrapeando la pag 313
# estas escrapeando la pag 314
# estas escrapeando la pag 315
# estas escrapeando la pag 316
# estas escrapeando la pag 317
# estas escrapeando la pag 318
# estas escrapeando la pag 319
# estas escrapeando la pag 320
# estas escrapeando la pag 321
# estas escrapeando la pag 322
# estas escrapeando la pag 323
# estas escrapeando la pag 324
# estas escrapeando la pag 325
# estas escrapeando la pag 326
# estas escrapeando la pag 327
# estas escrapeando la pag 328
# estas escrapeando la pag 329
# estas escrapeando la pag 330
# estas escrapeando la pag 331
# estas escrapeando la pag 332
# estas escrapeando la pag 333
# estas escrapeando la pag 334
# estas escrapeando la pag 335
# estas escrapeando la pag 336
# estas escrapeando la pag 337
# estas escrapeando la pag 338
# estas escrapeando la pag 339
# estas escrapeando la pag 340
# estas escrapeando la pag 341
# estas escrapeando la pag 342
# estas escrapeando la pag 343
# estas escrapeando la pag 344
# estas escrapeando la pag 345
# estas escrapeando la pag 346
# estas escrapeando la pag 347
# estas escrapeando la pag 348
# estas escrapeando la pag 349
# estas escrapeando la pag 350
# estas escrapeando la pag 351
# estas escrapeando la pag 352
# estas escrapeando la pag 353
# estas escrapeando la pag 354
# estas escrapeando la pag 355
# estas escrapeando la pag 356
# estas escrapeando la pag 357
# estas escrapeando la pag 358
# estas escrapeando la pag 359
# estas escrapeando la pag 360
# estas escrapeando la pag 361
# estas escrapeando la pag 362
# estas escrapeando la pag 363
# estas escrapeando la pag 364
# estas escrapeando la pag 365
# estas escrapeando la pag 366
# estas escrapeando la pag 367
# estas escrapeando la pag 368
# estas escrapeando la pag 369
# estas escrapeando la pag 370
# estas escrapeando la pag 371
# estas escrapeando la pag 372
# estas escrapeando la pag 373
# estas escrapeando la pag 374
# estas escrapeando la pag 375
# estas escrapeando la pag 376

# %%
df_catalogo=pd.DataFrame(datos_book)
df_catalogo
# Out:
#     Titulo Revista                  Area         Tematica  \
# 0       Argumentos  V. Ciencias Sociales  Social Sciences
# 1       Argumentos  V. Ciencias Sociales  Social Sciences
# 2       Argumentos  V. Ciencias Sociales  Social Sciences
# 3       Argumentos  V. Ciencias Sociales  Social Sciences
# 4       Argumentos  V. Ciencias Sociales  Social Sciences
# ..             ...                   ...              ...
# 372     Argumentos  V. Ciencias Sociales  Social Sciences
# 373     Argumentos  V. Ciencias Sociales  Social Sciences
# 374     Argumentos  V. Ciencias Sociales  Social Sciences
# 375     Argumentos  V. Ciencias Sociales  Social Sciences
# 376     Argumentos  V. Ciencias Sociales  Social Sciences
#
#                                        Titulo Articulo  \
# 0                                       Cintillo legal
# 1                                               Índice
# 2                                         Presentación
# 3    Un encuentro para la apropiación de la salud e...
# 4    Autonomía emocional feminista: bordando experi...
# ..                                                 ...
# 372  Conflictos intratables por el agua en México:\...
# 373  Crímen y economía: una revisión crítica\nde la...
# 374  Memorias en riesgo, desmemoria, olvidos y reco...
# 375                                  Sueños en vigilia
# 376                                        Los Autores
#
#                                                Resumen Abstract  \
# 0                                                 None     None
# 1                                                 None     None
# 2                                                 None     None
# 3    Este trabajo describe el acompañamiento creati...     None
# 4    El presente artículo aborda la generación de n...     None
# ..                                                 ...      ...
# 372  La gobernanza del agua se ha politizado en déc...     None
# 373  El vínculo entre crimen y economía es amplio, ...     None
# 374                                               None     None
# 375                                               None     None
# 376                                               None     None
#
#                                          Link Articulo  \
# 0    https://argumentos.xoc.uam.mx/index.php/argume...
# 1    https://argumentos.xoc.uam.mx/index.php/argume...
# 2    https://argumentos.xoc.uam.mx/index.php/argume...
# 3    https://argumentos.xoc.uam.mx/index.php/argume...
# 4    https://argumentos.xoc.uam.mx/index.php/argume...
# ..                                                 ...
# 372  https://argumentos.xoc.uam.mx/index.php/argume...
# 373  https://argumentos.xoc.uam.mx/index.php/argume...
# 374  https://argumentos.xoc.uam.mx/index.php/argume...
# 375  https://argumentos.xoc.uam.mx/index.php/argume...
# 376  https://argumentos.xoc.uam.mx/index.php/argume...
#
#                                               Link PDF
# 0    https://argumentos.xoc.uam.mx/index.php/argume...
# 1    https://argumentos.xoc.uam.mx/index.php/argume...
# 2    https://argumentos.xoc.uam.mx/index.php/argume...
# 3    https://argumentos.xoc.uam.mx/index.php/argume...
# 4    https://argumentos.xoc.uam.mx/index.php/argume...
# ..                                                 ...
# 372  https://argumentos.xoc.uam.mx/index.php/argume...
# 373  https://argumentos.xoc.uam.mx/index.php/argume...
# 374  https://argumentos.xoc.uam.mx/index.php/argume...
# 375  https://argumentos.xoc.uam.mx/index.php/argume...
# 376  https://argumentos.xoc.uam.mx/index.php/argume...
#
# [377 rows x 8 columns]

# %%
df_catalogo.to_csv('Revista205.01.csv', index=False)
