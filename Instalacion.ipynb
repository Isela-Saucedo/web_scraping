# %%
import pandas
pandas.__version__
# Out:
# '1.4.2'

# %%
pip install beautifulsoup4
# Out:
# Requirement already satisfied: beautifulsoup4 in /opt/conda/lib/python3.10/site-packages (4.11.1)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/lib/python3.10/site-packages (from beautifulsoup4) (2.3.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install requests
# Out:
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (2.27.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /opt/conda/lib/python3.10/site-packages (from requests) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests) (2022.5.18.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests) (1.26.9)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in /opt/conda/lib/python3.10/site-packages (1.4.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /opt/conda/lib/python3.10/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas) (2022.1)
# Requirement already satisfied: numpy>=1.21.0 in /opt/conda/lib/python3.10/site-packages (from pandas) (1.21.6)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install lxml
# Out:
# Collecting lxml
#   Downloading lxml-4.9.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (6.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 4.7 MB/s eta 0:00:0000:0100:01
# Installing collected packages: lxml
# Successfully installed lxml-4.9.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install jupyterlab-git
# Out:
# Collecting jupyterlab-git
#   Downloading jupyterlab_git-0.37.1-py3-none-any.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 3.9 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: jupyter-server in /opt/conda/lib/python3.10/site-packages (from jupyterlab-git) (1.17.0)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from jupyterlab-git) (21.3)
# Collecting nbdime~=3.1
#   Downloading nbdime-3.1.1-py2.py3-none-any.whl (5.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 6.0 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: nbformat in /opt/conda/lib/python3.10/site-packages (from jupyterlab-git) (5.4.0)
# Requirement already satisfied: pexpect in /opt/conda/lib/python3.10/site-packages (from jupyterlab-git) (4.8.0)
# Requirement already satisfied: colorama in /opt/conda/lib/python3.10/site-packages (from nbdime~=3.1->jupyterlab-git) (0.4.4)
# Collecting jupyter-server-mathjax>=0.2.2
#   Downloading jupyter_server_mathjax-0.2.5-py3-none-any.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 5.9 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: pygments in /opt/conda/lib/python3.10/site-packages (from nbdime~=3.1->jupyterlab-git) (2.12.0)
# Collecting GitPython!=2.1.4,!=2.1.5,!=2.1.6
#   Downloading GitPython-3.1.27-py3-none-any.whl (181 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.2/181.2 kB 5.2 MB/s eta 0:00:00
# Requirement already satisfied: jinja2>=2.9 in /opt/conda/lib/python3.10/site-packages (from nbdime~=3.1->jupyterlab-git) (3.1.2)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from nbdime~=3.1->jupyterlab-git) (2.27.1)
# Requirement already satisfied: tornado in /opt/conda/lib/python3.10/site-packages (from nbdime~=3.1->jupyterlab-git) (6.1)
# Requirement already satisfied: jupyter-client>=6.1.12 in /opt/conda/lib/python3.10/site-packages (from jupyter-server->jupyterlab-git) (7.3.1)
# Requirement already satisfied: pyzmq>=17 in /opt/conda/lib/python3.10/site-packages (from jupyter-server->jupyterlab-git) (23.0.0)
# Requirement already satisfied: anyio<4,>=3.1.0 in /opt/conda/lib/python3.10/site-packages (from jupyter-server->jupyterlab-git) (3.6.1)
# Requirement already satisfied: prometheus-client in /opt/conda/lib/python3.10/site-packages (from jupyter-server->jupyterlab-git) (0.14.1)
# Requirement already satisfied: nbconvert>=6.4.4 in /opt/conda/lib/python3.10/site-packages (from jupyter-server->jupyterlab-git) (6.5.0)
# Requirement already satisfied: websocket-client in /opt/conda/lib/python3.10/site-packages (from jupyter-server->jupyterlab-git) (1.3.2)
# Requirement already satisfied: jupyter-core>=4.7.0 in /opt/conda/lib/python3.10/site-packages (from jupyter-server->jupyterlab-git) (4.10.0)
# Requirement already satisfied: argon2-cffi in /opt/conda/lib/python3.10/site-packages (from jupyter-server->jupyterlab-git) (21.3.0)
# Requirement already satisfied: terminado>=0.8.3 in /opt/conda/lib/python3.10/site-packages (from jupyter-server->jupyterlab-git) (0.15.0)
# Requirement already satisfied: Send2Trash in /opt/conda/lib/python3.10/site-packages (from jupyter-server->jupyterlab-git) (1.8.0)
# Requirement already satisfied: traitlets>=5.1 in /opt/conda/lib/python3.10/site-packages (from jupyter-server->jupyterlab-git) (5.2.1.post0)
# Requirement already satisfied: jsonschema>=2.6 in /opt/conda/lib/python3.10/site-packages (from nbformat->jupyterlab-git) (4.5.1)
# Requirement already satisfied: fastjsonschema in /opt/conda/lib/python3.10/site-packages (from nbformat->jupyterlab-git) (2.15.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging->jupyterlab-git) (3.0.9)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/conda/lib/python3.10/site-packages (from pexpect->jupyterlab-git) (0.7.0)
# Requirement already satisfied: sniffio>=1.1 in /opt/conda/lib/python3.10/site-packages (from anyio<4,>=3.1.0->jupyter-server->jupyterlab-git) (1.2.0)
# Requirement already satisfied: idna>=2.8 in /opt/conda/lib/python3.10/site-packages (from anyio<4,>=3.1.0->jupyter-server->jupyterlab-git) (3.3)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.9-py3-none-any.whl (63 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.1/63.1 kB 7.3 MB/s eta 0:00:00
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2>=2.9->nbdime~=3.1->jupyterlab-git) (2.1.1)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /opt/conda/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat->jupyterlab-git) (0.18.1)
# Requirement already satisfied: attrs>=17.4.0 in /opt/conda/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat->jupyterlab-git) (21.4.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from jupyter-client>=6.1.12->jupyter-server->jupyterlab-git) (2.8.2)
# Requirement already satisfied: entrypoints in /opt/conda/lib/python3.10/site-packages (from jupyter-client>=6.1.12->jupyter-server->jupyterlab-git) (0.4)
# Requirement already satisfied: nest-asyncio>=1.5.4 in /opt/conda/lib/python3.10/site-packages (from jupyter-client>=6.1.12->jupyter-server->jupyterlab-git) (1.5.5)
# Requirement already satisfied: pandocfilters>=1.4.1 in /opt/conda/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server->jupyterlab-git) (1.5.0)
# Requirement already satisfied: defusedxml in /opt/conda/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server->jupyterlab-git) (0.7.1)
# Requirement already satisfied: beautifulsoup4 in /opt/conda/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server->jupyterlab-git) (4.11.1)
# Requirement already satisfied: nbclient>=0.5.0 in /opt/conda/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server->jupyterlab-git) (0.6.3)
# Requirement already satisfied: tinycss2 in /opt/conda/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server->jupyterlab-git) (1.1.1)
# Requirement already satisfied: jupyterlab-pygments in /opt/conda/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server->jupyterlab-git) (0.2.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in /opt/conda/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server->jupyterlab-git) (0.8.4)
# Requirement already satisfied: bleach in /opt/conda/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server->jupyterlab-git) (5.0.0)
# Requirement already satisfied: argon2-cffi-bindings in /opt/conda/lib/python3.10/site-packages (from argon2-cffi->jupyter-server->jupyterlab-git) (21.2.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->nbdime~=3.1->jupyterlab-git) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /opt/conda/lib/python3.10/site-packages (from requests->nbdime~=3.1->jupyterlab-git) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->nbdime~=3.1->jupyterlab-git) (2022.5.18.1)
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.8.2->jupyter-client>=6.1.12->jupyter-server->jupyterlab-git) (1.16.0)
# Requirement already satisfied: cffi>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from argon2-cffi-bindings->argon2-cffi->jupyter-server->jupyterlab-git) (1.15.0)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/lib/python3.10/site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server->jupyterlab-git) (2.3.1)
# Requirement already satisfied: webencodings in /opt/conda/lib/python3.10/site-packages (from bleach->nbconvert>=6.4.4->jupyter-server->jupyterlab-git) (0.5.1)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.10/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->jupyter-server->jupyterlab-git) (2.21)
# Installing collected packages: smmap, gitdb, GitPython, jupyter-server-mathjax, nbdime, jupyterlab-git
# Successfully installed GitPython-3.1.27 gitdb-4.0.9 jupyter-server-mathjax-0.2.5 jupyterlab-git-0.37.1 nbdime-3.1.1 smmap-5.0.0
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install -c conda-forge jupyterlab-git
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: -
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - conda-forge/linux-64::ruamel.yaml==0.17.21=py310h5764c6d_1
#   - conda-forge/noarch::backports==1.0=py_2
#   - conda-forge/noarch::notebook==6.4.11=pyha770c72_0
#   - conda-forge/linux-64::setuptools==62.3.2=py310hff52083_0
#   - conda-forge/noarch::beautifulsoup4==4.11.1=pyha770c72_0
#   - conda-forge/noarch::pyjwt==2.4.0=pyhd8ed1ab_0
#   - conda-forge/linux-64::importlib-metadata==4.11.4=py310hff52083_0
#   - conda-forge/noarch::stack_data==0.2.0=pyhd8ed1ab_0
#   - conda-forge/noarch::pandocfilters==1.5.0=pyhd8ed1ab_0
#   - conda-forge/linux-64::argon2-cffi-bindings==21.2.0=py310h5764c6d_2
#   - conda-forge/noarch::parso==0.8.3=pyhd8ed1ab_0
#   - conda-forge/noarch::nbconvert-core==6.5.0=pyhd8ed1ab_0
#   - conda-forge/noarch::entrypoints==0.4=pyhd8ed1ab_0
#   - conda-forge/noarch::attrs==21.4.0=pyhd8ed1ab_0
#   - conda-forge/noarch::tqdm==4.64.0=pyhd8ed1ab_0
#   - conda-forge/linux-64::brotlipy==0.7.0=py310h5764c6d_1004
#   - conda-forge/noarch::flit-core==3.7.1=pyhd8ed1ab_0
#   - conda-forge/linux-64::sqlalchemy==1.4.36=py310h5764c6d_0
#   - conda-forge/noarch::colorama==0.4.4=pyh9f0ad1d_0
#   - conda-forge/noarch::urllib3==1.26.9=pyhd8ed1ab_0
#   - conda-forge/linux-64::pyzmq==23.0.0=py310h330234f_0
#   - conda-forge/noarch::mako==1.2.0=pyhd8ed1ab_1
#   - conda-forge/noarch::pip==22.1.1=pyhd8ed1ab_0
#   - conda-forge/linux-64::jedi==0.18.1=py310hff52083_1
#   - conda-forge/linux-64::debugpy==1.6.0=py310hd8f1fbe_0
#   - conda-forge/noarch::jupyterlab==3.4.2=pyhd8ed1ab_0
#   - conda-forge/noarch::charset-normalizer==2.0.12=pyhd8ed1ab_0
#   - conda-forge/linux-64::pycosat==0.6.3=py310h5764c6d_1010
#   - conda-forge/noarch::certipy==0.1.3=py_0
#   - conda-forge/noarch::prometheus_client==0.14.1=pyhd8ed1ab_0
#   - conda-forge/linux-64::sqlite==3.38.5=h4ff8645_0
#   - conda-forge/linux-64::ipython==8.4.0=py310hff52083_0
#   - conda-forge/noarch::json5==0.9.5=pyh9f0ad1d_0
#   - conda-forge/linux-64::readline==8.1=h46c0cb4_0
#   - conda-forge/noarch::jupyterlab_pygments==0.2.2=pyhd8ed1ab_0
#   - conda-forge/noarch::oauthlib==3.2.0=pyhd8ed1ab_0
#   - conda-forge/noarch::pickleshare==0.7.5=py_1003
#   - conda-forge/noarch::blinker==1.4=py_1
#   - conda-forge/noarch::zipp==3.8.0=pyhd8ed1ab_0
#   - conda-forge/linux-64::psutil==5.9.1=py310h5764c6d_0
#   - conda-forge/noarch::backcall==0.2.0=pyh9f0ad1d_0
#   - conda-forge/noarch::ipython_genutils==0.2.0=py_1
#   - conda-forge/noarch::importlib_metadata==4.11.4=hd8ed1ab_0
#   - conda-forge/linux-64::sniffio==1.2.0=py310hff52083_3
#   - conda-forge/linux-64::pyrsistent==0.18.1=py310h5764c6d_1
#   - conda-forge/noarch::jsonschema==4.5.1=pyhd8ed1ab_0
#   - conda-forge/noarch::tinycss2==1.1.1=pyhd8ed1ab_0
#   - conda-forge/noarch::send2trash==1.8.0=pyhd8ed1ab_0
#   - conda-forge/linux-64::libmambapy==0.23.3=py310hab0e683_1
#   - conda-forge/noarch::websocket-client==1.3.2=pyhd8ed1ab_0
#   - conda-forge/linux-64::conda==4.12.0=py310hff52083_0
#   - conda-forge/linux-64::markupsafe==2.1.1=py310h5764c6d_1
#   - conda-forge/linux-64::ipykernel==6.13.0=py310hfdc917e_0
#   - conda-forge/noarch::traitlets==5.2.1.post0=pyhd8ed1ab_0
#   - conda-forge/noarch::bleach==5.0.0=pyhd8ed1ab_0
#   - conda-forge/noarch::wcwidth==0.2.5=pyh9f0ad1d_2
#   - conda-forge/linux-64::cryptography==37.0.2=py310h597c629_0
#   - conda-forge/noarch::nbformat==5.4.0=pyhd8ed1ab_0
#   - conda-forge/linux-64::mistune==0.8.4=py310h6acc77f_1005
#   - conda-forge/noarch::pyopenssl==22.0.0=pyhd8ed1ab_0
#   - conda-forge/noarch::pygments==2.12.0=pyhd8ed1ab_0
#   - conda-forge/noarch::argon2-cffi==21.3.0=pyhd8ed1ab_0
#   - conda-forge/noarch::decorator==5.1.1=pyhd8ed1ab_0
#   - conda-forge/noarch::wheel==0.37.1=pyhd8ed1ab_0
#   - conda-forge/noarch::soupsieve==2.3.1=pyhd8ed1ab_0
#   - conda-forge/noarch::jupyterhub-base==2.3.0=pyhd8ed1ab_0
#   - conda-forge/noarch::pexpect==4.8.0=pyh9f0ad1d_2
#   - conda-forge/noarch::pytz==2022.1=pyhd8ed1ab_0
#   - conda-forge/noarch::python-fastjsonschema==2.15.3=pyhd8ed1ab_0
#   - conda-forge/noarch::pycparser==2.21=pyhd8ed1ab_0
#   - conda-forge/noarch::async_generator==1.10=py_0
#   - conda-forge/noarch::nbclassic==0.3.7=pyhd8ed1ab_0
#   - conda-forge/noarch::ptyprocess==0.7.0=pyhd3deb0d_0
#   - conda-forge/noarch::nbclient==0.6.3=pyhd8ed1ab_0
#   - conda-forge/noarch::jupyter_server==1.17.0=pyhd8ed1ab_0
#   - conda-forge/noarch::pamela==1.0.0=py_0
#   - conda-forge/linux-64::anyio==3.6.1=py310hff52083_0
#   - conda-forge/noarch::pure_eval==0.2.2=pyhd8ed1ab_0
#   - conda-forge/noarch::nbconvert==6.5.0=pyhd8ed1ab_0
#   - conda-forge/linux-64::pysocks==1.7.1=py310hff52083_5
#   - conda-forge/linux-64::tornado==6.1=py310h5764c6d_3
#   - conda-forge/noarch::nbconvert-pandoc==6.5.0=pyhd8ed1ab_0
#   - conda-forge/noarch::jupyter_telemetry==0.1.0=pyhd8ed1ab_1
#   - conda-forge/linux-64::cffi==1.15.0=py310h0fdd8cc_0
#   - conda-forge/linux-64::greenlet==1.1.2=py310hd8f1fbe_2
#   - conda-forge/linux-64::mamba==0.23.3=py310hf87f941_1
#   - conda-forge/noarch::python-dateutil==2.8.2=pyhd8ed1ab_0
#   - conda-forge/noarch::python-json-logger==2.0.1=pyh9f0ad1d_0
#   - conda-forge/linux-64::pycurl==7.45.1=py310h2aed498_1
#   - conda-forge/linux-64::python_abi==3.10=2_cp310
#   - conda-forge/noarch::idna==3.3=pyhd8ed1ab_0
#   - conda-forge/noarch::executing==0.8.3=pyhd8ed1ab_0
#   - conda-forge/linux-64::ruamel.yaml.clib==0.2.6=py310h5764c6d_1
#   - conda-forge/noarch::backports.functools_lru_cache==1.6.4=pyhd8ed1ab_0
#   - conda-forge/linux-64::certifi==2022.5.18.1=py310hff52083_0
#   - conda-forge/noarch::prompt-toolkit==3.0.29=pyha770c72_0
#   - conda-forge/noarch::pyparsing==3.0.9=pyhd8ed1ab_0
#   - conda-forge/noarch::packaging==21.3=pyhd8ed1ab_0
#   - conda-forge/noarch::jupyter_client==7.3.1=pyhd8ed1ab_0
#   - conda-forge/noarch::notebook-shim==0.1.0=pyhd8ed1ab_0
#   - conda-forge/linux-64::conda-package-handling==1.8.1=py310h5764c6d_1
#   - conda-forge/noarch::babel==2.10.1=pyhd8ed1ab_0
#   - conda-forge/noarch::asttokens==2.0.5=pyhd8ed1ab_0
#   - conda-forge/noarch::importlib_resources==5.7.1=pyhd8ed1ab_1
#   - conda-forge/noarch::jinja2==3.1.2=pyhd8ed1ab_0
#   - conda-forge/noarch::jupyterhub==2.3.0=pyhd8ed1ab_0
#   - conda-forge/noarch::webencodings==0.5.1=py_1
#   - conda-forge/linux-64::terminado==0.15.0=py310hff52083_0
#   - conda-forge/noarch::defusedxml==0.7.1=pyhd8ed1ab_0
#   - conda-forge/linux-64::jupyter_core==4.10.0=py310hff52083_0
#   - conda-forge/noarch::six==1.16.0=pyh6c4a22f_0
#   - conda-forge/noarch::requests==2.27.1=pyhd8ed1ab_0
#   - conda-forge/linux-64::ruamel_yaml==0.15.80=py310h5764c6d_1007
#   - conda-forge/noarch::matplotlib-inline==0.1.3=pyhd8ed1ab_0
#   - conda-forge/noarch::nest-asyncio==1.5.5=pyhd8ed1ab_0
#   - conda-forge/noarch::jupyterlab_server==2.14.0=pyhd8ed1ab_0
#   - conda-forge/noarch::alembic==1.7.7=pyhd8ed1ab_0
#   - conda-forge/linux-64::python==3.10.4=h9a8a25e_0_cpython
#   - conda-forge/noarch::r-patchwork==1.1.1=r41hc72bb7e_0
#   - conda-forge/noarch::r-parsnip==0.2.1=r41hc72bb7e_0
#   - conda-forge/linux-64::r-warp==0.2.0=r41hcfec24a_1
#   - conda-forge/noarch::r-workflowsets==0.2.1=r41hc72bb7e_0
#   - conda-forge/linux-64::r-slider==0.2.2=r41hcfec24a_0
#   - conda-forge/noarch::r-furrr==0.3.0=r41hc72bb7e_0
#   - conda-forge/noarch::r-infer==1.0.0=r41hc72bb7e_0
#   - conda-forge/noarch::r-gpfit==1.0_8=r41hc72bb7e_1
#   - conda-forge/linux-64::r-yardstick==0.0.9=r41h03ef668_0
#   - conda-forge/linux-64::r-dicedesign==1.9=r41hcfec24a_0
#   - conda-forge/linux-64::r-lhs==1.1.5=r41h7525677_0
#   - conda-forge/noarch::r-tidymodels==0.2.0=r41hc72bb7e_0
#   - conda-forge/noarch::r-rsample==0.1.1=r41hc72bb7e_0
#   - conda-forge/noarch::r-conflicted==1.1.0=r41hc72bb7e_0
#   - conda-forge/noarch::r-tune==0.2.0=r41hc72bb7e_0
#   - conda-forge/noarch::r-dials==0.1.1=r41hc72bb7e_0
#   - conda-forge/noarch::r-modeldata==0.1.1=r41hc72bb7e_0
#   - conda-forge/noarch::r-workflows==0.2.6=r41hc72bb7e_0
#   - conda-forge/noarch::r-googlesheets4==1.0.0=r41h785f33e_0
#   - conda-forge/noarch::r-bslib==0.3.1=r41hc72bb7e_0
#   - conda-forge/linux-64::r-xml2==1.3.3=r41h7525677_1
#   - conda-forge/noarch::r-waldo==0.4.0=r41hc72bb7e_0
#   - conda-forge/noarch::r-generics==0.1.2=r41hc72bb7e_0
#   - conda-forge/linux-64::rpy2==3.5.1=py310r41hde88566_0
#   - conda-forge/linux-64::r-testthat==3.1.4=r41h7525677_0
#   - conda-forge/linux-64::r-curl==4.3.2=r41hcfec24a_0
#   - conda-forge/noarch::r-fontawesome==0.2.2=r41hc72bb7e_0
#   - conda-forge/noarch::r-irkernel==1.3=r41hc72bb7e_0
#   - conda-forge/noarch::r-usethis==2.1.6=r41hc72bb7e_0
#   - conda-forge/noarch::r-rematch2==2.1.2=r41hc72bb7e_1
#   - conda-forge/noarch::r-credentials==1.3.2=r41hc72bb7e_0
#   - conda-forge/linux-64::r-bitops==1.0_7=r41hcfec24a_0
#   - conda-forge/linux-64::r-covr==3.5.1=r41h03ef668_0
#   - conda-forge/linux-64::r-utf8==1.2.2=r41hcfec24a_0
#   - conda-forge/linux-64::r-proxy==0.4_26=r41hcfec24a_0
#   - conda-forge/noarch::r-hardhat==0.2.0=r41hc72bb7e_0
#   - conda-forge/noarch::r-progress==1.2.2=r41hc72bb7e_2
#   - conda-forge/noarch::r-prettyunits==1.1.1=r41hc72bb7e_1
#   - conda-forge/noarch::r-assertthat==0.2.1=r41hc72bb7e_2
#   - conda-forge/noarch::r-pkgconfig==2.0.3=r41hc72bb7e_1
#   - conda-forge/linux-64::r-rcpp==1.0.8.3=r41h7525677_0
#   - conda-forge/noarch::r-plogr==0.2.0=r41hc72bb7e_1003
#   - conda-forge/noarch::r-broom==0.8.0=r41hc72bb7e_0
#   - conda-forge/linux-64::r-digest==0.6.29=r41h03ef668_0
#   - conda-forge/linux-64::r-xfun==0.31=r41h7525677_0
#   - conda-forge/noarch::r-foreach==1.5.2=r41hc72bb7e_0
#   - conda-forge/linux-64::r-cachem==1.0.6=r41hcfec24a_0
#   - conda-forge/linux-64::r-cli==3.3.0=r41h7525677_0
#   - conda-forge/noarch::r-desc==1.4.1=r41hc72bb7e_0
#   - conda-forge/linux-64::r-git2r==0.30.1=r41h96773ce_0
#   - conda-forge/linux-64::r-tibble==3.1.7=r41h06615bd_0
#   - conda-forge/linux-64::r-gert==1.5.0=r41h30f61c7_1
#   - conda-forge/linux-64::r-purrr==0.3.4=r41hcfec24a_1
#   - conda-forge/linux-64::r-httpuv==1.6.5=r41h03ef668_0
#   - conda-forge/noarch::r-brew==1.0_7=r41hc72bb7e_0
#   - conda-forge/noarch::r-quantmod==0.4.20=r41hc72bb7e_0
#   - conda-forge/linux-64::r-lazyeval==0.2.2=r41hcfec24a_2
#   - conda-forge/noarch::r-rmarkdown==2.14=r41hc72bb7e_0
#   - conda-forge/linux-64::pytz-deprecation-shim==0.1.0.post0=py310hff52083_1
#   - conda-forge/linux-64::r-bit64==4.0.5=r41hcfec24a_0
#   - conda-forge/linux-64::r-rcpparmadillo==0.11.1.1.0=r41h43535f1_0
#   - conda-forge/linux-64::r-tseries==0.10_51=r41h1463581_0
#   - conda-forge/noarch::r-iterators==1.0.14=r41hc72bb7e_0
#   - conda-forge/linux-64::r-ttr==0.24.3=r41h06615bd_0
#   - conda-forge/linux-64::tzlocal==4.2=py310hff52083_0
#   - conda-forge/linux-64::r-proc==1.18.0=r41h03ef668_0
#   - conda-forge/linux-64::r-farver==2.1.0=r41h03ef668_0
#   - conda-forge/linux-64::r-ellipsis==0.3.2=r41hcfec24a_0
#   - conda-forge/noarch::r-ggplot2==3.3.6=r41hc72bb7e_0
#   - conda-forge/linux-64::r-processx==3.5.3=r41h06615bd_0
#   - conda-forge/noarch::r-httr==1.4.3=r41hc72bb7e_0
#   - conda-forge/noarch::r-pkgbuild==1.3.1=r41hc72bb7e_0
#   - conda-forge/noarch::r-scales==1.2.0=r41hc72bb7e_0
#   - conda-forge/linux-64::r-data.table==1.14.2=r41hcfec24a_0
#   - conda-forge/noarch::r-timedate==3043.102=r41hc72bb7e_1002
#   - conda-forge/noarch::r-pillar==1.7.0=r41hc72bb7e_0
#   - conda-forge/noarch::r-devtools==2.4.3=r41hc72bb7e_0
#   - conda-forge/linux-64::r-mgcv==1.8_40=r41h0154571_0
#   - conda-forge/linux-64::r-hexbin==1.28.2=r41h8da6f51_0
#   - conda-forge/linux-64::r-promises==1.2.0.1=r41h03ef668_0
#   - conda-forge/linux-64::r-readxl==1.4.0=r41hf23e330_0
#   - conda-forge/noarch::python-tzdata==2022.1=pyhd8ed1ab_0
#   - conda-forge/linux-64::r-later==1.2.0=r41h03ef668_0
#   - conda-forge/linux-64::r-roxygen2==7.2.0=r41h7525677_0
#   - conda-forge/noarch::r-repr==1.1.4=r41h785f33e_0
#   - conda-forge/noarch::r-cpp11==0.4.2=r41hc72bb7e_0
#   - conda-forge/linux-64::r-fs==1.5.2=r41h7525677_1
#   - conda-forge/noarch::r-squarem==2021.1=r41hc72bb7e_0
#   - conda-forge/noarch::r-crosstalk==1.2.0=r41hc72bb7e_0
#   - conda-forge/linux-64::r-rodbc==1.3_19=r41hcfec24a_0
#   - conda-forge/linux-64::r-haven==2.5.0=r41h7525677_0
#   - conda-forge/linux-64::r-fracdiff==1.5_1=r41hb699f27_1
#   - conda-forge/noarch::r-evaluate==0.15=r41hc72bb7e_0
#   - conda-forge/linux-64::r-sys==3.4=r41hcfec24a_0
#   - conda-forge/noarch::r-rematch==1.0.1=r41hc72bb7e_1004
#   - conda-forge/noarch::simplegeneric==0.8.1=py_1
#   - conda-forge/linux-64::r-mime==0.12=r41hcfec24a_0
#   - conda-forge/linux-64::r-rsqlite==2.2.8=r41h03ef668_0
#   - conda-forge/noarch::r-ids==1.0.1=r41hc72bb7e_1
#   - conda-forge/linux-64::r-ipred==0.9_12=r41hcfec24a_0
#   - conda-forge/noarch::r-future==1.26.1=r41hc72bb7e_0
#   - conda-forge/linux-64::r-fansi==1.0.3=r41h06615bd_0
#   - conda-forge/linux-64::r-sass==0.4.1=r41h7525677_0
#   - conda-forge/linux-64::r-survival==3.3_1=r41h06615bd_0
#   - conda-forge/linux-64::r-diffobj==0.3.5=r41hcfec24a_0
#   - conda-forge/linux-64::r-vroom==1.5.7=r41h03ef668_0
#   - conda-forge/noarch::r-gtable==0.3.0=r41hc72bb7e_3
#   - conda-forge/noarch::r-munsell==0.5.0=r41hc72bb7e_1004
#   - conda-forge/linux-64::r-tidyr==1.2.0=r41h03ef668_0
#   - conda-forge/noarch::r-rstudioapi==0.13=r41hc72bb7e_0
#   - conda-forge/linux-64::r-backports==1.4.1=r41hcfec24a_0
#   - conda-forge/linux-64::r-randomforest==4.7_1.1=r41h8da6f51_0
#   - conda-forge/linux-64::r-base64enc==0.1_3=r41hcfec24a_1004
#   - conda-forge/noarch::r-dt==0.23=r41hc72bb7e_0
#   - conda-forge/linux-64::r-matrix==1.4_1=r41h0154571_0
#   - conda-forge/noarch::r-dtplyr==1.2.1=r41hc72bb7e_0
#   - conda-forge/noarch::r-withr==2.5.0=r41hc72bb7e_0
#   - conda-forge/linux-64::r-htmltools==0.5.2=r41h03ef668_0
#   - conda-forge/linux-64::r-uuid==1.1_0=r41h06615bd_0
#   - conda-forge/noarch::r-gitcreds==0.1.1=r41hc72bb7e_0
#   - conda-forge/noarch::r-globals==0.15.0=r41hc72bb7e_0
#   - conda-forge/linux-64::r-base==4.1.3=h06d3f91_1
#   - conda-forge/noarch::r-forcats==0.5.1=r41hc72bb7e_0
#   - conda-forge/noarch::r-future.apply==1.9.0=r41hc72bb7e_0
#   - conda-forge/noarch::r-selectr==0.4_2=r41hc72bb7e_1
#   - conda-forge/noarch::r-xtable==1.8_4=r41hc72bb7e_3
#   - conda-forge/noarch::r-parallelly==1.31.1=r41hc72bb7e_0
#   - conda-forge/noarch::r-cellranger==1.1.0=r41hc72bb7e_1004
#   - conda-forge/noarch::r-lifecycle==1.0.1=r41hc72bb7e_0
#   - conda-forge/linux-64::r-glue==1.6.2=r41h06615bd_0
#   - conda-forge/linux-64::r-rappdirs==0.3.3=r41hcfec24a_0
#   - conda-forge/noarch::r-dbplyr==2.1.1=r41hc72bb7e_0
#   - conda-forge/noarch::r-lava==1.6.10=r41hc72bb7e_0
#   - conda-forge/linux-64::r-reshape2==1.4.4=r41h03ef668_1
#   - conda-forge/noarch::r-numderiv==2016.8_1.1=r41hc72bb7e_3
#   - conda-forge/linux-64::r-rlang==1.0.2=r41h7525677_0
#   - conda-forge/noarch::r-stringr==1.4.0=r41hc72bb7e_2
#   - conda-forge/noarch::r-hms==1.1.1=r41hc72bb7e_0
#   - conda-forge/linux-64::r-askpass==1.1=r41hcfec24a_2
#   - conda-forge/noarch::r-memoise==2.0.1=r41hc72bb7e_0
#   - conda-forge/linux-64::r-sourcetools==0.1.7=r41h03ef668_1002
#   - conda-forge/linux-64::r-pbdzmq==0.3_7=r41h42bf92c_0
#   - conda-forge/noarch::r-rprojroot==2.0.3=r41hc72bb7e_0
#   - conda-forge/linux-64::r-e1071==1.7_9=r41h03ef668_0
#   - conda-forge/linux-64::r-modelmetrics==1.2.2.2=r41h03ef668_1
#   - conda-forge/noarch::r-irdisplay==1.1=r41hd8ed1ab_0
#   - conda-forge/noarch::r-rvest==1.0.2=r41hc72bb7e_0
#   - conda-forge/linux-64::r-caret==6.0_92=r41h06615bd_0
#   - conda-forge/linux-64::r-vctrs==0.4.1=r41h7525677_0
#   - conda-forge/linux-64::r-tidyselect==1.1.2=r41hc72bb7e_0
#   - conda-forge/linux-64::r-readr==2.1.2=r41h03ef668_0
#   - conda-forge/linux-64::r-ps==1.7.0=r41h06615bd_0
#   - conda-forge/linux-64::r-xts==0.12.1=r41h06615bd_0
#   - conda-forge/linux-64::r-lmtest==0.9_40=r41h8da6f51_0
#   - conda-forge/linux-64::r-nlme==3.1_157=r41h8da6f51_0
#   - conda-forge/linux-64::r-pkgload==1.2.4=r41h03ef668_0
#   - conda-forge/noarch::r-clipr==0.8.0=r41hc72bb7e_0
#   - conda-forge/linux-64::r-prodlim==2019.11.13=r41h03ef668_1
#   - conda-forge/linux-64::r-colorspace==2.0_3=r41h06615bd_0
#   - conda-forge/noarch::r-knitr==1.39=r41hc72bb7e_0
#   - conda-forge/linux-64::r-openssl==2.0.2=r41hfaab4ff_0
#   - conda-forge/linux-64::r-class==7.3_20=r41hcfec24a_0
#   - conda-forge/noarch::r-htmlwidgets==1.5.4=r41hc72bb7e_0
#   - conda-forge/noarch::r-rversions==2.1.1=r41hc72bb7e_0
#   - conda-forge/noarch::r-listenv==0.8.0=r41hc72bb7e_1
#   - conda-forge/linux-64::r-rcurl==1.98_1.6=r41hcfec24a_0
#   - conda-forge/linux-64::r-mass==7.3_57=r41h06615bd_0
#   - conda-forge/noarch::r-viridislite==0.4.0=r41hc72bb7e_0
#   - conda-forge/linux-64::r-rpart==4.1.16=r41hcfec24a_0
#   - conda-forge/noarch::r-shiny==1.7.1=r41h785f33e_0
#   - conda-forge/linux-64::r-brio==1.1.3=r41hcfec24a_0
#   - conda-forge/noarch::r-praise==1.0.0=r41hc72bb7e_1005
#   - conda-forge/linux-64::r-urca==1.3_0=r41h8da6f51_1006
#   - conda-forge/noarch::r-jquerylib==0.1.4=r41hc72bb7e_0
#   - conda-forge/noarch::r-reprex==2.0.1=r41hc72bb7e_0
#   - conda-forge/linux-64::r-zoo==1.8_10=r41h06615bd_0
#   - conda-forge/noarch::r-blob==1.2.3=r41hc72bb7e_0
#   - conda-forge/linux-64::r-yaml==2.3.5=r41h06615bd_0
#   - conda-forge/noarch::r-rcmdcheck==1.4.0=r41h785f33e_0
#   - conda-forge/noarch::r-r6==2.5.1=r41hc72bb7e_0
#   - conda-forge/linux-64::r-dplyr==1.0.9=r41h7525677_0
#   - conda-forge/noarch::r-gh==1.3.0=r41hc72bb7e_0
#   - conda-forge/noarch::r-codetools==0.2_18=r41hc72bb7e_0
#   - conda-forge/noarch::r-highr==0.9=r41hc72bb7e_0
#   - conda-forge/noarch::r-dbi==1.1.2=r41hc72bb7e_0
#   - conda-forge/linux-64::r-kernsmooth==2.23_20=r41h742201e_0
#   - conda-forge/linux-64::r-nnet==7.3_17=r41hcfec24a_0
#   - conda-forge/linux-64::r-bit==4.0.4=r41hcfec24a_0
#   - conda-forge/noarch::r-ini==0.3.1=r41hc72bb7e_1003
#   - conda-forge/linux-64::r-isoband==0.2.5=r41h03ef668_0
#   - conda-forge/noarch::r-tinytex==0.39=r41hc72bb7e_0
#   - conda-forge/noarch::r-sessioninfo==1.2.2=r41hc72bb7e_0
#   - conda-forge/noarch::r-progressr==0.10.0=r41hc72bb7e_0
#   - conda-forge/noarch::r-crayon==1.5.1=r41hc72bb7e_0
#   - conda-forge/noarch::r-nycflights13==1.0.2=r41hc72bb7e_0
#   - conda-forge/linux-64::r-zip==2.2.0=r41hcfec24a_0
#   - conda-forge/linux-64::r-jsonlite==1.8.0=r41h06615bd_0
#   - conda-forge/noarch::r-tidyverse==1.3.1=r41hc72bb7e_0
#   - conda-forge/noarch::r-rex==1.2.1=r41hc72bb7e_0
#   - conda-forge/noarch::r-labeling==0.4.2=r41hc72bb7e_1
#   - conda-forge/linux-64::r-lubridate==1.8.0=r41h03ef668_0
#   - conda-forge/linux-64::r-fastmap==1.1.0=r41h03ef668_0
#   - conda-forge/linux-64::r-lattice==0.20_45=r41hcfec24a_0
#   - conda-forge/noarch::r-callr==3.7.0=r41hc72bb7e_0
#   - conda-forge/noarch::r-recipes==0.2.0=r41hc72bb7e_0
#   - conda-forge/linux-64::r-plyr==1.8.7=r41h7525677_0
#   - conda-forge/noarch::r-rcolorbrewer==1.1_3=r41h785f33e_0
#   - conda-forge/noarch::r-googledrive==2.0.0=r41hc72bb7e_0
#   - conda-forge/linux-64::r-magrittr==2.0.3=r41h06615bd_0
#   - conda-forge/noarch::r-remotes==2.4.2=r41hc72bb7e_0
#   - conda-forge/linux-64::r-stringi==1.7.6=r41h30a9eb7_2
#   - conda-forge/linux-64::r-tzdb==0.3.0=r41h7525677_0
#   - conda-forge/linux-64::r-quadprog==1.5_8=r41h742201e_3
#   - conda-forge/linux-64::r-commonmark==1.8.0=r41h06615bd_0
#   - conda-forge/linux-64::r-forecast==8.16=r41hcec875b_0
#   - conda-forge/linux-64::r-gower==1.0.0=r41hcfec24a_0
#   - conda-forge/noarch::r-xopen==1.0.0=r41hc72bb7e_1003
#   - conda-forge/noarch::r-whisker==0.4=r41hc72bb7e_1
#   - conda-forge/noarch::r-gargle==1.2.0=r41hc72bb7e_0
#   - conda-forge/noarch::r-modelr==0.1.8=r41hc72bb7e_0
#   - conda-forge/noarch::altair==4.2.0=pyhd8ed1ab_1
#   - conda-forge/linux-64::pandas==1.4.2=py310h769672d_2
#   - conda-forge/linux-64::cytoolz==0.11.2=py310h5764c6d_2
#   - conda-forge/linux-64::bokeh==2.4.3=py310hff52083_0
#   - conda-forge/noarch::sortedcontainers==2.4.0=pyhd8ed1ab_0
#   - conda-forge/linux-64::pyyaml==6.0=py310h5764c6d_4
#   - conda-forge/noarch::partd==1.2.0=pyhd8ed1ab_0
#   - conda-forge/linux-64::h5py==3.6.0=nompi_py310he751f51_100
#   - conda-forge/noarch::seaborn-base==0.11.2=pyhd8ed1ab_0
#   - conda-forge/linux-64::click==8.1.3=py310hff52083_0
#   - conda-forge/noarch::dask==2022.5.2=pyhd8ed1ab_0
#   - conda-forge/linux-64::pytables==3.7.0=py310hf5df6ce_0
#   - conda-forge/noarch::jupyterlab_widgets==1.1.0=pyhd8ed1ab_0
#   - conda-forge/linux-64::msgpack-python==1.0.3=py310hbf28c38_1
#   - conda-forge/noarch::distributed==2022.5.2=pyhd8ed1ab_0
#   - conda-forge/noarch::fsspec==2022.5.0=pyhd8ed1ab_0
#   - conda-forge/linux-64::fonttools==4.33.3=py310h5764c6d_0
#   - conda-forge/linux-64::pywavelets==1.3.0=py310hde88566_1
#   - conda-forge/noarch::ipywidgets==7.7.0=pyhd8ed1ab_0
#   - conda-forge/linux-64::numpy==1.21.6=py310h45f3432_0
#   - conda-forge/noarch::xlrd==2.0.1=pyhd8ed1ab_3
#   - conda-forge/linux-64::scipy==1.8.1=py310h7612f91_0
#   - conda-forge/noarch::threadpoolctl==3.1.0=pyh8a188c0_0
#   - conda-forge/noarch::networkx==2.8.2=pyhd8ed1ab_0
#   - conda-forge/noarch::heapdict==1.0.1=py_0
#   - conda-forge/noarch::tifffile==2022.5.4=pyhd8ed1ab_0
#   - conda-forge/linux-64::llvmlite==0.38.1=py310h58363a5_0
#   - conda-forge/noarch::dask-core==2022.5.2=pyhd8ed1ab_0
#   - conda-forge/noarch::ipympl==0.9.1=pyhd8ed1ab_0
#   - conda-forge/linux-64::protobuf==3.20.1=py310hd8f1fbe_0
#   - conda-forge/linux-64::unicodedata2==14.0.0=py310h5764c6d_1
#   - conda-forge/linux-64::scikit-image==0.19.2=py310hb5077e9_0
#   - conda-forge/linux-64::kiwisolver==1.4.2=py310hbf28c38_1
#   - conda-forge/noarch::cached_property==1.5.2=pyha770c72_1
#   - conda-forge/linux-64::numexpr==2.8.0=py310hf05e7a9_102
#   - conda-forge/noarch::patsy==0.5.2=pyhd8ed1ab_0
#   - conda-forge/noarch::toolz==0.11.2=pyhd8ed1ab_0
#   - conda-forge/linux-64::bottleneck==1.3.4=py310hde88566_1
#   - conda-forge/noarch::cycler==0.11.0=pyhd8ed1ab_0
#   - conda-forge/noarch::typing_extensions==4.2.0=pyha770c72_1
#   - conda-forge/noarch::dill==0.3.5.1=pyhd8ed1ab_0
#   - conda-forge/linux-64::cython==0.29.30=py310hd8f1fbe_0
#   - conda-forge/linux-64::sympy==1.10.1=py310hff52083_0
#   - conda-forge/noarch::joblib==1.1.0=pyhd8ed1ab_0
#   - conda-forge/noarch::zict==2.2.0=pyhd8ed1ab_0
#   - conda-forge/noarch::tblib==1.7.0=pyhd8ed1ab_0
#   - conda-forge/noarch::imageio==2.19.2=pyhcf75d05_0
#   - conda-forge/linux-64::pillow==9.1.1=py310he619898_0
#   - conda-forge/linux-64::matplotlib-base==3.5.2=py310h5701ce4_0
#   - conda-forge/noarch::cached-property==1.5.2=hd8ed1ab_1
#   - conda-forge/noarch::mpmath==1.2.1=pyhd8ed1ab_0
#   - conda-forge/noarch::munkres==1.1.4=pyh9f0ad1d_0
#   - conda-forge/noarch::cloudpickle==2.1.0=pyhd8ed1ab_0
#   - conda-forge/noarch::locket==1.0.0=pyhd8ed1ab_0
#   - conda-forge/linux-64::widgetsnbextension==3.6.0=py310hff52083_0
#   - conda-forge/linux-64::statsmodels==0.13.2=py310h96516ba_0
#   - conda-forge/linux-64::scikit-learn==1.1.1=py310hffb9edd_0
#   - conda-forge/linux-64::numba==0.55.1=py310ha5257ce_1
#   - conda-forge/linux-64::lz4==4.0.0=py310h5d5e884_2
#   - conda-forge/noarch::seaborn==0.11.2=hd8ed1ab_0
#   - conda-forge/linux-64::imagecodecs==2022.2.22=py310h31a0021_5
#   - conda-forge/linux-64::gmpy2==2.1.2=py310h92f7908_0
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.12.0
#   latest version: 4.13.0
#
# Please update conda by running
#
#     $ conda update -n base conda
#
#
#
# ## Package Plan ##
#
#   environment location: /opt/conda
#
#   added / updated specs:
#     - jupyterlab-git
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2022.6.15  |       ha878542_0         149 KB  conda-forge
#     gitdb-4.0.9                |     pyhd8ed1ab_0          46 KB  conda-forge
#     gitpython-3.1.27           |     pyhd8ed1ab_0         123 KB  conda-forge
#     jupyter-server-mathjax-0.2.5|     pyhc268e32_0         2.3 MB  conda-forge
#     jupyterlab-git-0.37.1      |     pyhd8ed1ab_0         972 KB  conda-forge
#     nbdime-3.1.1               |     pyhd8ed1ab_0         4.4 MB  conda-forge
#     openssl-1.1.1p             |       h166bdaf_0         2.1 MB  conda-forge
#     readline-8.1.2             |       h0f457ee_0         291 KB  conda-forge
#     smmap-3.0.5                |     pyh44b312d_0          22 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        10.4 MB
#
# The following NEW packages will be INSTALLED:
#
#   gitdb              conda-forge/noarch::gitdb-4.0.9-pyhd8ed1ab_0
#   gitpython          conda-forge/noarch::gitpython-3.1.27-pyhd8ed1ab_0
#   jupyter-server-ma~ conda-forge/noarch::jupyter-server-mathjax-0.2.5-pyhc268e32_0
#   jupyterlab-git     conda-forge/noarch::jupyterlab-git-0.37.1-pyhd8ed1ab_0
#   nbdime             conda-forge/noarch::nbdime-3.1.1-pyhd8ed1ab_0
#   smmap              conda-forge/noarch::smmap-3.0.5-pyh44b312d_0
#
# The following packages will be UPDATED:
#
#   ca-certificates                    2022.5.18.1-ha878542_0 --> 2022.6.15-ha878542_0
#   openssl                                 1.1.1o-h166bdaf_0 --> 1.1.1p-h166bdaf_0
#   readline                                   8.1-h46c0cb4_0 --> 8.1.2-h0f457ee_0
#
#
#
# Downloading and Extracting Packages
# jupyterlab-git-0.37. | 972 KB    | ##################################### | 100%
# gitdb-4.0.9          | 46 KB     | ##################################### | 100%
# smmap-3.0.5          | 22 KB     | ##################################### | 100%
# gitpython-3.1.27     | 123 KB    | ##################################### | 100%
# nbdime-3.1.1         | 4.4 MB    | ##################################### | 100%
# jupyter-server-mathj | 2.3 MB    | ##################################### | 100%
# readline-8.1.2       | 291 KB    | ##################################### | 100%
# openssl-1.1.1p       | 2.1 MB    | ##################################### | 100%
# ca-certificates-2022 | 149 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda update -n base conda
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda
#
#   added / updated specs:
#     - conda
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     alembic-1.8.0              |     pyhd8ed1ab_0         137 KB  conda-forge
#     babel-2.10.3               |     pyhd8ed1ab_0         6.7 MB  conda-forge
#     certifi-2022.6.15          |  py310hff52083_0         155 KB  conda-forge
#     colorama-0.4.5             |     pyhd8ed1ab_0          18 KB  conda-forge
#     conda-4.13.0               |  py310hff52083_1         996 KB  conda-forge
#     imagecodecs-2022.2.22      |  py310h3ac3b6e_6         2.6 MB  conda-forge
#     imageio-2.19.3             |     pyhcf75d05_0         3.2 MB  conda-forge
#     importlib_resources-5.8.0  |     pyhd8ed1ab_0          22 KB  conda-forge
#     ipykernel-6.15.0           |     pyh210e3f2_0          96 KB  conda-forge
#     jinja2-3.1.2               |     pyhd8ed1ab_1          99 KB  conda-forge
#     jsonschema-4.6.0           |     pyhd8ed1ab_0          62 KB  conda-forge
#     jupyter_client-7.3.4       |     pyhd8ed1ab_0          91 KB  conda-forge
#     jupyter_server-1.17.1      |     pyhd8ed1ab_0         236 KB  conda-forge
#     jupyterlab_widgets-1.1.1   |     pyhd8ed1ab_0         133 KB  conda-forge
#     kiwisolver-1.4.3           |  py310hbf28c38_0          75 KB  conda-forge
#     libarchive-3.5.2           |       hb890918_3         1.6 MB  conda-forge
#     libdeflate-1.12            |       h166bdaf_0          78 KB  conda-forge
#     libtiff-4.4.0              |       hc85c160_1         638 KB  conda-forge
#     libzlib-1.2.12             |       h166bdaf_1          63 KB  conda-forge
#     msgpack-python-1.0.4       |  py310hbf28c38_0          88 KB  conda-forge
#     nbclient-0.6.4             |     pyhd8ed1ab_1          65 KB  conda-forge
#     networkx-2.8.4             |     pyhd8ed1ab_0         1.6 MB  conda-forge
#     pillow-9.1.1               |  py310he619898_1        44.8 MB  conda-forge
#     pycurl-7.45.1              |  py310h2aed498_2          74 KB  conda-forge
#     pyzmq-23.1.0               |  py310h330234f_0         484 KB  conda-forge
#     r-dbi-1.1.3                |    r41hc72bb7e_0         754 KB  conda-forge
#     r-dbplyr-2.2.0             |    r41hc72bb7e_0        1001 KB  conda-forge
#     r-dials-1.0.0              |    r41hc72bb7e_0         379 KB  conda-forge
#     r-hardhat-1.1.0            |    r41hc72bb7e_0         796 KB  conda-forge
#     r-infer-1.0.2              |    r41hc72bb7e_0         2.1 MB  conda-forge
#     r-ipred-0.9_13             |    r41h06615bd_0         394 KB  conda-forge
#     r-nlme-3.1_158             |    r41h8da6f51_0         2.3 MB  conda-forge
#     r-parallelly-1.32.0        |    r41hc72bb7e_0         316 KB  conda-forge
#     r-parsnip-1.0.0            |    r41hc72bb7e_0         1.4 MB  conda-forge
#     r-processx-3.6.1           |    r41h06615bd_0         305 KB  conda-forge
#     r-progressr-0.10.1         |    r41hc72bb7e_0         280 KB  conda-forge
#     r-proxy-0.4_27             |    r41h06615bd_0         190 KB  conda-forge
#     r-ps-1.7.1                 |    r41h06615bd_0         323 KB  conda-forge
#     r-rcpparmadillo-0.11.2.0.0 |    r41h9f5de39_0         952 KB  conda-forge
#     r-tinytex-0.40             |    r41hc72bb7e_0         139 KB  conda-forge
#     r-yardstick-1.0.0          |    r41h06615bd_0         848 KB  conda-forge
#     requests-2.28.0            |     pyhd8ed1ab_0          52 KB  conda-forge
#     setuptools-62.6.0          |  py310hff52083_0         1.4 MB  conda-forge
#     stack_data-0.3.0           |     pyhd8ed1ab_0          23 KB  conda-forge
#     traitlets-5.3.0            |     pyhd8ed1ab_0          85 KB  conda-forge
#     websocket-client-1.3.3     |     pyhd8ed1ab_0          41 KB  conda-forge
#     zlib-1.2.12                |       h166bdaf_1          91 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        77.9 MB
#
# The following packages will be REMOVED:
#
#   pip-22.1.1-pyhd8ed1ab_0
#   wheel-0.37.1-pyhd8ed1ab_0
#
# The following packages will be UPDATED:
#
#   alembic                                1.7.7-pyhd8ed1ab_0 --> 1.8.0-pyhd8ed1ab_0
#   babel                                 2.10.1-pyhd8ed1ab_0 --> 2.10.3-pyhd8ed1ab_0
#   certifi                       2022.5.18.1-py310hff52083_0 --> 2022.6.15-py310hff52083_0
#   colorama                               0.4.4-pyh9f0ad1d_0 --> 0.4.5-pyhd8ed1ab_0
#   conda                              4.12.0-py310hff52083_0 --> 4.13.0-py310hff52083_1
#   imagecodecs                     2022.2.22-py310h31a0021_5 --> 2022.2.22-py310h3ac3b6e_6
#   imageio                               2.19.2-pyhcf75d05_0 --> 2.19.3-pyhcf75d05_0
#   importlib_resourc~                     5.7.1-pyhd8ed1ab_1 --> 5.8.0-pyhd8ed1ab_0
#   ipykernel          conda-forge/linux-64::ipykernel-6.13.~ --> conda-forge/noarch::ipykernel-6.15.0-pyh210e3f2_0
#   jinja2                                 3.1.2-pyhd8ed1ab_0 --> 3.1.2-pyhd8ed1ab_1
#   jsonschema                             4.5.1-pyhd8ed1ab_0 --> 4.6.0-pyhd8ed1ab_0
#   jupyter_client                         7.3.1-pyhd8ed1ab_0 --> 7.3.4-pyhd8ed1ab_0
#   jupyter_server                        1.17.0-pyhd8ed1ab_0 --> 1.17.1-pyhd8ed1ab_0
#   jupyterlab_widgets                     1.1.0-pyhd8ed1ab_0 --> 1.1.1-pyhd8ed1ab_0
#   kiwisolver                          1.4.2-py310hbf28c38_1 --> 1.4.3-py310hbf28c38_0
#   libarchive                               3.5.2-hb890918_2 --> 3.5.2-hb890918_3
#   libdeflate                                1.10-h7f98852_0 --> 1.12-h166bdaf_0
#   libtiff                                  4.3.0-h0fcbabc_4 --> 4.4.0-hc85c160_1
#   libzlib                                 1.2.12-h166bdaf_0 --> 1.2.12-h166bdaf_1
#   msgpack-python                      1.0.3-py310hbf28c38_1 --> 1.0.4-py310hbf28c38_0
#   nbclient                               0.6.3-pyhd8ed1ab_0 --> 0.6.4-pyhd8ed1ab_1
#   networkx                               2.8.2-pyhd8ed1ab_0 --> 2.8.4-pyhd8ed1ab_0
#   pillow                              9.1.1-py310he619898_0 --> 9.1.1-py310he619898_1
#   pycurl                             7.45.1-py310h2aed498_1 --> 7.45.1-py310h2aed498_2
#   pyzmq                              23.0.0-py310h330234f_0 --> 23.1.0-py310h330234f_0
#   r-dbi                                 1.1.2-r41hc72bb7e_0 --> 1.1.3-r41hc72bb7e_0
#   r-dbplyr                              2.1.1-r41hc72bb7e_0 --> 2.2.0-r41hc72bb7e_0
#   r-dials                               0.1.1-r41hc72bb7e_0 --> 1.0.0-r41hc72bb7e_0
#   r-hardhat                             0.2.0-r41hc72bb7e_0 --> 1.1.0-r41hc72bb7e_0
#   r-infer                               1.0.0-r41hc72bb7e_0 --> 1.0.2-r41hc72bb7e_0
#   r-ipred                              0.9_12-r41hcfec24a_0 --> 0.9_13-r41h06615bd_0
#   r-nlme                              3.1_157-r41h8da6f51_0 --> 3.1_158-r41h8da6f51_0
#   r-parallelly                         1.31.1-r41hc72bb7e_0 --> 1.32.0-r41hc72bb7e_0
#   r-parsnip                             0.2.1-r41hc72bb7e_0 --> 1.0.0-r41hc72bb7e_0
#   r-processx                            3.5.3-r41h06615bd_0 --> 3.6.1-r41h06615bd_0
#   r-progressr                          0.10.0-r41hc72bb7e_0 --> 0.10.1-r41hc72bb7e_0
#   r-proxy                              0.4_26-r41hcfec24a_0 --> 0.4_27-r41h06615bd_0
#   r-ps                                  1.7.0-r41h06615bd_0 --> 1.7.1-r41h06615bd_0
#   r-rcpparmadillo                  0.11.1.1.0-r41h43535f1_0 --> 0.11.2.0.0-r41h9f5de39_0
#   r-tinytex                              0.39-r41hc72bb7e_0 --> 0.40-r41hc72bb7e_0
#   r-yardstick                           0.0.9-r41h03ef668_0 --> 1.0.0-r41h06615bd_0
#   requests                              2.27.1-pyhd8ed1ab_0 --> 2.28.0-pyhd8ed1ab_0
#   setuptools                         62.3.2-py310hff52083_0 --> 62.6.0-py310hff52083_0
#   stack_data                             0.2.0-pyhd8ed1ab_0 --> 0.3.0-pyhd8ed1ab_0
#   traitlets                        5.2.1.post0-pyhd8ed1ab_0 --> 5.3.0-pyhd8ed1ab_0
#   websocket-client                       1.3.2-pyhd8ed1ab_0 --> 1.3.3-pyhd8ed1ab_0
#   zlib                                    1.2.12-h166bdaf_0 --> 1.2.12-h166bdaf_1
#
#
#
# Downloading and Extracting Packages
# libdeflate-1.12      | 78 KB     | ##################################### | 100%
# importlib_resources- | 22 KB     | ##################################### | 100%
# r-hardhat-1.1.0      | 796 KB    | ##################################### | 100%
# kiwisolver-1.4.3     | 75 KB     | ##################################### | 100%
# r-parsnip-1.0.0      | 1.4 MB    | ##################################### | 100%
# certifi-2022.6.15    | 155 KB    | ##################################### | 100%
# websocket-client-1.3 | 41 KB     | ##################################### | 100%
# r-rcpparmadillo-0.11 | 952 KB    | ##################################### | 100%
# conda-4.13.0         | 996 KB    | ##################################### | 100%
# libarchive-3.5.2     | 1.6 MB    | ##################################### | 100%
# alembic-1.8.0        | 137 KB    | ##################################### | 100%
# jupyter_server-1.17. | 236 KB    | ##################################### | 100%
# stack_data-0.3.0     | 23 KB     | ##################################### | 100%
# r-proxy-0.4_27       | 190 KB    | ##################################### | 100%
# babel-2.10.3         | 6.7 MB    | ##################################### | 100%
# r-processx-3.6.1     | 305 KB    | ##################################### | 100%
# pillow-9.1.1         | 44.8 MB   | ##################################### | 100%
# r-tinytex-0.40       | 139 KB    | ##################################### | 100%
# pycurl-7.45.1        | 74 KB     | ##################################### | 100%
# jupyterlab_widgets-1 | 133 KB    | ##################################### | 100%
# traitlets-5.3.0      | 85 KB     | ##################################### | 100%
# colorama-0.4.5       | 18 KB     | ##################################### | 100%
# nbclient-0.6.4       | 65 KB     | ##################################### | 100%
# ipykernel-6.15.0     | 96 KB     | ##################################### | 100%
# zlib-1.2.12          | 91 KB     | ##################################### | 100%
# r-dbplyr-2.2.0       | 1001 KB   | ##################################### | 100%
# imagecodecs-2022.2.2 | 2.6 MB    | ##################################### | 100%
# jupyter_client-7.3.4 | 91 KB     | ##################################### | 100%
# r-dials-1.0.0        | 379 KB    | ##################################### | 100%
# r-infer-1.0.2        | 2.1 MB    | ##################################### | 100%
# jsonschema-4.6.0     | 62 KB     | ##################################### | 100%
# jinja2-3.1.2         | 99 KB     | ##################################### | 100%
# setuptools-62.6.0    | 1.4 MB    | ##################################### | 100%
# r-ps-1.7.1           | 323 KB    | ##################################### | 100%
# imageio-2.19.3       | 3.2 MB    | ##################################### | 100%
# r-nlme-3.1_158       | 2.3 MB    | ##################################### | 100%
# networkx-2.8.4       | 1.6 MB    | ##################################### | 100%
# r-yardstick-1.0.0    | 848 KB    | ##################################### | 100%
# requests-2.28.0      | 52 KB     | ##################################### | 100%
# libzlib-1.2.12       | 63 KB     | ##################################### | 100%
# r-ipred-0.9_13       | 394 KB    | ##################################### | 100%
# pyzmq-23.1.0         | 484 KB    | ##################################### | 100%
# r-dbi-1.1.3          | 754 KB    | ##################################### | 100%
# libtiff-4.4.0        | 638 KB    | ##################################### | 100%
# r-progressr-0.10.1   | 280 KB    | ##################################### | 100%
# msgpack-python-1.0.4 | 88 KB     | ##################################### | 100%
# r-parallelly-1.32.0  | 316 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade jupyterlab-git
# Out:
# /opt/conda/bin/python: No module named pip
# Note: you may need to restart the kernel to use updated packages.

# %%
run:jupyter server extension list
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File /opt/conda/lib/python3.10/site-packages/IPython/core/magics/execution.py:696, in ExecutionMagics.run(self, parameter_s, runner, file_finder)
#     695     fpath = arg_lst[0]
# --> 696     filename = file_finder(fpath)
#     697 except IndexError as e:
#
# File /opt/conda/lib/python3.10/site-packages/IPython/utils/path.py:91, in get_py_filename(name)
#      90 else:
# ---> 91     raise IOError('File `%r` not found.' % name)
#
# OSError: File `':jupyter.py'` not found.
#
# The above exception was the direct cause of the following exception:
#
# Exception                                 Traceback (most recent call last)
# Input In [5], in <cell line: 1>()
# ----> 1 get_ipython().run_line_magic('run', ':jupyter server extension list')
#
# File /opt/conda/lib/python3.10/site-packages/IPython/core/interactiveshell.py:2305, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2303     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2304 with self.builtin_trap:
# -> 2305     result = fn(*args, **kwargs)
#    2306 return result
#
# File /opt/conda/lib/python3.10/site-packages/IPython/core/magics/execution.py:707, in ExecutionMagics.run(self, parameter_s, runner, file_finder)
#     705     if os.name == 'nt' and re.match(r"^'.*'$",fpath):
#     706         warn('For Windows, use double quotes to wrap a filename: %run "mypath\\myfile.py"')
# --> 707     raise Exception(msg) from e
#     708 except TypeError:
#     709     if fpath in sys.meta_path:
#
# Exception: File `':jupyter.py'` not found.
