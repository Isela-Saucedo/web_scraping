# %%
import requests
import bs4
from bs4 import BeautifulSoup
from urllib.parse import urljoin
import pandas as pd

# %%
url_inicial = 'https://argumentos.xoc.uam.mx/index.php/argumentos/issue/archive/4'
url_root = 'https://argumentos.xoc.uam.mx/index.php/argumentos/issue/archive/4'
r=requests.get(url_inicial)

# %%
soup = BeautifulSoup(r.text, 'html.parser')

# %%
box = soup.find('ul', class_='issues_archive')
volumen=box.findAll('div', class_='obj_issue_summary')
vol = [x.find('a').get('href')for x in volumen]
vol=[urljoin(url_root,i) for i in vol]
vol
# Out:
# ['https://argumentos.xoc.uam.mx/index.php/argumentos/issue/view/63',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/issue/view/64',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/issue/view/65',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/issue/view/66',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/issue/view/67',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/issue/view/68',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/issue/view/69',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/issue/view/70',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/issue/view/71',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/issue/view/72',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/issue/view/73',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/issue/view/74',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/issue/view/75',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/issue/view/76',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/issue/view/77',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/issue/view/78',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/issue/view/79',
#  'https://argumentos.xoc.uam.mx/index.php/argumentos/issue/view/80']

# %%
def get_url_items(sopa, url): 
    box = soup.find('ul', class_='issues_archive')
    volumen=box.findAll('div', class_='obj_issue_summary')
    vol = [x.find('a').get('href')for x in volumen]
    vol=[urljoin(url_root,i) for i in vol]
    return vol

# %%
links_items=[]
i=0
while i<1:
    i+=1
    print(f'Estoy en la pagina {url_inicial}')
    r_pag=requests.get(url_inicial)
    s_p=BeautifulSoup(r_pag.text,'html.parser')
    links=get_url_items(s_p, url_inicial)
    links_items.append(links)
# Out:
# Estoy en la pagina https://argumentos.xoc.uam.mx/index.php/argumentos/issue/archive/4

# %%
list_scraper=[]
for i in links_items:
    for j in i:
        list_scraper.append(j)
len(list_scraper)
# Out:
# 18

# %%
uno=list_scraper[0]
r_item=requests.get(uno)
s_item=BeautifulSoup(r_item.text, 'html.parser')

# %%
#funcion para iniciar el escraper de cada libro
def scraper_book(url):
    content_book={}
    r=requests.get(url)
    tire='Argumentos'
    a='V. Ciencias Sociales'
    tem='Social Sciences'
    url='https://argumentos.xoc.uam.mx/index.php/argumentos'
    s_item=BeautifulSoup(r.text,'html.parser')
    #titulo de revista
    try:
        titulo=tire
        content_book['Titulo de revista']=tire
    except AttributeError:
        content_book['Titulo de revista']=None
    #area
    try:
        area=a
        content_book['Área']=a
    except AttributeError:
        content_book['Área']=None
    #tematica
    try:
        tema=tem
        content_book['Temática']=tem
    except AttributeError:
        content_book['Temática']=None
    #titulo libro
    try:
        titu=s_item.find('h2', id='issue-number').get_text(strip=True)
        content_book['Titulo del libro']=titu
    except AttributeError:
        content_book['Titulo del libro']=None
    #resumen
    try:
        resu=s_item.find('a', class_='cover').get_text(strip=True)
        content_book['Resumen']=resu
    except AttributeError:
        content_book['Resumen']=None
    #Link incial
    try:
        inicial=url
        content_book['Link inicial']=url
    except AttributeError:
        content_book['Link inicial']=None
    #link articulo
    try:
        link=s_item.find('a', class_='obj_galley_link pdf').get('href')
        content_book['Link articulo']=urljoin(url_root, link)
    except AttributeError:
        content_book['Link articulo']=None
    return content_book

# %%
list_scraper=list_scraper[0:25]
datos_book=[]
for idx, i in enumerate(list_scraper):
    print(f'estas escrapeando la pag {idx}')
    datos_book.append(scraper_book(i))
# Out:
# estas escrapeando la pag 0
# estas escrapeando la pag 1
# estas escrapeando la pag 2
# estas escrapeando la pag 3
# estas escrapeando la pag 4
# estas escrapeando la pag 5
# estas escrapeando la pag 6
# estas escrapeando la pag 7
# estas escrapeando la pag 8
# estas escrapeando la pag 9
# estas escrapeando la pag 10
# estas escrapeando la pag 11
# estas escrapeando la pag 12
# estas escrapeando la pag 13
# estas escrapeando la pag 14
# estas escrapeando la pag 15
# estas escrapeando la pag 16
# estas escrapeando la pag 17

# %%
df_catalogo=pd.DataFrame(datos_book)
df_catalogo
# Out:
#    Titulo de revista                  Área         Temática  \
# 0         Argumentos  V. Ciencias Sociales  Social Sciences
# 1         Argumentos  V. Ciencias Sociales  Social Sciences
# 2         Argumentos  V. Ciencias Sociales  Social Sciences
# 3         Argumentos  V. Ciencias Sociales  Social Sciences
# 4         Argumentos  V. Ciencias Sociales  Social Sciences
# 5         Argumentos  V. Ciencias Sociales  Social Sciences
# 6         Argumentos  V. Ciencias Sociales  Social Sciences
# 7         Argumentos  V. Ciencias Sociales  Social Sciences
# 8         Argumentos  V. Ciencias Sociales  Social Sciences
# 9         Argumentos  V. Ciencias Sociales  Social Sciences
# 10        Argumentos  V. Ciencias Sociales  Social Sciences
# 11        Argumentos  V. Ciencias Sociales  Social Sciences
# 12        Argumentos  V. Ciencias Sociales  Social Sciences
# 13        Argumentos  V. Ciencias Sociales  Social Sciences
# 14        Argumentos  V. Ciencias Sociales  Social Sciences
# 15        Argumentos  V. Ciencias Sociales  Social Sciences
# 16        Argumentos  V. Ciencias Sociales  Social Sciences
# 17        Argumentos  V. Ciencias Sociales  Social Sciences
#
#                 Titulo del libro Resumen  \
# 0     No. 20, Septiembre de 1994
# 1         No. 19, Agosto de 1993
# 2          No. 18, Abril de 1993
# 3   No. 16-17, Diciembre de 1992
# 4          No. 15, Abril de 1992
# 5      No. 14, Diciembre de 1991
# 6     No. 13, Septiembre de 1991
# 7          No. 12, Abril de 1991
# 8   No. 10-11, Diciembre de 1990
# 9           No. 9, Abril de 1990
# 10      No. 8, Diciembre de 1989
# 11         No. 7, Agosto de 1989
# 12          No. 6, Abril de 1989
# 13      No. 5, Noviembre de 1988
# 14          No. 4, Junio de 1988
# 15          No. 3, Marzo de 1988
# 16      No. 2, Noviembre de 1987
# 17         Núm. 1, Junio de 1987
#
#                                          Link inicial  \
# 0   https://argumentos.xoc.uam.mx/index.php/argume...
# 1   https://argumentos.xoc.uam.mx/index.php/argume...
# 2   https://argumentos.xoc.uam.mx/index.php/argume...
# 3   https://argumentos.xoc.uam.mx/index.php/argume...
# 4   https://argumentos.xoc.uam.mx/index.php/argume...
# 5   https://argumentos.xoc.uam.mx/index.php/argume...
# 6   https://argumentos.xoc.uam.mx/index.php/argume...
# 7   https://argumentos.xoc.uam.mx/index.php/argume...
# 8   https://argumentos.xoc.uam.mx/index.php/argume...
# 9   https://argumentos.xoc.uam.mx/index.php/argume...
# 10  https://argumentos.xoc.uam.mx/index.php/argume...
# 11  https://argumentos.xoc.uam.mx/index.php/argume...
# 12  https://argumentos.xoc.uam.mx/index.php/argume...
# 13  https://argumentos.xoc.uam.mx/index.php/argume...
# 14  https://argumentos.xoc.uam.mx/index.php/argume...
# 15  https://argumentos.xoc.uam.mx/index.php/argume...
# 16  https://argumentos.xoc.uam.mx/index.php/argume...
# 17  https://argumentos.xoc.uam.mx/index.php/argume...
#
#                                         Link articulo
# 0   https://argumentos.xoc.uam.mx/index.php/argume...
# 1   https://argumentos.xoc.uam.mx/index.php/argume...
# 2   https://argumentos.xoc.uam.mx/index.php/argume...
# 3   https://argumentos.xoc.uam.mx/index.php/argume...
# 4   https://argumentos.xoc.uam.mx/index.php/argume...
# 5   https://argumentos.xoc.uam.mx/index.php/argume...
# 6   https://argumentos.xoc.uam.mx/index.php/argume...
# 7   https://argumentos.xoc.uam.mx/index.php/argume...
# 8   https://argumentos.xoc.uam.mx/index.php/argume...
# 9   https://argumentos.xoc.uam.mx/index.php/argume...
# 10  https://argumentos.xoc.uam.mx/index.php/argume...
# 11  https://argumentos.xoc.uam.mx/index.php/argume...
# 12  https://argumentos.xoc.uam.mx/index.php/argume...
# 13  https://argumentos.xoc.uam.mx/index.php/argume...
# 14  https://argumentos.xoc.uam.mx/index.php/argume...
# 15  https://argumentos.xoc.uam.mx/index.php/argume...
# 16  https://argumentos.xoc.uam.mx/index.php/argume...
# 17  https://argumentos.xoc.uam.mx/index.php/argume...

# %%
df_catalogo.to_csv('Revista205.04.csv', index=False)
