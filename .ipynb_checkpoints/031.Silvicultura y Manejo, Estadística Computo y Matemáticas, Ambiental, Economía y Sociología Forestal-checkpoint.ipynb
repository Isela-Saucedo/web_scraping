# %%
import requests
import bs4
from bs4 import BeautifulSoup
from urllib.parse import urljoin
import pandas as pd

# %%
url_inicial = 'https://revistas.chapingo.mx/forestales/'
url_root = 'https://revistas.chapingo.mx/forestales/'
r=requests.get(url_inicial)

# %%
soup = BeautifulSoup(r.text, 'html.parser')

# %%
box = soup.find('div', id='accordionExample')
volumen=box.findAll('div', class_='card')
vol = [x.find('a').get('href')for x in volumen]
vol=[urljoin(url_root,i) for i in vol]
vol
# Out:
# ['https://revistas.chapingo.mx/forestales/?section=articles&subsec=issues&numero=299',
#  'https://revistas.chapingo.mx/forestales/?section=articles&subsec=issues&numero=289',
#  'https://revistas.chapingo.mx/forestales/?section=articles&subsec=issues&numero=279',
#  'https://revistas.chapingo.mx/forestales/?section=articles&subsec=issues&numero=266',
#  'https://revistas.chapingo.mx/forestales/?section=articles&subsec=issues&numero=250',
#  'https://revistas.chapingo.mx/forestales/?section=articles&subsec=issues&numero=233',
#  'https://revistas.chapingo.mx/forestales/?section=articles&subsec=issues&numero=214',
#  'https://revistas.chapingo.mx/forestales/?section=articles&subsec=issues&numero=195',
#  'https://revistas.chapingo.mx/forestales/?section=articles&subsec=issues&numero=167',
#  'https://revistas.chapingo.mx/forestales/?section=articles&subsec=issues&numero=140',
#  'https://revistas.chapingo.mx/forestales/?section=articles&subsec=issues&numero=120',
#  'https://revistas.chapingo.mx/forestales/?section=articles&subsec=issues&numero=105',
#  'https://revistas.chapingo.mx/forestales/?section=articles&subsec=issues&numero=63',
#  'https://revistas.chapingo.mx/forestales/?section=articles&subsec=issues&numero=39',
#  'https://revistas.chapingo.mx/forestales/?section=articles&subsec=issues&numero=37',
#  'https://revistas.chapingo.mx/forestales/?section=articles&subsec=issues&numero=35',
#  'https://revistas.chapingo.mx/forestales/?section=articles&subsec=issues&numero=33',
#  'https://revistas.chapingo.mx/forestales/?section=articles&subsec=issues&numero=31',
#  'https://revistas.chapingo.mx/forestales/?section=articles&subsec=issues&numero=29',
#  'https://revistas.chapingo.mx/forestales/?section=articles&subsec=issues&numero=27',
#  'https://revistas.chapingo.mx/forestales/?section=articles&subsec=issues&numero=25',
#  'https://revistas.chapingo.mx/forestales/?section=articles&subsec=issues&numero=23',
#  'https://revistas.chapingo.mx/forestales/?section=articles&subsec=issues&numero=21',
#  'https://revistas.chapingo.mx/forestales/?section=articles&subsec=issues&numero=211',
#  'https://revistas.chapingo.mx/forestales/?section=articles&subsec=issues&numero=213']

# %%
def get_url_items(sopa, url): 
    box = soup.find('div', id='accordionExample')
    volumen=box.findAll('div', class_='card')
    vol = [x.find('a').get('href')for x in volumen]
    vol=[urljoin(url_root,i) for i in vol]
    return vol

# %%
links_items=[]
i=0
while i<1:
    i+=1
    print(f'Estoy en la pagina {url_inicial}')
    r_pag=requests.get(url_inicial)
    s_p=BeautifulSoup(r_pag.text,'html.parser')
    links=get_url_items(s_p, url_inicial)
    links_items.append(links) 
    #next_a=s_p.select('div.cmp_pagination > a')
    #if not next_a or not next_a[0].get('href'):
     #   break
    #url_inicial = urljoin(url_inicial, next_a[0].get('href'))
# Out:
# Estoy en la pagina https://revistas.chapingo.mx/forestales/

# %%
list_scraper=[]
for i in links_items:
    for j in i:
        list_scraper.append(j)
len(list_scraper)
# Out:
# 25

# %%
uno=list_scraper[0]
r_item=requests.get(uno)
s_item=BeautifulSoup(r_item.text, 'html.parser')

# %%
#funcion para iniciar el escraper de cada libro
def scraper_book(url):
    content_book={}
    r=requests.get(url)
    tire='Acta Botánica Mexicana'
    a='II. Biología y Química'
    tem='Botánica'
    url='http://abm.ojs.inecol.mx/index.php/abm/index'
    s_item=BeautifulSoup(r.text,'html.parser')
    #titulo de revista
    try:
        titulo=tire
        content_book['Titulo de revista']=tire
    except AttributeError:
        content_book['Titulo de revista']=None
    #area
    try:
        area=a
        content_book['Área']=a
    except AttributeError:
        content_book['Área']=None
    #tematica
    try:
        tema=tem
        content_book['Temática']=tem
    except AttributeError:
        content_book['Temática']=None
    #titulo libro
    try:
        titu=s_item.find('h3', class_='titart').get_text(strip=True)
        content_book['Titulo del libro']=titu
    except AttributeError:
        content_book['Titulo del libro']=None
    #resumen
    try:
        resu=s_item.find('div', id='articleAbstract').get_text(strip=True)
        content_book['Resumen']=resu
    except AttributeError:
        content_book['Resumen']=None
    #Link incial
    try:
        inicial=url
        content_book['Link inicial']=url
    except AttributeError:
        content_book['Link inicial']=None
    #link articulo
    try:
        link=s_item.find('a', class_='link-art pr-3').get('href')
        content_book['Link articulo']=urljoin(url_root, link)
    except AttributeError:
        content_book['Link articulo']=None
    return content_book

# %%
list_scraper=list_scraper[0:25]
datos_book=[]
for idx, i in enumerate(list_scraper):
    print(f'estas escrapeando la pag {idx}')
    datos_book.append(scraper_book(i))
# Out:
# estas escrapeando la pag 0
# estas escrapeando la pag 1
# estas escrapeando la pag 2
# estas escrapeando la pag 3
# estas escrapeando la pag 4
# estas escrapeando la pag 5
# estas escrapeando la pag 6
# estas escrapeando la pag 7
# estas escrapeando la pag 8
# estas escrapeando la pag 9
# estas escrapeando la pag 10
# estas escrapeando la pag 11
# estas escrapeando la pag 12
# estas escrapeando la pag 13
# estas escrapeando la pag 14
# estas escrapeando la pag 15
# estas escrapeando la pag 16
# estas escrapeando la pag 17
# estas escrapeando la pag 18
# estas escrapeando la pag 19
# estas escrapeando la pag 20
# estas escrapeando la pag 21
# estas escrapeando la pag 22
# estas escrapeando la pag 23
# estas escrapeando la pag 24

# %%
df_catalogo=pd.DataFrame(datos_book)
df_catalogo
# Out:
#                                               Volumen  \
# 0   Vol. XXVIII, issue 1 , issue   January - April...
# 1   Vol. XXVII, issue 1 , issue   January - April ...
# 2   Vol. XXVI, issue 1 , issue   January - April 2...
# 3    Vol. XXV, issue 1 , issue   January - April 2019
# 4   Vol. XXIV, issue 1 , issue   January - April 2018
# 5   Vol. XXIII, issue 1 , issue   January - April ...
# 6   Vol. XXII, issue 1 , issue   January - April 2016
# 7    Vol. XXI, issue 1 , issue   January - April 2015
# 8     Vol. XX, issue 1 , issue   January - April 2014
# 9    Vol. XIX, issue 1 , issue   January - April 2013
# 10  Vol. XVIII, issue 1 , issue   January - April ...
# 11  Vol. XVII, issue 1 , issue   January - April 2011
# 12    Vol. XVI, issue 1 , issue   January - June 2010
# 13     Vol. XV, issue 1 , issue   January - June 2009
# 14    Vol. XIV, issue 1 , issue   January - June 2008
# 15   Vol. XIII, issue 1 , issue   January - June 2007
# 16    Vol. XII, issue 1 , issue   January - June 2006
# 17     Vol. XI, issue 1 , issue   January - June 2005
# 18      Vol. X, issue 1 , issue   January - June 2004
# 19     Vol. IX, issue 1 , issue   January - June 2003
# 20   Vol. VIII, issue 1 , issue   January - June 2002
# 21    Vol. VII, issue 1 , issue   January - June 2001
# 22     Vol. VI, issue 1 , issue   January - June 2000
# 23      Vol. V, issue 1 , issue   January - June 1999
# 24    Vol. IV, issue 2 , issue   July - December 1998
#
#                                              Articulo  \
# 0   Does the severity of a forest fire modify the ...
# 1   Root growth ofTaxodium mucronatumTen. planted ...
# 2   The color of urban dust as an indicator of hea...
# 3   Economic valuation of three ecosystem services...
# 4   Inoculation with an edible ectomycorrhizal fun...
# 5   Spatio-temporal analysis of forest modeling in...
# 6                                            Foreword
# 7   Macropropagation of Erythrina americanain a gr...
# 8   COMPARATIVE ANALYSIS OF THREE SYNTHETIC UNIT H...
# 9   TRAPPING OFPhytophthora cinnamomiIN OAK FOREST...
# 10  DECOMPOSITION AND NUTRIENT RELEASE PATTERNS OF...
# 11  EVALUATION OF THREE ADHESIVES IN THE MANUFACTU...
# 12  EFFECT OF GAMMA RADIATION ONAbies religiosa(Ku...
# 13  COMPARISONS OF BOLE VOLUME ESTIMATION TECHNIQU...
# 14  PROTEIN POLYMORPHISM INPinus hartwegiiLindl. A...
# 15  EVALUATION OF THE INDICATING CONCENTRATION OF ...
# 16  VEGETATION CHANGES AT THE PILON RIVER SUBBASIN...
# 17  THE GENUSCladocolea(Loranthaceae) IN MEXICO: T...
# 18  EFFECT OF SEEDLING QUALITY, ASPECT AND MICROSI...
# 19            PHYTOALEXINS: A PLANT DEFENSE MECHANISM
# 20  DIAGNOSIS OF THE STATUS OF OFFICIAL FOREST GRE...
# 21                             DEGRADATION OF FORESTS
# 22  SUCCESSION OF ECOLOGICAL GROUPS OF TREES IN A ...
# 23  Fragmentation of habitats and management of pr...
# 24                              The biological window
#
#                                                 Autor  \
# 0   Daniel A. Cadena-Zamudio;Daniel A. Cadena-Zamu...
# 1   Pablo Hernández-López;Pablo Hernández-López×In...
# 2   Rafael García;Rafael García×Institución: Unive...
# 3   Daniela Ruiz-Sandoval;Daniela Ruiz-Sandoval×In...
# 4   José L. Barragán-Soriano;José L. Barragán-Sori...
# 5   Saira Y. Martínez-Santiago;Saira Y. Martínez-S...
# 6   Dante Arturo Rodríguez-TrejoDante Arturo Rodrí...
# 7   Tara C.  Fehling-Fraser;Tara C.  Fehling-Frase...
