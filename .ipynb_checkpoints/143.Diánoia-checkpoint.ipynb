# %%
import requests
import bs4
from bs4 import BeautifulSoup
from urllib.parse import urljoin
import pandas as pd

# %%
url_inicial = 'http://dianoia.filosoficas.unam.mx/index.php/dianoia/issue/archive?issuesPage=3#issues'
url_root = 'http://dianoia.filosoficas.unam.mx/index.php/dianoia/issue/archive?issuesPage=3#issues'
r=requests.get(url_inicial)

# %%
soup = BeautifulSoup(r.text, 'html.parser')

# %%
box = soup.find('div', id='issues')
volumen=box.findAll('div', style='float: left; width: 100%;')
vol = [x.find('a').get('href')for x in volumen]
vol=[urljoin(url_root,i) for i in vol]
vol
# Out:
# ['http://dianoia.filosoficas.unam.mx/index.php/dianoia/issue/view/Volumen%2018%2C%20n%C3%BAmero%2018%2C%20enero%201972',
#  'http://dianoia.filosoficas.unam.mx/index.php/dianoia/issue/view/Volumen%2017%2C%20n%C3%BAmero%2017%2C%20enero%201971',
#  'http://dianoia.filosoficas.unam.mx/index.php/dianoia/issue/view/Volumen%2016%2C%20n%C3%BAmero%2016%2C%20enero%201970',
#  'http://dianoia.filosoficas.unam.mx/index.php/dianoia/issue/view/Volumen%2015%2C%20n%C3%BAmero%2015%2C%20enero%201969',
#  'http://dianoia.filosoficas.unam.mx/index.php/dianoia/issue/view/Volumen%2014%2C%20n%C3%BAmero%2014%2C%20enero%201968',
#  'http://dianoia.filosoficas.unam.mx/index.php/dianoia/issue/view/Volumen%2013%2C%20n%C3%BAmero%2013%2C%20enero%201967',
#  'http://dianoia.filosoficas.unam.mx/index.php/dianoia/issue/view/Volumen%2012%2C%20n%C3%BAmero%2012%2C%20enero%201966',
#  'http://dianoia.filosoficas.unam.mx/index.php/dianoia/issue/view/Volumen%2011%2C%20n%C3%BAmero%2011%2C%20enero%201965',
# ...

# %%
def get_url_items(sopa, url): 
    box = soup.find('div', id='issues')
    volumen=box.findAll('div', style='float: left; width: 100%;')
    vol = [x.find('a').get('href')for x in volumen]
    vol=[urljoin(url_root,i) for i in vol]
    return vol

# %%
links_items=[]
i=0
while i<1:
    i+=1
    print(f'Estoy en la pagina {url_inicial}')
    r_pag=requests.get(url_inicial)
    s_p=BeautifulSoup(r_pag.text,'html.parser')
    links=get_url_items(s_p, url_inicial)
    links_items.append(links)
# Out:
# Estoy en la pagina http://dianoia.filosoficas.unam.mx/index.php/dianoia/issue/archive?issuesPage=3#issues

# %%
list_scraper=[]
for i in links_items:
    for j in i:
        list_scraper.append(j)
len(list_scraper)
# Out:
# 18

# %%
uno=list_scraper[0]
r_item=requests.get(uno)
s_item=BeautifulSoup(r_item.text, 'html.parser')

# %%
#funcion para iniciar el escraper de cada libro
def scraper_book(url):
    content_book={}
    r=requests.get(url)
    tire='Diánoia'
    a='IV. Humanidades y Ciencias de la Conducta'
    tem='Filosofía'
    url='http://dianoia.filosoficas.unam.mx'
    s_item=BeautifulSoup(r.text,'html.parser')
    #titulo de revista
    try:
        titulo=tire
        content_book['Titulo de revista']=tire
    except AttributeError:
        content_book['Titulo de revista']=None
    #area
    try:
        area=a
        content_book['Área']=a
    except AttributeError:
        content_book['Área']=None
    #tematica
    try:
        tema=tem
        content_book['Temática']=tem
    except AttributeError:
        content_book['Temática']=None
    #titulo libro
    try:
        titu=s_item.find('div', class_='tocTitle').get_text(strip=True)
        content_book['Titulo del libro']=titu
    except AttributeError:
        content_book['Titulo del libro']=None
    #resumen
    try:
        resu=s_item.find('a', class_='cover').get_text(strip=True)
        content_book['Resumen']=resu
    except AttributeError:
        content_book['Resumen']=None
    #Link incial
    try:
        inicial=url
        content_book['Link inicial']=url
    except AttributeError:
        content_book['Link inicial']=None
    #link articulo
    try:
        link=s_item.find('a', class_='file').get('href')
        content_book['Link articulo']=urljoin(url_root, link)
    except AttributeError:
        content_book['Link articulo']=None
    return content_book

# %%
list_scraper=list_scraper[0:18]
datos_book=[]
for idx, i in enumerate(list_scraper):
    print(f'estas escrapeando la pag {idx}')
    datos_book.append(scraper_book(i))
# Out:
# estas escrapeando la pag 0
# estas escrapeando la pag 1
# estas escrapeando la pag 2
# estas escrapeando la pag 3
# estas escrapeando la pag 4
# estas escrapeando la pag 5
# estas escrapeando la pag 6
# estas escrapeando la pag 7
# estas escrapeando la pag 8
# estas escrapeando la pag 9
# estas escrapeando la pag 10
# estas escrapeando la pag 11
# estas escrapeando la pag 12
# estas escrapeando la pag 13
# estas escrapeando la pag 14
# estas escrapeando la pag 15
# estas escrapeando la pag 16
# estas escrapeando la pag 17

# %%
df_catalogo=pd.DataFrame(datos_book)
df_catalogo
# Out:
#    Titulo de revista                                       Área   Temática  \
# 0            Diánoia  IV. Humanidades y Ciencias de la Conducta  Filosofía
# 1            Diánoia  IV. Humanidades y Ciencias de la Conducta  Filosofía
# 2            Diánoia  IV. Humanidades y Ciencias de la Conducta  Filosofía
# 3            Diánoia  IV. Humanidades y Ciencias de la Conducta  Filosofía
# 4            Diánoia  IV. Humanidades y Ciencias de la Conducta  Filosofía
# 5            Diánoia  IV. Humanidades y Ciencias de la Conducta  Filosofía
# 6            Diánoia  IV. Humanidades y Ciencias de la Conducta  Filosofía
# 7            Diánoia  IV. Humanidades y Ciencias de la Conducta  Filosofía
# 8            Diánoia  IV. Humanidades y Ciencias de la Conducta  Filosofía
# 9            Diánoia  IV. Humanidades y Ciencias de la Conducta  Filosofía
# 10           Diánoia  IV. Humanidades y Ciencias de la Conducta  Filosofía
# ...

# %%
df_catalogo.to_csv('Revista143.03.csv', index=False)
