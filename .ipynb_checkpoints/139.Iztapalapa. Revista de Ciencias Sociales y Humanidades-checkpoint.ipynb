# %%
import requests
import bs4
from bs4 import BeautifulSoup
from urllib.parse import urljoin
import pandas as pd

# %%
url_inicial = 'http://revistaiztapalapa.izt.uam.mx/index.php/izt/issue/archive'
url_root = 'http://revistaiztapalapa.izt.uam.mx/index.php/izt/issue/archive'
r=requests.get(url_inicial)

# %%
soup = BeautifulSoup(r.text, 'html.parser')

# %%
box = soup.find('div', id='issues')
volumen=box.findAll('div', style='float: left; width: 100%;')
vol = [x.find('a').get('href')for x in volumen]
vol=[urljoin(url_root,i) for i in vol]
vol
# Out:
# ['https://revistaiztapalapa.izt.uam.mx/index.php/izt/issue/view/Gentrificaci%C3%B3n%20en%20ciudades%20mexicanas',
#  'https://revistaiztapalapa.izt.uam.mx/index.php/izt/issue/view/Un%20archivo%20de%20cine%20etnogr%C3%A1fico%20mexicano',
#  'https://revistaiztapalapa.izt.uam.mx/index.php/izt/issue/view/Retos%20de%20los%20estudios%20literarios',
#  'https://revistaiztapalapa.izt.uam.mx/index.php/izt/issue/view/%C2%BFGobernar%20mediante%20normas%20privadas%3F%20Transformaciones%20de%20la%20gobernanza%20de%20los%20recursos%20naturales%20en%20M%C3%A9xico%20y%20Am%C3%A9rica%20Central',
#  'https://revistaiztapalapa.izt.uam.mx/index.php/izt/issue/view/2',
#  'https://revistaiztapalapa.izt.uam.mx/index.php/izt/issue/view/4',
#  'https://revistaiztapalapa.izt.uam.mx/index.php/izt/issue/view/N%C3%BAm.%2081%20%282016%29%3A%20Miscel%C3%A1nea',
# ...

# %%
def get_url_items(sopa, url): 
    box = soup.find('div', id='issues')
    volumen=box.findAll('div', style='float: left; width: 100%;')
    vol = [x.find('a').get('href')for x in volumen]
    vol=[urljoin(url_root,i) for i in vol]
    return vol

# %%
links_items=[]
i=0
while i<1:
    i+=1
    print(f'Estoy en la pagina {url_inicial}')
    r_pag=requests.get(url_inicial)
    s_p=BeautifulSoup(r_pag.text,'html.parser')
    links=get_url_items(s_p, url_inicial)
    links_items.append(links)
# Out:
# Estoy en la pagina http://revistaiztapalapa.izt.uam.mx/index.php/izt/issue/archive

# %%
list_scraper=[]
for i in links_items:
    for j in i:
        list_scraper.append(j)
len(list_scraper)
# Out:
# 43

# %%
uno=list_scraper[0]
r_item=requests.get(uno)
s_item=BeautifulSoup(r_item.text, 'html.parser')

# %%
#funcion para iniciar el escraper de cada libro
def scraper_book(url):
    content_book={}
    r=requests.get(url)
    tire='Iztapalapa. Revista de Ciencias Sociales y Humanidades'
    a='V. Ciencias Sociales'
    tem='Transdisciplinariedades Sociales'
    url='http://revistaiztapalapa.izt.uam.mx/index.php/izt/issue/archive'
    s_item=BeautifulSoup(r.text,'html.parser')
    #titulo de revista
    try:
        titulo=tire
        content_book['Titulo de revista']=tire
    except AttributeError:
        content_book['Titulo de revista']=None
    #area
    try:
        area=a
        content_book['Área']=a
    except AttributeError:
        content_book['Área']=None
    #tematica
    try:
        tema=tem
        content_book['Temática']=tem
    except AttributeError:
        content_book['Temática']=None
    #titulo libro
    try:
        titu=s_item.find('h3').get_text(strip=True)
        content_book['Titulo del libro']=titu
    except AttributeError:
        content_book['Titulo del libro']=None
    #resumen
    try:
        resu=s_item.find('a', class_='cover').get_text(strip=True)
        content_book['Resumen']=resu
    except AttributeError:
        content_book['Resumen']=None
    #Link incial
    try:
        inicial=url
        content_book['Link inicial']=url
    except AttributeError:
        content_book['Link inicial']=None
    #link articulo
    try:
        link=s_item.find('a', class_='current').get('href')
        content_book['Link articulo']=urljoin(url_root, link)
    except AttributeError:
        content_book['Link articulo']=None
    return content_book

# %%
list_scraper=list_scraper[0:43]
datos_book=[]
for idx, i in enumerate(list_scraper):
    print(f'estas escrapeando la pag {idx}')
    datos_book.append(scraper_book(i))
# Out:
# estas escrapeando la pag 0
# estas escrapeando la pag 1
# estas escrapeando la pag 2
# estas escrapeando la pag 3
# estas escrapeando la pag 4
# estas escrapeando la pag 5
# estas escrapeando la pag 6
# estas escrapeando la pag 7
# estas escrapeando la pag 8
# estas escrapeando la pag 9
# estas escrapeando la pag 10
# estas escrapeando la pag 11
# estas escrapeando la pag 12
# estas escrapeando la pag 13
# estas escrapeando la pag 14
# estas escrapeando la pag 15
# estas escrapeando la pag 16
# estas escrapeando la pag 17
# estas escrapeando la pag 18
# estas escrapeando la pag 19
# estas escrapeando la pag 20
# estas escrapeando la pag 21
# estas escrapeando la pag 22
# estas escrapeando la pag 23
# estas escrapeando la pag 24
# estas escrapeando la pag 25
# estas escrapeando la pag 26
# estas escrapeando la pag 27
# estas escrapeando la pag 28
# estas escrapeando la pag 29
# estas escrapeando la pag 30
# estas escrapeando la pag 31
# estas escrapeando la pag 32
# ...

# %%
df_catalogo=pd.DataFrame(datos_book)
df_catalogo
# Out:
#                                     Titulo de revista                  Área  \
# 0   Iztapalapa. Revista de Ciencias Sociales y Hum...  V. Ciencias Sociales
# 1   Iztapalapa. Revista de Ciencias Sociales y Hum...  V. Ciencias Sociales
# 2   Iztapalapa. Revista de Ciencias Sociales y Hum...  V. Ciencias Sociales
# 3   Iztapalapa. Revista de Ciencias Sociales y Hum...  V. Ciencias Sociales
# 4   Iztapalapa. Revista de Ciencias Sociales y Hum...  V. Ciencias Sociales
# 5   Iztapalapa. Revista de Ciencias Sociales y Hum...  V. Ciencias Sociales
# 6   Iztapalapa. Revista de Ciencias Sociales y Hum...  V. Ciencias Sociales
# 7   Iztapalapa. Revista de Ciencias Sociales y Hum...  V. Ciencias Sociales
# 8   Iztapalapa. Revista de Ciencias Sociales y Hum...  V. Ciencias Sociales
# 9   Iztapalapa. Revista de Ciencias Sociales y Hum...  V. Ciencias Sociales
# 10  Iztapalapa. Revista de Ciencias Sociales y Hum...  V. Ciencias Sociales
# ...

# %%
df_catalogo.to_csv('Revista139.csv', index=False)
