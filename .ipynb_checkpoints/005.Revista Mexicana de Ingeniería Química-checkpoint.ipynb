# %%
import requests
import bs4
from bs4 import BeautifulSoup
from urllib.parse import urljoin
import pandas as pd

# %%
url_inicial = 'http://www.rmiq.org/ojs311/index.php/rmiq/issue/archive'
url_root = 'http://www.rmiq.org/ojs311/index.php/rmiq/issue/archive'

# %%
r=requests.get(url_inicial)

# %%
soup = BeautifulSoup(r.text, 'html.parser')

# %%
lista_articulo = soup.find_all('div', class_='obj_issue_summary')
links_libros = [x.find('a').get('href') for x in lista_articulo]
links_libros = [urljoin (url_root, i) for i in links_libros]
links_libros
# Out:
# ['http://www.rmiq.org/ojs311/index.php/rmiq/issue/view/65',
#  'http://www.rmiq.org/ojs311/index.php/rmiq/issue/view/64',
#  'http://www.rmiq.org/ojs311/index.php/rmiq/issue/view/63',
#  'http://www.rmiq.org/ojs311/index.php/rmiq/issue/view/62',
#  'http://www.rmiq.org/ojs311/index.php/rmiq/issue/view/60',
#  'http://www.rmiq.org/ojs311/index.php/rmiq/issue/view/56',
#  'http://www.rmiq.org/ojs311/index.php/rmiq/issue/view/57',
#  'http://www.rmiq.org/ojs311/index.php/rmiq/issue/view/58',
#  'http://www.rmiq.org/ojs311/index.php/rmiq/issue/view/54',
#  'http://www.rmiq.org/ojs311/index.php/rmiq/issue/view/55',
#  'http://www.rmiq.org/ojs311/index.php/rmiq/issue/view/53',
#  'http://www.rmiq.org/ojs311/index.php/rmiq/issue/view/50',
#  'http://www.rmiq.org/ojs311/index.php/rmiq/issue/view/51',
#  'http://www.rmiq.org/ojs311/index.php/rmiq/issue/view/52',
#  'http://www.rmiq.org/ojs311/index.php/rmiq/issue/view/48',
#  'http://www.rmiq.org/ojs311/index.php/rmiq/issue/view/46',
#  'http://www.rmiq.org/ojs311/index.php/rmiq/issue/view/47',
#  'http://www.rmiq.org/ojs311/index.php/rmiq/issue/view/49',
#  'http://www.rmiq.org/ojs311/index.php/rmiq/issue/view/43',
#  'http://www.rmiq.org/ojs311/index.php/rmiq/issue/view/44',
#  'http://www.rmiq.org/ojs311/index.php/rmiq/issue/view/45',
#  'http://www.rmiq.org/ojs311/index.php/rmiq/issue/view/39',
#  'http://www.rmiq.org/ojs311/index.php/rmiq/issue/view/40',
#  'http://www.rmiq.org/ojs311/index.php/rmiq/issue/view/41',
#  'http://www.rmiq.org/ojs311/index.php/rmiq/issue/view/36',
#  'http://www.rmiq.org/ojs311/index.php/rmiq/issue/view/37',
#  'http://www.rmiq.org/ojs311/index.php/rmiq/issue/view/38',
#  'http://www.rmiq.org/ojs311/index.php/rmiq/issue/view/33',
#  'http://www.rmiq.org/ojs311/index.php/rmiq/issue/view/34',
#  'http://www.rmiq.org/ojs311/index.php/rmiq/issue/view/35',
#  'http://www.rmiq.org/ojs311/index.php/rmiq/issue/view/30',
#  'http://www.rmiq.org/ojs311/index.php/rmiq/issue/view/31',
#  'http://www.rmiq.org/ojs311/index.php/rmiq/issue/view/32',
#  'http://www.rmiq.org/ojs311/index.php/rmiq/issue/view/25',
#  'http://www.rmiq.org/ojs311/index.php/rmiq/issue/view/28',
#  'http://www.rmiq.org/ojs311/index.php/rmiq/issue/view/29',
#  'http://www.rmiq.org/ojs311/index.php/rmiq/issue/view/22',
#  'http://www.rmiq.org/ojs311/index.php/rmiq/issue/view/23',
#  'http://www.rmiq.org/ojs311/index.php/rmiq/issue/view/24',
#  'http://www.rmiq.org/ojs311/index.php/rmiq/issue/view/19',
#  'http://www.rmiq.org/ojs311/index.php/rmiq/issue/view/20',
#  'http://www.rmiq.org/ojs311/index.php/rmiq/issue/view/21',
#  'http://www.rmiq.org/ojs311/index.php/rmiq/issue/view/16',
#  'http://www.rmiq.org/ojs311/index.php/rmiq/issue/view/18',
#  'http://www.rmiq.org/ojs311/index.php/rmiq/issue/view/12',
#  'http://www.rmiq.org/ojs311/index.php/rmiq/issue/view/8',
#  'http://www.rmiq.org/ojs311/index.php/rmiq/issue/view/9',
#  'http://www.rmiq.org/ojs311/index.php/rmiq/issue/view/27',
#  'http://www.rmiq.org/ojs311/index.php/rmiq/issue/view/26',
#  'http://www.rmiq.org/ojs311/index.php/rmiq/issue/view/15',
#  'http://www.rmiq.org/ojs311/index.php/rmiq/issue/view/11',
#  'http://www.rmiq.org/ojs311/index.php/rmiq/issue/view/7',
#  'http://www.rmiq.org/ojs311/index.php/rmiq/issue/view/6',
#  'http://www.rmiq.org/ojs311/index.php/rmiq/issue/view/5',
#  'http://www.rmiq.org/ojs311/index.php/rmiq/issue/view/4',
#  'http://www.rmiq.org/ojs311/index.php/rmiq/issue/view/3',
#  'http://www.rmiq.org/ojs311/index.php/rmiq/issue/view/2',
#  'http://www.rmiq.org/ojs311/index.php/rmiq/issue/view/1',
#  'http://www.rmiq.org/ojs311/index.php/rmiq/issue/view/10',
#  'http://www.rmiq.org/ojs311/index.php/rmiq/issue/view/14',
#  'http://www.rmiq.org/ojs311/index.php/rmiq/issue/view/13',
#  'http://www.rmiq.org/ojs311/index.php/rmiq/issue/view/17',
#  'http://www.rmiq.org/ojs311/index.php/rmiq/issue/view/59']

# %%
def get_url_items(soup,url):
    lista_articulo = soup.find_all('div', class_='obj_issue_summary')
    links_libros = [x.find('a').get('href') for x in lista_articulo]
    links_libros = [urljoin (url_root, i) for i in links_libros]
    return links_libros

# %%
links_items=[]
i = 0
while i<1:
    i+=1
    print(f'Estoy en la pagina {url_inicial}')
    r_pag = requests.get(url_inicial)
    s_p = BeautifulSoup(r_pag.text, 'html.parser')
    links = get_url_items(s_p, url_inicial)
    links_items.append(links)
    #next_a = s_p.select('li.page-item > a')
    #if not next_a or not next_a[0].get('href'):
     #   break
      #  url_inicial = urljoin(url_inicial, next_a[0].get('href'))
# Out:
# Estoy en la pagina http://www.rmiq.org/ojs311/index.php/rmiq/issue/archive

# %%
list_scraper=[]
for i in links_items:
    for j in i:
        list_scraper.append(j)
len(list_scraper)
# Out:
# 63

# %%
uno=list_scraper[0]
r_item=requests.get(uno)
s_item=BeautifulSoup(r_item.text, 'html.parser')

# %%
#funcion para iniciar el escraper de cada libro
def scraper_book(url):
    content_book={}
    r=requests.get(url)
    tire='Revista Mexicana de Ingeniería Química'
    a='VII. Ingenierías'
    tem='Ingeniería Química y sus interfaces con otras disciplinas de la Ingeniería: Termodinámica Catálisis, Cinética y Reactores; Simulación y Control; Fenómenos de Transporte; Seguridad; Ingeniería de Procesos; Biotecnología; Ingeniería de Alimentos'
    url='http://www.rmiq.org/'
    s_item=BeautifulSoup(r.text,'html.parser')
    #titulo de revista
    try:
        titulo=tire
        content_book['Titulo de revista']=tire
    except AttributeError:
        content_book['Titulo de revista']=None
    #area
    try:
        area=a
        content_book['Área']=a
    except AttributeError:
        content_book['Área']=None
    #tematica
    try:
        tema=tem
        content_book['Temática']=tem
    except AttributeError:
        content_book['Temática']=None
    #titulo libro
    try:
        titu=s_item.find('li', class_='current').get_text(strip=True)
        content_book['Titulo del libro']=titu
    except AttributeError:
        content_book['Titulo del libro']=None
    #resumen
    try:
        resu=s_item.find('p').get_text(strip=True)
        content_book['Resumen']=resu
    except AttributeError:
        content_book['Resumen']=None
    #Link incial
    try:
        inicial=url
        content_book['Link inicial']=url
    except AttributeError:
        content_book['Link inicial']=None
    #link articulo
    try:
        link=s_item.find('a', class_='obj_galley_link pdf').get('href')
        content_book['Link articulo']=urljoin(url_root, link)
    except AttributeError:
        content_book['Link articulo']=None
    return content_book

# %%
list_scraper=list_scraper[0:63]
datos_book=[]
for idx, i in enumerate(list_scraper):
    print(f'estas escrapeando la pag {idx}')
    datos_book.append(scraper_book(i))
# Out:
# estas escrapeando la pag 0
# estas escrapeando la pag 1
# estas escrapeando la pag 2
# estas escrapeando la pag 3
# estas escrapeando la pag 4
# estas escrapeando la pag 5
# estas escrapeando la pag 6
# estas escrapeando la pag 7
# estas escrapeando la pag 8
# estas escrapeando la pag 9
# estas escrapeando la pag 10
# estas escrapeando la pag 11
# estas escrapeando la pag 12
# estas escrapeando la pag 13
# estas escrapeando la pag 14
# estas escrapeando la pag 15
# estas escrapeando la pag 16
# estas escrapeando la pag 17
# estas escrapeando la pag 18
# estas escrapeando la pag 19
# estas escrapeando la pag 20
# estas escrapeando la pag 21
# estas escrapeando la pag 22
# estas escrapeando la pag 23
# estas escrapeando la pag 24
# estas escrapeando la pag 25
# estas escrapeando la pag 26
# estas escrapeando la pag 27
# estas escrapeando la pag 28
# estas escrapeando la pag 29
# estas escrapeando la pag 30
# estas escrapeando la pag 31
# estas escrapeando la pag 32
# estas escrapeando la pag 33
# estas escrapeando la pag 34
# estas escrapeando la pag 35
# estas escrapeando la pag 36
# estas escrapeando la pag 37
# estas escrapeando la pag 38
# estas escrapeando la pag 39
# estas escrapeando la pag 40
# estas escrapeando la pag 41
# estas escrapeando la pag 42
# estas escrapeando la pag 43
# estas escrapeando la pag 44
# estas escrapeando la pag 45
# estas escrapeando la pag 46
# estas escrapeando la pag 47
# estas escrapeando la pag 48
# estas escrapeando la pag 49
# estas escrapeando la pag 50
# estas escrapeando la pag 51
# estas escrapeando la pag 52
# estas escrapeando la pag 53
# estas escrapeando la pag 54
# estas escrapeando la pag 55
# estas escrapeando la pag 56
# estas escrapeando la pag 57
# estas escrapeando la pag 58
# estas escrapeando la pag 59
# estas escrapeando la pag 60
# estas escrapeando la pag 61
# estas escrapeando la pag 62

# %%
df_catalogo=pd.DataFrame(datos_book)
df_catalogo
# Out:
#                          Titulo de revista              Área  \
# 0   Revista Mexicana de Ingeniería Química  VII. Ingenierías
# 1   Revista Mexicana de Ingeniería Química  VII. Ingenierías
# 2   Revista Mexicana de Ingeniería Química  VII. Ingenierías
# 3   Revista Mexicana de Ingeniería Química  VII. Ingenierías
# 4   Revista Mexicana de Ingeniería Química  VII. Ingenierías
# ..                                     ...               ...
# 58  Revista Mexicana de Ingeniería Química  VII. Ingenierías
# 59  Revista Mexicana de Ingeniería Química  VII. Ingenierías
# 60  Revista Mexicana de Ingeniería Química  VII. Ingenierías
# 61  Revista Mexicana de Ingeniería Química  VII. Ingenierías
# 62  Revista Mexicana de Ingeniería Química  VII. Ingenierías
#
#                                              Temática  \
# 0   Ingeniería Química y sus interfaces con otras ...
# 1   Ingeniería Química y sus interfaces con otras ...
# 2   Ingeniería Química y sus interfaces con otras ...
# 3   Ingeniería Química y sus interfaces con otras ...
# 4   Ingeniería Química y sus interfaces con otras ...
# ..                                                ...
# 58  Ingeniería Química y sus interfaces con otras ...
# 59  Ingeniería Química y sus interfaces con otras ...
# 60  Ingeniería Química y sus interfaces con otras ...
# 61  Ingeniería Química y sus interfaces con otras ...
# 62  Ingeniería Química y sus interfaces con otras ...
#
#                                   Titulo del libro  \
# 0                   Vol 21 No 2 (2022): May-August
# 1          Vol 21 No 1 (2022): January-April, 2022
# 2     Vol 20 No 3 (2021): September-December, 2021
# 3              Vol 20 No 2 (2021): May-August 2021
# 4      Vol 1 No 3 (2002): September-December, 2002
# ..                                             ...
# 58  Vol 16 No 3 (2017): September - December, 2017
# 59     Vol 15 No 3 (2016): September-December 2016
# 60             Vol 15 No 2 (2016): May-August 2016
# 61            Vol 14 No 2 (2015): May-August, 2015
# 62          Vol 1 No 1 (2002): January-April, 2002
#
#                                               Resumen          Link inicial  \
# 0   REVISTA MEXICANA DE INGENIERIA QUIMICA, Vol. 2...  http://www.rmiq.org/
# 1   REVISTA MEXICANA DE INGENIERIA QUIMICA, Vol. 2...  http://www.rmiq.org/
# 2   REVISTA MEXICANA DE INGENIERIA QUIMICA, Vol. 2...  http://www.rmiq.org/
# 3   REVISTA MEXICANA DE INGENIERIA QUIMICA, Vol. 2...  http://www.rmiq.org/
# 4                                                None  http://www.rmiq.org/
# ..                                                ...                   ...
# 58  REVISTA MEXICANA DE INGENIERIA QUIMICA, Vol. 1...  http://www.rmiq.org/
# 59  REVISTA MEXICANA DE INGENIERIA QUIMICA, Vol. 1...  http://www.rmiq.org/
# 60  REVISTA MEXICANA DE INGENIERIA QUIMICA, Vol. 1...  http://www.rmiq.org/
# 61  REVISTA MEXICANA DE INGENIERIA QUIMICA, Vol. 1...  http://www.rmiq.org/
# 62                                               None  http://www.rmiq.org/
#
#                                         Link articulo
# 0   http://www.rmiq.org/ojs311/index.php/rmiq/arti...
# 1   http://www.rmiq.org/ojs311/index.php/rmiq/arti...
# 2   http://www.rmiq.org/ojs311/index.php/rmiq/arti...
# 3   http://www.rmiq.org/ojs311/index.php/rmiq/arti...
# 4   http://www.rmiq.org/ojs311/index.php/rmiq/arti...
# ..                                                ...
# 58  http://www.rmiq.org/ojs311/index.php/rmiq/arti...
# 59  http://www.rmiq.org/ojs311/index.php/rmiq/arti...
# 60  http://www.rmiq.org/ojs311/index.php/rmiq/arti...
# 61  http://www.rmiq.org/ojs311/index.php/rmiq/arti...
# 62  http://www.rmiq.org/ojs311/index.php/rmiq/arti...
#
# [63 rows x 7 columns]

# %%
df_catalogo.to_csv('Revista05.csv', index=False)
