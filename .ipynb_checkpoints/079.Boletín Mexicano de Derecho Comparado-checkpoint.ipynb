# %%
import requests
import bs4
from bs4 import BeautifulSoup
from urllib.parse import urljoin
import pandas as pd

# %%
url_inicial = 'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/archive'
url_root = 'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/archive'
r=requests.get(url_inicial)

# %%
soup = BeautifulSoup(r.text, 'html.parser')

# %%
box = soup.find('div', class_='issues media-list')
volumen=box.findAll('div', class_='issue-summary media')
vol = [x.find('a').get('href')for x in volumen]
vol=[urljoin(url_root,i) for i in vol]
vol
# Out:
# ['https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/676',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/664',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/661',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/659',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/653',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/650',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/645',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/626',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/605',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/614',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/598',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/582',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/570',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/562',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/552',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/544',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/537',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/179',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/177',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/176',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/175',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/174',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/173',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/172',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/171',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/170',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/169',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/168',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/167',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/166',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/165',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/164',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/163',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/162',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/161',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/160',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/159',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/137',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/136',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/135',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/134',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/133',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/132',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/131',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/130',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/129',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/128',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/127',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/126',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/125',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/124',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/123',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/122',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/121',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/120',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/119',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/118',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/117',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/116',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/113',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/112',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/111',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/110',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/109',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/108',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/107',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/106',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/105',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/104',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/103',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/102',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/101',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/100',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/99',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/98',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/97',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/96',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/95',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/94',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/93',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/92',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/91',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/90',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/89',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/88',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/87',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/86',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/85',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/84',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/83',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/82',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/81',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/80',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/79',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/78',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/77',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/76',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/75',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/74',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/73',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/72',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/71',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/70',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/69',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/68',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/67',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/66',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/65',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/64',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/63',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/62',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/61',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/60',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/59',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/58',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/57',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/56',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/55',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/54',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/53',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/52',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/51',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/50',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/49',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/48',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/47',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/46',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/45',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/44',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/43',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/42',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/41',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/40',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/39',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/38',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/37',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/36',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/35',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/34',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/33',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/32',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/31',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/30',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/29',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/28',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/27',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/26',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/25',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/24',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/23',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/22',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/21',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/20',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/19',
#  'https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/view/18']

# %%
def get_url_items(sopa, url): 
    box = soup.find('div', class_='issues media-list')
    volumen=box.findAll('div', class_='issue-summary media')
    vol = [x.find('a').get('href')for x in volumen]
    vol=[urljoin(url_root,i) for i in vol]
    return vol

# %%
links_items=[]
i=0
while i<1:
    i+=1
    print(f'Estoy en la pagina {url_inicial}')
    r_pag=requests.get(url_inicial)
    s_p=BeautifulSoup(r_pag.text,'html.parser')
    links=get_url_items(s_p, url_inicial)
    links_items.append(links)
# Out:
# Estoy en la pagina https://revistas.juridicas.unam.mx/index.php/derecho-comparado/issue/archive

# %%
list_scraper=[]
for i in links_items:
    for j in i:
        list_scraper.append(j)
len(list_scraper)
# Out:
# 155

# %%
uno=list_scraper[0]
r_item=requests.get(uno)
s_item=BeautifulSoup(r_item.text, 'html.parser')

# %%
#funcion para iniciar el escraper de cada libro
def scraper_book(url):
    content_book={}
    r=requests.get(url)
    tire='Boletín Mexicano de Derecho Comparado'
    a='V. Ciencias Sociales'
    tem='Derecho'
    url='https://revistas.juridicas.unam.mx/index.php/derecho-comparado'
    s_item=BeautifulSoup(r.text,'html.parser')
    #titulo de revista
    try:
        titulo=tire
        content_book['Titulo de revista']=tire
    except AttributeError:
        content_book['Titulo de revista']=None
    #area
    try:
        area=a
        content_book['Área']=a
    except AttributeError:
        content_book['Área']=None
    #tematica
    try:
        tema=tem
        content_book['Temática']=tem
    except AttributeError:
        content_book['Temática']=None
    #titulo libro
    try:
        titu=s_item.find('li', class_='active').get_text(strip=True)
        content_book['Titulo del libro']=titu
    except AttributeError:
        content_book['Titulo del libro']=None
    #resumen
    try:
        resu=s_item.find('a', class_='cover').get_text(strip=True)
        content_book['Resumen']=resu
    except AttributeError:
        content_book['Resumen']=None
    #Link incial
    try:
        inicial=url
        content_book['Link inicial']=url
    except AttributeError:
        content_book['Link inicial']=None
    #link articulo
    try:
        link=s_item.find('a', class_='galley-link btn btn-primary pdf').get('href')
        content_book['Link articulo']=urljoin(url_root, link)
    except AttributeError:
        content_book['Link articulo']=None
    return content_book

# %%
list_scraper=list_scraper[0:155]
datos_book=[]
for idx, i in enumerate(list_scraper):
    print(f'estas escrapeando la pag {idx}')
    datos_book.append(scraper_book(i))
# Out:
# estas escrapeando la pag 0
# estas escrapeando la pag 1
# estas escrapeando la pag 2
# estas escrapeando la pag 3
# estas escrapeando la pag 4
# estas escrapeando la pag 5
# estas escrapeando la pag 6
# estas escrapeando la pag 7
# estas escrapeando la pag 8
# estas escrapeando la pag 9
# estas escrapeando la pag 10
# estas escrapeando la pag 11
# estas escrapeando la pag 12
# estas escrapeando la pag 13
# estas escrapeando la pag 14
# estas escrapeando la pag 15
# estas escrapeando la pag 16
# estas escrapeando la pag 17
# estas escrapeando la pag 18
# estas escrapeando la pag 19
# estas escrapeando la pag 20
# estas escrapeando la pag 21
# estas escrapeando la pag 22
# estas escrapeando la pag 23
# estas escrapeando la pag 24
# estas escrapeando la pag 25
# estas escrapeando la pag 26
# estas escrapeando la pag 27
# estas escrapeando la pag 28
# estas escrapeando la pag 29
# estas escrapeando la pag 30
# estas escrapeando la pag 31
# estas escrapeando la pag 32
# estas escrapeando la pag 33
# estas escrapeando la pag 34
# estas escrapeando la pag 35
# estas escrapeando la pag 36
# estas escrapeando la pag 37
# estas escrapeando la pag 38
# estas escrapeando la pag 39
# estas escrapeando la pag 40
# estas escrapeando la pag 41
# estas escrapeando la pag 42
# estas escrapeando la pag 43
# estas escrapeando la pag 44
# estas escrapeando la pag 45
# estas escrapeando la pag 46
# estas escrapeando la pag 47
# estas escrapeando la pag 48
# estas escrapeando la pag 49
# estas escrapeando la pag 50
# estas escrapeando la pag 51
# estas escrapeando la pag 52
# estas escrapeando la pag 53
# estas escrapeando la pag 54
# estas escrapeando la pag 55
# estas escrapeando la pag 56
# estas escrapeando la pag 57
# estas escrapeando la pag 58
# estas escrapeando la pag 59
# estas escrapeando la pag 60
# estas escrapeando la pag 61
# estas escrapeando la pag 62
# estas escrapeando la pag 63
# estas escrapeando la pag 64
# estas escrapeando la pag 65
# estas escrapeando la pag 66
# estas escrapeando la pag 67
# estas escrapeando la pag 68
# estas escrapeando la pag 69
# estas escrapeando la pag 70
# estas escrapeando la pag 71
# estas escrapeando la pag 72
# estas escrapeando la pag 73
# estas escrapeando la pag 74
# estas escrapeando la pag 75
# estas escrapeando la pag 76
# estas escrapeando la pag 77
# estas escrapeando la pag 78
# estas escrapeando la pag 79
# estas escrapeando la pag 80
# estas escrapeando la pag 81
# estas escrapeando la pag 82
# estas escrapeando la pag 83
# estas escrapeando la pag 84
# estas escrapeando la pag 85
# estas escrapeando la pag 86
# estas escrapeando la pag 87
# estas escrapeando la pag 88
# estas escrapeando la pag 89
# estas escrapeando la pag 90
# estas escrapeando la pag 91
# estas escrapeando la pag 92
# estas escrapeando la pag 93
# estas escrapeando la pag 94
# estas escrapeando la pag 95
# estas escrapeando la pag 96
# estas escrapeando la pag 97
# estas escrapeando la pag 98
# estas escrapeando la pag 99
# estas escrapeando la pag 100
# estas escrapeando la pag 101
# estas escrapeando la pag 102
# estas escrapeando la pag 103
# estas escrapeando la pag 104
# estas escrapeando la pag 105
# estas escrapeando la pag 106
# estas escrapeando la pag 107
# estas escrapeando la pag 108
# estas escrapeando la pag 109
# estas escrapeando la pag 110
# estas escrapeando la pag 111
# estas escrapeando la pag 112
# estas escrapeando la pag 113
# estas escrapeando la pag 114
# estas escrapeando la pag 115
# estas escrapeando la pag 116
# estas escrapeando la pag 117
# estas escrapeando la pag 118
# estas escrapeando la pag 119
# estas escrapeando la pag 120
# estas escrapeando la pag 121
# estas escrapeando la pag 122
# estas escrapeando la pag 123
# estas escrapeando la pag 124
# estas escrapeando la pag 125
# estas escrapeando la pag 126
# estas escrapeando la pag 127
# estas escrapeando la pag 128
# estas escrapeando la pag 129
# estas escrapeando la pag 130
# estas escrapeando la pag 131
# estas escrapeando la pag 132
# estas escrapeando la pag 133
# estas escrapeando la pag 134
# estas escrapeando la pag 135
# estas escrapeando la pag 136
# estas escrapeando la pag 137
# estas escrapeando la pag 138
# estas escrapeando la pag 139
# estas escrapeando la pag 140
# estas escrapeando la pag 141
# estas escrapeando la pag 142
# estas escrapeando la pag 143
# estas escrapeando la pag 144
# estas escrapeando la pag 145
# estas escrapeando la pag 146
# estas escrapeando la pag 147
# estas escrapeando la pag 148
# estas escrapeando la pag 149
# estas escrapeando la pag 150
# estas escrapeando la pag 151
# estas escrapeando la pag 152
# estas escrapeando la pag 153
# estas escrapeando la pag 154

# %%
df_catalogo=pd.DataFrame(datos_book)
df_catalogo
# Out:
#                          Titulo de revista                  Área Temática  \
# 0    Boletín Mexicano de Derecho Comparado  V. Ciencias Sociales  Derecho
# 1    Boletín Mexicano de Derecho Comparado  V. Ciencias Sociales  Derecho
# 2    Boletín Mexicano de Derecho Comparado  V. Ciencias Sociales  Derecho
# 3    Boletín Mexicano de Derecho Comparado  V. Ciencias Sociales  Derecho
# 4    Boletín Mexicano de Derecho Comparado  V. Ciencias Sociales  Derecho
# ..                                     ...                   ...      ...
# 150  Boletín Mexicano de Derecho Comparado  V. Ciencias Sociales  Derecho
# 151  Boletín Mexicano de Derecho Comparado  V. Ciencias Sociales  Derecho
# 152  Boletín Mexicano de Derecho Comparado  V. Ciencias Sociales  Derecho
# 153  Boletín Mexicano de Derecho Comparado  V. Ciencias Sociales  Derecho
# 154  Boletín Mexicano de Derecho Comparado  V. Ciencias Sociales  Derecho
#
#                                       Titulo del libro Resumen  \
# 0    Nueva serie, año LIV, número 161, Mayo-Agosto ...
# 1    Nueva serie, año LIV, número 160, enero-abril ...
# 2    Nueva serie, año LIII, número 159, septiembre-...
# 3    Nueva serie, año LIII, número 158, Mayo-Agosto...
# 4    Nueva serie, año LIII, número 157, enero-abril...
# ..                                                 ...     ...
# 150                                          Número  6
# 151                                          Número  5
# 152                                          Número  4
# 153                                        Número  2-3
# 154                                          Número  1
#
#                                           Link inicial  \
# 0    https://revistas.juridicas.unam.mx/index.php/d...
# 1    https://revistas.juridicas.unam.mx/index.php/d...
# 2    https://revistas.juridicas.unam.mx/index.php/d...
# 3    https://revistas.juridicas.unam.mx/index.php/d...
# 4    https://revistas.juridicas.unam.mx/index.php/d...
# ..                                                 ...
# 150  https://revistas.juridicas.unam.mx/index.php/d...
# 151  https://revistas.juridicas.unam.mx/index.php/d...
# 152  https://revistas.juridicas.unam.mx/index.php/d...
# 153  https://revistas.juridicas.unam.mx/index.php/d...
# 154  https://revistas.juridicas.unam.mx/index.php/d...
#
#                                          Link articulo
# 0    https://revistas.juridicas.unam.mx/index.php/d...
# 1    https://revistas.juridicas.unam.mx/index.php/d...
# 2    https://revistas.juridicas.unam.mx/index.php/d...
# 3    https://revistas.juridicas.unam.mx/index.php/d...
# 4    https://revistas.juridicas.unam.mx/index.php/d...
# ..                                                 ...
# 150  https://revistas.juridicas.unam.mx/index.php/d...
# 151  https://revistas.juridicas.unam.mx/index.php/d...
# 152  https://revistas.juridicas.unam.mx/index.php/d...
# 153  https://revistas.juridicas.unam.mx/index.php/d...
# 154  https://revistas.juridicas.unam.mx/index.php/d...
#
# [155 rows x 7 columns]

# %%
df_catalogo.to_csv('Revista77.csv', index=False)
