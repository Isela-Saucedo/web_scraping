# %%
import requests
import bs4
from bs4 import BeautifulSoup
from urllib.parse import urljoin
import pandas as pd

# %%
url_inicial = 'https://smis.mx/index.php/RIS/issue/archive/4'
url_root = 'https://smis.mx/index.php/RIS/issue/archive/4'
r=requests.get(url_inicial)

# %%
soup = BeautifulSoup(r.text, 'html.parser')

# %%
lista_articulo = soup.find_all('div', class_='issue-block news-block col-sm-6 col-md-6 col-lg-4')
links_libros = [x.find('a').get('href') for x in lista_articulo]
links_libros = [urljoin (url_root, i) for i in links_libros]
links_libros
# Out:
# ['https://smis.mx/index.php/RIS/issue/view/92',
#  'https://smis.mx/index.php/RIS/issue/view/93',
#  'https://smis.mx/index.php/RIS/issue/view/95',
#  'https://smis.mx/index.php/RIS/issue/view/94',
#  'https://smis.mx/index.php/RIS/issue/view/96',
#  'https://smis.mx/index.php/RIS/issue/view/97',
#  'https://smis.mx/index.php/RIS/issue/view/98',
#  'https://smis.mx/index.php/RIS/issue/view/99',
#  'https://smis.mx/index.php/RIS/issue/view/100',
#  'https://smis.mx/index.php/RIS/issue/view/101',
#  'https://smis.mx/index.php/RIS/issue/view/102',
#  'https://smis.mx/index.php/RIS/issue/view/103',
#  'https://smis.mx/index.php/RIS/issue/view/104',
#  'https://smis.mx/index.php/RIS/issue/view/105',
#  'https://smis.mx/index.php/RIS/issue/view/106',
#  'https://smis.mx/index.php/RIS/issue/view/107',
#  'https://smis.mx/index.php/RIS/issue/view/108']

# %%
def get_url_items(soup,url):
    lista_articulo = soup.find_all('div', class_='issue-block news-block col-sm-6 col-md-6 col-lg-4')
    links_libros = [x.find('a').get('href') for x in lista_articulo]
    links_libros = [urljoin (url_root, i) for i in links_libros]
    return links_libros

# %%
links_items=[]
i=0
while i<1:
    i+=1
    print(f'Estoy en la pagina {url_inicial}')
    r_pag=requests.get(url_inicial)
    s_p=BeautifulSoup(r_pag.text,'html.parser')
    links=get_url_items(s_p, url_inicial)
    links_items.append(links)
# Out:
# Estoy en la pagina https://smis.mx/index.php/RIS/issue/archive/4

# %%
list_scraper=[]
for i in links_items:
    for j in i:
        list_scraper.append(j)
len(list_scraper)
# Out:
# 17

# %%
uno=list_scraper[0]
r_item=requests.get(uno)
s_item=BeautifulSoup(r_item.text, 'html.parser')

# %%
#funcion para iniciar el escraper de cada libro
def scraper_book(url):
    content_book={}
    r=requests.get(url)
    tire='Revista de Ingeniería Sísmica'
    a='VII. Ingenierías'
    tem='Ingeniería Sísmica'
    url='http://smis.mx/'
    s_item=BeautifulSoup(r.text,'html.parser')
    #titulo de revista
    try:
        titulo=tire
        content_book['Titulo de revista']=tire
    except AttributeError:
        content_book['Titulo de revista']=None
    #area
    try:
        area=a
        content_book['Área']=a
    except AttributeError:
        content_book['Área']=None
    #tematica
    try:
        tema=tem
        content_book['Temática']=tem
    except AttributeError:
        content_book['Temática']=None
    #titulo libro
    try:
        titu=s_item.find('h4', class_='issue-article-title card-title').get_text(strip=True)
        content_book['Titulo del libro']=titu
    except AttributeError:
        content_book['Titulo del libro']=None
    #resumen
    try:
        resu=s_item.find('a', class_='cover').get_text(strip=True)
        content_book['Resumen']=resu
    except AttributeError:
        content_book['Resumen']=None
    #Link incial
    try:
        inicial=url
        content_book['Link inicial']=url
    except AttributeError:
        content_book['Link inicial']=None
    #link articulo
    try:
        link=s_item.find('div', class_='card one-article-intoc').get('href')
        content_book['Link articulo']=urljoin(url_root, link)
    except AttributeError:
        content_book['Link articulo']=None
    return content_book

# %%
list_scraper=list_scraper[0:25]
datos_book=[]
for idx, i in enumerate(list_scraper):
    print(f'estas escrapeando la pag {idx}')
    datos_book.append(scraper_book(i))
# Out:
# estas escrapeando la pag 0
# estas escrapeando la pag 1
# estas escrapeando la pag 2
# estas escrapeando la pag 3
# estas escrapeando la pag 4
# estas escrapeando la pag 5
# estas escrapeando la pag 6
# estas escrapeando la pag 7
# estas escrapeando la pag 8
# estas escrapeando la pag 9
# estas escrapeando la pag 10
# estas escrapeando la pag 11
# estas escrapeando la pag 12
# estas escrapeando la pag 13
# estas escrapeando la pag 14
# estas escrapeando la pag 15
# estas escrapeando la pag 16

# %%
df_catalogo=pd.DataFrame(datos_book)
df_catalogo
# Out:
#                 Titulo de revista              Área            Temática  \
# 0   Revista de Ingeniería Sísmica  VII. Ingenierías  Ingeniería Sísmica
# 1   Revista de Ingeniería Sísmica  VII. Ingenierías  Ingeniería Sísmica
# 2   Revista de Ingeniería Sísmica  VII. Ingenierías  Ingeniería Sísmica
# 3   Revista de Ingeniería Sísmica  VII. Ingenierías  Ingeniería Sísmica
# 4   Revista de Ingeniería Sísmica  VII. Ingenierías  Ingeniería Sísmica
# 5   Revista de Ingeniería Sísmica  VII. Ingenierías  Ingeniería Sísmica
# 6   Revista de Ingeniería Sísmica  VII. Ingenierías  Ingeniería Sísmica
# 7   Revista de Ingeniería Sísmica  VII. Ingenierías  Ingeniería Sísmica
# 8   Revista de Ingeniería Sísmica  VII. Ingenierías  Ingeniería Sísmica
# 9   Revista de Ingeniería Sísmica  VII. Ingenierías  Ingeniería Sísmica
# 10  Revista de Ingeniería Sísmica  VII. Ingenierías  Ingeniería Sísmica
# 11  Revista de Ingeniería Sísmica  VII. Ingenierías  Ingeniería Sísmica
# ...

# %%
df_catalogo.to_csv('Revista109.04.csv', index=False)
