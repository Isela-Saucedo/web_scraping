# %%
import requests
import bs4
from bs4 import BeautifulSoup
from urllib.parse import urljoin
import pandas as pd

# %%
url_inicial='http://tzintzun.umich.mx/index.php/TZN/issue/view/86'
url_root= 'http://tzintzun.umich.mx/index.php/TZN/issue/view/86'
r = requests.get(url_inicial)

# %%
soup = BeautifulSoup(r.text, 'html.parser')

# %%
box = soup.find('ul', class_='cmp_article_list articles')
volumen=box.findAll('div', class_='obj_article_summary')
vol = [x.find('a').get('href')for x in volumen]
vol=[urljoin(url_root,i) for i in vol]
vol
# Out:
# ['http://tzintzun.umich.mx/index.php/TZN/article/view/947',
#  'http://tzintzun.umich.mx/index.php/TZN/article/view/948',
#  'http://tzintzun.umich.mx/index.php/TZN/article/view/949',
#  'http://tzintzun.umich.mx/index.php/TZN/article/view/950',
#  'http://tzintzun.umich.mx/index.php/TZN/article/view/953',
#  'http://tzintzun.umich.mx/index.php/TZN/article/view/955',
#  'http://tzintzun.umich.mx/index.php/TZN/article/view/956']

# %%
def get_url_items(sopa, url): 
    box = soup.find('ul', class_='cmp_article_list articles')
    volumen=box.findAll('div', class_='obj_issue_summary')
    vol = [x.find('a').get('href')for x in volumen]
    vol=[urljoin(url_root,i) for i in vol]
    return vol

# %%
links_items=[]
i=0
while i<1:
    i+=1
    print(f'Estoy en la pagina {url_inicial}')
    r_pag=requests.get(url_inicial)
    s_p=BeautifulSoup(r_pag.text,'html.parser')
    links=get_url_items(s_p, url_inicial)
    links_items.append(links) 
    next_a=s_p.select('div.cmp_pagination > a')
    if not next_a or not next_a[0].get('href'):
        break
    url_inicial = urljoin(url_inicial, next_a[0].get('href'))
# Out:
# Estoy en la pagina http://tzintzun.umich.mx/index.php/TZN/issue/view/86

# %%
list_scraper=[]
for i in links_items:
    for j in i:
        list_scraper.append(j)
len(list_scraper)
# Out:
# 0

# %%
uno=list_scraper[0]
r_item=requests.get(uno)
s_item=BeautifulSoup(r_item.text, 'html.parser')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [29], in <cell line: 1>()
# ----> 1 uno=list_scraper[0]
#       2 r_item=requests.get(uno)
#       3 s_item=BeautifulSoup(r_item.text, 'html.parser')
#
# IndexError: list index out of range

# %%
#funcion para iniciar el escraper de cada libro
def scraper_book(url):
    content_book={}
    r=requests.get(url)
    tire='Tzintzun. Revista de Estudios Históricos'
    a='IV. Humanidades y Ciencias de la Conducta'
    tem='Historia'
    url='http://tzintzun.umich.mx/'
    s_item=BeautifulSoup(r.text,'html.parser')
    #titulo de revista
    try:
        titulo=tire
        content_book['Titulo de revista']=tire
    except AttributeError:
        content_book['Titulo de revista']=None
    #area
    try:
        area=a
        content_book['Área']=a
    except AttributeError:
        content_book['Área']=None
    #tematica
    try:
        tema=tem
        content_book['Temática']=tem
    except AttributeError:
        content_book['Temática']=None
    #titulo libro
    try:
        titu=s_item.find('h1', class_='page_title').get_text(strip=True)
        content_book['Titulo del libro']=titu
    except AttributeError:
        content_book['Titulo del libro']=None
    #abstract
    try:
        abst=s_item.find('a', rel='license').get_text(strip=True)
        content_book['Abstract']=abst
    except AttributeError:
        content_book['Abstract']=None
    #resumen
    try:
        resu=s_item.find('p').get_text(strip=True)
        content_book['Resumen']=resu
    except AttributeError:
        content_book['Resumen']=None
    #Link incial
    try:
        inicial=url
        content_book['Link inicial']=url
    except AttributeError:
        content_book['Link inicial']=None
    #link articulo
    try:
        link=s_item.find('a', class_='obj_galley_link pdf').get('href')
        content_book['Link articulo']=urljoin(url_root, link)
    except AttributeError:
        content_book['Link articulo']=None
    return content_book

# %%
list_scraper=list_scraper[0:21]
datos_book=[]
for idx, i in enumerate(list_scraper):
    print(f'estas escrapeando la pag {idx}')
    datos_book.append(scraper_book(i))

# %%
df_catalogo=pd.DataFrame(datos_book)
df_catalogo
# Out:
#                            Titulo de revista  \
# 0   Tzintzun. Revista de Estudios Históricos
# 1   Tzintzun. Revista de Estudios Históricos
# 2   Tzintzun. Revista de Estudios Históricos
# 3   Tzintzun. Revista de Estudios Históricos
# 4   Tzintzun. Revista de Estudios Históricos
# 5   Tzintzun. Revista de Estudios Históricos
# 6   Tzintzun. Revista de Estudios Históricos
# 7   Tzintzun. Revista de Estudios Históricos
# 8   Tzintzun. Revista de Estudios Históricos
# 9   Tzintzun. Revista de Estudios Históricos
# 10  Tzintzun. Revista de Estudios Históricos
# 11  Tzintzun. Revista de Estudios Históricos
# 12  Tzintzun. Revista de Estudios Históricos
# 13  Tzintzun. Revista de Estudios Históricos
# 14  Tzintzun. Revista de Estudios Históricos
# 15  Tzintzun. Revista de Estudios Históricos
# 16  Tzintzun. Revista de Estudios Históricos
# 17  Tzintzun. Revista de Estudios Históricos
# 18  Tzintzun. Revista de Estudios Históricos
# 19  Tzintzun. Revista de Estudios Históricos
# ...

# %%
df_catalogo.to_csv('Revista09.3.csv', index=False)
