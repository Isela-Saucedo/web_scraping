# %%
import requests
import bs4
from bs4 import BeautifulSoup
from urllib.parse import urljoin
import pandas as pd

# %%
url_inicial = 'https://arqueologiamexicana.mx/inicio?page=10'
url_root = 'https://arqueologiamexicana.mx/inicio?page=10'
r=requests.get(url_inicial)

# %%
soup = BeautifulSoup(r.text, 'html.parser')

# %%
lista_articulo = soup.find_all('li', class_='col-md-12')
links_libros = [x.find('a').get('href') for x in lista_articulo]
links_libros = [urljoin (url_root, i) for i in links_libros]
links_libros
# Out:
# ['https://arqueologiamexicana.mx/mexico-antiguo/el-pez-de-xochicalco-identificacion',
#  'https://arqueologiamexicana.mx/mexico-antiguo/tlapa-guerrero',
#  'https://arqueologiamexicana.mx/mexico-antiguo/asedio-de-tenochtitlan',
#  'https://arqueologiamexicana.mx/mexico-antiguo/la-consagracion-de-un-nacimiento',
#  'https://arqueologiamexicana.mx/mexico-antiguo/fiesta-y-gastronomia-en-atzompa',
#  'https://arqueologiamexicana.mx/mexico-antiguo/el-guajolote-y-el-venado-en-los-festines',
#  'https://arqueologiamexicana.mx/mexico-antiguo/el-estado-de-chiapas',
#  'https://arqueologiamexicana.mx/mexico-antiguo/los-alimentos-en-tututepec-prehispanico',
#  'https://arqueologiamexicana.mx/mexico-antiguo/ghilo-flor-del-tejate',
#  'https://arqueologiamexicana.mx/mexico-antiguo/arqueologia-de-coyolxauhqui',
#  'https://arqueologiamexicana.mx/mexico-antiguo/las-comidas-rituales-y-cotidianas-en-oaxaca',
#  'https://arqueologiamexicana.mx/mexico-antiguo/yollotlicue-y-los-extranjeros']

# %%
def get_url_items(soup,url):
    lista_articulo = soup.find_all('li', class_='col-md-12')
    links_libros = [x.find('a').get('href') for x in lista_articulo]
    links_libros = [urljoin (url_root, i) for i in links_libros]
    return links_libros

# %%
links_items=[]
i=0
while i<1:
    i+=1
    print(f'Estoy en la pagina {url_inicial}')
    r_pag=requests.get(url_inicial)
    s_p=BeautifulSoup(r_pag.text,'html.parser')
    links=get_url_items(s_p, url_inicial)
    links_items.append(links)
# Out:
# Estoy en la pagina https://arqueologiamexicana.mx/inicio?page=10

# %%
list_scraper=[]
for i in links_items:
    for j in i:
        list_scraper.append(j)
len(list_scraper)
# Out:
# 12

# %%
uno=list_scraper[0]
r_item=requests.get(uno)
s_item=BeautifulSoup(r_item.text, 'html.parser')

# %%
#funcion para iniciar el escraper de cada libro
def scraper_book(url):
    content_book={}
    r=requests.get(url)
    tire='Arqueología Mexicana'
    a='NULL'
    tem='NULL'
    url='https://arqueologiamexicana.mx/'
    s_item=BeautifulSoup(r.text,'html.parser')
    #titulo de revista
    try:
        titulo=tire
        content_book['Titulo de revista']=tire
    except AttributeError:
        content_book['Titulo de revista']=None
    #area
    try:
        area=a
        content_book['Área']=a
    except AttributeError:
        content_book['Área']=None
    #tematica
    try:
        tema=tem
        content_book['Temática']=tem
    except AttributeError:
        content_book['Temática']=None
    #titulo libro
    try:
        titu=s_item.find('h3', class_='main-title left col-md-12').get_text(strip=True)
        content_book['Titulo del libro']=titu
    except AttributeError:
        content_book['Titulo del libro']=None
    #resumen
    try:
        resu=s_item.find('div', class_='field-item even').get_text(strip=True)
        content_book['Resumen']=resu
    except AttributeError:
        content_book['Resumen']=None
    #Link incial
    try:
        inicial=url
        content_book['Link inicial']=url
    except AttributeError:
        content_book['Link inicial']=None
    #link articulo
    try:
        link=s_item.find('a', class_='revista-pie__info__datos__contenedor__venta--url-digital').get('href')
        content_book['Link articulo']=urljoin(url_root, link)
    except AttributeError:
        content_book['Link articulo']=None
    return content_book

# %%
list_scraper=list_scraper[0:12]
datos_book=[]
for idx, i in enumerate(list_scraper):
    print(f'estas escrapeando la pag {idx}')
    datos_book.append(scraper_book(i))
# Out:
# estas escrapeando la pag 0
# estas escrapeando la pag 1
# estas escrapeando la pag 2
# estas escrapeando la pag 3
# estas escrapeando la pag 4
# estas escrapeando la pag 5
# estas escrapeando la pag 6
# estas escrapeando la pag 7
# estas escrapeando la pag 8
# estas escrapeando la pag 9
# estas escrapeando la pag 10
# estas escrapeando la pag 11

# %%
df_catalogo=pd.DataFrame(datos_book)
df_catalogo
# Out:
#        Titulo de revista  Área Temática  \
# 0   Arqueología Mexicana  NULL     NULL
# 1   Arqueología Mexicana  NULL     NULL
# 2   Arqueología Mexicana  NULL     NULL
# 3   Arqueología Mexicana  NULL     NULL
# 4   Arqueología Mexicana  NULL     NULL
# 5   Arqueología Mexicana  NULL     NULL
# 6   Arqueología Mexicana  NULL     NULL
# 7   Arqueología Mexicana  NULL     NULL
# 8   Arqueología Mexicana  NULL     NULL
# 9   Arqueología Mexicana  NULL     NULL
# 10  Arqueología Mexicana  NULL     NULL
# 11  Arqueología Mexicana  NULL     NULL
#
#                                Titulo del libro  \
# 0          El pez de Xochicalco. Identificación
# 1                               Tlapa, Guerrero
# 2                        Asedio de Tenochtitlan
# 3              La consagración de un nacimiento
# 4               Fiesta y gastronomía en Atzompa
# 5      El guajolote y el venado en los festines
# 6                          El estado de Chiapas
# ...

# %%
df_catalogo.to_csv('Revista105.10.csv', index=False)
