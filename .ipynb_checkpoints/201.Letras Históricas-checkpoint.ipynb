# %%
import requests
import bs4
from bs4 import BeautifulSoup
from urllib.parse import urljoin
import pandas as pd

# %%
url_inicial = 'https://polcul.xoc.uam.mx/index.php/polcul/issue/archive'
url_root = 'https://polcul.xoc.uam.mx/index.php/polcul/issue/archive'
r=requests.get(url_inicial)

# %%
soup = BeautifulSoup(r.text, 'html.parser')

# %%
lista_articulo = soup.find_all('div', class_='obj_issue_summary')
links_libros = [x.find('a').get('href') for x in lista_articulo]
links_libros = [urljoin (url_root, i) for i in links_libros]
links_libros
# Out:
# ['https://polcul.xoc.uam.mx/index.php/polcul/issue/view/95',
#  'https://polcul.xoc.uam.mx/index.php/polcul/issue/view/94',
#  'https://polcul.xoc.uam.mx/index.php/polcul/issue/view/93',
#  'https://polcul.xoc.uam.mx/index.php/polcul/issue/view/92',
#  'https://polcul.xoc.uam.mx/index.php/polcul/issue/view/91',
#  'https://polcul.xoc.uam.mx/index.php/polcul/issue/view/90',
#  'https://polcul.xoc.uam.mx/index.php/polcul/issue/view/89',
#  'https://polcul.xoc.uam.mx/index.php/polcul/issue/view/88',
#  'https://polcul.xoc.uam.mx/index.php/polcul/issue/view/87',
#  'https://polcul.xoc.uam.mx/index.php/polcul/issue/view/86',
#  'https://polcul.xoc.uam.mx/index.php/polcul/issue/view/85',
#  'https://polcul.xoc.uam.mx/index.php/polcul/issue/view/84',
#  'https://polcul.xoc.uam.mx/index.php/polcul/issue/view/83',
#  'https://polcul.xoc.uam.mx/index.php/polcul/issue/view/82',
#  'https://polcul.xoc.uam.mx/index.php/polcul/issue/view/81',
#  'https://polcul.xoc.uam.mx/index.php/polcul/issue/view/80',
#  'https://polcul.xoc.uam.mx/index.php/polcul/issue/view/79',
#  'https://polcul.xoc.uam.mx/index.php/polcul/issue/view/78',
#  'https://polcul.xoc.uam.mx/index.php/polcul/issue/view/77',
#  'https://polcul.xoc.uam.mx/index.php/polcul/issue/view/76',
#  'https://polcul.xoc.uam.mx/index.php/polcul/issue/view/75',
#  'https://polcul.xoc.uam.mx/index.php/polcul/issue/view/74',
#  'https://polcul.xoc.uam.mx/index.php/polcul/issue/view/73',
#  'https://polcul.xoc.uam.mx/index.php/polcul/issue/view/72',
#  'https://polcul.xoc.uam.mx/index.php/polcul/issue/view/71']

# %%
def get_url_items(soup,url):
    lista_articulo = soup.find_all('div', class_='obj_issue_summary')
    links_libros = [x.find('a').get('href') for x in lista_articulo]
    links_libros = [urljoin (url_root, i) for i in links_libros]
    return links_libros

# %%
links_items=[]
i=0
while i<1:
    i+=1
    print(f'Estoy en la pagina {url_inicial}')
    r_pag=requests.get(url_inicial)
    s_p=BeautifulSoup(r_pag.text,'html.parser')
    links=get_url_items(s_p, url_inicial)
    links_items.append(links)
# Out:
# Estoy en la pagina https://polcul.xoc.uam.mx/index.php/polcul/issue/archive

# %%
list_scraper=[]
for i in links_items:
    for j in i:
        list_scraper.append(j)
len(list_scraper)
# Out:
# 25

# %%
uno=list_scraper[0]
r_item=requests.get(uno)
s_item=BeautifulSoup(r_item.text, 'html.parser')

# %%
#funcion para iniciar el escraper de cada libro
def scraper_book(url):
    content_book={}
    r=requests.get(url)
    tire='Letras Históricas'
    a='IV. Humanidades y Ciencias de la Conducta'
    tem='Historia'
    url='http://www.letrashistoricas.cucsh.udg.mx/index.php/LH/login'
    s_item=BeautifulSoup(r.text,'html.parser')
    #titulo de revista
    try:
        titulo=tire
        content_book['Titulo de revista']=tire
    except AttributeError:
        content_book['Titulo de revista']=None
    #area
    try:
        area=a
        content_book['Área']=a
    except AttributeError:
        content_book['Área']=None
    #tematica
    try:
        tema=tem
        content_book['Temática']=tem
    except AttributeError:
        content_book['Temática']=None
    #titulo libro
    try:
        titu=s_item.find('h1', class_='text-left issue-header').get_text(strip=True)
        content_book['Titulo del libro']=titu
    except AttributeError:
        content_book['Titulo del libro']=None
    #resumen
    try:
        resu=s_item.find('a', class_='cover').get_text(strip=True)
        content_book['Resumen']=resu
    except AttributeError:
        content_book['Resumen']=None
    #Link incial
    try:
        inicial=url
        content_book['Link inicial']=url
    except AttributeError:
        content_book['Link inicial']=None
    #link articulo
    try:
        link=s_item.find('a', class_='btn galley-link obj_galley_link file').get('href')
        content_book['Link articulo']=urljoin(url_root, link)
    except AttributeError:
        content_book['Link articulo']=None
    return content_book

# %%
list_scraper=list_scraper[0:25]
datos_book=[]
for idx, i in enumerate(list_scraper):
    print(f'estas escrapeando la pag {idx}')
    datos_book.append(scraper_book(i))
# Out:
# estas escrapeando la pag 0
# estas escrapeando la pag 1
# estas escrapeando la pag 2
# estas escrapeando la pag 3
# estas escrapeando la pag 4
# estas escrapeando la pag 5
# estas escrapeando la pag 6
# estas escrapeando la pag 7
# estas escrapeando la pag 8
# estas escrapeando la pag 9
# estas escrapeando la pag 10
# estas escrapeando la pag 11
# estas escrapeando la pag 12
# estas escrapeando la pag 13
# estas escrapeando la pag 14
# estas escrapeando la pag 15
# estas escrapeando la pag 16
# estas escrapeando la pag 17
# estas escrapeando la pag 18
# estas escrapeando la pag 19
# estas escrapeando la pag 20
# estas escrapeando la pag 21
# estas escrapeando la pag 22
# estas escrapeando la pag 23
# estas escrapeando la pag 24

# %%
df_catalogo=pd.DataFrame(datos_book)
df_catalogo
# Out:
#     Titulo de revista                                       Área  Temática  \
# 0   Letras Históricas  IV. Humanidades y Ciencias de la Conducta  Historia
# 1   Letras Históricas  IV. Humanidades y Ciencias de la Conducta  Historia
# 2   Letras Históricas  IV. Humanidades y Ciencias de la Conducta  Historia
# 3   Letras Históricas  IV. Humanidades y Ciencias de la Conducta  Historia
# 4   Letras Históricas  IV. Humanidades y Ciencias de la Conducta  Historia
# 5   Letras Históricas  IV. Humanidades y Ciencias de la Conducta  Historia
# 6   Letras Históricas  IV. Humanidades y Ciencias de la Conducta  Historia
# 7   Letras Históricas  IV. Humanidades y Ciencias de la Conducta  Historia
# 8   Letras Históricas  IV. Humanidades y Ciencias de la Conducta  Historia
# 9   Letras Históricas  IV. Humanidades y Ciencias de la Conducta  Historia
# 10  Letras Históricas  IV. Humanidades y Ciencias de la Conducta  Historia
# 11  Letras Históricas  IV. Humanidades y Ciencias de la Conducta  Historia
# 12  Letras Históricas  IV. Humanidades y Ciencias de la Conducta  Historia
# 13  Letras Históricas  IV. Humanidades y Ciencias de la Conducta  Historia
# 14  Letras Históricas  IV. Humanidades y Ciencias de la Conducta  Historia
# 15  Letras Históricas  IV. Humanidades y Ciencias de la Conducta  Historia
# 16  Letras Históricas  IV. Humanidades y Ciencias de la Conducta  Historia
# 17  Letras Históricas  IV. Humanidades y Ciencias de la Conducta  Historia
# 18  Letras Históricas  IV. Humanidades y Ciencias de la Conducta  Historia
# 19  Letras Históricas  IV. Humanidades y Ciencias de la Conducta  Historia
# 20  Letras Históricas  IV. Humanidades y Ciencias de la Conducta  Historia
# 21  Letras Históricas  IV. Humanidades y Ciencias de la Conducta  Historia
# 22  Letras Históricas  IV. Humanidades y Ciencias de la Conducta  Historia
# 23  Letras Históricas  IV. Humanidades y Ciencias de la Conducta  Historia
# 24  Letras Históricas  IV. Humanidades y Ciencias de la Conducta  Historia
#
#    Titulo del libro Resumen  \
# 0              None
# 1              None
# 2              None
# 3              None
# 4              None
# 5              None
# 6              None
# 7              None
# 8              None
# 9              None
# 10             None
# 11             None
# 12             None
# 13             None
# 14             None
# 15             None
# 16             None
# 17             None
# 18             None
# 19             None
# 20             None
# 21             None
# 22             None
# 23             None
# 24             None
#
#                                          Link inicial Link articulo
# 0   http://www.letrashistoricas.cucsh.udg.mx/index...          None
# 1   http://www.letrashistoricas.cucsh.udg.mx/index...          None
# 2   http://www.letrashistoricas.cucsh.udg.mx/index...          None
# 3   http://www.letrashistoricas.cucsh.udg.mx/index...          None
# 4   http://www.letrashistoricas.cucsh.udg.mx/index...          None
# 5   http://www.letrashistoricas.cucsh.udg.mx/index...          None
# 6   http://www.letrashistoricas.cucsh.udg.mx/index...          None
# 7   http://www.letrashistoricas.cucsh.udg.mx/index...          None
# 8   http://www.letrashistoricas.cucsh.udg.mx/index...          None
# 9   http://www.letrashistoricas.cucsh.udg.mx/index...          None
# 10  http://www.letrashistoricas.cucsh.udg.mx/index...          None
# 11  http://www.letrashistoricas.cucsh.udg.mx/index...          None
# 12  http://www.letrashistoricas.cucsh.udg.mx/index...          None
# 13  http://www.letrashistoricas.cucsh.udg.mx/index...          None
# 14  http://www.letrashistoricas.cucsh.udg.mx/index...          None
# 15  http://www.letrashistoricas.cucsh.udg.mx/index...          None
# 16  http://www.letrashistoricas.cucsh.udg.mx/index...          None
# 17  http://www.letrashistoricas.cucsh.udg.mx/index...          None
# 18  http://www.letrashistoricas.cucsh.udg.mx/index...          None
# 19  http://www.letrashistoricas.cucsh.udg.mx/index...          None
# 20  http://www.letrashistoricas.cucsh.udg.mx/index...          None
# 21  http://www.letrashistoricas.cucsh.udg.mx/index...          None
# 22  http://www.letrashistoricas.cucsh.udg.mx/index...          None
# 23  http://www.letrashistoricas.cucsh.udg.mx/index...          None
# 24  http://www.letrashistoricas.cucsh.udg.mx/index...          None

# %%
df_catalogo.to_csv('Revista201.01.csv', index=False)
