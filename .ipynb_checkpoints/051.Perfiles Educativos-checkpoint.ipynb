# %%
import requests
import bs4
from bs4 import BeautifulSoup
from urllib.parse import urljoin
import pandas as pd

# %%
url_inicial = 'https://www.iisue.unam.mx/perfiles/numeros-anteriores'
url_root = 'https://www.iisue.unam.mx/perfiles/numeros-anteriores'
r=requests.get(url_inicial)

# %%
soup = BeautifulSoup(r.text, 'html.parser')

# %%
box = soup.find('div', class_='container')
volumen=box.findAll('div', class_='col-4 col-md-3 col-lg-2')
vol = [x.find('a').get('href')for x in volumen]
vol=[urljoin(url_root,i) for i in vol]
vol
# Out:
# ['https://perfileseducativos.unam.mx/iisue_pe/index.php/perfiles/issue/view/4494',
#  'https://perfileseducativos.unam.mx/iisue_pe/index.php/perfiles/issue/view/4488',
#  'https://perfileseducativos.unam.mx/iisue_pe/index.php/perfiles/issue/view/4489',
#  'https://perfileseducativos.unam.mx/iisue_pe/index.php/perfiles/issue/view/4490',
#  'https://perfileseducativos.unam.mx/iisue_pe/index.php/perfiles/issue/view/4492',
#  'https://perfileseducativos.unam.mx/iisue_pe/index.php/perfiles/issue/view/4493',
#  'https://perfileseducativos.unam.mx/iisue_pe/index.php/perfiles/issue/view/4483',
#  'https://perfileseducativos.unam.mx/iisue_pe/index.php/perfiles/issue/view/4484',
#  'https://perfileseducativos.unam.mx/iisue_pe/index.php/perfiles/issue/view/4485',
#  'https://perfileseducativos.unam.mx/iisue_pe/index.php/perfiles/issue/view/4487',
#  'https://perfileseducativos.unam.mx/iisue_pe/index.php/perfiles/issue/view/4478',
#  'https://perfileseducativos.unam.mx/iisue_pe/index.php/perfiles/issue/view/4479',
#  'https://perfileseducativos.unam.mx/iisue_pe/index.php/perfiles/issue/view/4480',
#  'https://perfileseducativos.unam.mx/iisue_pe/index.php/perfiles/issue/view/4481',
#  'https://perfileseducativos.unam.mx/iisue_pe/index.php/perfiles/issue/view/4473',
#  'https://perfileseducativos.unam.mx/iisue_pe/index.php/perfiles/issue/view/4474',
#  'https://perfileseducativos.unam.mx/iisue_pe/index.php/perfiles/issue/view/4475',
#  'https://perfileseducativos.unam.mx/iisue_pe/index.php/perfiles/issue/view/4477',
#  'https://perfileseducativos.unam.mx/iisue_pe/index.php/perfiles/issue/view/4476',
#  'https://perfileseducativos.unam.mx/iisue_pe/index.php/perfiles/issue/view/4469',
#  'https://perfileseducativos.unam.mx/iisue_pe/index.php/perfiles/issue/view/4470',
#  'https://perfileseducativos.unam.mx/iisue_pe/index.php/perfiles/issue/view/4471',
#  'https://perfileseducativos.unam.mx/iisue_pe/index.php/perfiles/issue/view/4472',
#  'https://perfileseducativos.unam.mx/iisue_pe/index.php/perfiles/issue/view/4292',
#  'https://perfileseducativos.unam.mx/iisue_pe/index.php/perfiles/issue/view/4440',
#  'https://perfileseducativos.unam.mx/iisue_pe/index.php/perfiles/issue/view/4450',
#  'https://perfileseducativos.unam.mx/iisue_pe/index.php/perfiles/issue/view/4454',
#  'https://www.iisue.unam.mx/perfiles/numeros/2016/e',
#  'https://perfileseducativos.unam.mx/iisue_pe/index.php/perfiles/issue/view/3770',
#  'https://perfileseducativos.unam.mx/iisue_pe/index.php/perfiles/issue/view/3927',
#  'https://perfileseducativos.unam.mx/iisue_pe/index.php/perfiles/issue/view/4157',
#  'https://perfileseducativos.unam.mx/iisue_pe/index.php/perfiles/issue/view/4160',
#  'https://www.iisue.unam.mx/perfiles/numeros/2015/e',
#  'https://perfileseducativos.unam.mx/iisue_pe/index.php/perfiles/issue/view/3537',
#  'https://perfileseducativos.unam.mx/iisue_pe/index.php/perfiles/issue/view/3686',
#  'https://perfileseducativos.unam.mx/iisue_pe/index.php/perfiles/issue/view/3680',
#  'https://perfileseducativos.unam.mx/iisue_pe/index.php/perfiles/issue/view/3687',
#  'https://perfileseducativos.unam.mx/iisue_pe/index.php/perfiles/issue/view/2877',
#  'https://perfileseducativos.unam.mx/iisue_pe/index.php/perfiles/issue/view/3096',
#  'https://perfileseducativos.unam.mx/iisue_pe/index.php/perfiles/issue/view/3293',
#  'https://perfileseducativos.unam.mx/iisue_pe/index.php/perfiles/issue/view/3432',
#  'https://www.iisue.unam.mx/perfiles/numeros/2013/e',
#  'https://perfileseducativos.unam.mx/iisue_pe/index.php/perfiles/issue/view/2453',
#  'https://perfileseducativos.unam.mx/iisue_pe/index.php/perfiles/issue/view/2603',
#  'https://perfileseducativos.unam.mx/iisue_pe/index.php/perfiles/issue/view/2762',
#  'https://perfileseducativos.unam.mx/iisue_pe/index.php/perfiles/issue/view/2764',
#  'https://www.iisue.unam.mx/perfiles/numeros/2012/e',
#  'https://perfileseducativos.unam.mx/iisue_pe/index.php/perfiles/issue/view/1921',
#  'https://perfileseducativos.unam.mx/iisue_pe/index.php/perfiles/issue/view/2089',
#  'https://perfileseducativos.unam.mx/iisue_pe/index.php/perfiles/issue/view/2331',
#  'https://perfileseducativos.unam.mx/iisue_pe/index.php/perfiles/issue/view/2332',
#  'https://www.iisue.unam.mx/perfiles/numeros/2011/e',
#  'https://perfileseducativos.unam.mx/iisue_pe/index.php/perfiles/issue/view/1546',
#  'https://perfileseducativos.unam.mx/iisue_pe/index.php/perfiles/issue/view/1547',
#  'https://perfileseducativos.unam.mx/iisue_pe/index.php/perfiles/issue/view/1550',
#  'https://perfileseducativos.unam.mx/iisue_pe/index.php/perfiles/issue/view/1718',
#  'https://www.iisue.unam.mx/perfiles/numeros/2010/e',
#  'https://perfileseducativos.unam.mx/iisue_pe/index.php/perfiles/issue/view/1541',
#  'https://perfileseducativos.unam.mx/iisue_pe/index.php/perfiles/issue/view/1542',
#  'https://perfileseducativos.unam.mx/iisue_pe/index.php/perfiles/issue/view/1543',
#  'https://perfileseducativos.unam.mx/iisue_pe/index.php/perfiles/issue/view/1545',
#  'https://www.iisue.unam.mx/perfiles/numeros/2008/119',
#  'https://www.iisue.unam.mx/perfiles/numeros/2008/120',
#  'https://www.iisue.unam.mx/perfiles/numeros/2008/121',
#  'https://www.iisue.unam.mx/perfiles/numeros/2008/122',
#  'https://www.iisue.unam.mx/perfiles/numeros/2007/115',
#  'https://www.iisue.unam.mx/perfiles/numeros/2007/116',
#  'https://www.iisue.unam.mx/perfiles/numeros/2007/117',
#  'https://www.iisue.unam.mx/perfiles/numeros/2007/118',
#  'https://www.iisue.unam.mx/perfiles/numeros/2006/111',
#  'https://www.iisue.unam.mx/perfiles/numeros/2006/112',
#  'https://www.iisue.unam.mx/perfiles/numeros/2006/113',
#  'https://www.iisue.unam.mx/perfiles/numeros/2006/114',
#  'https://www.iisue.unam.mx/perfiles/numeros/2005/107',
#  'https://www.iisue.unam.mx/perfiles/numeros/2005/108',
#  'https://www.iisue.unam.mx/perfiles/numeros/2005/109-110',
#  'https://www.iisue.unam.mx/perfiles/numeros/2004/103',
#  'https://www.iisue.unam.mx/perfiles/numeros/2004/104',
#  'https://www.iisue.unam.mx/perfiles/numeros/2004/105-106',
#  'https://www.iisue.unam.mx/perfiles/numeros/2003/99',
#  'https://www.iisue.unam.mx/perfiles/numeros/2003/100',
#  'https://www.iisue.unam.mx/perfiles/numeros/2003/101',
#  'https://www.iisue.unam.mx/perfiles/numeros/2003/102',
#  'https://www.iisue.unam.mx/perfiles/numeros/2002/95',
#  'https://www.iisue.unam.mx/perfiles/numeros/2002/96',
#  'https://www.iisue.unam.mx/perfiles/numeros/2002/97-98',
#  'https://www.iisue.unam.mx/perfiles/numeros/2001/91',
#  'https://www.iisue.unam.mx/perfiles/numeros/2001/92',
#  'https://www.iisue.unam.mx/perfiles/numeros/2001/93',
#  'https://www.iisue.unam.mx/perfiles/numeros/2001/94',
#  'https://www.iisue.unam.mx/perfiles/numeros/2000/87',
#  'https://www.iisue.unam.mx/perfiles/numeros/2000/88',
#  'https://www.iisue.unam.mx/perfiles/numeros/2000/89-90',
#  'https://www.iisue.unam.mx/perfiles/numeros/1999/83-84',
#  'https://www.iisue.unam.mx/perfiles/numeros/1999/85-86',
#  'https://www.iisue.unam.mx/perfiles/numeros/1998/79-80',
#  'https://www.iisue.unam.mx/perfiles/numeros/1998/81',
#  'https://www.iisue.unam.mx/perfiles/numeros/1998/82',
#  'https://www.iisue.unam.mx/perfiles/numeros/1997/75',
#  'https://www.iisue.unam.mx/perfiles/numeros/1997/76-77',
#  'https://www.iisue.unam.mx/perfiles/numeros/1997/78',
#  'https://www.iisue.unam.mx/perfiles/numeros/1996/71',
#  'https://www.iisue.unam.mx/perfiles/numeros/1996/72',
#  'https://www.iisue.unam.mx/perfiles/numeros/1996/73',
#  'https://www.iisue.unam.mx/perfiles/numeros/1996/74',
#  'https://www.iisue.unam.mx/perfiles/numeros/1995/67',
#  'https://www.iisue.unam.mx/perfiles/numeros/1995/68',
#  'https://www.iisue.unam.mx/perfiles/numeros/1995/69',
#  'https://www.iisue.unam.mx/perfiles/numeros/1995/70',
#  'https://www.iisue.unam.mx/perfiles/numeros/1994/63',
#  'https://www.iisue.unam.mx/perfiles/numeros/1994/64',
#  'https://www.iisue.unam.mx/perfiles/numeros/1994/65',
#  'https://www.iisue.unam.mx/perfiles/numeros/1994/66',
#  'https://www.iisue.unam.mx/perfiles/numeros/1993/59',
#  'https://www.iisue.unam.mx/perfiles/numeros/1993/60',
#  'https://www.iisue.unam.mx/perfiles/numeros/1993/61',
#  'https://www.iisue.unam.mx/perfiles/numeros/1993/62',
#  'https://www.iisue.unam.mx/perfiles/numeros/1992/55-56',
#  'https://www.iisue.unam.mx/perfiles/numeros/1992/57-58',
#  'https://www.iisue.unam.mx/perfiles/numeros/1991/51-52',
#  'https://www.iisue.unam.mx/perfiles/numeros/1991/53-54',
#  'https://www.iisue.unam.mx/perfiles/numeros/1990/47-48',
#  'https://www.iisue.unam.mx/perfiles/numeros/1990/49-50',
#  'https://www.iisue.unam.mx/perfiles/numeros/1989/43-44',
#  'https://www.iisue.unam.mx/perfiles/numeros/1989/45-46',
#  'https://www.iisue.unam.mx/perfiles/numeros/1988/39',
#  'https://www.iisue.unam.mx/perfiles/numeros/1988/40',
#  'https://www.iisue.unam.mx/perfiles/numeros/1988/41-42',
#  'https://www.iisue.unam.mx/perfiles/numeros/1987/35',
#  'https://www.iisue.unam.mx/perfiles/numeros/1987/36',
#  'https://www.iisue.unam.mx/perfiles/numeros/1987/37',
#  'https://www.iisue.unam.mx/perfiles/numeros/1987/38',
#  'https://www.iisue.unam.mx/perfiles/numeros/1986/31',
#  'https://www.iisue.unam.mx/perfiles/numeros/1986/32',
#  'https://www.iisue.unam.mx/perfiles/numeros/1986/33',
#  'https://www.iisue.unam.mx/perfiles/numeros/1986/34',
#  'https://www.iisue.unam.mx/perfiles/numeros/1985/27-28',
#  'https://www.iisue.unam.mx/perfiles/numeros/1985/29-30',
#  'https://www.iisue.unam.mx/perfiles/numeros/1984/4',
#  'https://www.iisue.unam.mx/perfiles/numeros/1984/5',
#  'https://www.iisue.unam.mx/perfiles/numeros/1984/6',
#  'https://www.iisue.unam.mx/perfiles/numeros/1984/7',
#  'https://www.iisue.unam.mx/perfiles/numeros/1983/1',
#  'https://www.iisue.unam.mx/perfiles/numeros/1983/2',
#  'https://www.iisue.unam.mx/perfiles/numeros/1983/3',
#  'https://www.iisue.unam.mx/perfiles/numeros/1983/19',
#  'https://www.iisue.unam.mx/perfiles/numeros/1982/15',
#  'https://www.iisue.unam.mx/perfiles/numeros/1982/16',
#  'https://www.iisue.unam.mx/perfiles/numeros/1982/17',
#  'https://www.iisue.unam.mx/perfiles/numeros/1982/18',
#  'https://www.iisue.unam.mx/perfiles/numeros/1981/11',
#  'https://www.iisue.unam.mx/perfiles/numeros/1981/12',
#  'https://www.iisue.unam.mx/perfiles/numeros/1981/13',
#  'https://www.iisue.unam.mx/perfiles/numeros/1981/14',
#  'https://www.iisue.unam.mx/perfiles/numeros/1980/7',
#  'https://www.iisue.unam.mx/perfiles/numeros/1980/8',
#  'https://www.iisue.unam.mx/perfiles/numeros/1980/9',
#  'https://www.iisue.unam.mx/perfiles/numeros/1980/10',
#  'https://www.iisue.unam.mx/perfiles/numeros/1979/3',
#  'https://www.iisue.unam.mx/perfiles/numeros/1979/4',
#  'https://www.iisue.unam.mx/perfiles/numeros/1979/5',
#  'https://www.iisue.unam.mx/perfiles/numeros/1979/6',
#  'https://www.iisue.unam.mx/perfiles/numeros/1978/1',
#  'https://www.iisue.unam.mx/perfiles/numeros/1978/2']

# %%
def get_url_items(sopa, url): 
    box = soup.find('div', class_='container')
    volumen=box.findAll('div', class_='col-4 col-md-3 col-lg-2')
    vol = [x.find('a').get('href')for x in volumen]
    vol=[urljoin(url_root,i) for i in vol]
    return vol

# %%
links_items=[]
i=0
while i<1:
    i+=1
    print(f'Estoy en la pagina {url_inicial}')
    r_pag=requests.get(url_inicial)
    s_p=BeautifulSoup(r_pag.text,'html.parser')
    links=get_url_items(s_p, url_inicial)
    links_items.append(links)
# Out:
# Estoy en la pagina https://www.iisue.unam.mx/perfiles/numeros-anteriores

# %%
list_scraper=[]
for i in links_items:
    for j in i:
        list_scraper.append(j)
len(list_scraper)
# Out:
# 164

# %%
uno=list_scraper[0]
r_item=requests.get(uno)
s_item=BeautifulSoup(r_item.text, 'html.parser')

# %%
#funcion para iniciar el escraper de cada libro
def scraper_book(url):
    content_book={}
    r=requests.get(url)
    tire='Perfiles Educativos'
    a='V. Ciencias Sociales'
    tem='Investigación Educativa'
    url='http://www.iisue.unam.mx/perfiles'
    s_item=BeautifulSoup(r.text,'html.parser')
    #titulo de revista
    try:
        titulo=tire
        content_book['Titulo de revista']=tire
    except AttributeError:
        content_book['Titulo de revista']=None
    #area
    try:
        area=a
        content_book['Área']=a
    except AttributeError:
        content_book['Área']=None
    #tematica
    try:
        tema=tem
        content_book['Temática']=tem
    except AttributeError:
        content_book['Temática']=None
    #titulo libro
    try:
        titu=s_item.find('div', class_='title').get_text(strip=True)
        content_book['Titulo del libro']=titu
    except AttributeError:
        content_book['Titulo del libro']=None
    #resumen
    try:
        resu=s_item.find('a', class_='cover').get_text(strip=True)
        content_book['Resumen']=resu
    except AttributeError:
        content_book['Resumen']=None
    #Link incial
    try:
        inicial=url
        content_book['Link inicial']=url
    except AttributeError:
        content_book['Link inicial']=None
    #link articulo
    try:
        link=s_item.find('a', class_='obj_galley_link pdf').get('href')
        content_book['Link articulo']=urljoin(url_root, link)
    except AttributeError:
        content_book['Link articulo']=None
    return content_book

# %%
list_scraper=list_scraper[0:164]
datos_book=[]
for idx, i in enumerate(list_scraper):
    print(f'estas escrapeando la pag {idx}')
    datos_book.append(scraper_book(i))
# Out:
# estas escrapeando la pag 0
# estas escrapeando la pag 1
# estas escrapeando la pag 2
# estas escrapeando la pag 3
# estas escrapeando la pag 4
# estas escrapeando la pag 5
# estas escrapeando la pag 6
# estas escrapeando la pag 7
# estas escrapeando la pag 8
# estas escrapeando la pag 9
# estas escrapeando la pag 10
# estas escrapeando la pag 11
# estas escrapeando la pag 12
# estas escrapeando la pag 13
# estas escrapeando la pag 14
# estas escrapeando la pag 15
# estas escrapeando la pag 16
# estas escrapeando la pag 17
# estas escrapeando la pag 18
# estas escrapeando la pag 19
# estas escrapeando la pag 20
# estas escrapeando la pag 21
# estas escrapeando la pag 22
# estas escrapeando la pag 23
# estas escrapeando la pag 24
# estas escrapeando la pag 25
# estas escrapeando la pag 26
# estas escrapeando la pag 27
# estas escrapeando la pag 28
# estas escrapeando la pag 29
# estas escrapeando la pag 30
# estas escrapeando la pag 31
# estas escrapeando la pag 32
# estas escrapeando la pag 33
# estas escrapeando la pag 34
# estas escrapeando la pag 35
# estas escrapeando la pag 36
# estas escrapeando la pag 37
# estas escrapeando la pag 38
# estas escrapeando la pag 39
# estas escrapeando la pag 40
# estas escrapeando la pag 41
# estas escrapeando la pag 42
# estas escrapeando la pag 43
# estas escrapeando la pag 44
# estas escrapeando la pag 45
# estas escrapeando la pag 46
# estas escrapeando la pag 47
# estas escrapeando la pag 48
# estas escrapeando la pag 49
# estas escrapeando la pag 50
# estas escrapeando la pag 51
# estas escrapeando la pag 52
# estas escrapeando la pag 53
# estas escrapeando la pag 54
# estas escrapeando la pag 55
# estas escrapeando la pag 56
# estas escrapeando la pag 57
# estas escrapeando la pag 58
# estas escrapeando la pag 59
# estas escrapeando la pag 60
# estas escrapeando la pag 61
# estas escrapeando la pag 62
# estas escrapeando la pag 63
# estas escrapeando la pag 64
# estas escrapeando la pag 65
# estas escrapeando la pag 66
# estas escrapeando la pag 67
# estas escrapeando la pag 68
# estas escrapeando la pag 69
# estas escrapeando la pag 70
# estas escrapeando la pag 71
# estas escrapeando la pag 72
# estas escrapeando la pag 73
# estas escrapeando la pag 74
# estas escrapeando la pag 75
# estas escrapeando la pag 76
# estas escrapeando la pag 77
# estas escrapeando la pag 78
# estas escrapeando la pag 79
# estas escrapeando la pag 80
# estas escrapeando la pag 81
# estas escrapeando la pag 82
# estas escrapeando la pag 83
# estas escrapeando la pag 84
# estas escrapeando la pag 85
# estas escrapeando la pag 86
# estas escrapeando la pag 87
# estas escrapeando la pag 88
# estas escrapeando la pag 89
# estas escrapeando la pag 90
# estas escrapeando la pag 91
# estas escrapeando la pag 92
# estas escrapeando la pag 93
# estas escrapeando la pag 94
# estas escrapeando la pag 95
# estas escrapeando la pag 96
# estas escrapeando la pag 97
# estas escrapeando la pag 98
# estas escrapeando la pag 99
# estas escrapeando la pag 100
# estas escrapeando la pag 101
# estas escrapeando la pag 102
# estas escrapeando la pag 103
# estas escrapeando la pag 104
# estas escrapeando la pag 105
# estas escrapeando la pag 106
# estas escrapeando la pag 107
# estas escrapeando la pag 108
# estas escrapeando la pag 109
# estas escrapeando la pag 110
# estas escrapeando la pag 111
# estas escrapeando la pag 112
# estas escrapeando la pag 113
# estas escrapeando la pag 114
# estas escrapeando la pag 115
# estas escrapeando la pag 116
# estas escrapeando la pag 117
# estas escrapeando la pag 118
# estas escrapeando la pag 119
# estas escrapeando la pag 120
# estas escrapeando la pag 121
# estas escrapeando la pag 122
# estas escrapeando la pag 123
# estas escrapeando la pag 124
# estas escrapeando la pag 125
# estas escrapeando la pag 126
# estas escrapeando la pag 127
# estas escrapeando la pag 128
# estas escrapeando la pag 129
# estas escrapeando la pag 130
# estas escrapeando la pag 131
# estas escrapeando la pag 132
# estas escrapeando la pag 133
# estas escrapeando la pag 134
# estas escrapeando la pag 135
# estas escrapeando la pag 136
# estas escrapeando la pag 137
# estas escrapeando la pag 138
# estas escrapeando la pag 139
# estas escrapeando la pag 140
# estas escrapeando la pag 141
# estas escrapeando la pag 142
# estas escrapeando la pag 143
# estas escrapeando la pag 144
# estas escrapeando la pag 145
# estas escrapeando la pag 146
# estas escrapeando la pag 147
# estas escrapeando la pag 148
# estas escrapeando la pag 149
# estas escrapeando la pag 150
# estas escrapeando la pag 151
# estas escrapeando la pag 152
# estas escrapeando la pag 153
# estas escrapeando la pag 154
# estas escrapeando la pag 155
# estas escrapeando la pag 156
# estas escrapeando la pag 157
# estas escrapeando la pag 158
# estas escrapeando la pag 159
# estas escrapeando la pag 160
# estas escrapeando la pag 161
# estas escrapeando la pag 162
# estas escrapeando la pag 163

# %%
df_catalogo=pd.DataFrame(datos_book)
df_catalogo
# Out:
#        Titulo de revista                  Área                 Temática  \
# 0    Perfiles Educativos  V. Ciencias Sociales  Investigación Educativa
# 1    Perfiles Educativos  V. Ciencias Sociales  Investigación Educativa
# 2    Perfiles Educativos  V. Ciencias Sociales  Investigación Educativa
# 3    Perfiles Educativos  V. Ciencias Sociales  Investigación Educativa
# 4    Perfiles Educativos  V. Ciencias Sociales  Investigación Educativa
# ..                   ...                   ...                      ...
# 159  Perfiles Educativos  V. Ciencias Sociales  Investigación Educativa
# 160  Perfiles Educativos  V. Ciencias Sociales  Investigación Educativa
# 161  Perfiles Educativos  V. Ciencias Sociales  Investigación Educativa
# 162  Perfiles Educativos  V. Ciencias Sociales  Investigación Educativa
# 163  Perfiles Educativos  V. Ciencias Sociales  Investigación Educativa
#
#                         Titulo del libro Resumen  \
# 0          Vol. 44 Núm. 175: Enero-Marzo
# 1          Vol. 43 Núm. 171: Enero-Marzo
# 2          Vol. 43 Núm. 172: Abril-Junio
# 3     Vol. 43 Núm. 173: Julio-Septiembre
# 4    Vol. 43 Núm. 174: Octubre-Diciembre
# ..                                   ...     ...
# 159                                 None    None
# 160                                 None    None
# 161                                 None    None
# 162                                 None    None
# 163                                 None    None
#
#                           Link inicial  \
# 0    http://www.iisue.unam.mx/perfiles
# 1    http://www.iisue.unam.mx/perfiles
# 2    http://www.iisue.unam.mx/perfiles
# 3    http://www.iisue.unam.mx/perfiles
# 4    http://www.iisue.unam.mx/perfiles
# ..                                 ...
# 159  http://www.iisue.unam.mx/perfiles
# 160  http://www.iisue.unam.mx/perfiles
# 161  http://www.iisue.unam.mx/perfiles
# 162  http://www.iisue.unam.mx/perfiles
# 163  http://www.iisue.unam.mx/perfiles
#
#                                          Link articulo
# 0    https://perfileseducativos.unam.mx/iisue_pe/in...
# 1    https://perfileseducativos.unam.mx/iisue_pe/in...
# 2    https://perfileseducativos.unam.mx/iisue_pe/in...
# 3    https://perfileseducativos.unam.mx/iisue_pe/in...
# 4    https://perfileseducativos.unam.mx/iisue_pe/in...
# ..                                                 ...
# 159                                               None
# 160                                               None
# 161                                               None
# 162                                               None
# 163                                               None
#
# [164 rows x 7 columns]

# %%
df_catalogo.to_csv('Revista51.csv', index=False)
