# %%
import requests
import bs4
from bs4 import BeautifulSoup
from urllib.parse import urljoin
import pandas as pd

# %%
url_inicial = 'https://migracionesinternacionales.colef.mx/index.php/migracionesinternacionales/issue/archive'
url_root = 'https://migracionesinternacionales.colef.mx/index.php/migracionesinternacionales/issue/archive'
r=requests.get(url_inicial)

# %%
soup = BeautifulSoup(r.text, 'html.parser')

# %%
box = soup.find('div', class_='row')
volumen=box.findAll('article', class_='col-md-3 col-lg-2 archived-issue')
vol = [x.find('a').get('href')for x in volumen]
vol=[urljoin(url_root,i) for i in vol]
vol
# Out:
# ['https://migracionesinternacionales.colef.mx/index.php/migracionesinternacionales/issue/view/123',
#  'https://migracionesinternacionales.colef.mx/index.php/migracionesinternacionales/issue/view/121',
#  'https://migracionesinternacionales.colef.mx/index.php/migracionesinternacionales/issue/view/120',
#  'https://migracionesinternacionales.colef.mx/index.php/migracionesinternacionales/issue/view/118',
#  'https://migracionesinternacionales.colef.mx/index.php/migracionesinternacionales/issue/view/112',
#  'https://migracionesinternacionales.colef.mx/index.php/migracionesinternacionales/issue/view/110',
#  'https://migracionesinternacionales.colef.mx/index.php/migracionesinternacionales/issue/view/86',
#  'https://migracionesinternacionales.colef.mx/index.php/migracionesinternacionales/issue/view/39',
#  'https://migracionesinternacionales.colef.mx/index.php/migracionesinternacionales/issue/view/16',
# ...

# %%
vol2 =[]
for i in vol: 
    url_inicial1=i 
    r1 = requests.get(url_inicial1)
    soup1 = BeautifulSoup(r1.text, 'html.parser')
    box1 = soup1.find('section', class_='issue-section') 
    volumen1=box1.findAll('div', class_='col-md-8 offset-md-4')
    vol1 = [x.find('a').get('href')for x in volumen1]
    vol2+=vol1

# %%
vol2
# Out:
# ['https://migracionesinternacionales.colef.mx/index.php/migracionesinternacionales/article/view/2340',
#  'https://migracionesinternacionales.colef.mx/index.php/migracionesinternacionales/article/view/2410',
#  'https://migracionesinternacionales.colef.mx/index.php/migracionesinternacionales/article/view/2431',
#  'https://migracionesinternacionales.colef.mx/index.php/migracionesinternacionales/article/view/2385',
#  'https://migracionesinternacionales.colef.mx/index.php/migracionesinternacionales/article/view/2311',
#  'https://migracionesinternacionales.colef.mx/index.php/migracionesinternacionales/article/view/2491',
#  'https://migracionesinternacionales.colef.mx/index.php/migracionesinternacionales/article/view/2336',
#  'https://migracionesinternacionales.colef.mx/index.php/migracionesinternacionales/article/view/2419',
#  'https://migracionesinternacionales.colef.mx/index.php/migracionesinternacionales/article/view/2483',
# ...

# %%
def get_url_items(sopa,url):
    box1 = soup1.find('section', class_='issue-section') 
    volumen1=box1.findAll('div', class_='col-md-8 offset-md-4')
    vol1 = [x.find('a').get('href')for x in volumen1]
    return vol2

# %%
links_items=[]
i=0
while i<1:
    i+=1
    print(f'Estoy en la pagina {url_inicial}')
    r_pag=requests.get(url_inicial)
    s_p=BeautifulSoup(r_pag.text,'html.parser')
    links=get_url_items(s_p, url_inicial)
    links_items.append(links) 
    next_a=s_p.select('li.next > a')
    if not next_a or not next_a[0].get('href'):
        break
# Out:
# Estoy en la pagina https://migracionesinternacionales.colef.mx/index.php/migracionesinternacionales/issue/archive

# %%
list_scraper=[]
for i in links_items:
    for j in i:
        list_scraper.append(j)
len(list_scraper)
# Out:
# 299

# %%
uno=list_scraper[0]
r_item=requests.get(uno)
s_item=BeautifulSoup(r_item.text, 'html.parser')

# %%
#funcion para iniciar el escraper de cada libro
def scraper_book(url):
    content_book={}
    r=requests.get(url)
    tire='Migraciones Internacionales'
    a='V. Ciencias Sociales'
    tem='Demografía, Geografía, Planeación y Desarrollo'
    s_item=BeautifulSoup(r.text,'html.parser')
 #titulo de revista
    try:
        titulo=tire
        content_book['Titulo Revista']=tire
    except AttributeError:
        content_book['Titulo Revista']=None
    #area
    try:
        area=a
        content_book['Area']=a
    except AttributeError:
        content_book['Area']=None
    #tematica
    try:
        tema=tem
        content_book['Tematica']=tem
    except AttributeError:
        content_book['Tematica']=None
    #titulo articulo
    try:
        titu=s_item.find('h1', class_='article-page__title').get_text(strip=True)
        content_book['Titulo Articulo']=titu
    except AttributeError:
        content_book['Titulo Articulo']=None
    #resumen
    try:
        resu=s_item.find('h3', class_='resumen')
        content_book['Resumen']=resu.find_next_sibling('p').get_text(strip=True)
    except AttributeError:
        content_book['Resumen']=None
    #abstract
    try:
        abst=s_item.find('div', id='item cover_image').get_text(strip=True)
        content_book['Abstract']=abst
    except AttributeError:
        content_book['Abstract']=None
    #Link incial
    try:
        linkart=url
        content_book['Link Articulo']=linkart
    except AttributeError:
        content_book['Link Articulo']=None
    #link articulo
    try:
        link=s_item.find('a', class_='article__btn pdf').get('href')
        content_book['Link PDF']=urljoin(url_root, link)
    except AttributeError:
        content_book['Link PDF']=None
    return content_book

# %%
list_scraper=list_scraper[0:299]
datos_book=[]
for idx, i in enumerate(list_scraper):
    print(f'estas escrapeando la pag {idx}')
    datos_book.append(scraper_book(i))
# Out:
# estas escrapeando la pag 0
# estas escrapeando la pag 1
# estas escrapeando la pag 2
# estas escrapeando la pag 3
# estas escrapeando la pag 4
# estas escrapeando la pag 5
# estas escrapeando la pag 6
# estas escrapeando la pag 7
# estas escrapeando la pag 8
# estas escrapeando la pag 9
# estas escrapeando la pag 10
# estas escrapeando la pag 11
# estas escrapeando la pag 12
# estas escrapeando la pag 13
# estas escrapeando la pag 14
# estas escrapeando la pag 15
# estas escrapeando la pag 16
# estas escrapeando la pag 17
# estas escrapeando la pag 18
# estas escrapeando la pag 19
# estas escrapeando la pag 20
# estas escrapeando la pag 21
# estas escrapeando la pag 22
# estas escrapeando la pag 23
# estas escrapeando la pag 24
# estas escrapeando la pag 25
# estas escrapeando la pag 26
# estas escrapeando la pag 27
# estas escrapeando la pag 28
# estas escrapeando la pag 29
# estas escrapeando la pag 30
# estas escrapeando la pag 31
# estas escrapeando la pag 32
# ...

# %%
df_catalogo=pd.DataFrame(datos_book)
df_catalogo
# Out:
#                   Titulo Revista                  Area  \
# 0    Migraciones Internacionales  V. Ciencias Sociales
# 1    Migraciones Internacionales  V. Ciencias Sociales
# 2    Migraciones Internacionales  V. Ciencias Sociales
# 3    Migraciones Internacionales  V. Ciencias Sociales
# 4    Migraciones Internacionales  V. Ciencias Sociales
# ..                           ...                   ...
# 294  Migraciones Internacionales  V. Ciencias Sociales
# 295  Migraciones Internacionales  V. Ciencias Sociales
# 296  Migraciones Internacionales  V. Ciencias Sociales
# 297  Migraciones Internacionales  V. Ciencias Sociales
# 298  Migraciones Internacionales  V. Ciencias Sociales
#
#                                            Tematica  \
# 0    Demografía, Geografía, Planeación y Desarrollo
# 1    Demografía, Geografía, Planeación y Desarrollo
# 2    Demografía, Geografía, Planeación y Desarrollo
# 3    Demografía, Geografía, Planeación y Desarrollo
# ...

# %%
df_catalogo.to_csv('Revista67.csv', index=False)
