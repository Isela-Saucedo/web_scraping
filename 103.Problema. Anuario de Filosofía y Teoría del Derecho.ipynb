# %%
import requests
import bs4
from bs4 import BeautifulSoup
from urllib.parse import urljoin
import pandas as pd

# %%
url_inicial = 'https://revistas.juridicas.unam.mx/index.php/filosofia-derecho/issue/archive'
url_root = 'https://revistas.juridicas.unam.mx/index.php/filosofia-derecho/issue/archive'
r=requests.get(url_inicial)

# %%
soup = BeautifulSoup(r.text, 'html.parser')

# %%
box = soup.find('div', class_='issues media-list')
volumen=box.findAll('div', class_='issue-summary media')
vol = [x.find('a').get('href')for x in volumen]
vol=[urljoin(url_root,i) for i in vol]
vol
# Out:
# ['https://revistas.juridicas.unam.mx/index.php/filosofia-derecho/issue/view/689',
#  'https://revistas.juridicas.unam.mx/index.php/filosofia-derecho/issue/view/667',
#  'https://revistas.juridicas.unam.mx/index.php/filosofia-derecho/issue/view/644',
#  'https://revistas.juridicas.unam.mx/index.php/filosofia-derecho/issue/view/616',
#  'https://revistas.juridicas.unam.mx/index.php/filosofia-derecho/issue/view/587',
#  'https://revistas.juridicas.unam.mx/index.php/filosofia-derecho/issue/view/555',
#  'https://revistas.juridicas.unam.mx/index.php/filosofia-derecho/issue/view/379',
#  'https://revistas.juridicas.unam.mx/index.php/filosofia-derecho/issue/view/378',
#  'https://revistas.juridicas.unam.mx/index.php/filosofia-derecho/issue/view/377',
#  'https://revistas.juridicas.unam.mx/index.php/filosofia-derecho/issue/view/376',
#  'https://revistas.juridicas.unam.mx/index.php/filosofia-derecho/issue/view/375',
#  'https://revistas.juridicas.unam.mx/index.php/filosofia-derecho/issue/view/374',
#  'https://revistas.juridicas.unam.mx/index.php/filosofia-derecho/issue/view/373',
#  'https://revistas.juridicas.unam.mx/index.php/filosofia-derecho/issue/view/372',
#  'https://revistas.juridicas.unam.mx/index.php/filosofia-derecho/issue/view/371',
#  'https://revistas.juridicas.unam.mx/index.php/filosofia-derecho/issue/view/370']

# %%
def get_url_items(sopa, url): 
    box = soup.find('div', class_='issues media-list')
    volumen=box.findAll('div', class_='issue-summary media')
    vol = [x.find('a').get('href')for x in volumen]
    vol=[urljoin(url_root,i) for i in vol]
    return vol

# %%
links_items=[]
i=0
while i<1:
    i+=1
    print(f'Estoy en la pagina {url_inicial}')
    r_pag=requests.get(url_inicial)
    s_p=BeautifulSoup(r_pag.text,'html.parser')
    links=get_url_items(s_p, url_inicial)
    links_items.append(links)
# Out:
# Estoy en la pagina https://revistas.juridicas.unam.mx/index.php/filosofia-derecho/issue/archive

# %%
list_scraper=[]
for i in links_items:
    for j in i:
        list_scraper.append(j)
len(list_scraper)
# Out:
# 16

# %%
uno=list_scraper[0]
r_item=requests.get(uno)
s_item=BeautifulSoup(r_item.text, 'html.parser')

# %%
#funcion para iniciar el escraper de cada libro
def scraper_book(url):
    content_book={}
    r=requests.get(url)
    tire='Problema. Anuario de Filosofía y Teoría del Derecho'
    a='V. Ciencias Sociales'
    tem='Filosofía Jurídica, Política, y Moral'
    url='https://revistas.juridicas.unam.mx/index.php/filosofia-derecho'
    s_item=BeautifulSoup(r.text,'html.parser')
    #titulo de revista
    try:
        titulo=tire
        content_book['Titulo de revista']=tire
    except AttributeError:
        content_book['Titulo de revista']=None
    #area
    try:
        area=a
        content_book['Área']=a
    except AttributeError:
        content_book['Área']=None
    #tematica
    try:
        tema=tem
        content_book['Temática']=tem
    except AttributeError:
        content_book['Temática']=None
    #titulo libro
    try:
        titu=s_item.find('li', class_='active').get_text(strip=True)
        content_book['Titulo del libro']=titu
    except AttributeError:
        content_book['Titulo del libro']=None
    #resumen
    try:
        resu=s_item.find('a', class_='cover').get_text(strip=True)
        content_book['Resumen']=resu
    except AttributeError:
        content_book['Resumen']=None
    #Link incial
    try:
        inicial=url
        content_book['Link inicial']=url
    except AttributeError:
        content_book['Link inicial']=None
    #link articulo
    try:
        link=s_item.find('a', class_='galley-link btn btn-primary pdf').get('href')
        content_book['Link articulo']=urljoin(url_root, link)
    except AttributeError:
        content_book['Link articulo']=None
    return content_book

# %%
list_scraper=list_scraper[0:16]
datos_book=[]
for idx, i in enumerate(list_scraper):
    print(f'estas escrapeando la pag {idx}')
    datos_book.append(scraper_book(i))
# Out:
# estas escrapeando la pag 0
# estas escrapeando la pag 1
# estas escrapeando la pag 2
# estas escrapeando la pag 3
# estas escrapeando la pag 4
# estas escrapeando la pag 5
# estas escrapeando la pag 6
# estas escrapeando la pag 7
# estas escrapeando la pag 8
# estas escrapeando la pag 9
# estas escrapeando la pag 10
# estas escrapeando la pag 11
# estas escrapeando la pag 12
# estas escrapeando la pag 13
# estas escrapeando la pag 14
# estas escrapeando la pag 15

# %%
df_catalogo=pd.DataFrame(datos_book)
df_catalogo
# Out:
#                                     Titulo de revista                  Área  \
# 0   Problema. Anuario de Filosofía y Teoría del De...  V. Ciencias Sociales
# 1   Problema. Anuario de Filosofía y Teoría del De...  V. Ciencias Sociales
# 2   Problema. Anuario de Filosofía y Teoría del De...  V. Ciencias Sociales
# 3   Problema. Anuario de Filosofía y Teoría del De...  V. Ciencias Sociales
# 4   Problema. Anuario de Filosofía y Teoría del De...  V. Ciencias Sociales
# 5   Problema. Anuario de Filosofía y Teoría del De...  V. Ciencias Sociales
# 6   Problema. Anuario de Filosofía y Teoría del De...  V. Ciencias Sociales
# 7   Problema. Anuario de Filosofía y Teoría del De...  V. Ciencias Sociales
# 8   Problema. Anuario de Filosofía y Teoría del De...  V. Ciencias Sociales
# 9   Problema. Anuario de Filosofía y Teoría del De...  V. Ciencias Sociales
# 10  Problema. Anuario de Filosofía y Teoría del De...  V. Ciencias Sociales
# 11  Problema. Anuario de Filosofía y Teoría del De...  V. Ciencias Sociales
# 12  Problema. Anuario de Filosofía y Teoría del De...  V. Ciencias Sociales
# 13  Problema. Anuario de Filosofía y Teoría del De...  V. Ciencias Sociales
# 14  Problema. Anuario de Filosofía y Teoría del De...  V. Ciencias Sociales
# 15  Problema. Anuario de Filosofía y Teoría del De...  V. Ciencias Sociales
#
#                                  Temática                    Titulo del libro  \
# 0   Filosofía Jurídica, Política, y Moral  Número 16, enero-diciembre de 2022
# 1   Filosofía Jurídica, Política, y Moral  Número 15, enero-diciembre de 2021
# 2   Filosofía Jurídica, Política, y Moral  Número 14, enero-diciembre de 2020
# 3   Filosofía Jurídica, Política, y Moral  Número 13, enero-diciembre de 2019
# 4   Filosofía Jurídica, Política, y Moral  Número 12, enero-diciembre de 2018
# 5   Filosofía Jurídica, Política, y Moral  Número 11, enero-diciembre de 2017
# 6   Filosofía Jurídica, Política, y Moral  Número 10, enero-diciembre de 2016
# 7   Filosofía Jurídica, Política, y Moral                            Número 9
# 8   Filosofía Jurídica, Política, y Moral                            Número 8
# 9   Filosofía Jurídica, Política, y Moral                            Número 7
# 10  Filosofía Jurídica, Política, y Moral                            Número 6
# 11  Filosofía Jurídica, Política, y Moral                            Número 5
# 12  Filosofía Jurídica, Política, y Moral                            Número 4
# 13  Filosofía Jurídica, Política, y Moral                            Número 3
# 14  Filosofía Jurídica, Política, y Moral                            Número 2
# 15  Filosofía Jurídica, Política, y Moral                            Número 1
#
#    Resumen                                       Link inicial  \
# 0           https://revistas.juridicas.unam.mx/index.php/f...
# 1           https://revistas.juridicas.unam.mx/index.php/f...
# 2           https://revistas.juridicas.unam.mx/index.php/f...
# 3           https://revistas.juridicas.unam.mx/index.php/f...
# 4           https://revistas.juridicas.unam.mx/index.php/f...
# 5           https://revistas.juridicas.unam.mx/index.php/f...
# 6           https://revistas.juridicas.unam.mx/index.php/f...
# 7           https://revistas.juridicas.unam.mx/index.php/f...
# 8           https://revistas.juridicas.unam.mx/index.php/f...
# 9           https://revistas.juridicas.unam.mx/index.php/f...
# 10          https://revistas.juridicas.unam.mx/index.php/f...
# 11          https://revistas.juridicas.unam.mx/index.php/f...
# 12          https://revistas.juridicas.unam.mx/index.php/f...
# 13          https://revistas.juridicas.unam.mx/index.php/f...
# 14          https://revistas.juridicas.unam.mx/index.php/f...
# 15          https://revistas.juridicas.unam.mx/index.php/f...
#
#                                         Link articulo
# 0   https://revistas.juridicas.unam.mx/index.php/f...
# 1   https://revistas.juridicas.unam.mx/index.php/f...
# 2   https://revistas.juridicas.unam.mx/index.php/f...
# 3   https://revistas.juridicas.unam.mx/index.php/f...
# 4   https://revistas.juridicas.unam.mx/index.php/f...
# 5   https://revistas.juridicas.unam.mx/index.php/f...
# 6   https://revistas.juridicas.unam.mx/index.php/f...
# 7   https://revistas.juridicas.unam.mx/index.php/f...
# 8   https://revistas.juridicas.unam.mx/index.php/f...
# 9   https://revistas.juridicas.unam.mx/index.php/f...
# 10  https://revistas.juridicas.unam.mx/index.php/f...
# 11  https://revistas.juridicas.unam.mx/index.php/f...
# 12  https://revistas.juridicas.unam.mx/index.php/f...
# 13  https://revistas.juridicas.unam.mx/index.php/f...
# 14  https://revistas.juridicas.unam.mx/index.php/f...
# 15  https://revistas.juridicas.unam.mx/index.php/f...

# %%
df_catalogo.to_csv('Revista103.csv', index=False)
