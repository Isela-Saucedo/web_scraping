# %%
import requests
import bs4
from bs4 import BeautifulSoup
from urllib.parse import urljoin
import pandas as pd

# %%
url_inicial = 'https://sinectica.iteso.mx/index.php/SINECTICA/issue/archive'
url_root = 'https://sinectica.iteso.mx/index.php/SINECTICA/issue/archive'
r=requests.get(url_inicial)

# %%
soup = BeautifulSoup(r.text, 'html.parser')

# %%
box = soup.find('ul', class_='issues_archive')
volumen=box.findAll('div', class_='obj_issue_summary')
vol = [x.find('a').get('href')for x in volumen]
vol=[urljoin(url_root,i) for i in vol]
vol
# Out:
# ['https://sinectica.iteso.mx/index.php/SINECTICA/issue/view/61',
#  'https://sinectica.iteso.mx/index.php/SINECTICA/issue/view/60',
#  'https://sinectica.iteso.mx/index.php/SINECTICA/issue/view/59',
#  'https://sinectica.iteso.mx/index.php/SINECTICA/issue/view/58',
#  'https://sinectica.iteso.mx/index.php/SINECTICA/issue/view/57',
#  'https://sinectica.iteso.mx/index.php/SINECTICA/issue/view/56',
#  'https://sinectica.iteso.mx/index.php/SINECTICA/issue/view/55',
#  'https://sinectica.iteso.mx/index.php/SINECTICA/issue/view/54',
#  'https://sinectica.iteso.mx/index.php/SINECTICA/issue/view/53',
#  'https://sinectica.iteso.mx/index.php/SINECTICA/issue/view/52',
#  'https://sinectica.iteso.mx/index.php/SINECTICA/issue/view/51',
#  'https://sinectica.iteso.mx/index.php/SINECTICA/issue/view/50',
#  'https://sinectica.iteso.mx/index.php/SINECTICA/issue/view/49',
#  'https://sinectica.iteso.mx/index.php/SINECTICA/issue/view/1',
# ...

# %%
def get_url_items(sopa, url): 
    box = soup.find('ul', class_='issues_archive')
    volumen=box.findAll('div', class_='obj_issue_summary')
    vol = [x.find('a').get('href')for x in volumen]
    vol=[urljoin(url_root,i) for i in vol]
    return vol

# %%
links_items=[]
i=0
while i<1:
    i+=1
    print(f'Estoy en la pagina {url_inicial}')
    r_pag=requests.get(url_inicial)
    s_p=BeautifulSoup(r_pag.text,'html.parser')
    links=get_url_items(s_p, url_inicial)
    links_items.append(links)
# Out:
# Estoy en la pagina https://sinectica.iteso.mx/index.php/SINECTICA/issue/archive

# %%
list_scraper=[]
for i in links_items:
    for j in i:
        list_scraper.append(j)
len(list_scraper)
# Out:
# 25

# %%
uno=list_scraper[0]
r_item=requests.get(uno)
s_item=BeautifulSoup(r_item.text, 'html.parser')

# %%
#funcion para iniciar el escraper de cada libro
def scraper_book(url):
    content_book={}
    r=requests.get(url)
    tire='Sinéctica. Revista Electrónica de Educación'
    a='IV. Humanidades y Ciencias de la Conducta'
    tem='Artes y Humanidades'
    url='https://sinectica.iteso.mx'
    s_item=BeautifulSoup(r.text,'html.parser')
    #titulo de revista
    try:
        titulo=tire
        content_book['Titulo de revista']=tire
    except AttributeError:
        content_book['Titulo de revista']=None
    #area
    try:
        area=a
        content_book['Área']=a
    except AttributeError:
        content_book['Área']=None
    #tematica
    try:
        tema=tem
        content_book['Temática']=tem
    except AttributeError:
        content_book['Temática']=None
    #titulo libro
    try:
        titu=s_item.find('h1').get_text(strip=True)
        content_book['Titulo del libro']=titu
    except AttributeError:
        content_book['Titulo del libro']=None
    #resumen
    try:
        resu=s_item.find('div', class_='description').get_text(strip=True)
        content_book['Resumen']=resu
    except AttributeError:
        content_book['Resumen']=None
    #Link incial
    try:
        inicial=url
        content_book['Link inicial']=url
    except AttributeError:
        content_book['Link inicial']=None
    #link articulo
    try:
        link=s_item.find('a', class_='obj_galley_link pdf').get('href')
        content_book['Link articulo']=urljoin(url_root, link)
    except AttributeError:
        content_book['Link articulo']=None
    return content_book

# %%
list_scraper=list_scraper[0:25]
datos_book=[]
for idx, i in enumerate(list_scraper):
    print(f'estas escrapeando la pag {idx}')
    datos_book.append(scraper_book(i))
# Out:
# estas escrapeando la pag 0
# estas escrapeando la pag 1
# estas escrapeando la pag 2
# estas escrapeando la pag 3
# estas escrapeando la pag 4
# estas escrapeando la pag 5
# estas escrapeando la pag 6
# estas escrapeando la pag 7
# estas escrapeando la pag 8
# estas escrapeando la pag 9
# estas escrapeando la pag 10
# estas escrapeando la pag 11
# estas escrapeando la pag 12
# estas escrapeando la pag 13
# estas escrapeando la pag 14
# estas escrapeando la pag 15
# estas escrapeando la pag 16
# estas escrapeando la pag 17
# estas escrapeando la pag 18
# estas escrapeando la pag 19
# estas escrapeando la pag 20
# estas escrapeando la pag 21
# estas escrapeando la pag 22
# estas escrapeando la pag 23
# estas escrapeando la pag 24

# %%
df_catalogo=pd.DataFrame(datos_book)
df_catalogo
# Out:
#                               Titulo de revista  \
# 0   Sinéctica. Revista Electrónica de Educación
# 1   Sinéctica. Revista Electrónica de Educación
# 2   Sinéctica. Revista Electrónica de Educación
# 3   Sinéctica. Revista Electrónica de Educación
# 4   Sinéctica. Revista Electrónica de Educación
# 5   Sinéctica. Revista Electrónica de Educación
# 6   Sinéctica. Revista Electrónica de Educación
# 7   Sinéctica. Revista Electrónica de Educación
# 8   Sinéctica. Revista Electrónica de Educación
# 9   Sinéctica. Revista Electrónica de Educación
# 10  Sinéctica. Revista Electrónica de Educación
# 11  Sinéctica. Revista Electrónica de Educación
# 12  Sinéctica. Revista Electrónica de Educación
# 13  Sinéctica. Revista Electrónica de Educación
# 14  Sinéctica. Revista Electrónica de Educación
# 15  Sinéctica. Revista Electrónica de Educación
# 16  Sinéctica. Revista Electrónica de Educación
# 17  Sinéctica. Revista Electrónica de Educación
# ...

# %%
df_catalogo.to_csv('Revista169.01.csv', index=False)
