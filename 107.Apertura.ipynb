# %%
import requests
import bs4
from bs4 import BeautifulSoup
from urllib.parse import urljoin
import pandas as pd

# %%
url_inicial = 'http://www.udgvirtual.udg.mx/apertura/index.php/apertura/issue/archive'
url_root = 'http://www.udgvirtual.udg.mx/apertura/index.php/apertura/issue/archive'
r=requests.get(url_inicial)

# %%
soup = BeautifulSoup(r.text, 'html.parser')

# %%
box = soup.find('div', id='issues')
volumen=box.findAll('div', id='issue')
vol = [x.find('a').get('href')for x in volumen]
vol=[urljoin(url_root,i) for i in vol]
vol
# Out:
# ['http://www.udgvirtual.udg.mx/apertura/index.php/apertura/issue/view/Ap.v14n1',
#  'http://www.udgvirtual.udg.mx/apertura/index.php/apertura/issue/view/Ap.v13n2',
#  'http://www.udgvirtual.udg.mx/apertura/index.php/apertura/issue/view/137',
#  'http://www.udgvirtual.udg.mx/apertura/index.php/apertura/issue/view/136',
#  'http://www.udgvirtual.udg.mx/apertura/index.php/apertura/issue/view/135',
#  'http://www.udgvirtual.udg.mx/apertura/index.php/apertura/issue/view/132',
#  'http://www.udgvirtual.udg.mx/apertura/index.php/apertura/issue/view/130',
#  'http://www.udgvirtual.udg.mx/apertura/index.php/apertura/issue/view/129',
#  'http://www.udgvirtual.udg.mx/apertura/index.php/apertura/issue/view/128',
#  'http://www.udgvirtual.udg.mx/apertura/index.php/apertura/issue/view/125',
#  'http://www.udgvirtual.udg.mx/apertura/index.php/apertura/issue/view/90',
#  'http://www.udgvirtual.udg.mx/apertura/index.php/apertura/issue/view/89',
# ...

# %%
def get_url_items(sopa, url): 
    box = soup.find('div', id='issues')
    volumen=box.findAll('div', id='issue')
    vol = [x.find('a').get('href')for x in volumen]
    vol=[urljoin(url_root,i) for i in vol]
    return vol

# %%
links_items=[]
i=0
while i<1:
    i+=1
    print(f'Estoy en la pagina {url_inicial}')
    r_pag=requests.get(url_inicial)
    s_p=BeautifulSoup(r_pag.text,'html.parser')
    links=get_url_items(s_p, url_inicial)
    links_items.append(links)
# Out:
# Estoy en la pagina http://www.udgvirtual.udg.mx/apertura/index.php/apertura/issue/archive

# %%
list_scraper=[]
for i in links_items:
    for j in i:
        list_scraper.append(j)
len(list_scraper)
# Out:
# 60

# %%
uno=list_scraper[0]
r_item=requests.get(uno)
s_item=BeautifulSoup(r_item.text, 'html.parser')

# %%
#funcion para iniciar el escraper de cada libro
def scraper_book(url):
    content_book={}
    r=requests.get(url)
    tire='Apertura'
    a='V. Ciencias Sociales'
    tem='Educación'
    url='http://www.udgvirtual.udg.mx/apertura/index.php/apertura/index'
    s_item=BeautifulSoup(r.text,'html.parser')
    #titulo de revista
    try:
        titulo=tire
        content_book['Titulo de revista']=tire
    except AttributeError:
        content_book['Titulo de revista']=None
    #area
    try:
        area=a
        content_book['Área']=a
    except AttributeError:
        content_book['Área']=None
    #tematica
    try:
        tema=tem
        content_book['Temática']=tem
    except AttributeError:
        content_book['Temática']=None
    #titulo libro
    try:
        titu=s_item.find('h3').get_text(strip=True)
        content_book['Titulo del libro']=titu
    except AttributeError:
        content_book['Titulo del libro']=None
    #resumen
    try:
        resu=s_item.find('a', class_='cover').get_text(strip=True)
        content_book['Resumen']=resu
    except AttributeError:
        content_book['Resumen']=None
    #Link incial
    try:
        inicial=url
        content_book['Link inicial']=url
    except AttributeError:
        content_book['Link inicial']=None
    #link articulo
    try:
        link=s_item.find('a', class_='file').get('href')
        content_book['Link articulo']=urljoin(url_root, link)
    except AttributeError:
        content_book['Link articulo']=None
    return content_book

# %%
list_scraper=list_scraper[0:60]
datos_book=[]
for idx, i in enumerate(list_scraper):
    print(f'estas escrapeando la pag {idx}')
    datos_book.append(scraper_book(i))
# Out:
# estas escrapeando la pag 0
# estas escrapeando la pag 1
# estas escrapeando la pag 2
# estas escrapeando la pag 3
# estas escrapeando la pag 4
# estas escrapeando la pag 5
# estas escrapeando la pag 6
# estas escrapeando la pag 7
# estas escrapeando la pag 8
# estas escrapeando la pag 9
# estas escrapeando la pag 10
# estas escrapeando la pag 11
# estas escrapeando la pag 12
# estas escrapeando la pag 13
# estas escrapeando la pag 14
# estas escrapeando la pag 15
# estas escrapeando la pag 16
# estas escrapeando la pag 17
# estas escrapeando la pag 18
# estas escrapeando la pag 19
# estas escrapeando la pag 20
# estas escrapeando la pag 21
# estas escrapeando la pag 22
# estas escrapeando la pag 23
# estas escrapeando la pag 24
# estas escrapeando la pag 25
# estas escrapeando la pag 26
# estas escrapeando la pag 27
# estas escrapeando la pag 28
# estas escrapeando la pag 29
# estas escrapeando la pag 30
# estas escrapeando la pag 31
# estas escrapeando la pag 32
# ...

# %%
df_catalogo=pd.DataFrame(datos_book)
df_catalogo
# Out:
#    Titulo de revista                  Área   Temática  \
# 0           Apertura  V. Ciencias Sociales  Educación
# 1           Apertura  V. Ciencias Sociales  Educación
# 2           Apertura  V. Ciencias Sociales  Educación
# 3           Apertura  V. Ciencias Sociales  Educación
# 4           Apertura  V. Ciencias Sociales  Educación
# 5           Apertura  V. Ciencias Sociales  Educación
# 6           Apertura  V. Ciencias Sociales  Educación
# 7           Apertura  V. Ciencias Sociales  Educación
# 8           Apertura  V. Ciencias Sociales  Educación
# 9           Apertura  V. Ciencias Sociales  Educación
# 10          Apertura  V. Ciencias Sociales  Educación
# 11          Apertura  V. Ciencias Sociales  Educación
# 12          Apertura  V. Ciencias Sociales  Educación
# 13          Apertura  V. Ciencias Sociales  Educación
# 14          Apertura  V. Ciencias Sociales  Educación
# 15          Apertura  V. Ciencias Sociales  Educación
# ...

# %%
df_catalogo.to_csv('Revista107.csv', index=False)
