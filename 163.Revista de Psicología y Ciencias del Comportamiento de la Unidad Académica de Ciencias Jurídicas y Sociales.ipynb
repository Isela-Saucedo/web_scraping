# %%
import requests
import bs4
from bs4 import BeautifulSoup
from urllib.parse import urljoin
import pandas as pd

# %%
url_inicial = 'https://revistapcc.uat.edu.mx/index.php/RPC/issue/archive'
url_root = 'https://revistapcc.uat.edu.mx/index.php/RPC/issue/archive'
r=requests.get(url_inicial)

# %%
soup = BeautifulSoup(r.text, 'html.parser')

# %%
box = soup.find('ul', class_='issues_archive')
volumen=box.findAll('div', class_='obj_issue_summary')
vol = [x.find('a').get('href')for x in volumen]
vol=[urljoin(url_root,i) for i in vol]
vol
# Out:
# ['https://revistapcc.uat.edu.mx/index.php/RPC/issue/view/43',
#  'https://revistapcc.uat.edu.mx/index.php/RPC/issue/view/42',
#  'https://revistapcc.uat.edu.mx/index.php/RPC/issue/view/41',
#  'https://revistapcc.uat.edu.mx/index.php/RPC/issue/view/40',
#  'https://revistapcc.uat.edu.mx/index.php/RPC/issue/view/39',
#  'https://revistapcc.uat.edu.mx/index.php/RPC/issue/view/38',
#  'https://revistapcc.uat.edu.mx/index.php/RPC/issue/view/Vol.%2010%2C%20N%C3%BAm.%201',
#  'https://revistapcc.uat.edu.mx/index.php/RPC/issue/view/Vol.%209%2C%20N%C3%BAm.%202',
#  'https://revistapcc.uat.edu.mx/index.php/RPC/issue/view/Volume%209%2C%20Issue%201',
#  'https://revistapcc.uat.edu.mx/index.php/RPC/issue/view/Vol.%208%2C%20N%C3%BAm.%202',
#  'https://revistapcc.uat.edu.mx/index.php/RPC/issue/view/Vol.%208%2C%20N%C3%BAm.%201',
#  'https://revistapcc.uat.edu.mx/index.php/RPC/issue/view/Vol.%207%2C%20N%C3%BAm.%202',
#  'https://revistapcc.uat.edu.mx/index.php/RPC/issue/view/Vol.%207%2C%20N%C3%BAm.%201',
#  'https://revistapcc.uat.edu.mx/index.php/RPC/issue/view/Vol.%206%2C%20N%C3%BAm.%202',
#  'https://revistapcc.uat.edu.mx/index.php/RPC/issue/view/Vol.%206%2C%20N%C3%BAm.%201',
#  'https://revistapcc.uat.edu.mx/index.php/RPC/issue/view/Vol.%205%2C%20N%C3%BAm.%202',
#  'https://revistapcc.uat.edu.mx/index.php/RPC/issue/view/Vol.%205%2C%20N%C3%BAm.%201',
#  'https://revistapcc.uat.edu.mx/index.php/RPC/issue/view/Vol.%204%2C%20N%C3%BAm.%202',
#  'https://revistapcc.uat.edu.mx/index.php/RPC/issue/view/Vol.%204%2C%20N%C3%BAm.%201',
#  'https://revistapcc.uat.edu.mx/index.php/RPC/issue/view/Vol.%203%2C%20N%C3%BAm.%202']

# %%
def get_url_items(sopa, url): 
    box = soup.find('ul', class_='issues_archive')
    volumen=box.findAll('div', class_='obj_issue_summary')
    vol = [x.find('a').get('href')for x in volumen]
    vol=[urljoin(url_root,i) for i in vol]
    return vol

# %%
links_items=[]
i=0
while i<1:
    i+=1
    print(f'Estoy en la pagina {url_inicial}')
    r_pag=requests.get(url_inicial)
    s_p=BeautifulSoup(r_pag.text,'html.parser')
    links=get_url_items(s_p, url_inicial)
    links_items.append(links)
# Out:
# Estoy en la pagina https://revistapcc.uat.edu.mx/index.php/RPC/issue/archive

# %%
list_scraper=[]
for i in links_items:
    for j in i:
        list_scraper.append(j)
len(list_scraper)
# Out:
# 20

# %%
uno=list_scraper[0]
r_item=requests.get(uno)
s_item=BeautifulSoup(r_item.text, 'html.parser')

# %%
#funcion para iniciar el escraper de cada libro
def scraper_book(url):
    content_book={}
    r=requests.get(url)
    tire='Revista de Psicología y Ciencias del Comportamiento de la Unidad Académica de Ciencias Jurídicas y Sociales'
    a='Multidisciplinaria'
    tem='Multidisciplinar'
    url='https://revistapcc.uat.edu.mx/index.php/RPC'
    s_item=BeautifulSoup(r.text,'html.parser')
    #titulo de revista
    try:
        titulo=tire
        content_book['Titulo de revista']=tire
    except AttributeError:
        content_book['Titulo de revista']=None
    #area
    try:
        area=a
        content_book['Área']=a
    except AttributeError:
        content_book['Área']=None
    #tematica
    try:
        tema=tem
        content_book['Temática']=tem
    except AttributeError:
        content_book['Temática']=None
    #titulo libro
    try:
        titu=s_item.find('h3', class_='title').get_text(strip=True)
        content_book['Titulo del libro']=titu
    except AttributeError:
        content_book['Titulo del libro']=None
    #resumen
    try:
        resu=s_item.find('a', class_='cover').get_text(strip=True)
        content_book['Resumen']=resu
    except AttributeError:
        content_book['Resumen']=None
    #Link incial
    try:
        inicial=url
        content_book['Link inicial']=url
    except AttributeError:
        content_book['Link inicial']=None
    #link articulo
    try:
        link=s_item.find('a', class_='obj_galley_link pdf').get('href')
        content_book['Link articulo']=urljoin(url_root, link)
    except AttributeError:
        content_book['Link articulo']=None
    return content_book

# %%
list_scraper=list_scraper[0:20]
datos_book=[]
for idx, i in enumerate(list_scraper):
    print(f'estas escrapeando la pag {idx}')
    datos_book.append(scraper_book(i))
# Out:
# estas escrapeando la pag 0
# estas escrapeando la pag 1
# estas escrapeando la pag 2
# estas escrapeando la pag 3
# estas escrapeando la pag 4
# estas escrapeando la pag 5
# estas escrapeando la pag 6
# estas escrapeando la pag 7
# estas escrapeando la pag 8
# estas escrapeando la pag 9
# estas escrapeando la pag 10
# estas escrapeando la pag 11
# estas escrapeando la pag 12
# estas escrapeando la pag 13
# estas escrapeando la pag 14
# estas escrapeando la pag 15
# estas escrapeando la pag 16
# estas escrapeando la pag 17
# estas escrapeando la pag 18
# estas escrapeando la pag 19

# %%
df_catalogo=pd.DataFrame(datos_book)
df_catalogo
# Out:
#                                     Titulo de revista                Área  \
# 0   Revista de Psicología y Ciencias del Comportam...  Multidisciplinaria
# 1   Revista de Psicología y Ciencias del Comportam...  Multidisciplinaria
# 2   Revista de Psicología y Ciencias del Comportam...  Multidisciplinaria
# 3   Revista de Psicología y Ciencias del Comportam...  Multidisciplinaria
# 4   Revista de Psicología y Ciencias del Comportam...  Multidisciplinaria
# 5   Revista de Psicología y Ciencias del Comportam...  Multidisciplinaria
# 6   Revista de Psicología y Ciencias del Comportam...  Multidisciplinaria
# 7   Revista de Psicología y Ciencias del Comportam...  Multidisciplinaria
# 8   Revista de Psicología y Ciencias del Comportam...  Multidisciplinaria
# 9   Revista de Psicología y Ciencias del Comportam...  Multidisciplinaria
# 10  Revista de Psicología y Ciencias del Comportam...  Multidisciplinaria
# 11  Revista de Psicología y Ciencias del Comportam...  Multidisciplinaria
# 12  Revista de Psicología y Ciencias del Comportam...  Multidisciplinaria
# 13  Revista de Psicología y Ciencias del Comportam...  Multidisciplinaria
# 14  Revista de Psicología y Ciencias del Comportam...  Multidisciplinaria
# 15  Revista de Psicología y Ciencias del Comportam...  Multidisciplinaria
# 16  Revista de Psicología y Ciencias del Comportam...  Multidisciplinaria
# 17  Revista de Psicología y Ciencias del Comportam...  Multidisciplinaria
# 18  Revista de Psicología y Ciencias del Comportam...  Multidisciplinaria
# 19  Revista de Psicología y Ciencias del Comportam...  Multidisciplinaria
#
#             Temática                                   Titulo del libro  \
# 0   Multidisciplinar                                          Editorial
# 1   Multidisciplinar                                          EDITORIAL
# 2   Multidisciplinar  Posicionamiento e imagen de las apps de entreg...
# 3   Multidisciplinar  Sugerencias para la organización de la dinámic...
# 4   Multidisciplinar                      Editorial Volumen 11 Número 1
# 5   Multidisciplinar                      Editorial Volumen 10 Número 2
# 6   Multidisciplinar  Diez años divulgando y promoviendo ciencia, RP...
# 7   Multidisciplinar  La Psicología del Tránsito, una necesidad urge...
# 8   Multidisciplinar                   EDITORIAL DEL VOLUMEN 9 NÚMERO 1
# 9   Multidisciplinar  La calidad del reporte científico. Apuntes sob...
# 10  Multidisciplinar            Contribuciones del volumen 8, número 1.
# 11  Multidisciplinar            Contribuciones del volumen 7, número 2.
# 12  Multidisciplinar                      Editorial Volumen 7, Número 1
# 13  Multidisciplinar                    El comportamiento de la ciencia
# 14  Multidisciplinar                      Editorial Volumen 6, Número 1
# 15  Multidisciplinar  El poder de las minorías y la representación s...
# 16  Multidisciplinar  La psicología en el sur de Tamaulipas: reflexi...
# 17  Multidisciplinar  Lo “exo” en el comportamiento humano: de la ex...
# 18  Multidisciplinar                   Editorial del Volumen 4 Número 1
# 19  Multidisciplinar                       Editorial Volumen 3 Número 2
#
#    Resumen                                 Link inicial  \
# 0           https://revistapcc.uat.edu.mx/index.php/RPC
# 1           https://revistapcc.uat.edu.mx/index.php/RPC
# 2           https://revistapcc.uat.edu.mx/index.php/RPC
# 3           https://revistapcc.uat.edu.mx/index.php/RPC
# 4           https://revistapcc.uat.edu.mx/index.php/RPC
# 5           https://revistapcc.uat.edu.mx/index.php/RPC
# 6           https://revistapcc.uat.edu.mx/index.php/RPC
# 7           https://revistapcc.uat.edu.mx/index.php/RPC
# 8           https://revistapcc.uat.edu.mx/index.php/RPC
# 9           https://revistapcc.uat.edu.mx/index.php/RPC
# 10          https://revistapcc.uat.edu.mx/index.php/RPC
# 11          https://revistapcc.uat.edu.mx/index.php/RPC
# 12          https://revistapcc.uat.edu.mx/index.php/RPC
# 13          https://revistapcc.uat.edu.mx/index.php/RPC
# 14          https://revistapcc.uat.edu.mx/index.php/RPC
# 15          https://revistapcc.uat.edu.mx/index.php/RPC
# 16          https://revistapcc.uat.edu.mx/index.php/RPC
# 17          https://revistapcc.uat.edu.mx/index.php/RPC
# 18          https://revistapcc.uat.edu.mx/index.php/RPC
# 19          https://revistapcc.uat.edu.mx/index.php/RPC
#
#                                         Link articulo
# 0   https://revistapcc.uat.edu.mx/index.php/RPC/ar...
# 1   https://revistapcc.uat.edu.mx/index.php/RPC/ar...
# 2   https://revistapcc.uat.edu.mx/index.php/RPC/ar...
# 3   https://revistapcc.uat.edu.mx/index.php/RPC/ar...
# 4   https://revistapcc.uat.edu.mx/index.php/RPC/ar...
# 5   https://revistapcc.uat.edu.mx/index.php/RPC/ar...
# 6   https://revistapcc.uat.edu.mx/index.php/RPC/ar...
# 7   https://revistapcc.uat.edu.mx/index.php/RPC/ar...
# 8   https://revistapcc.uat.edu.mx/index.php/RPC/ar...
# 9   https://revistapcc.uat.edu.mx/index.php/RPC/ar...
# 10  https://revistapcc.uat.edu.mx/index.php/RPC/ar...
# 11  https://revistapcc.uat.edu.mx/index.php/RPC/ar...
# 12  https://revistapcc.uat.edu.mx/index.php/RPC/ar...
# 13  https://revistapcc.uat.edu.mx/index.php/RPC/ar...
# 14  https://revistapcc.uat.edu.mx/index.php/RPC/ar...
# 15  https://revistapcc.uat.edu.mx/index.php/RPC/ar...
# 16  https://revistapcc.uat.edu.mx/index.php/RPC/ar...
# 17  https://revistapcc.uat.edu.mx/index.php/RPC/ar...
# 18  https://revistapcc.uat.edu.mx/index.php/RPC/ar...
# 19  https://revistapcc.uat.edu.mx/index.php/RPC/ar...

# %%
df_catalogo.to_csv('Revista163.csv', index=False)
