# %%
import requests
import bs4
from bs4 import BeautifulSoup
from urllib.parse import urljoin
import pandas as pd

# %%
url_inicial = 'https://revistas-filologicas.unam.mx/literatura-mexicana/index.php/lm/issue/archive'
url_root = 'https://revistas-filologicas.unam.mx/literatura-mexicana/index.php/lm/issue/archive'
r=requests.get(url_inicial)

# %%
soup = BeautifulSoup(r.text, 'html.parser')

# %%
box = soup.find('div', id='issues')
volumen=box.findAll('div', style='float: left; width: 100%;')
vol = [x.find('a').get('href')for x in volumen]
vol=[urljoin(url_root,i) for i in vol]
vol
# Out:
# ['https://revistas-filologicas.unam.mx/literatura-mexicana/index.php/lm/issue/view/75',
#  'https://revistas-filologicas.unam.mx/literatura-mexicana/index.php/lm/issue/view/73',
#  'https://revistas-filologicas.unam.mx/literatura-mexicana/index.php/lm/issue/view/71',
#  'https://revistas-filologicas.unam.mx/literatura-mexicana/index.php/lm/issue/view/69',
#  'https://revistas-filologicas.unam.mx/literatura-mexicana/index.php/lm/issue/view/67',
#  'https://revistas-filologicas.unam.mx/literatura-mexicana/index.php/lm/issue/view/61',
#  'https://revistas-filologicas.unam.mx/literatura-mexicana/index.php/lm/issue/view/58',
#  'https://revistas-filologicas.unam.mx/literatura-mexicana/index.php/lm/issue/view/51',
#  'https://revistas-filologicas.unam.mx/literatura-mexicana/index.php/lm/issue/view/49',
#  'https://revistas-filologicas.unam.mx/literatura-mexicana/index.php/lm/issue/view/47',
#  'https://revistas-filologicas.unam.mx/literatura-mexicana/index.php/lm/issue/view/45',
# ...

# %%
vol2 =[]
for i in vol: 
    url_inicial1=i 
    r1 = requests.get(url_inicial1)
    soup1 = BeautifulSoup(r1.text, 'html.parser')
    box1 = soup1.find('div', id='content') 
    volumen1=box1.findAll('table', class_='tocArticle')
    vol1 = [x.find('a').get('href')for x in volumen1]
    vol2+=vol1

# %%
vol2
# Out:
# ['https://revistas-filologicas.unam.mx/literatura-mexicana/index.php/lm/article/view/1252',
#  'https://revistas-filologicas.unam.mx/literatura-mexicana/index.php/lm/article/view/1247',
#  'https://revistas-filologicas.unam.mx/literatura-mexicana/index.php/lm/article/view/1254',
#  'https://revistas-filologicas.unam.mx/literatura-mexicana/index.php/lm/article/view/1244',
#  'https://revistas-filologicas.unam.mx/literatura-mexicana/index.php/lm/article/view/1246',
#  'https://revistas-filologicas.unam.mx/literatura-mexicana/index.php/lm/article/view/1242',
#  'https://revistas-filologicas.unam.mx/literatura-mexicana/index.php/lm/article/view/1243',
#  'https://revistas-filologicas.unam.mx/literatura-mexicana/index.php/lm/article/view/1253',
#  'https://revistas-filologicas.unam.mx/literatura-mexicana/index.php/lm/article/view/1255/1364',
#  'https://revistas-filologicas.unam.mx/literatura-mexicana/index.php/lm/article/view/1256/1365',
# ...

# %%
def get_url_items(sopa,url):
    box1 = soup1.find('div', id='content') 
    volumen1=box1.findAll('table', class_='tocArticle')
    vol1 = [x.find('a').get('href')for x in volumen1]
    return vol2

# %%
links_items=[]
i=0
while i<1:
    i+=1
    print(f'Estoy en la pagina {url_inicial}')
    r_pag=requests.get(url_inicial)
    s_p=BeautifulSoup(r_pag.text,'html.parser')
    links=get_url_items(s_p, url_inicial)
    links_items.append(links)
# Out:
# Estoy en la pagina https://revistas-filologicas.unam.mx/literatura-mexicana/index.php/lm/issue/archive

# %%
list_scraper=[]
for i in links_items:
    for j in i:
        list_scraper.append(j)
len(list_scraper)
# Out:
# 537

# %%
uno=list_scraper[0]
r_item=requests.get(uno)
s_item=BeautifulSoup(r_item.text, 'html.parser')

# %%
#funcion para iniciar el escraper de cada libro
def scraper_book(url):
    content_book={}
    r=requests.get(url)
    tire='Literatura Mexicana'
    a='IV. Humanidades y Ciencias de la Conducta'
    tem='Literatura Mexicana'
    s_item=BeautifulSoup(r.text,'html.parser')
    #titulo de revista
    try:
        titulo=tire
        content_book['Titulo Revista']=tire
    except AttributeError:
        content_book['Titulo Revista']=None
    #area
    try:
        area=a
        content_book['Area']=a
    except AttributeError:
        content_book['Area']=None
    #tematica
    try:
        tema=tem
        content_book['Tematica']=tem
    except AttributeError:
        content_book['Tematica']=None
    #titulo articulo
    try:
        titu=s_item.find('div', id='articleTitle').get_text(strip=True)
        content_book['Titulo Articulo']=titu
    except AttributeError:
        content_book['Titulo Articulo']=None
    #resumen
    try:
        resu=s_item.find('div', id='articleAbstract').get_text(strip=True)
        content_book['Resumen']=resu.replace("Resumen","")
    except AttributeError:
        content_book['Resumen']=None
    #abstract
    try:
        abst=s_item.find('div', id='item cover_image').get_text(strip=True)
        content_book['Abstract']=abst
    except AttributeError:
        content_book['Abstract']=None
    #Link incial
    try:
        linkart=url
        content_book['Link Articulo']=linkart
    except AttributeError:
        content_book['Link Articulo']=None
    #link articulo
    try:
        link=s_item.find('a', class_='file pdfBig').get('href')
        content_book['Link PDF']=urljoin(url_root, link)
    except AttributeError:
        content_book['Link PDF']=None
    return content_book

# %%
list_scraper=list_scraper[0:537]
datos_book=[]
for idx, i in enumerate(list_scraper):
    print(f'estas escrapeando la pag {idx}')
    datos_book.append(scraper_book(i))
# Out:
# estas escrapeando la pag 0
# estas escrapeando la pag 1
# estas escrapeando la pag 2
# estas escrapeando la pag 3
# estas escrapeando la pag 4
# estas escrapeando la pag 5
# estas escrapeando la pag 6
# estas escrapeando la pag 7
# estas escrapeando la pag 8
# estas escrapeando la pag 9
# estas escrapeando la pag 10
# estas escrapeando la pag 11
# estas escrapeando la pag 12
# estas escrapeando la pag 13
# estas escrapeando la pag 14
# estas escrapeando la pag 15
# estas escrapeando la pag 16
# estas escrapeando la pag 17
# estas escrapeando la pag 18
# estas escrapeando la pag 19
# estas escrapeando la pag 20
# estas escrapeando la pag 21
# estas escrapeando la pag 22
# estas escrapeando la pag 23
# estas escrapeando la pag 24
# estas escrapeando la pag 25
# estas escrapeando la pag 26
# estas escrapeando la pag 27
# estas escrapeando la pag 28
# estas escrapeando la pag 29
# estas escrapeando la pag 30
# estas escrapeando la pag 31
# estas escrapeando la pag 32
# ...

# %%
df_catalogo=pd.DataFrame(datos_book)
df_catalogo
# Out:
#           Titulo Revista                                       Area  \
# 0    Literatura Mexicana  IV. Humanidades y Ciencias de la Conducta
# 1    Literatura Mexicana  IV. Humanidades y Ciencias de la Conducta
# 2    Literatura Mexicana  IV. Humanidades y Ciencias de la Conducta
# 3    Literatura Mexicana  IV. Humanidades y Ciencias de la Conducta
# 4    Literatura Mexicana  IV. Humanidades y Ciencias de la Conducta
# ..                   ...                                        ...
# 532  Literatura Mexicana  IV. Humanidades y Ciencias de la Conducta
# 533  Literatura Mexicana  IV. Humanidades y Ciencias de la Conducta
# 534  Literatura Mexicana  IV. Humanidades y Ciencias de la Conducta
# 535  Literatura Mexicana  IV. Humanidades y Ciencias de la Conducta
# 536  Literatura Mexicana  IV. Humanidades y Ciencias de la Conducta
#
#                 Tematica                                    Titulo Articulo  \
# ...

# %%
df_catalogo.to_csv('Revista145.csv', index=False)
