# %%
import requests
import bs4
from bs4 import BeautifulSoup
from urllib.parse import urljoin
import pandas as pd

# %%
url_inicial = 'https://chapingo-cori.mx/geografia/geografia/issue/archive'
url_root = 'https://chapingo-cori.mx/geografia/geografia/issue/archive'
r=requests.get(url_inicial)

# %%
soup = BeautifulSoup(r.text, 'html.parser')

# %%
box = soup.find('div', class_='container page-archives')
volumen=box.findAll('div', class_='col-md-3 col-lg-2')
vol = [x.find('a').get('href')for x in volumen]
vol=[urljoin(url_root,i) for i in vol]
vol
# Out:
# ['https://chapingo-cori.mx/geografia/geografia/issue/view/16',
#  'https://chapingo-cori.mx/geografia/geografia/issue/view/12',
#  'https://chapingo-cori.mx/geografia/geografia/issue/view/10',
#  'https://chapingo-cori.mx/geografia/geografia/issue/view/9',
#  'https://chapingo-cori.mx/geografia/geografia/issue/view/8',
#  'https://chapingo-cori.mx/geografia/geografia/issue/view/2',
#  'https://chapingo-cori.mx/geografia/geografia/issue/view/1',
#  'https://chapingo-cori.mx/geografia/geografia/issue/view/3',
#  'https://chapingo-cori.mx/geografia/geografia/issue/view/4',
#  'https://chapingo-cori.mx/geografia/geografia/issue/view/5',
#  'https://chapingo-cori.mx/geografia/geografia/issue/view/6',
#  'https://chapingo-cori.mx/geografia/geografia/issue/view/7']

# %%
vol2 =[]
for i in vol: 
    url_inicial1=i 
    r1 = requests.get(url_inicial1)
    soup1 = BeautifulSoup(r1.text, 'html.parser')
    box1 = soup1.find('div', class_='issue-toc') 
    volumen1=box1.findAll('div', class_='article-summary')
    vol1 = [x.find('a').get('href')for x in volumen1]
    vol2+=vol1

# %%
vol2
# Out:
# ['https://chapingo-cori.mx/geografia/geografia/article/view/r.rga.2022.69.01',
#  'https://chapingo-cori.mx/geografia/geografia/article/view/r.rga.2022.69.02',
#  'https://chapingo-cori.mx/geografia/geografia/article/view/r.rga.2022.68.presentation',
#  'https://chapingo-cori.mx/geografia/geografia/article/view/r.rga.2021.68.01',
#  'https://chapingo-cori.mx/geografia/geografia/article/view/r.rga.2021.68.02',
#  'https://chapingo-cori.mx/geografia/geografia/article/view/r.rga.2021.68.03',
#  'https://chapingo-cori.mx/geografia/geografia/article/view/r.rga.2022.68.04',
#  'https://chapingo-cori.mx/geografia/geografia/article/view/r.rga.2019.68.05',
#  'https://chapingo-cori.mx/geografia/geografia/article/view/r.rga.2021.68.06',
#  'https://chapingo-cori.mx/geografia/geografia/article/view/r.rga.2022.68.07',
#  'https://chapingo-cori.mx/geografia/geografia/article/view/r.rga.2019.68.09',
#  'https://chapingo-cori.mx/geografia/geografia/article/view/r.rga.2022.068.bookreview',
#  'https://chapingo-cori.mx/geografia/geografia/article/view/189',
#  'https://chapingo-cori.mx/geografia/geografia/article/view/r.rga.2021.67.01',
#  'https://chapingo-cori.mx/geografia/geografia/article/view/r.rga.2021.67.02',
#  'https://chapingo-cori.mx/geografia/geografia/article/view/r.rga.2021.67.03',
#  'https://chapingo-cori.mx/geografia/geografia/article/view/r.rga.2021.67.04',
#  'https://chapingo-cori.mx/geografia/geografia/article/view/r.rga.2021.67.05',
#  'https://chapingo-cori.mx/geografia/geografia/article/view/r.rga.2021.67.06',
#  'https://chapingo-cori.mx/geografia/geografia/article/view/r.rga.2021.67.07',
#  'https://chapingo-cori.mx/geografia/geografia/article/view/r.rga.2021.67.08',
#  'https://chapingo-cori.mx/geografia/geografia/article/view/190',
#  'https://chapingo-cori.mx/geografia/geografia/article/view/168',
#  'https://chapingo-cori.mx/geografia/geografia/article/view/r.rga.2021.66.01',
#  'https://chapingo-cori.mx/geografia/geografia/article/view/r.rga.2021.66.02',
#  'https://chapingo-cori.mx/geografia/geografia/article/view/r.rga.2021.66.03',
#  'https://chapingo-cori.mx/geografia/geografia/article/view/r.rga.2019.66.04',
#  'https://chapingo-cori.mx/geografia/geografia/article/view/r.rga.2021.66.05',
#  'https://chapingo-cori.mx/geografia/geografia/article/view/r.rga.2021.66.06',
#  'https://chapingo-cori.mx/geografia/geografia/article/view/r.rga.2021.66.07',
#  'https://chapingo-cori.mx/geografia/geografia/article/view/r.rga.2021.66.08',
#  'https://chapingo-cori.mx/geografia/geografia/article/view/r.rga.2021.66.09',
#  'https://chapingo-cori.mx/geografia/geografia/article/view/138',
#  'https://chapingo-cori.mx/geografia/geografia/article/view/r.rga.2019.65.01',
#  'https://chapingo-cori.mx/geografia/geografia/article/view/r.rga.2020.65.02',
#  'https://chapingo-cori.mx/geografia/geografia/article/view/r.rga.2020.65.03',
#  'https://chapingo-cori.mx/geografia/geografia/article/view/r.rga.2020.65.04',
#  'https://chapingo-cori.mx/geografia/geografia/article/view/r.rga.2020.65.05',
#  'https://chapingo-cori.mx/geografia/geografia/article/view/r.rga.2020.65.06',
#  'https://chapingo-cori.mx/geografia/geografia/article/view/86',
#  'https://chapingo-cori.mx/geografia/geografia/article/view/r.rga.2019.64.01',
#  'https://chapingo-cori.mx/geografia/geografia/article/view/r.rga.2019.64.02',
#  'https://chapingo-cori.mx/geografia/geografia/article/view/r.rga.2019.64.03',
#  'https://chapingo-cori.mx/geografia/geografia/article/view/r.rga.2019.64.04',
#  'https://chapingo-cori.mx/geografia/geografia/article/view/r.rga.2019.64.05',
#  'https://chapingo-cori.mx/geografia/geografia/article/view/r.rga.2019.64.06',
#  'https://chapingo-cori.mx/geografia/geografia/article/view/r.rga.2020.64.07',
#  'https://chapingo-cori.mx/geografia/geografia/article/view/r.rga.2020.64.08',
#  'https://chapingo-cori.mx/geografia/geografia/article/view/r.rga.2019.64.10',
#  'https://chapingo-cori.mx/geografia/geografia/article/view/rga.2019.64.11',
#  'https://chapingo-cori.mx/geografia/geografia/article/view/r.rga.2020.64.12',
#  'https://chapingo-cori.mx/geografia/geografia/article/view/82',
#  'https://chapingo-cori.mx/geografia/geografia/article/view/1',
#  'https://chapingo-cori.mx/geografia/geografia/article/view/r.rga.2019.63.03',
#  'https://chapingo-cori.mx/geografia/geografia/article/view/r.rga.2019.63.08',
#  'https://chapingo-cori.mx/geografia/geografia/article/view/r.rga.2019.63.09',
#  'https://chapingo-cori.mx/geografia/geografia/article/view/r.rga.2018.63.01',
#  'https://chapingo-cori.mx/geografia/geografia/article/view/r.rga.2019.63.04',
#  'https://chapingo-cori.mx/geografia/geografia/article/view/r.rga.2019.63.02',
#  'https://chapingo-cori.mx/geografia/geografia/article/view/r.rga.2017.63.05',
#  'https://chapingo-cori.mx/geografia/geografia/article/view/r.rga.2019.63.07',
#  'https://chapingo-cori.mx/geografia/geografia/article/view/11',
#  'https://chapingo-cori.mx/geografia/geografia/article/view/12',
#  'https://chapingo-cori.mx/geografia/geografia/article/view/14',
#  'https://chapingo-cori.mx/geografia/geografia/article/view/27',
#  'https://chapingo-cori.mx/geografia/geografia/article/view/r.rga.2018.62.06',
#  'https://chapingo-cori.mx/geografia/geografia/article/view/r.rga.2019.62.01',
#  'https://chapingo-cori.mx/geografia/geografia/article/view/r.rga.2019.62.03',
#  'https://chapingo-cori.mx/geografia/geografia/article/view/r.rga.2018.62.05',
#  'https://chapingo-cori.mx/geografia/geografia/article/view/r.rga.2018.62.04',
#  'https://chapingo-cori.mx/geografia/geografia/article/view/r.rga.2018.62.02',
#  'https://chapingo-cori.mx/geografia/geografia/article/view/r.rga.2018.62.07',
#  'https://chapingo-cori.mx/geografia/geografia/article/view/37',
#  'https://chapingo-cori.mx/geografia/geografia/article/view/39',
#  'https://chapingo-cori.mx/geografia/geografia/article/view/41',
#  'https://chapingo-cori.mx/geografia/geografia/article/view/r.rga.2017.61.02',
#  'https://chapingo-cori.mx/geografia/geografia/article/view/r.rga.2017.60.005',
#  'https://chapingo-cori.mx/geografia/geografia/article/view/r.rga.2018.61.11',
#  'https://chapingo-cori.mx/geografia/geografia/article/view/r.rga.2018.61.14',
#  'https://chapingo-cori.mx/geografia/geografia/article/view/r.rga.2017.61.05',
#  'https://chapingo-cori.mx/geografia/geografia/article/view/r.rga.2017.61.04',
#  'https://chapingo-cori.mx/geografia/geografia/article/view/r.rga.2017.61.03',
#  'https://chapingo-cori.mx/geografia/geografia/article/view/r.rga.2018.61.10',
#  'https://chapingo-cori.mx/geografia/geografia/article/view/50',
#  'https://chapingo-cori.mx/geografia/geografia/article/view/51',
#  'https://chapingo-cori.mx/geografia/geografia/article/view/52',
#  'https://chapingo-cori.mx/geografia/geografia/article/view/53',
#  'https://chapingo-cori.mx/geografia/geografia/article/view/r.rga.2017.59.007',
#  'https://chapingo-cori.mx/geografia/geografia/article/view/r.rga.2018.60.002',
#  'https://chapingo-cori.mx/geografia/geografia/article/view/r.rga.2018.60.003',
#  'https://chapingo-cori.mx/geografia/geografia/article/view/58',
#  'https://chapingo-cori.mx/geografia/geografia/article/view/r.rga.2017.59.004',
#  'https://chapingo-cori.mx/geografia/geografia/article/view/r.rga.2017.59.005',
#  'https://chapingo-cori.mx/geografia/geografia/article/view/r.rga.2017.59.001',
#  'https://chapingo-cori.mx/geografia/geografia/article/view/r.rga.2017.59.003',
#  'https://chapingo-cori.mx/geografia/geografia/article/view/r.rga.2017.59.002',
#  'https://chapingo-cori.mx/geografia/geografia/article/view/r.rga.2017.59.006',
#  'https://chapingo-cori.mx/geografia/geografia/article/view/66',
#  'https://chapingo-cori.mx/geografia/geografia/article/view/67',
#  'https://chapingo-cori.mx/geografia/geografia/article/view/r.rga.2017.58.002',
#  'https://chapingo-cori.mx/geografia/geografia/article/view/r.rga.2017.58.003',
#  'https://chapingo-cori.mx/geografia/geografia/article/view/r.rga.2017.58.001',
#  'https://chapingo-cori.mx/geografia/geografia/article/view/r.rga.2017.58.004']

# %%
def get_url_items(sopa,url):
    box1 = soup1.find('div', class_='issue-toc') 
    volumen1=box1.findAll('div', class_='article-summary')
    vol1 = [x.find('a').get('href')for x in volumen1]
    return vol2

# %%
links_items=[]
i=0
while i<1:
    i+=1
    print(f'Estoy en la pagina {url_inicial}')
    r_pag=requests.get(url_inicial)
    s_p=BeautifulSoup(r_pag.text,'html.parser')
    links=get_url_items(s_p, url_inicial)
    links_items.append(links)
# Out:
# Estoy en la pagina https://chapingo-cori.mx/geografia/geografia/issue/archive

# %%
list_scraper=[]
for i in links_items:
    for j in i:
        list_scraper.append(j)
len(list_scraper)
# Out:
# 103

# %%
uno=list_scraper[0]
r_item=requests.get(uno)
s_item=BeautifulSoup(r_item.text, 'html.parser')

# %%
#funcion para iniciar el escraper de cada libro
def scraper_book(url):
    content_book={}
    r=requests.get(url)
    tire='Revista de Geografía Agrícola'
    a='V. Ciencias Sociales'
    tem='Estudios Regionales y Desarrollo Rural'
    s_item=BeautifulSoup(r.text,'html.parser')
    #titulo de revista
    try:
        titulo=tire
        content_book['Titulo Revista']=tire
    except AttributeError:
        content_book['Titulo Revista']=None
    #area
    try:
        area=a
        content_book['Area']=a
    except AttributeError:
        content_book['Area']=None
    #tematica
    try:
        tema=tem
        content_book['Tematica']=tem
    except AttributeError:
        content_book['Tematica']=None
    #titulo articulo
    try:
        titu=s_item.find('h1', class_='article-details-fulltitle').get_text(strip=True)
        content_book['Titulo Articulo']=titu
    except AttributeError:
        content_book['Titulo Articulo']=None
    #resumen
    try:
        resu=s_item.find('div', class_='article-details-block article-details-abstract').get_text(strip=True)
        content_book['Resumen']=resu.replace("Resumen","")
    except AttributeError:
        content_book['Resumen']=None
    #abstract
    try:
        abst=s_item.find('div', id='item cover_image').get_text(strip=True)
        content_book['Abstract']=abst
    except AttributeError:
        content_book['Abstract']=None
    #Link incial
    try:
        linkart=url
        content_book['Link Articulo']=linkart
    except AttributeError:
        content_book['Link Articulo']=None
    #link articulo
    try:
        link=s_item.find('a', class_='btn btn-primary').get('href')
        content_book['Link PDF']=urljoin(url_root, link)
    except AttributeError:
        content_book['Link PDF']=None
    return content_book

# %%
list_scraper=list_scraper[0:103]
datos_book=[]
for idx, i in enumerate(list_scraper):
    print(f'estas escrapeando la pag {idx}')
    datos_book.append(scraper_book(i))
# Out:
# estas escrapeando la pag 0
# estas escrapeando la pag 1
# estas escrapeando la pag 2
# estas escrapeando la pag 3
# estas escrapeando la pag 4
# estas escrapeando la pag 5
# estas escrapeando la pag 6
# estas escrapeando la pag 7
# estas escrapeando la pag 8
# estas escrapeando la pag 9
# estas escrapeando la pag 10
# estas escrapeando la pag 11
# estas escrapeando la pag 12
# estas escrapeando la pag 13
# estas escrapeando la pag 14
# estas escrapeando la pag 15
# estas escrapeando la pag 16
# estas escrapeando la pag 17
# estas escrapeando la pag 18
# estas escrapeando la pag 19
# estas escrapeando la pag 20
# estas escrapeando la pag 21
# estas escrapeando la pag 22
# estas escrapeando la pag 23
# estas escrapeando la pag 24
# estas escrapeando la pag 25
# estas escrapeando la pag 26
# estas escrapeando la pag 27
# estas escrapeando la pag 28
# estas escrapeando la pag 29
# estas escrapeando la pag 30
# estas escrapeando la pag 31
# estas escrapeando la pag 32
# estas escrapeando la pag 33
# estas escrapeando la pag 34
# estas escrapeando la pag 35
# estas escrapeando la pag 36
# estas escrapeando la pag 37
# estas escrapeando la pag 38
# estas escrapeando la pag 39
# estas escrapeando la pag 40
# estas escrapeando la pag 41
# estas escrapeando la pag 42
# estas escrapeando la pag 43
# estas escrapeando la pag 44
# estas escrapeando la pag 45
# estas escrapeando la pag 46
# estas escrapeando la pag 47
# estas escrapeando la pag 48
# estas escrapeando la pag 49
# estas escrapeando la pag 50
# estas escrapeando la pag 51
# estas escrapeando la pag 52
# estas escrapeando la pag 53
# estas escrapeando la pag 54
# estas escrapeando la pag 55
# estas escrapeando la pag 56
# estas escrapeando la pag 57
# estas escrapeando la pag 58
# estas escrapeando la pag 59
# estas escrapeando la pag 60
# estas escrapeando la pag 61
# estas escrapeando la pag 62
# estas escrapeando la pag 63
# estas escrapeando la pag 64
# estas escrapeando la pag 65
# estas escrapeando la pag 66
# estas escrapeando la pag 67
# estas escrapeando la pag 68
# estas escrapeando la pag 69
# estas escrapeando la pag 70
# estas escrapeando la pag 71
# estas escrapeando la pag 72
# estas escrapeando la pag 73
# estas escrapeando la pag 74
# estas escrapeando la pag 75
# estas escrapeando la pag 76
# estas escrapeando la pag 77
# estas escrapeando la pag 78
# estas escrapeando la pag 79
# estas escrapeando la pag 80
# estas escrapeando la pag 81
# estas escrapeando la pag 82
# estas escrapeando la pag 83
# estas escrapeando la pag 84
# estas escrapeando la pag 85
# estas escrapeando la pag 86
# estas escrapeando la pag 87
# estas escrapeando la pag 88
# estas escrapeando la pag 89
# estas escrapeando la pag 90
# estas escrapeando la pag 91
# estas escrapeando la pag 92
# estas escrapeando la pag 93
# estas escrapeando la pag 94
# estas escrapeando la pag 95
# estas escrapeando la pag 96
# estas escrapeando la pag 97
# estas escrapeando la pag 98
# estas escrapeando la pag 99
# estas escrapeando la pag 100
# estas escrapeando la pag 101
# estas escrapeando la pag 102

# %%
df_catalogo=pd.DataFrame(datos_book)
df_catalogo
# Out:
#                     Titulo Revista                  Area  \
# 0    Revista de Geografía Agrícola  V. Ciencias Sociales
# 1    Revista de Geografía Agrícola  V. Ciencias Sociales
# 2    Revista de Geografía Agrícola  V. Ciencias Sociales
# 3    Revista de Geografía Agrícola  V. Ciencias Sociales
# 4    Revista de Geografía Agrícola  V. Ciencias Sociales
# ..                             ...                   ...
# 98   Revista de Geografía Agrícola  V. Ciencias Sociales
# 99   Revista de Geografía Agrícola  V. Ciencias Sociales
# 100  Revista de Geografía Agrícola  V. Ciencias Sociales
# 101  Revista de Geografía Agrícola  V. Ciencias Sociales
# 102  Revista de Geografía Agrícola  V. Ciencias Sociales
#
#                                    Tematica  \
# 0    Estudios Regionales y Desarrollo Rural
# 1    Estudios Regionales y Desarrollo Rural
# 2    Estudios Regionales y Desarrollo Rural
# 3    Estudios Regionales y Desarrollo Rural
# 4    Estudios Regionales y Desarrollo Rural
# ..                                      ...
# 98   Estudios Regionales y Desarrollo Rural
# 99   Estudios Regionales y Desarrollo Rural
# 100  Estudios Regionales y Desarrollo Rural
# 101  Estudios Regionales y Desarrollo Rural
# 102  Estudios Regionales y Desarrollo Rural
#
#                                        Titulo Articulo  \
# 0    Concentración del capital agroexportador trans...
# 1    Clasificación de la frontera agrícola de Méxic...
# 2    Presentación de la Revista de Geografía Agríco...
# 3    Elaboración del zacahuil: Saber-hacer e insumo...
# 4    Gestión comunitaria del agua para riego en dos...
# ..                                                 ...
# 98             LA PITA DE OAXACA O “ANANAS MACRODONTE”
# 99   Maíz: Sustento de vida en la cultura Teenek. C...
# 100  Procesos de cambio en la actividad agrícola e ...
# 101  La milpa del occidente de Mesoamérica: profund...
# 102  Emprendimiento sostenible: una visión integral...
#
#                                                Resumen Abstract  \
# 0    A partir de 2014 las exportaciones agrícolas d...     None
# 1    En este trabajo se clasificaron los polígonos ...     None
# 2    ¿Nuevos arreglos institucionales?El 11 de marz...     None
# 3    El zacahuil, alimento ancestral, símbolo de id...     None
# 4    La gestión del agua hace alusión a la organiza...     None
# ..                                                 ...      ...
# 98                                                None     None
# 99   Mediante un largo proceso de experimentación l...     None
# 100  En México los procesos de cambio en áreas geog...     None
# 101  El núcleo del sistema alimentario precerámico ...     None
# 102  En este escrito se describe el emprendimiento ...     None
#
#                                          Link Articulo  \
# 0    https://chapingo-cori.mx/geografia/geografia/a...
# 1    https://chapingo-cori.mx/geografia/geografia/a...
# 2    https://chapingo-cori.mx/geografia/geografia/a...
# 3    https://chapingo-cori.mx/geografia/geografia/a...
# 4    https://chapingo-cori.mx/geografia/geografia/a...
# ..                                                 ...
# 98   https://chapingo-cori.mx/geografia/geografia/a...
# 99   https://chapingo-cori.mx/geografia/geografia/a...
# 100  https://chapingo-cori.mx/geografia/geografia/a...
# 101  https://chapingo-cori.mx/geografia/geografia/a...
# 102  https://chapingo-cori.mx/geografia/geografia/a...
#
#                                               Link PDF
# 0    https://chapingo-cori.mx/geografia/geografia/a...
# 1    https://chapingo-cori.mx/geografia/geografia/a...
# 2    https://chapingo-cori.mx/geografia/geografia/a...
# 3    https://chapingo-cori.mx/geografia/geografia/a...
# 4    https://chapingo-cori.mx/geografia/geografia/a...
# ..                                                 ...
# 98   https://chapingo-cori.mx/geografia/geografia/a...
# 99   https://chapingo-cori.mx/geografia/geografia/a...
# 100  https://chapingo-cori.mx/geografia/geografia/a...
# 101  https://chapingo-cori.mx/geografia/geografia/a...
# 102  https://chapingo-cori.mx/geografia/geografia/a...
#
# [103 rows x 8 columns]

# %%
df_catalogo.to_csv('Revista161.csv', index=False)
