# %%
import requests
import bs4
from bs4 import BeautifulSoup
from urllib.parse import urljoin
import pandas as pd

# %%
url_inicial = 'https://chapingo-cori.mx/geografia/geografia/issue/archive'
url_root = 'https://chapingo-cori.mx/geografia/geografia/issue/archive'
r=requests.get(url_inicial)

# %%
soup = BeautifulSoup(r.text, 'html.parser')

# %%
box = soup.find('div', class_='container page-archives')
volumen=box.findAll('div', class_='col-md-3 col-lg-2')
vol = [x.find('a').get('href')for x in volumen]
vol=[urljoin(url_root,i) for i in vol]
vol
# Out:
# ['https://chapingo-cori.mx/geografia/geografia/issue/view/16',
#  'https://chapingo-cori.mx/geografia/geografia/issue/view/12',
#  'https://chapingo-cori.mx/geografia/geografia/issue/view/10',
#  'https://chapingo-cori.mx/geografia/geografia/issue/view/9',
#  'https://chapingo-cori.mx/geografia/geografia/issue/view/8',
#  'https://chapingo-cori.mx/geografia/geografia/issue/view/2',
#  'https://chapingo-cori.mx/geografia/geografia/issue/view/1',
#  'https://chapingo-cori.mx/geografia/geografia/issue/view/3',
#  'https://chapingo-cori.mx/geografia/geografia/issue/view/4',
#  'https://chapingo-cori.mx/geografia/geografia/issue/view/5',
#  'https://chapingo-cori.mx/geografia/geografia/issue/view/6',
#  'https://chapingo-cori.mx/geografia/geografia/issue/view/7']

# %%
def get_url_items(sopa, url): 
    box = soup.find('div', class_='container page-archives')
    volumen=box.findAll('div', class_='col-md-3 col-lg-2')
    vol = [x.find('a').get('href')for x in volumen]
    vol=[urljoin(url_root,i) for i in vol]
    return vol

# %%
links_items=[]
i=0
while i<1:
    i+=1
    print(f'Estoy en la pagina {url_inicial}')
    r_pag=requests.get(url_inicial)
    s_p=BeautifulSoup(r_pag.text,'html.parser')
    links=get_url_items(s_p, url_inicial)
    links_items.append(links)
# Out:
# Estoy en la pagina https://chapingo-cori.mx/geografia/geografia/issue/archive

# %%
list_scraper=[]
for i in links_items:
    for j in i:
        list_scraper.append(j)
len(list_scraper)
# Out:
# 12

# %%
uno=list_scraper[0]
r_item=requests.get(uno)
s_item=BeautifulSoup(r_item.text, 'html.parser')

# %%
#funcion para iniciar el escraper de cada libro
def scraper_book(url):
    content_book={}
    r=requests.get(url)
    tire='Revista de Geografía Agrícola'
    a='V. Ciencias Sociales'
    tem='Estudios Regionales y Desarrollo Rural'
    url='https://chapingo-cori.mx/geografia/geografia'
    s_item=BeautifulSoup(r.text,'html.parser')
    #titulo de revista
    try:
        titulo=tire
        content_book['Titulo de revista']=tire
    except AttributeError:
        content_book['Titulo de revista']=None
    #area
    try:
        area=a
        content_book['Área']=a
    except AttributeError:
        content_book['Área']=None
    #tematica
    try:
        tema=tem
        content_book['Temática']=tem
    except AttributeError:
        content_book['Temática']=None
    #titulo libro
    try:
        titu=s_item.find('div', class_='article-summary-title').get_text(strip=True)
        content_book['Titulo del libro']=titu
    except AttributeError:
        content_book['Titulo del libro']=None
    #resumen
    try:
        resu=s_item.find('a', class_='cover').get_text(strip=True)
        content_book['Resumen']=resu
    except AttributeError:
        content_book['Resumen']=None
    #Link incial
    try:
        inicial=url
        content_book['Link inicial']=url
    except AttributeError:
        content_book['Link inicial']=None
    #link articulo
    try:
        link=s_item.find('a', class_='btn btn-primary').get('href')
        content_book['Link articulo']=urljoin(url_root, link)
    except AttributeError:
        content_book['Link articulo']=None
    return content_book

# %%
list_scraper=list_scraper[0:12]
datos_book=[]
for idx, i in enumerate(list_scraper):
    print(f'estas escrapeando la pag {idx}')
    datos_book.append(scraper_book(i))
# Out:
# estas escrapeando la pag 0
# estas escrapeando la pag 1
# estas escrapeando la pag 2
# estas escrapeando la pag 3
# estas escrapeando la pag 4
# estas escrapeando la pag 5
# estas escrapeando la pag 6
# estas escrapeando la pag 7
# estas escrapeando la pag 8
# estas escrapeando la pag 9
# estas escrapeando la pag 10
# estas escrapeando la pag 11

# %%
df_catalogo=pd.DataFrame(datos_book)
df_catalogo
# Out:
#                 Titulo de revista                  Área  \
# 0   Revista de Geografía Agrícola  V. Ciencias Sociales
