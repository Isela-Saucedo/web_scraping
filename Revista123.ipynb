# %%
import requests
import bs4
from bs4 import BeautifulSoup
from urllib.parse import urljoin
import pandas as pd

# %%
url_inicial = 'http://revistas.unam.mx/index.php/rmop/issue/archive'
url_root = 'http://revistas.unam.mx/index.php/rmop/issue/archive'
r=requests.get(url_inicial)

# %%
soup = BeautifulSoup(r.text, 'html.parser')

# %%
box = soup.find('div', id='issues')
volumen=box.findAll('h4')
vol = [x.find('a').get('href')for x in volumen]
vol=[urljoin(url_root,i) for i in vol]
vol
# Out:
# ['http://revistas.unam.mx/index.php/rmop/issue/view/Julio%20-%20diciembre',
#  'http://revistas.unam.mx/index.php/rmop/issue/view/Enero%20-%20junio',
#  'http://revistas.unam.mx/index.php/rmop/issue/view/No%2031%20%282021%29%3A%20Julio-diciembre',
#  'http://revistas.unam.mx/index.php/rmop/issue/view/Enero-junio',
#  'http://revistas.unam.mx/index.php/rmop/issue/view/5750',
#  'http://revistas.unam.mx/index.php/rmop/issue/view/5370',
#  'http://revistas.unam.mx/index.php/rmop/issue/view/5239',
#  'http://revistas.unam.mx/index.php/rmop/issue/view/Enero-junio%20%282019%29',
#  'http://revistas.unam.mx/index.php/rmop/issue/view/Julio-diciembre',
#  'http://revistas.unam.mx/index.php/rmop/issue/view/Enero-junio%202018',
#  'http://revistas.unam.mx/index.php/rmop/issue/view/4680',
#  'http://revistas.unam.mx/index.php/rmop/issue/view/4470',
#  'http://revistas.unam.mx/index.php/rmop/issue/view/4378',
#  'http://revistas.unam.mx/index.php/rmop/issue/view/4189',
#  'http://revistas.unam.mx/index.php/rmop/issue/view/3988',
#  'http://revistas.unam.mx/index.php/rmop/issue/view/3639',
#  'http://revistas.unam.mx/index.php/rmop/issue/view/3638',
#  'http://revistas.unam.mx/index.php/rmop/issue/view/3601',
#  'http://revistas.unam.mx/index.php/rmop/issue/view/3513',
#  'http://revistas.unam.mx/index.php/rmop/issue/view/3389',
#  'http://revistas.unam.mx/index.php/rmop/issue/view/3373',
#  'http://revistas.unam.mx/index.php/rmop/issue/view/3371',
#  'http://revistas.unam.mx/index.php/rmop/issue/view/3370',
#  'http://revistas.unam.mx/index.php/rmop/issue/view/3397',
#  'http://revistas.unam.mx/index.php/rmop/issue/view/3409',
#  'http://revistas.unam.mx/index.php/rmop/issue/view/3391',
#  'http://revistas.unam.mx/index.php/rmop/issue/view/3404',
#  'http://revistas.unam.mx/index.php/rmop/issue/view/3408',
#  'http://revistas.unam.mx/index.php/rmop/issue/view/3405',
#  'http://revistas.unam.mx/index.php/rmop/issue/view/3393',
#  'http://revistas.unam.mx/index.php/rmop/issue/view/3400',
#  'http://revistas.unam.mx/index.php/rmop/issue/view/3411',
#  'http://revistas.unam.mx/index.php/rmop/issue/view/3410']

# %%
vol2 =[]
for i in vol: 
    url_inicial1=i 
    r1 = requests.get(url_inicial1)
    soup1 = BeautifulSoup(r1.text, 'html.parser')
    box1 = soup1.find('div', id='content') 
    volumen1=box1.findAll('ul', class_='menu')
    vol1 = [x.find('a').get('href')for x in volumen1]
    vol2+=vol1

# %%
vol2
# Out:
# ['http://revistas.unam.mx/index.php/rmop/issue/view/Julio%20-%20diciembre/showToc',
#  'http://revistas.unam.mx/index.php/rmop/issue/view/Enero%20-%20junio/showToc',
#  'http://revistas.unam.mx/index.php/rmop/issue/view/No%2031%20%282021%29%3A%20Julio-diciembre/showToc',
#  'http://revistas.unam.mx/index.php/rmop/issue/view/Enero-junio/showToc',
#  'http://revistas.unam.mx/index.php/rmop/issue/view/5750/showToc',
#  'http://revistas.unam.mx/index.php/rmop/issue/view/5370/showToc',
#  'http://revistas.unam.mx/index.php/rmop/issue/view/5239/showToc',
#  'http://revistas.unam.mx/index.php/rmop/issue/view/Enero-junio%20%282019%29/showToc',
#  'http://revistas.unam.mx/index.php/rmop/issue/view/Julio-diciembre/showToc',
#  'http://revistas.unam.mx/index.php/rmop/issue/view/Enero-junio%202018/showToc',
#  'http://revistas.unam.mx/index.php/rmop/issue/view/4680/showToc',
#  'http://revistas.unam.mx/index.php/rmop/issue/view/4470/showToc',
#  'http://revistas.unam.mx/index.php/rmop/issue/view/4378/showToc',
#  'http://revistas.unam.mx/index.php/rmop/issue/view/4189/showToc',
#  'http://revistas.unam.mx/index.php/rmop/issue/view/3988/showToc',
#  'http://revistas.unam.mx/index.php/rmop/issue/view/3639/showToc',
#  'http://revistas.unam.mx/index.php/rmop/issue/view/3638/showToc',
#  'http://revistas.unam.mx/index.php/rmop/issue/view/3601/showToc',
#  'http://revistas.unam.mx/index.php/rmop/issue/view/3513/showToc',
#  'http://revistas.unam.mx/index.php/rmop/issue/view/3389/showToc',
#  'http://revistas.unam.mx/index.php/rmop/issue/view/3373/showToc',
#  'http://revistas.unam.mx/index.php/rmop/issue/view/3371/showToc',
#  'http://revistas.unam.mx/index.php/rmop/issue/view/3370/showToc',
#  'http://revistas.unam.mx/index.php/rmop/issue/view/3397/showToc',
#  'http://revistas.unam.mx/index.php/rmop/issue/view/3409/showToc',
#  'http://revistas.unam.mx/index.php/rmop/issue/view/3391/showToc',
#  'http://revistas.unam.mx/index.php/rmop/issue/view/3404/showToc',
#  'http://revistas.unam.mx/index.php/rmop/issue/view/3408/showToc',
#  'http://revistas.unam.mx/index.php/rmop/issue/view/3405/showToc',
#  'http://revistas.unam.mx/index.php/rmop/issue/view/3393/showToc',
#  'http://revistas.unam.mx/index.php/rmop/issue/view/3400/showToc',
#  'http://revistas.unam.mx/index.php/rmop/issue/view/3411/showToc',
#  'http://revistas.unam.mx/index.php/rmop/issue/view/3410/showToc']

# %%
vol3 =[]
for b in vol2: 
    url_inicial2=b 
    r2 = requests.get(url_inicial2)
    soup2 = BeautifulSoup(r2.text, 'html.parser')
    box2 = soup2.find('div', id='content') 
    volumen2=box2.findAll('a')
    vol2= [o.get('href')for o in volumen2]
    vol1 = [urljoin (url_root, i) for i in vol1]
    vol2 = [urljoin (url_root, i) for i in vol2]
    vol3 = [urljoin (url_root, i) for i in vol3]
    vol3+=vol2

# %%
vol3
# Out:
# ['http://dx.doi.org/10.22201/fcpys.24484911e.2022.33',
#  'http://revistas.unam.mx/index.php/rmop/article/view/82975/72814',
#  'http://revistas.unam.mx/index.php/rmop/article/view/82274',
#  'http://revistas.unam.mx/index.php/rmop/article/view/82274',
#  'http://revistas.unam.mx/index.php/rmop/article/view/82274/72818',
#  'http://revistas.unam.mx/index.php/rmop/article/view/82195',
#  'http://revistas.unam.mx/index.php/rmop/article/view/82195',
#  'http://revistas.unam.mx/index.php/rmop/article/view/82195/72819',
#  'http://revistas.unam.mx/index.php/rmop/article/view/81900',
#  'http://revistas.unam.mx/index.php/rmop/article/view/81900',
#  'http://revistas.unam.mx/index.php/rmop/article/view/81900/72820',
#  'http://revistas.unam.mx/index.php/rmop/article/view/81953',
#  'http://revistas.unam.mx/index.php/rmop/article/view/81953',
#  'http://revistas.unam.mx/index.php/rmop/article/view/81953/72824',
#  'http://revistas.unam.mx/index.php/rmop/article/view/82237',
#  'http://revistas.unam.mx/index.php/rmop/article/view/82237',
#  'http://revistas.unam.mx/index.php/rmop/article/view/82237/72821',
#  'http://revistas.unam.mx/index.php/rmop/article/view/80998',
#  'http://revistas.unam.mx/index.php/rmop/article/view/80998',
#  'http://revistas.unam.mx/index.php/rmop/article/view/80998/72822',
#  'http://revistas.unam.mx/index.php/rmop/article/view/82197',
#  'http://revistas.unam.mx/index.php/rmop/article/view/82197',
#  'http://revistas.unam.mx/index.php/rmop/article/view/82197/72817',
#  'http://revistas.unam.mx/index.php/rmop/article/view/79805',
#  'http://revistas.unam.mx/index.php/rmop/article/view/79805',
#  'http://revistas.unam.mx/index.php/rmop/article/view/79805/72823',
#  'http://revistas.unam.mx/index.php/rmop/article/view/80426',
#  'http://revistas.unam.mx/index.php/rmop/article/view/80426',
#  'http://revistas.unam.mx/index.php/rmop/article/view/80426/72816',
#  'http://revistas.unam.mx/index.php/rmop/article/view/75559',
#  'http://revistas.unam.mx/index.php/rmop/article/view/75559',
#  'http://revistas.unam.mx/index.php/rmop/article/view/75559/72815',
#  'http://creativecommons.org/licenses/by-nc-nd/4.0/',
#  'https://www.unam.mx',
#  'http://creativecommons.org/licenses/by-nc-nd/4.0/',
#  'http://revistas.unam.mx/index.php/rmop',
#  'http://dx.doi.org/10.22201/fcpys.24484911e.2022.32',
#  'http://revistas.unam.mx/index.php/rmop/article/view/81602',
#  'http://revistas.unam.mx/index.php/rmop/article/view/81602/71866',
#  'http://revistas.unam.mx/index.php/rmop/article/view/80605',
#  'http://revistas.unam.mx/index.php/rmop/article/view/80605',
#  'http://revistas.unam.mx/index.php/rmop/article/view/80605/71821',
#  'http://revistas.unam.mx/index.php/rmop/article/view/80605/72269',
#  'http://revistas.unam.mx/index.php/rmop/article/view/80697',
#  'http://revistas.unam.mx/index.php/rmop/article/view/80697',
#  'http://revistas.unam.mx/index.php/rmop/article/view/80697/71822',
#  'http://revistas.unam.mx/index.php/rmop/article/view/80697/72276',
#  'http://revistas.unam.mx/index.php/rmop/article/view/80379',
#  'http://revistas.unam.mx/index.php/rmop/article/view/80379',
#  'http://revistas.unam.mx/index.php/rmop/article/view/80379/71823',
#  'http://revistas.unam.mx/index.php/rmop/article/view/80379/72277',
#  'http://revistas.unam.mx/index.php/rmop/article/view/80376',
#  'http://revistas.unam.mx/index.php/rmop/article/view/80376',
#  'http://revistas.unam.mx/index.php/rmop/article/view/80376/71824',
#  'http://revistas.unam.mx/index.php/rmop/article/view/80376/72284',
#  'http://revistas.unam.mx/index.php/rmop/article/view/79992',
#  'http://revistas.unam.mx/index.php/rmop/article/view/79992',
#  'http://revistas.unam.mx/index.php/rmop/article/view/79992/71825',
#  'http://revistas.unam.mx/index.php/rmop/article/view/79992/72288',
#  'http://revistas.unam.mx/index.php/rmop/article/view/80607',
#  'http://revistas.unam.mx/index.php/rmop/article/view/80607',
#  'http://revistas.unam.mx/index.php/rmop/article/view/80607/71826',
#  'http://revistas.unam.mx/index.php/rmop/article/view/80607/72290',
#  'http://revistas.unam.mx/index.php/rmop/article/view/80652',
#  'http://revistas.unam.mx/index.php/rmop/article/view/80652',
#  'http://revistas.unam.mx/index.php/rmop/article/view/80652/71830',
#  'http://revistas.unam.mx/index.php/rmop/article/view/80652/72291',
#  'http://revistas.unam.mx/index.php/rmop/article/view/80496',
#  'http://revistas.unam.mx/index.php/rmop/article/view/80496',
#  'http://revistas.unam.mx/index.php/rmop/article/view/80496/71828',
#  'http://revistas.unam.mx/index.php/rmop/article/view/80693',
#  'http://revistas.unam.mx/index.php/rmop/article/view/80693',
#  'http://revistas.unam.mx/index.php/rmop/article/view/80693/71829',
#  'http://creativecommons.org/licenses/by-nc-nd/4.0/',
#  'https://www.unam.mx',
#  'http://creativecommons.org/licenses/by-nc-nd/4.0/',
#  'http://revistas.unam.mx/index.php/rmop',
#  'http://dx.doi.org/10.22201/fcpys.24484911e.2022.31',
#  'http://revistas.unam.mx/index.php/rmop/article/view/79855',
#  'http://revistas.unam.mx/index.php/rmop/article/view/79855/70609',
#  'http://revistas.unam.mx/index.php/rmop/article/view/79855/71347',
#  'http://revistas.unam.mx/index.php/rmop/article/view/79855/71937',
#  'http://revistas.unam.mx/index.php/rmop/article/view/77923',
#  'http://revistas.unam.mx/index.php/rmop/article/view/77923',
#  'http://revistas.unam.mx/index.php/rmop/article/view/77923/70601',
#  'http://revistas.unam.mx/index.php/rmop/article/view/77923/71348',
#  'http://revistas.unam.mx/index.php/rmop/article/view/

#  'http://revistas.unam.mx/index.php/rmop/article/view/41771',
#  'http://revistas.unam.mx/index.php/rmop/article/view/41771/37940',
#  'http://revistas.unam.mx/index.php/rmop/article/view/41790',
#  'http://revistas.unam.mx/index.php/rmop/article/view/41790',
#  'http://revistas.unam.mx/index.php/rmop/article/view/41790/37950',
#  'http://revistas.unam.mx/index.php/rmop/article/view/41787',
#  'http://revistas.unam.mx/index.php/rmop/article/view/41787',
#  'http://revistas.unam.mx/index.php/rmop/article/view/41787/37948',
#  'http://revistas.unam.mx/index.php/rmop/article/view/41792',
#  'http://revistas.unam.mx/index.php/rmop/article/view/41792',
#  'http://revistas.unam.mx/index.php/rmop/article/view/41792/37952',
#  'http://creativecommons.org/licenses/by-nc-nd/4.0/',
#  'https://www.unam.mx',
#  'http://creativecommons.org/licenses/by-nc-nd/4.0/',
#  'http://revistas.unam.mx/index.php/rmop',
#  'http://dx.doi.org/10.22201/fcpys.24484911e.2010.9',
#  'http://revistas.unam.mx/index.php/rmop/article/view/41802/37959',
#  'http://revistas.unam.mx/index.php/rmop/article/view/41810',
#  'http://revistas.unam.mx/index.php/rmop/article/view/41810',
#  'http://revistas.unam.mx/index.php/rmop/article/view/41810/37964',
#  'http://revistas.unam.mx/index.php/rmop/article/view/41814',
#  'http://revistas.unam.mx/index.php/rmop/article/view/41814',
#  'http://revistas.unam.mx/index.php/rmop/article/view/41814/37967',
#  'http://revistas.unam.mx/index.php/rmop/article/view/41807',
#  'http://revistas.unam.mx/index.php/rmop/article/view/41807',
#  'http://revistas.unam.mx/index.php/rmop/article/view/41807/37962',
#  'http://revistas.unam.mx/index.php/rmop/article/view/41803',
#  'http://revistas.unam.mx/index.php/rmop/article/view/41803',
#  'http://revistas.unam.mx/index.php/rmop/article/view/41803/37960',
#  'http://revistas.unam.mx/index.php/rmop/article/view/41818',
#  'http://revistas.unam.mx/index.php/rmop/article/view/41818',
#  'http://revistas.unam.mx/index.php/rmop/article/view/41818/37968',
#  'http://revistas.unam.mx/index.php/rmop/article/view/41824/37971',
#  'http://revistas.unam.mx/index.php/rmop/article/view/41827/37973',
#  'http://creativecommons.org/licenses/by-nc-nd/4.0/',
#  'https://www.unam.mx',
#  'http://creativecommons.org/licenses/by-nc-nd/4.0/',
#  'http://revistas.unam.mx/index.php/rmop',
#  'http://dx.doi.org/10.22201/fcpys.24484911e.2010.8',
#  'http://revistas.unam.mx/index.php/rmop/article/view/41625/38717',
#  'http://revistas.unam.mx/index.php/rmop/article/view/41701',
#  'http://revistas.unam.mx/index.php/rmop/article/view/41701',
#  'http://revistas.unam.mx/index.php/rmop/article/view/41701/38718',
#  'http://revistas.unam.mx/index.php/rmop/article/view/41703',
#  'http://revistas.unam.mx/index.php/rmop/article/view/41703',
#  'http://revistas.unam.mx/index.php/rmop/article/view/41703/38719',
#  'http://revistas.unam.mx/index.php/rmop/article/view/41706',
#  'http://revistas.unam.mx/index.php/rmop/article/view/41706',
#  'http://revistas.unam.mx/index.php/rmop/article/view/41706/38721',
#  'http://revistas.unam.mx/index.php/rmop/article/view/41704',
#  'http://revistas.unam.mx/index.php/rmop/article/view/41704',
#  'http://revistas.unam.mx/index.php/rmop/article/view/41704/38720',
#  'http://revistas.unam.mx/index.php/rmop/article/view/41707/38722',
#  'http://revistas.unam.mx/index.php/rmop/article/view/41713/38723',
#  'http://revistas.unam.mx/index.php/rmop/article/view/41715/38724',
#  'http://creativecommons.org/licenses/by-nc-nd/4.0/',
#  'https://www.unam.mx',
#  'http://creativecommons.org/licenses/by-nc-nd/4.0/',
#  'http://revistas.unam.mx/index.php/rmop',
#  'http://dx.doi.org/10.22201/fcpys.24484911e.2009.7',
#  'http://revistas.unam.mx/index.php/rmop/article/view/41760/38804',
#  'http://revistas.unam.mx/index.php/rmop/article/view/41848',
#  'http://revistas.unam.mx/index.php/rmop/article/view/41848',
#  'http://revistas.unam.mx/index.php/rmop/article/view/41848/37986',
#  'http://revistas.unam.mx/index.php/rmop/article/view/41770',
#  'http://revistas.unam.mx/index.php/rmop/article/view/41770',
#  'http://revistas.unam.mx/index.php/rmop/article/view/41770/38805',
#  'http://revistas.unam.mx/index.php/rmop/article/view/41772',
#  'http://revistas.unam.mx/index.php/rmop/article/view/41772',
#  'http://revistas.unam.mx/index.php/rmop/article/view/41772/38806',
#  'http://revistas.unam.mx/index.php/rmop/article/view/41774/38807',
#  'http://revistas.unam.mx/index.php/rmop/article/view/41775/38808',
#  'http://revistas.unam.mx/index.php/rmop/article/view/41777/38809',
#  'http://creativecommons.org/licenses/by-nc-nd/4.0/',
#  'https://www.unam.mx',
#  'http://creativecommons.org/licenses/by-nc-nd/4.0/',
#  'http://revistas.unam.mx/index.php/rmop',
#  'http://dx.doi.org/10.22201/fcpys.24484911e.2009.6',
#  'http://revistas.unam.mx/index.php/rmop/article/view/41801/37958',
#  'http://revistas.unam.mx/index.php/rmop/article/view/41811',
#  'http://revistas.unam.mx/index.php/rmop/article/view/41811',
#  'http://revistas.unam.mx/index.php/rmop/article/view/41811/37966',
#  'http://revistas.unam.mx/index.php/rmop/article/view/41819',
#  'http://revistas.unam.mx/index.php/rmop/article/view/41819',
#  'http://revistas.unam.mx/index.php/rmop/article/view/41819/37969',
#  'http://revistas.unam.mx/index.php/rmop/article/view/41825',
#  'http://revistas.unam.mx/index.php/rmop/article/view/41825',
#  'http://revistas.unam.mx/index.php/rmop/article/view/41825/37970',
#  'http://revistas.unam.mx/index.php/rmop/article/view/41809',
#  'http://revistas.unam.mx/index.php/rmop/article/view/41809',
#  'http://revistas.unam.mx/index.php/rmop/article/view/41809/37963',
#  'http://revistas.unam.mx/index.php/rmop/article/view/41829/37975',
#  'http://revistas.unam.mx/index.php/rmop/article/view/41826/37972',
#  'http://revistas.unam.mx/index.php/rmop/article/view/41828/37974',
#  'http://creativecommons.org/licenses/by-nc-nd/4.0/',
#  'https://www.unam.mx',
#  'http://creativecommons.org/licenses/by-nc-nd/4.0/',
#  'http://revistas.unam.mx/index.php/rmop',
#  'http://dx.doi.org/10.22201/fcpys.24484911e.2008.5',
#  'http://revistas.unam.mx/index.php/rmop/article/view/41762/37933',
#  'http://revistas.unam.mx/index.php/rmop/article/view/41764',
#  'http://revistas.unam.mx/index.php/rmop/article/view/41764',
#  'http://revistas.unam.mx/index.php/rmop/article/view/41764/37935',
#  'http://revistas.unam.mx/index.php/rmop/article/view/41769',
#  'http://revistas.unam.mx/index.php/rmop/article/view/41769',
#  'http://revistas.unam.mx/index.php/rmop/article/view/41769/37939',
#  'http://revistas.unam.mx/index.php/rmop/article/view/41766',
#  'http://revistas.unam.mx/index.php/rmop/article/view/41766',
#  'http://revistas.unam.mx/index.php/rmop/article/view/41766/37937',
#  'http://revistas.unam.mx/index.php/rmop/article/view/41778/37942',
#  'http://revistas.unam.mx/index.php/rmop/article/view/41773/37941',
#  'http://creativecommons.org/licenses/by-nc-nd/4.0/',
#  'https://www.unam.mx',
#  'http://creativecommons.org/licenses/by-nc-nd/4.0/',
#  'http://revistas.unam.mx/index.php/rmop',
#  'http://dx.doi.org/10.22201/fcpys.24484911e.2008.4',
#  'http://revistas.unam.mx/index.php/rmop/article/view/41688/37876',
#  'http://revistas.unam.mx/index.php/rmop/article/view/41649',
#  'http://revistas.unam.mx/index.php/rmop/article/view/41649',
#  'http://revistas.unam.mx/index.php/rmop/article/view/41649/37872',
#  'http://revistas.unam.mx/index.php/rmop/article/view/41645',
#  'http://revistas.unam.mx/index.php/rmop/article/view/41645',
#  'http://revistas.unam.mx/index.php/rmop/article/view/41645/37839',
#  'http://revistas.unam.mx/index.php/rmop/article/view/41643',
#  'http://revistas.unam.mx/index.php/rmop/article/view/41643',
#  'http://revistas.unam.mx/index.php/rmop/article/view/41643/37840',
#  'http://revistas.unam.mx/index.php/rmop/article/view/41646',
#  'http://revistas.unam.mx/index.php/rmop/article/view/41646',
#  'http://revistas.unam.mx/index.php/rmop/article/view/41646/37843',
#  'http://revistas.unam.mx/index.php/rmop/article/view/41682/37875',
#  'http://creativecommons.org/licenses/by-nc-nd/4.0/',
#  'https://www.unam.mx',
#  'http://creativecommons.org/licenses/by-nc-nd/4.0/',
#  'http://revistas.unam.mx/index.php/rmop',
#  'http://dx.doi.org/10.22201/fcpys.24484911e.2007.3',
#  'http://revistas.unam.mx/index.php/rmop/article/view/41692/37883',
#  'http://revistas.unam.mx/index.php/rmop/article/view/41709',
#  'http://revistas.unam.mx/index.php/rmop/article/view/41709',
#  'http://revistas.unam.mx/index.php/rmop/article/view/41709/37898',
#  'http://revistas.unam.mx/index.php/rmop/article/view/41702',
#  'http://revistas.unam.mx/index.php/rmop/article/view/41702',
#  ...]

# %%
def get_url_items(sopa,url):
    box2 = soup2.find('div', id='content') 
    volumen2=box2.findAll('a')
    vol2= [o.get('href')for o in volumen2]
    return vol3

# %%
links_items=[]
i=0
while i<1:
    i+=1
    print(f'Estoy en la pagina {url_inicial}')
    r_pag=requests.get(url_inicial)
    s_p=BeautifulSoup(r_pag.text,'html.parser')
    links=get_url_items(s_p, url_inicial)
    links_items.append(links) 
    next_a=s_p.select('li.next > a')
    if not next_a or not next_a[0].get('href'):
        break
# Out:
# Estoy en la pagina http://revistas.unam.mx/index.php/rmop/issue/archive

# %%
list_scraper=[]
for i in links_items:
    for j in i:
        list_scraper.append(j)
len(list_scraper)
# Out:
# 1072

# %%
uno=list_scraper[0]
r_item=requests.get(uno)
s_item=BeautifulSoup(r_item.text, 'html.parser')

# %%
#funcion para iniciar el escraper de cada libro
def scraper_book(url):
    content_book={}
    r=requests.get(url)
    tire='Revista Mexicana de Opinión Pública'
    a='V. Ciencias Sociales'
    tem='Opinión pública, Comunicación, Estudios electorales'
    s_item=BeautifulSoup(r.text,'html.parser')
    #titulo de revista
    try:
        titulo=tire
        content_book['Titulo Revista']=tire
    except AttributeError:
        content_book['Titulo Revista']=None
    #area
    try:
        area=a
        content_book['Area']=a
    except AttributeError:
        content_book['Area']=None
    #tematica
    try:
        tema=tem
        content_book['Tematica']=tem
    except AttributeError:
        content_book['Tematica']=None
    #titulo articulo
    try:
        titu=s_item.find('div', id='articleTitle').get_text(strip=True)
        content_book['Titulo Articulo']=titu
    except AttributeError:
        content_book['Titulo Articulo']=None
    #resumen
    try:
        resu=s_item.find('div', id='articleAbstract').get_text(strip=True)
        content_book['Resumen']=resu.replace("Resumen","")
    except AttributeError:
        content_book['Resumen']=None
    #abstract
    try:
        abst=s_item.find('div', id='item cover_image').get_text(strip=True)
        content_book['Abstract']=abst
    except AttributeError:
        content_book['Abstract']=None
    #Link incial
    try:
        linkart=url
        content_book['Link Articulo']=linkart
    except AttributeError:
        content_book['Link Articulo']=None
    #link articulo
    try:
        link=s_item.find('a', class_='file').get('href')
        content_book['Link PDF']=urljoin(url_root, link)
    except AttributeError:
        content_book['Link PDF']=None
    return content_book

# %%
list_scraper=list_scraper[0:1072]
datos_book=[]
for idx, i in enumerate(list_scraper):
    print(f'estas escrapeando la pag {idx}')
    datos_book.append(scraper_book(i))
# Out:
# estas escrapeando la pag 0
# estas escrapeando la pag 1
# estas escrapeando la pag 2
# estas escrapeando la pag 3
# estas escrapeando la pag 4
# estas escrapeando la pag 5
# estas escrapeando la pag 6
# estas escrapeando la pag 7
# estas escrapeando la pag 8
# estas escrapeando la pag 9
# estas escrapeando la pag 10
# estas escrapeando la pag 11
# estas escrapeando la pag 12
# estas escrapeando la pag 13
# estas escrapeando la pag 14
# estas escrapeando la pag 15
# estas escrapeando la pag 16
# estas escrapeando la pag 17
# estas escrapeando la pag 18
# estas escrapeando la pag 19
# estas escrapeando la pag 20
# estas escrapeando la pag 21
# estas escrapeando la pag 22
# estas escrapeando la pag 23
# estas escrapeando la pag 24
# estas escrapeando la pag 25
# estas escrapeando la pag 26
# estas escrapeando la pag 27
# estas escrapeando la pag 28
# estas escrapeando la pag 29
# estas escrapeando la pag 30
# estas escrapeando la pag 31
# estas escrapeando la pag 32
# estas escrapeando la pag 33
# estas escrapeando la pag 34
# estas escrapeando la pag 35
# estas escrapeando la pag 36
# estas escrapeando la pag 37
# estas escrapeando la pag 38
# estas escrapeando la pag 39
# estas escrapeando la pag 40
# estas escrapeando la pag 41
# estas escrapeando la pag 42
# /opt/conda/lib/python3.10/site-packages/bs4/builder/__init__.py:545: XMLParsedAsHTMLWarning: It looks like you're parsing an XML document using an HTML parser. If this really is an HTML document (maybe it's XHTML?), you can ignore or filter this warning. If it's XML, you should know that using an XML parser will be more reliable. To parse this document as XML, make sure you have the lxml package installed, and pass the keyword argument `features="xml"` into the BeautifulSoup constructor.
#   warnings.warn(
# estas escrapeando la pag 43
# estas escrapeando la pag 44
# estas escrapeando la pag 45
# estas escrapeando la pag 46
# estas escrapeando la pag 47
# estas escrapeando la pag 48
# estas escrapeando la pag 49
# estas escrapeando la pag 50
# estas escrapeando la pag 51
# estas escrapeando la pag 52
# estas escrapeando la pag 53
# estas escrapeando la pag 54
# estas escrapeando la pag 55
# estas escrapeando la pag 56
# estas escrapeando la pag 57
# estas escrapeando la pag 58
# estas escrapeando la pag 59
# estas escrapeando la pag 60
# estas escrapeando la pag 61
# estas escrapeando la pag 62
# estas escrapeando la pag 63
# estas escrapeando la pag 64
# estas escrapeando la pag 65
# estas escrapeando la pag 66
# estas escrapeando la pag 67
# estas escrapeando la pag 68
# estas escrapeando la pag 69
# estas escrapeando la pag 70
# estas escrapeando la pag 71
# estas escrapeando la pag 72
# estas escrapeando la pag 73
# estas escrapeando la pag 74
# estas escrapeando la pag 75
# estas escrapeando la pag 76
# estas escrapeando la pag 77
# estas escrapeando la pag 78
# estas escrapeando la pag 79
# estas escrapeando la pag 80
# estas escrapeando la pag 81
# estas escrapeando la pag 82
# estas escrapeando la pag 83
# estas escrapeando la pag 84
# estas escrapeando la pag 85
# estas escrapeando la pag 86
# estas escrapeando la pag 87
# estas escrapeando la pag 88
# estas escrapeando la pag 89
# estas escrapeando la pag 90
# estas escrapeando la pag 91
# estas escrapeando la pag 92
# estas escrapeando la pag 93
# estas escrapeando la pag 94
# estas escrapeando la pag 95
# estas escrapeando la pag 96
# estas escrapeando la pag 97
# estas escrapeando la pag 98
# estas escrapeando la pag 99
# estas escrapeando la pag 100
# estas escrapeando la pag 101
# estas escrapeando la pag 102
# estas escrapeando la pag 103
# estas escrapeando la pag 104
# estas escrapeando la pag 105
# estas escrapeando la pag 106
# estas escrapeando la pag 107
# estas escrapeando la pag 108
# estas escrapeando la pag 109
# estas escrapeando la pag 110
# estas escrapeando la pag 111
# estas escrapeando la pag 112
# estas escrapeando la pag 113
# estas escrapeando la pag 114
# estas escrapeando la pag 115
# estas escrapeando la pag 116
# estas escrapeando la pag 117
# estas escrapeando la pag 118
# estas escrapeando la pag 119
# estas escrapeando la pag 120
# estas escrapeando la pag 121
# estas escrapeando la pag 122
# estas escrapeando la pag 123
# estas escrapeando la pag 124
# estas escrapeando la pag 125
# estas escrapeando la pag 126
# estas escrapeando la pag 127
# estas escrapeando la pag 128
# estas escrapeando la pag 129
# estas escrapeando la pag 130
# estas escrapeando la pag 131
# estas escrapeando la pag 132
# estas escrapeando la pag 133
# estas escrapeando la pag 134
# estas escrapeando la pag 135
# estas escrapeando la pag 136
# estas escrapeando la pag 137
# estas escrapeando la pag 138
# estas escrapeando la pag 139
# estas escrapeando la pag 140
# estas escrapeando la pag 141
# estas escrapeando la pag 142
# estas escrapeando la pag 143
# estas escrapeando la pag 144
# estas escrapeando la pag 145
# estas escrapeando la pag 146
# estas escrapeando la pag 147
# estas escrapeando la pag 148
# estas escrapeando la pag 149
# estas escrapeando la pag 150
# estas escrapeando la pag 151
# estas escrapeando la pag 152
# estas escrapeando la pag 153
# estas escrapeando la pag 154
# estas escrapeando la pag 155
# estas escrapeando la pag 156
# estas escrapeando la pag 157
# estas escrapeando la pag 158
# estas escrapeando la pag 159
# estas escrapeando la pag 160
# estas escrapeando la pag 161
# estas escrapeando la pag 162
# estas escrapeando la pag 163
# estas escrapeando la pag 164
# estas escrapeando la pag 165
# estas escrapeando la pag 166
# estas escrapeando la pag 167
# estas escrapeando la pag 168
# estas escrapeando la pag 169
# estas escrapeando la pag 170
# estas escrapeando la pag 171
# estas escrapeando la pag 172
# estas escrapeando la pag 173
# estas escrapeando la pag 174
# estas escrapeando la pag 175
# estas escrapeando la pag 176
# estas escrapeando la pag 177
# estas escrapeando la pag 178
# estas escrapeando la pag 179
# estas escrapeando la pag 180
# estas escrapeando la pag 181
# estas escrapeando la pag 182
# estas escrapeando la pag 183
# estas escrapeando la pag 184
# estas escrapeando la pag 185
# estas escrapeando la pag 186
# estas escrapeando la pag 187
# estas escrapeando la pag 188
# estas escrapeando la pag 189
# estas escrapeando la pag 190
# estas escrapeando la pag 191
# estas escrapeando la pag 192
# estas escrapeando la pag 193
# estas escrapeando la pag 194
# estas escrapeando la pag 195
# estas escrapeando la pag 196
# estas escrapeando la pag 197
# estas escrapeando la pag 198
# estas escrapeando la pag 199
# estas escrapeando la pag 200
# estas escrapeando la pag 201
# estas escrapeando la pag 202
# estas escrapeando la pag 203
# estas escrapeando la pag 204
# estas escrapeando la pag 205
# estas escrapeando la pag 206
# estas escrapeando la pag 207
# estas escrapeando la pag 208
# estas escrapeando la pag 209
# estas escrapeando la pag 210
# estas escrapeando la pag 211
# estas escrapeando la pag 212
# estas escrapeando la pag 213
# estas escrapeando la pag 214
# estas escrapeando la pag 215
# estas escrapeando la pag 216
# estas escrapeando la pag 217
# estas escrapeando la pag 218
# estas escrapeando la pag 219
# estas escrapeando la pag 220
# estas escrapeando la pag 221
# estas escrapeando la pag 222
# estas escrapeando la pag 223
# estas escrapeando la pag 224
# estas escrapeando la pag 225
# estas escrapeando la pag 226
# estas escrapeando la pag 227
# estas escrapeando la pag 228
# estas escrapeando la pag 229
# estas escrapeando la pag 230
# estas escrapeando la pag 231
# estas escrapeando la pag 232
# estas escrapeando la pag 233
# estas escrapeando la pag 234
# estas escrapeando la pag 235
# estas escrapeando la pag 236
# estas escrapeando la pag 237
# estas escrapeando la pag 238
# estas escrapeando la pag 239
# estas escrapeando la pag 240
# estas escrapeando la pag 241
# estas escrapeando la pag 242
# estas escrapeando la pag 243
# estas escrapeando la pag 244
# estas escrapeando la pag 245
# estas escrapeando la pag 246
# estas escrapeando la pag 247
# estas escrapeando la pag 248
# estas escrapeando la pag 249
# estas escrapeando la pag 250
# estas escrapeando la pag 251
# estas escrapeando la pag 252
# estas escrapeando la pag 253
# estas escrapeando la pag 254
# estas escrapeando la pag 255
# estas escrapeando la pag 256
# estas escrapeando la pag 257
# estas escrapeando la pag 258
# estas escrapeando la pag 259
# estas escrapeando la pag 260
# estas escrapeando la pag 261
# estas escrapeando la pag 262
# estas escrapeando la pag 263
# estas escrapeando la pag 264
# estas escrapeando la pag 265
# estas escrapeando la pag 266
# estas escrapeando la pag 267
# estas escrapeando la pag 268
# estas escrapeando la pag 269
# estas escrapeando la pag 270
# estas escrapeando la pag 271
# estas escrapeando la pag 272
# estas escrapeando la pag 273
# estas escrapeando la pag 274
# estas escrapeando la pag 275
# estas escrapeando la pag 276
# estas escrapeando la pag 277
# estas escrapeando la pag 278
# estas escrapeando la pag 279
# estas escrapeando la pag 280
# estas escrapeando la pag 281
# estas escrapeando la pag 282
# estas escrapeando la pag 283
# estas escrapeando la pag 284
# estas escrapeando la pag 285
# estas escrapeando la pag 286
# estas escrapeando la pag 287
# estas escrapeando la pag 288
# estas escrapeando la pag 289
# estas escrapeando la pag 290
# estas escrapeando la pag 291
# estas escrapeando la pag 292
# estas escrapeando la pag 293
# estas escrapeando la pag 294
# estas escrapeando la pag 295
# estas escrapeando la pag 296
# estas escrapeando la pag 297
# estas escrapeando la pag 298
# estas escrapeando la pag 299
# estas escrapeando la pag 300
# estas escrapeando la pag 301
# estas escrapeando la pag 302
# estas escrapeando la pag 303
# estas escrapeando la pag 304
# estas escrapeando la pag 305
# estas escrapeando la pag 306
# estas escrapeando la pag 307
# estas escrapeando la pag 308
# estas escrapeando la pag 309
# estas escrapeando la pag 310
# estas escrapeando la pag 311
# estas escrapeando la pag 312
# estas escrapeando la pag 313
# estas escrapeando la pag 314
# estas escrapeando la pag 315
# estas escrapeando la pag 316
# estas escrapeando la pag 317
# estas escrapeando la pag 318
# estas escrapeando la pag 319
# estas escrapeando la pag 320
# estas escrapeando la pag 321
# estas escrapeando la pag 322
# estas escrapeando la pag 323
# estas escrapeando la pag 324
# estas escrapeando la pag 325
# estas escrapeando la pag 326
# estas escrapeando la pag 327
# estas escrapeando la pag 328
# estas escrapeando la pag 329
# estas escrapeando la pag 330
# estas escrapeando la pag 331
# estas escrapeando la pag 332
# estas escrapeando la pag 333
# estas escrapeando la pag 334
# estas escrapeando la pag 335
# estas escrapeando la pag 336
# estas escrapeando la pag 337
# estas escrapeando la pag 338
# estas escrapeando la pag 339
# estas escrapeando la pag 340
# estas escrapeando la pag 341
# estas escrapeando la pag 342
# estas escrapeando la pag 343
# estas escrapeando la pag 344
# estas escrapeando la pag 345
# estas escrapeando la pag 346
# estas escrapeando la pag 347
# estas escrapeando la pag 348
# estas escrapeando la pag 349
# estas escrapeando la pag 350
# estas escrapeando la pag 351
# estas escrapeando la pag 352
# estas escrapeando la pag 353
# estas escrapeando la pag 354
# estas escrapeando la pag 355
# estas escrapeando la pag 356
# estas escrapeando la pag 357
# estas escrapeando la pag 358
# estas escrapeando la pag 359
# estas escrapeando la pag 360
# estas escrapeando la pag 361
# estas escrapeando la pag 362
# estas escrapeando la pag 363
# estas escrapeando la pag 364
# estas escrapeando la pag 365
# estas escrapeando la pag 366
# estas escrapeando la pag 367
# estas escrapeando la pag 368
# estas escrapeando la pag 369
# estas escrapeando la pag 370
# estas escrapeando la pag 371
# estas escrapeando la pag 372
# estas escrapeando la pag 373
# estas escrapeando la pag 374
# estas escrapeando la pag 375
# estas escrapeando la pag 376
# estas escrapeando la pag 377
# estas escrapeando la pag 378
# estas escrapeando la pag 379
# estas escrapeando la pag 380
# estas escrapeando la pag 381
# estas escrapeando la pag 382
# estas escrapeando la pag 383
# estas escrapeando la pag 384
# estas escrapeando la pag 385
# estas escrapeando la pag 386
# estas escrapeando la pag 387
# estas escrapeando la pag 388
# estas escrapeando la pag 389
# estas escrapeando la pag 390
# estas escrapeando la pag 391
# estas escrapeando la pag 392
# estas escrapeando la pag 393
# estas escrapeando la pag 394
# estas escrapeando la pag 395
# estas escrapeando la pag 396
# estas escrapeando la pag 397
# estas escrapeando la pag 398
# estas escrapeando la pag 399
# estas escrapeando la pag 400
# estas escrapeando la pag 401
# estas escrapeando la pag 402
# estas escrapeando la pag 403
# estas escrapeando la pag 404
# estas escrapeando la pag 405
# estas escrapeando la pag 406
# estas escrapeando la pag 407
# estas escrapeando la pag 408
# estas escrapeando la pag 409
# estas escrapeando la pag 410
# estas escrapeando la pag 411
# estas escrapeando la pag 412
# estas escrapeando la pag 413
# estas escrapeando la pag 414
# estas escrapeando la pag 415
# estas escrapeando la pag 416
# estas escrapeando la pag 417
# estas escrapeando la pag 418
# estas escrapeando la pag 419
# estas escrapeando la pag 420
# estas escrapeando la pag 421
# estas escrapeando la pag 422
# estas escrapeando la pag 423
# estas escrapeando la pag 424
# estas escrapeando la pag 425
# estas escrapeando la pag 426
# estas escrapeando la pag 427
# estas escrapeando la pag 428
# estas escrapeando la pag 429
# estas escrapeando la pag 430
# estas escrapeando la pag 431
# estas escrapeando la pag 432
# estas escrapeando la pag 433
# estas escrapeando la pag 434
# estas escrapeando la pag 435
# estas escrapeando la pag 436
# estas escrapeando la pag 437
# estas escrapeando la pag 438
# estas escrapeando la pag 439
# estas escrapeando la pag 440
# estas escrapeando la pag 441
# estas escrapeando la pag 442
# estas escrapeando la pag 443
# estas escrapeando la pag 444
# estas escrapeando la pag 445
# estas escrapeando la pag 446
# estas escrapeando la pag 447
# estas escrapeando la pag 448
# estas escrapeando la pag 449
# estas escrapeando la pag 450
# estas escrapeando la pag 451
# estas escrapeando la pag 452
# estas escrapeando la pag 453
# estas escrapeando la pag 454
# estas escrapeando la pag 455
# estas escrapeando la pag 456
# estas escrapeando la pag 457
# estas escrapeando la pag 458
# estas escrapeando la pag 459
# estas escrapeando la pag 460
# estas escrapeando la pag 461
# estas escrapeando la pag 462
# estas escrapeando la pag 463
# estas escrapeando la pag 464
# estas escrapeando la pag 465
# estas escrapeando la pag 466
# estas escrapeando la pag 467
# estas escrapeando la pag 468
# estas escrapeando la pag 469
# estas escrapeando la pag 470
# estas escrapeando la pag 471
# estas escrapeando la pag 472
# estas escrapeando la pag 473
# estas escrapeando la pag 474
# estas escrapeando la pag 475
# estas escrapeando la pag 476
# estas escrapeando la pag 477
# estas escrapeando la pag 478
# estas escrapeando la pag 479
# estas escrapeando la pag 480
# estas escrapeando la pag 481
# estas escrapeando la pag 482
# estas escrapeando la pag 483
# estas escrapeando la pag 484
# estas escrapeando la pag 485
# estas escrapeando la pag 486
# estas escrapeando la pag 487
# estas escrapeando la pag 488
# estas escrapeando la pag 489
# estas escrapeando la pag 490
# estas escrapeando la pag 491
# estas escrapeando la pag 492
# estas escrapeando la pag 493
# estas escrapeando la pag 494
# estas escrapeando la pag 495
# estas escrapeando la pag 496
# estas escrapeando la pag 497
# estas escrapeando la pag 498
# estas escrapeando la pag 499
# estas escrapeando la pag 500
# estas escrapeando la pag 501
# estas escrapeando la pag 502
# estas escrapeando la pag 503
# estas escrapeando la pag 504
# estas escrapeando la pag 505
# estas escrapeando la pag 506
# estas escrapeando la pag 507
# estas escrapeando la pag 508
# estas escrapeando la pag 509
# estas escrapeando la pag 510
# estas escrapeando la pag 511
# estas escrapeando la pag 512
# estas escrapeando la pag 513
# estas escrapeando la pag 514
# estas escrapeando la pag 515
# estas escrapeando la pag 516
# estas escrapeando la pag 517
# estas escrapeando la pag 518
# estas escrapeando la pag 519
# estas escrapeando la pag 520
# estas escrapeando la pag 521
# estas escrapeando la pag 522
# estas escrapeando la pag 523
# estas escrapeando la pag 524
# estas escrapeando la pag 525
# estas escrapeando la pag 526
# estas escrapeando la pag 527
# estas escrapeando la pag 528
# estas escrapeando la pag 529
# estas escrapeando la pag 530
# estas escrapeando la pag 531
# estas escrapeando la pag 532
# estas escrapeando la pag 533
# estas escrapeando la pag 534
# estas escrapeando la pag 535
# estas escrapeando la pag 536
# estas escrapeando la pag 537
# estas escrapeando la pag 538
# estas escrapeando la pag 539
# estas escrapeando la pag 540
# estas escrapeando la pag 541
# estas escrapeando la pag 542
# estas escrapeando la pag 543
# estas escrapeando la pag 544
# estas escrapeando la pag 545
# estas escrapeando la pag 546
# estas escrapeando la pag 547
# estas escrapeando la pag 548
# estas escrapeando la pag 549
# estas escrapeando la pag 550
# estas escrapeando la pag 551
# estas escrapeando la pag 552
# estas escrapeando la pag 553
# estas escrapeando la pag 554
# estas escrapeando la pag 555
# estas escrapeando la pag 556
# estas escrapeando la pag 557
# estas escrapeando la pag 558
# estas escrapeando la pag 559
# estas escrapeando la pag 560
# estas escrapeando la pag 561
# estas escrapeando la pag 562
# estas escrapeando la pag 563
# estas escrapeando la pag 564
# estas escrapeando la pag 565
# estas escrapeando la pag 566
# estas escrapeando la pag 567
# estas escrapeando la pag 568
# estas escrapeando la pag 569
# estas escrapeando la pag 570
# estas escrapeando la pag 571
# estas escrapeando la pag 572
# estas escrapeando la pag 573
# estas escrapeando la pag 574
# estas escrapeando la pag 575
# estas escrapeando la pag 576
# estas escrapeando la pag 577
# estas escrapeando la pag 578
# estas escrapeando la pag 579
# estas escrapeando la pag 580
# estas escrapeando la pag 581
# estas escrapeando la pag 582
# estas escrapeando la pag 583
# estas escrapeando la pag 584
# estas escrapeando la pag 585
# estas escrapeando la pag 586
# estas escrapeando la pag 587
# estas escrapeando la pag 588
# estas escrapeando la pag 589
# estas escrapeando la pag 590
# estas escrapeando la pag 591
# estas escrapeando la pag 592
# estas escrapeando la pag 593
# estas escrapeando la pag 594
# estas escrapeando la pag 595
# estas escrapeando la pag 596
# estas escrapeando la pag 597
# estas escrapeando la pag 598
# estas escrapeando la pag 599
# estas escrapeando la pag 600
# estas escrapeando la pag 601
# estas escrapeando la pag 602
# estas escrapeando la pag 603
# estas escrapeando la pag 604
# estas escrapeando la pag 605
# estas escrapeando la pag 606
# estas escrapeando la pag 607
# estas escrapeando la pag 608
# estas escrapeando la pag 609
# estas escrapeando la pag 610
# estas escrapeando la pag 611
# estas escrapeando la pag 612
# estas escrapeando la pag 613
# estas escrapeando la pag 614
# estas escrapeando la pag 615
# estas escrapeando la pag 616
# estas escrapeando la pag 617
# estas escrapeando la pag 618
# estas escrapeando la pag 619
# estas escrapeando la pag 620
# estas escrapeando la pag 621
# estas escrapeando la pag 622
# estas escrapeando la pag 623
# estas escrapeando la pag 624
# estas escrapeando la pag 625
# estas escrapeando la pag 626
# estas escrapeando la pag 627
# estas escrapeando la pag 628
# estas escrapeando la pag 629
# estas escrapeando la pag 630
# estas escrapeando la pag 631
# estas escrapeando la pag 632
# estas escrapeando la pag 633
# estas escrapeando la pag 634
# estas escrapeando la pag 635
# estas escrapeando la pag 636
# estas escrapeando la pag 637
# estas escrapeando la pag 638
# estas escrapeando la pag 639
# estas escrapeando la pag 640
# estas escrapeando la pag 641
# estas escrapeando la pag 642
# estas escrapeando la pag 643
# estas escrapeando la pag 644
# estas escrapeando la pag 645
# estas escrapeando la pag 646
# estas escrapeando la pag 647
# estas escrapeando la pag 648
# estas escrapeando la pag 649
# estas escrapeando la pag 650
# estas escrapeando la pag 651
# estas escrapeando la pag 652
# estas escrapeando la pag 653
# estas escrapeando la pag 654
# estas escrapeando la pag 655
# estas escrapeando la pag 656
# estas escrapeando la pag 657
# estas escrapeando la pag 658
# estas escrapeando la pag 659
# estas escrapeando la pag 660
# estas escrapeando la pag 661
# estas escrapeando la pag 662
# estas escrapeando la pag 663
# estas escrapeando la pag 664
# estas escrapeando la pag 665
# estas escrapeando la pag 666
# estas escrapeando la pag 667
# estas escrapeando la pag 668
# estas escrapeando la pag 669
# estas escrapeando la pag 670
# estas escrapeando la pag 671
# estas escrapeando la pag 672
# estas escrapeando la pag 673
# estas escrapeando la pag 674
# estas escrapeando la pag 675
# estas escrapeando la pag 676
# estas escrapeando la pag 677
# estas escrapeando la pag 678
# estas escrapeando la pag 679
# estas escrapeando la pag 680
# estas escrapeando la pag 681
# estas escrapeando la pag 682
# estas escrapeando la pag 683
# estas escrapeando la pag 684
# estas escrapeando la pag 685
# estas escrapeando la pag 686
# estas escrapeando la pag 687
# estas escrapeando la pag 688
# estas escrapeando la pag 689
# estas escrapeando la pag 690
# estas escrapeando la pag 691
# estas escrapeando la pag 692
# estas escrapeando la pag 693
# estas escrapeando la pag 694
# estas escrapeando la pag 695
# estas escrapeando la pag 696
# estas escrapeando la pag 697
# estas escrapeando la pag 698
# estas escrapeando la pag 699
# estas escrapeando la pag 700
# estas escrapeando la pag 701
# estas escrapeando la pag 702
# estas escrapeando la pag 703
# estas escrapeando la pag 704
# estas escrapeando la pag 705
# estas escrapeando la pag 706
# estas escrapeando la pag 707
# estas escrapeando la pag 708
# estas escrapeando la pag 709
# estas escrapeando la pag 710
# estas escrapeando la pag 711
# estas escrapeando la pag 712
# estas escrapeando la pag 713
# estas escrapeando la pag 714
# estas escrapeando la pag 715
# estas escrapeando la pag 716
# estas escrapeando la pag 717
# estas escrapeando la pag 718
# estas escrapeando la pag 719
# estas escrapeando la pag 720
# estas escrapeando la pag 721
# estas escrapeando la pag 722
# estas escrapeando la pag 723
# estas escrapeando la pag 724
# estas escrapeando la pag 725
# estas escrapeando la pag 726
# estas escrapeando la pag 727
# estas escrapeando la pag 728
# estas escrapeando la pag 729
# estas escrapeando la pag 730
# estas escrapeando la pag 731
# estas escrapeando la pag 732
# estas escrapeando la pag 733
# estas escrapeando la pag 734
# estas escrapeando la pag 735
# estas escrapeando la pag 736
# estas escrapeando la pag 737
# estas escrapeando la pag 738
# estas escrapeando la pag 739
# estas escrapeando la pag 740
# estas escrapeando la pag 741
# estas escrapeando la pag 742
# estas escrapeando la pag 743
# estas escrapeando la pag 744
# estas escrapeando la pag 745
# estas escrapeando la pag 746
# estas escrapeando la pag 747
# estas escrapeando la pag 748
# estas escrapeando la pag 749
# estas escrapeando la pag 750
# estas escrapeando la pag 751
# estas escrapeando la pag 752
# estas escrapeando la pag 753
# estas escrapeando la pag 754
# estas escrapeando la pag 755
# estas escrapeando la pag 756
# estas escrapeando la pag 757
# estas escrapeando la pag 758
# estas escrapeando la pag 759
# estas escrapeando la pag 760
# estas escrapeando la pag 761
# estas escrapeando la pag 762
# estas escrapeando la pag 763
# estas escrapeando la pag 764
# estas escrapeando la pag 765
# estas escrapeando la pag 766
# estas escrapeando la pag 767
# estas escrapeando la pag 768
# estas escrapeando la pag 769
# estas escrapeando la pag 770
# estas escrapeando la pag 771
# estas escrapeando la pag 772
# estas escrapeando la pag 773
# estas escrapeando la pag 774
# estas escrapeando la pag 775
# estas escrapeando la pag 776
# estas escrapeando la pag 777
# estas escrapeando la pag 778
# estas escrapeando la pag 779
# estas escrapeando la pag 780
# estas escrapeando la pag 781
# estas escrapeando la pag 782
# estas escrapeando la pag 783
# estas escrapeando la pag 784
# estas escrapeando la pag 785
# estas escrapeando la pag 786
# estas escrapeando la pag 787
# estas escrapeando la pag 788
# estas escrapeando la pag 789
# estas escrapeando la pag 790
# estas escrapeando la pag 791
# estas escrapeando la pag 792
# estas escrapeando la pag 793
# estas escrapeando la pag 794
# estas escrapeando la pag 795
# estas escrapeando la pag 796
# estas escrapeando la pag 797
# estas escrapeando la pag 798
# estas escrapeando la pag 799
# estas escrapeando la pag 800
# estas escrapeando la pag 801
# estas escrapeando la pag 802
# estas escrapeando la pag 803
# estas escrapeando la pag 804
# estas escrapeando la pag 805
# estas escrapeando la pag 806
# estas escrapeando la pag 807
# estas escrapeando la pag 808
# estas escrapeando la pag 809
# estas escrapeando la pag 810
# estas escrapeando la pag 811
# estas escrapeando la pag 812
# estas escrapeando la pag 813
# estas escrapeando la pag 814
# estas escrapeando la pag 815
# estas escrapeando la pag 816
# estas escrapeando la pag 817
# estas escrapeando la pag 818
# estas escrapeando la pag 819
# estas escrapeando la pag 820
# estas escrapeando la pag 821
# estas escrapeando la pag 822
# estas escrapeando la pag 823
# estas escrapeando la pag 824
# estas escrapeando la pag 825
# estas escrapeando la pag 826
# estas escrapeando la pag 827
# estas escrapeando la pag 828
# estas escrapeando la pag 829
# estas escrapeando la pag 830
# estas escrapeando la pag 831
# estas escrapeando la pag 832
# estas escrapeando la pag 833
# estas escrapeando la pag 834
# estas escrapeando la pag 835
# estas escrapeando la pag 836
# estas escrapeando la pag 837
# estas escrapeando la pag 838
# estas escrapeando la pag 839
# estas escrapeando la pag 840
# estas escrapeando la pag 841
# estas escrapeando la pag 842
# estas escrapeando la pag 843
# estas escrapeando la pag 844
# estas escrapeando la pag 845
# estas escrapeando la pag 846
# estas escrapeando la pag 847
# estas escrapeando la pag 848
# estas escrapeando la pag 849
# estas escrapeando la pag 850
# estas escrapeando la pag 851
# estas escrapeando la pag 852
# estas escrapeando la pag 853
# estas escrapeando la pag 854
# estas escrapeando la pag 855
# estas escrapeando la pag 856
# estas escrapeando la pag 857
# estas escrapeando la pag 858
# estas escrapeando la pag 859
# estas escrapeando la pag 860
# estas escrapeando la pag 861
# estas escrapeando la pag 862
# estas escrapeando la pag 863
# estas escrapeando la pag 864
# estas escrapeando la pag 865
# estas escrapeando la pag 866
# estas escrapeando la pag 867
# estas escrapeando la pag 868
# estas escrapeando la pag 869
# estas escrapeando la pag 870
# estas escrapeando la pag 871
# estas escrapeando la pag 872
# estas escrapeando la pag 873
# estas escrapeando la pag 874

# %%
df_catalogo=pd.DataFrame(datos_book)
df_catalogo
# Out:
#                         Titulo Revista                  Area  \
# 0  Revista Mexicana de Opinión Pública  V. Ciencias Sociales
# 1  Revista Mexicana de Opinión Pública  V. Ciencias Sociales
# 2  Revista Mexicana de Opinión Pública  V. Ciencias Sociales
# 3  Revista Mexicana de Opinión Pública  V. Ciencias Sociales
# 4  Revista Mexicana de Opinión Pública  V. Ciencias Sociales
# 5  Revista Mexicana de Opinión Pública  V. Ciencias Sociales
# 6  Revista Mexicana de Opinión Pública  V. Ciencias Sociales
# 7  Revista Mexicana de Opinión Pública  V. Ciencias Sociales
#
#                                             Tematica  \
# 0  Opinión pública, Comunicación, Estudios electo...
# 1  Opinión pública, Comunicación, Estudios electo...
# 2  Opinión pública, Comunicación, Estudios electo...
# 3  Opinión pública, Comunicación, Estudios electo...
# 4  Opinión pública, Comunicación, Estudios electo...
# 5  Opinión pública, Comunicación, Estudios electo...
# 6  Opinión pública, Comunicación, Estudios electo...
# 7  Opinión pública, Comunicación, Estudios electo...
#
#                                      Titulo Articulo  \
# 0                                               None
# 1                                               None
# 2  Posverdad: construcción epistémica para la dom...
# 3  Posverdad: construcción epistémica para la dom...
# 4                                               None
# 5  Posverdad: hacia una metodología para el análi...
# 6  Posverdad: hacia una metodología para el análi...
# 7                                               None
#
#                                              Resumen Abstract  \
# 0                                               None     None
# 1                                               None     None
# 2  El trabajo se presenta como una aportación teó...     None
# 3  El trabajo se presenta como una aportación teó...     None
# 4                                               None     None
# 5  La emergencia de las redes sociales como medio...     None
# 6  La emergencia de las redes sociales como medio...     None
# 7                                               None     None
#
#                                        Link Articulo  \
# 0  http://dx.doi.org/10.22201/fcpys.24484911e.202...
# 1  http://revistas.unam.mx/index.php/rmop/article...
# 2  http://revistas.unam.mx/index.php/rmop/article...
# 3  http://revistas.unam.mx/index.php/rmop/article...
# 4  http://revistas.unam.mx/index.php/rmop/article...
# 5  http://revistas.unam.mx/index.php/rmop/article...
# 6  http://revistas.unam.mx/index.php/rmop/article...
# 7  http://revistas.unam.mx/index.php/rmop/article...
#
#                                             Link PDF
# 0                                               None
# 1                                               None
# 2  http://revistas.unam.mx/index.php/rmop/article...
# 3  http://revistas.unam.mx/index.php/rmop/article...
# 4                                               None
# 5  http://revistas.unam.mx/index.php/rmop/article...
# 6  http://revistas.unam.mx/index.php/rmop/article...
# 7                                               None

# %%
df_catalogo.to_csv('Revista123.csv', index=False)
