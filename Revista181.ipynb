# %%
import requests
import bs4
from bs4 import BeautifulSoup
from urllib.parse import urljoin
import pandas as pd

# %%
url_inicial = 'https://www.revistabiomedica.mx/index.php/revbiomed/issue/archive'
url_root = 'https://www.revistabiomedica.mx/index.php/revbiomed/issue/archive'
r=requests.get(url_inicial)

# %%
soup = BeautifulSoup(r.text, 'html.parser')

# %%
box = soup.find('div', id='issues')
volumen=box.findAll('div', class_='list')
vol = [x.find('a').get('href')for x in volumen]
vol=[urljoin(url_root,i) for i in vol]
vol
# Out:
# ['https://www.revistabiomedica.mx/index.php/revbiomed/issue/view/87',
#  'https://www.revistabiomedica.mx/index.php/revbiomed/issue/view/RevBiomed',
#  'https://www.revistabiomedica.mx/index.php/revbiomed/issue/view/85',
#  'https://www.revistabiomedica.mx/index.php/revbiomed/issue/view/84',
#  'https://www.revistabiomedica.mx/index.php/revbiomed/issue/view/32%20%281%29',
#  'https://www.revistabiomedica.mx/index.php/revbiomed/issue/view/82',
#  'https://www.revistabiomedica.mx/index.php/revbiomed/issue/view/81',
#  'https://www.revistabiomedica.mx/index.php/revbiomed/issue/view/80',
#  'https://www.revistabiomedica.mx/index.php/revbiomed/issue/view/79',
#  'https://www.revistabiomedica.mx/index.php/revbiomed/issue/view/78',
#  'https://www.revistabiomedica.mx/index.php/revbiomed/issue/view/77',
#  'https://www.revistabiomedica.mx/index.php/revbiomed/issue/view/76',
#  'https://www.revistabiomedica.mx/index.php/revbiomed/issue/view/75',
#  'https://www.revistabiomedica.mx/index.php/revbiomed/issue/view/74',
#  'https://www.revistabiomedica.mx/index.php/revbiomed/issue/view/73',
#  'https://www.revistabiomedica.mx/index.php/revbiomed/issue/view/72',
#  'https://www.revistabiomedica.mx/index.php/revbiomed/issue/view/71',
#  'https://www.revistabiomedica.mx/index.php/revbiomed/issue/view/70',
#  'https://www.revistabiomedica.mx/index.php/revbiomed/issue/view/3',
#  'https://www.revistabiomedica.mx/index.php/revbiomed/issue/view/2',
#  'https://www.revistabiomedica.mx/index.php/revbiomed/issue/view/4',
#  'https://www.revistabiomedica.mx/index.php/revbiomed/issue/view/5',
#  'https://www.revistabiomedica.mx/index.php/revbiomed/issue/view/1',
#  'https://www.revistabiomedica.mx/index.php/revbiomed/issue/view/6',
#  'https://www.revistabiomedica.mx/index.php/revbiomed/issue/view/7']

# %%
vol2 =[]
for i in vol: 
    url_inicial1=i 
    r1 = requests.get(url_inicial1)
    soup1 = BeautifulSoup(r1.text, 'html.parser')
    box1 = soup1.find('div', id='content') 
    volumen1=box1.findAll('table', class_='tocArticle')
    vol1 = [x.find('a').get('href')for x in volumen1]
    vol2+=vol1

# %%
vol2
# Out:
# ['https://www.revistabiomedica.mx/index.php/revbiomed/article/view/1028',
#  'https://www.revistabiomedica.mx/index.php/revbiomed/article/view/922',
#  'https://www.revistabiomedica.mx/index.php/revbiomed/article/view/929',
#  'https://www.revistabiomedica.mx/index.php/revbiomed/article/view/932',
#  'https://www.revistabiomedica.mx/index.php/revbiomed/article/view/908',
#  'https://www.revistabiomedica.mx/index.php/revbiomed/article/view/906',
#  'https://www.revistabiomedica.mx/index.php/revbiomed/article/view/931',
#  'https://www.revistabiomedica.mx/index.php/revbiomed/article/view/882',
#  'https://www.revistabiomedica.mx/index.php/revbiomed/article/view/903',
#  'https://www.revistabiomedica.mx/index.php/revbiomed/article/view/889',
#  'https://www.revistabiomedica.mx/index.php/revbiomed/article/view/904',
#  'https://www.revistabiomedica.mx/index.php/revbiomed/article/view/833',
#  'https://www.revistabiomedica.mx/index.php/revbiomed/article/view/869',
#  'https://www.revistabiomedica.mx/index.php/revbiomed/article/view/839',
#  'https://www.revistabiomedica.mx/index.php/revbiomed/article/view/786',
#  'https://www.revistabiomedica.mx/index.php/revbiomed/article/view/840',
#  'https://www.revistabiomedica.mx/index.php/revbiomed/article/view/728',
#  'https://www.revistabiomedica.mx/index.php/revbiomed/article/view/775',
#  'https://www.revistabiomedica.mx/index.php/revbiomed/article/view/739',
#  'https://www.revistabiomedica.mx/index.php/revbiomed/article/view/789',
#  'https://www.revistabiomedica.mx/index.php/revbiomed/article/view/706',
#  'https://www.revistabiomedica.mx/index.php/revbiomed/article/view/655',
#  'https://www.revistabiomedica.mx/index.php/revbiomed/article/view/722',
#  'https://www.revistabiomedica.mx/index.php/revbiomed/article/view/784',
#  'https://www.revistabiomedica.mx/index.php/revbiomed/article/view/661',
#  'https://www.revistabiomedica.mx/index.php/revbiomed/article/view/657',
#  'https://www.revistabiomedica.mx/index.php/revbiomed/article/view/741',
#  'https://www.revistabiomedica.mx/index.php/revbiomed/article/view/684',
#  'https://www.revistabiomedica.mx/index.php/revbiomed/article/view/662',
#  'https://www.revistabiomedica.mx/index.php/revbiomed/article/view/694',
#  'https://www.revistabiomedica.mx/index.php/revbiomed/article/view/718',
#  'https://www.revistabiomedica.mx/index.php/revbiomed/article/view/640',
#  'https://www.revistabiomedica.mx/index.php/revbiomed/article/view/637',
#  'https://www.revistabiomedica.mx/index.php/revbiomed/article/view/664',
#  'https://www.revistabiomedica.mx/index.php/revbiomed/article/view/674/653',
#  'https://www.revistabiomedica.mx/index.php/revbiomed/article/view/654',
#  'https://www.revistabiomedica.mx/index.php/revbiomed/article/view/627',
#  'https://www.revistabiomedica.mx/index.php/revbiomed/article/view/635',
#  'https://www.revistabiomedica.mx/index.php/revbiomed/article/view/642',
#  'https://www.revistabiomedica.mx/index.php/revbiomed/article/view/615',
#  'https://www.revistabiomedica.mx/index.php/revbiomed/article/view/628',
#  'https://www.revistabiomedica.mx/index.php/revbiomed/article/view/612',
#  'https://www.revistabiomedica.mx/index.php/revbiomed/article/view/607',
#  'https://www.revistabiomedica.mx/index.php/revbiomed/article/view/584',
#  'https://www.revistabiomedica.mx/index.php/revbiomed/article/view/581',
#  'https://www.revistabiomedica.mx/index.php/revbiomed/article/view/585',
#  'https://www.revistabiomedica.mx/index.php/revbiomed/article/view/549',
#  'https://www.revistabiomedica.mx/index.php/revbiomed/article/view/571',
#  'https://www.revistabiomedica.mx/index.php/revbiomed/article/view/575',
#  'https://www.revistabiomedica.mx/index.php/revbiomed/article/view/572',
#  'https://www.revistabiomedica.mx/index.php/revbiomed/article/view/557',
#  'https://www.revistabiomedica.mx/index.php/revbiomed/article/view/551',
#  'https://www.revistabiomedica.mx/index.php/revbiomed/article/view/552',
#  'https://www.revistabiomedica.mx/index.php/revbiomed/article/view/537',
#  'https://www.revistabiomedica.mx/index.php/revbiomed/article/view/538',
#  'https://www.revistabiomedica.mx/index.php/revbiomed/article/view/540',
#  'https://www.revistabiomedica.mx/index.php/revbiomed/article/view/542',
#  'https://www.revistabiomedica.mx/index.php/revbiomed/article/view/23',
#  'https://www.revistabiomedica.mx/index.php/revbiomed/article/view/24',
#  'https://www.revistabiomedica.mx/index.php/revbiomed/article/view/22',
#  'https://www.revistabiomedica.mx/index.php/revbiomed/article/view/27',
#  'https://www.revistabiomedica.mx/index.php/revbiomed/article/view/11',
#  'https://www.revistabiomedica.mx/index.php/revbiomed/article/view/12',
#  'https://www.revistabiomedica.mx/index.php/revbiomed/article/view/14',
#  'https://www.revistabiomedica.mx/index.php/revbiomed/article/view/15',
#  'https://www.revistabiomedica.mx/index.php/revbiomed/article/view/16',
#  'https://www.revistabiomedica.mx/index.php/revbiomed/article/view/39',
#  'https://www.revistabiomedica.mx/index.php/revbiomed/article/view/28',
#  'https://www.revistabiomedica.mx/index.php/revbiomed/article/view/30',
#  'https://www.revistabiomedica.mx/index.php/revbiomed/article/view/31',
#  'https://www.revistabiomedica.mx/index.php/revbiomed/article/view/180',
#  'https://www.revistabiomedica.mx/index.php/revbiomed/article/view/34',
#  'https://www.revistabiomedica.mx/index.php/revbiomed/article/view/36',
#  'https://www.revistabiomedica.mx/index.php/revbiomed/article/view/35',
#  'https://www.revistabiomedica.mx/index.php/revbiomed/article/view/38',
#  'https://www.revistabiomedica.mx/index.php/revbiomed/article/view/37',
#  'https://www.revistabiomedica.mx/index.php/revbiomed/article/view/1',
#  'https://www.revistabiomedica.mx/index.php/revbiomed/article/view/3',
#  'https://www.revistabiomedica.mx/index.php/revbiomed/article/view/7',
#  'https://www.revistabiomedica.mx/index.php/revbiomed/article/view/6',
#  'https://www.revistabiomedica.mx/index.php/revbiomed/article/view/9',
#  'https://www.revistabiomedica.mx/index.php/revbiomed/article/view/53',
#  'https://www.revistabiomedica.mx/index.php/revbiomed/article/view/41',
#  'https://www.revistabiomedica.mx/index.php/revbiomed/article/view/42',
#  'https://www.revistabiomedica.mx/index.php/revbiomed/article/view/44',
#  'https://www.revistabiomedica.mx/index.php/revbiomed/article/view/59',
#  'https://www.revistabiomedica.mx/index.php/revbiomed/article/view/47',
#  'https://www.revistabiomedica.mx/index.php/revbiomed/article/view/50',
#  'https://www.revistabiomedica.mx/index.php/revbiomed/article/view/49',
#  'https://www.revistabiomedica.mx/index.php/revbiomed/article/view/51',
#  'https://www.revistabiomedica.mx/index.php/revbiomed/article/view/52']

# %%
def get_url_items(sopa,url):
    box1 = soup1.find('div', id='content') 
    volumen1=box1.findAll('table', class_='tocArticle')
    vol1 = [x.find('a').get('href')for x in volumen1]
    return vol2

# %%
links_items=[]
i=0
while i<1:
    i+=1
    print(f'Estoy en la pagina {url_inicial}')
    r_pag=requests.get(url_inicial)
    s_p=BeautifulSoup(r_pag.text,'html.parser')
    links=get_url_items(s_p, url_inicial)
    links_items.append(links)
# Out:
# Estoy en la pagina https://www.revistabiomedica.mx/index.php/revbiomed/issue/archive

# %%
list_scraper=[]
for i in links_items:
    for j in i:
        list_scraper.append(j)
len(list_scraper)
# Out:
# 91

# %%
uno=list_scraper[0]
r_item=requests.get(uno)
s_item=BeautifulSoup(r_item.text, 'html.parser')

# %%
#funcion para iniciar el escraper de cada libro
def scraper_book(url):
    content_book={}
    r=requests.get(url)
    tire='Revista Biomédica'
    a='III. Medicina y Ciencias de la Salud'
    tem='Biomedica en General'
    s_item=BeautifulSoup(r.text,'html.parser')
    #titulo de revista
    try:
        titulo=tire
        content_book['Titulo Revista']=tire
    except AttributeError:
        content_book['Titulo Revista']=None
    #area
    try:
        area=a
        content_book['Area']=a
    except AttributeError:
        content_book['Area']=None
    #tematica
    try:
        tema=tem
        content_book['Tematica']=tem
    except AttributeError:
        content_book['Tematica']=None
    #titulo articulo
    try:
        titu=s_item.find('div', id='articleTitle').get_text(strip=True)
        content_book['Titulo Articulo']=titu
    except AttributeError:
        content_book['Titulo Articulo']=None
    #resumen
    try:
        resu=s_item.find('div', id='articleAbstract').get_text(strip=True)
        content_book['Resumen']=resu.replace("Resumen","")
    except AttributeError:
        content_book['Resumen']=None
    #abstract
    try:
        abst=s_item.find('div', id='item cover_image').get_text(strip=True)
        content_book['Abstract']=abst
    except AttributeError:
        content_book['Abstract']=None
    #Link incial
    try:
        linkart=url
        content_book['Link Articulo']=linkart
    except AttributeError:
        content_book['Link Articulo']=None
    #link articulo
    try:
        link=s_item.find('a', class_='file').get('href')
        content_book['Link PDF']=urljoin(url_root, link)
    except AttributeError:
        content_book['Link PDF']=None
    return content_book

# %%
list_scraper=list_scraper[0:91]
datos_book=[]
for idx, i in enumerate(list_scraper):
    print(f'estas escrapeando la pag {idx}')
    datos_book.append(scraper_book(i))
# Out:
# estas escrapeando la pag 0
# estas escrapeando la pag 1
# estas escrapeando la pag 2
# estas escrapeando la pag 3
# estas escrapeando la pag 4
# estas escrapeando la pag 5
# estas escrapeando la pag 6
# estas escrapeando la pag 7
# estas escrapeando la pag 8
# estas escrapeando la pag 9
# estas escrapeando la pag 10
# estas escrapeando la pag 11
# estas escrapeando la pag 12
# estas escrapeando la pag 13
# estas escrapeando la pag 14
# estas escrapeando la pag 15
# estas escrapeando la pag 16
# estas escrapeando la pag 17
# estas escrapeando la pag 18
# estas escrapeando la pag 19
# estas escrapeando la pag 20
# estas escrapeando la pag 21
# estas escrapeando la pag 22
# estas escrapeando la pag 23
# estas escrapeando la pag 24
# estas escrapeando la pag 25
# estas escrapeando la pag 26
# estas escrapeando la pag 27
# estas escrapeando la pag 28
# estas escrapeando la pag 29
# estas escrapeando la pag 30
# estas escrapeando la pag 31
# estas escrapeando la pag 32
# estas escrapeando la pag 33
# estas escrapeando la pag 34
# estas escrapeando la pag 35
# estas escrapeando la pag 36
# estas escrapeando la pag 37
# estas escrapeando la pag 38
# estas escrapeando la pag 39
# estas escrapeando la pag 40
# estas escrapeando la pag 41
# estas escrapeando la pag 42
# estas escrapeando la pag 43
# estas escrapeando la pag 44
# estas escrapeando la pag 45
# estas escrapeando la pag 46
# estas escrapeando la pag 47
# estas escrapeando la pag 48
# estas escrapeando la pag 49
# estas escrapeando la pag 50
# estas escrapeando la pag 51
# estas escrapeando la pag 52
# estas escrapeando la pag 53
# estas escrapeando la pag 54
# estas escrapeando la pag 55
# estas escrapeando la pag 56
# estas escrapeando la pag 57
# estas escrapeando la pag 58
# estas escrapeando la pag 59
# estas escrapeando la pag 60
# estas escrapeando la pag 61
# estas escrapeando la pag 62
# estas escrapeando la pag 63
# estas escrapeando la pag 64
# estas escrapeando la pag 65
# estas escrapeando la pag 66
# estas escrapeando la pag 67
# estas escrapeando la pag 68
# estas escrapeando la pag 69
# estas escrapeando la pag 70
# estas escrapeando la pag 71
# estas escrapeando la pag 72
# estas escrapeando la pag 73
# estas escrapeando la pag 74
# estas escrapeando la pag 75
# estas escrapeando la pag 76
# estas escrapeando la pag 77
# estas escrapeando la pag 78
# estas escrapeando la pag 79
# estas escrapeando la pag 80
# estas escrapeando la pag 81
# estas escrapeando la pag 82
# estas escrapeando la pag 83
# estas escrapeando la pag 84
# estas escrapeando la pag 85
# estas escrapeando la pag 86
# estas escrapeando la pag 87
# estas escrapeando la pag 88
# estas escrapeando la pag 89
# estas escrapeando la pag 90

# %%
df_catalogo=pd.DataFrame(datos_book)
df_catalogo
# Out:
#        Titulo Revista                                  Area  \
# 0   Revista Biomédica  III. Medicina y Ciencias de la Salud
# 1   Revista Biomédica  III. Medicina y Ciencias de la Salud
# 2   Revista Biomédica  III. Medicina y Ciencias de la Salud
# 3   Revista Biomédica  III. Medicina y Ciencias de la Salud
# 4   Revista Biomédica  III. Medicina y Ciencias de la Salud
# ..                ...                                   ...
# 86  Revista Biomédica  III. Medicina y Ciencias de la Salud
# 87  Revista Biomédica  III. Medicina y Ciencias de la Salud
# 88  Revista Biomédica  III. Medicina y Ciencias de la Salud
# 89  Revista Biomédica  III. Medicina y Ciencias de la Salud
# 90  Revista Biomédica  III. Medicina y Ciencias de la Salud
#
#                 Tematica                                    Titulo Articulo  \
# 0   Biomedica en General  Diabesidad en los mayas yucatecos. Genes, meta...
# 1   Biomedica en General  Comparación entre las mediciones antropométric...
# 2   Biomedica en General  Monitoreo del Mosquito Negro de los Pantanos A...
# 3   Biomedica en General  Perspectivas de la enseñanza de posgrado en va...
# 4   Biomedica en General  Utilidad del ultrasonido versus biopsia en el ...
# ..                   ...                                                ...
# 86  Biomedica en General  Distribución espacial y temporal de los sitios...
# 87  Biomedica en General  Juego patológico, depresión y trastorno de per...
# 88  Biomedica en General  Infertilidad humana causada por Mycoplasma spp...
# 89  Biomedica en General  Real images for prevention campaigns: A three ...
# 90  Biomedica en General  Eduardo Urzaiz Rodríguez: Universitario ejempl...
#
#                                               Resumen Abstract  \
# 0                       No aplica al ser un Editorial     None
# 1   Introducción:Las mediciones antropométricas (M...     None
# 2   Introducción.Aedestaeniorhynchuses un mosquito...     None
# 3   De acuerdo con el Dr. Duarte Nuno Vieira,profe...     None
# 4   Introducción:El ultrasonido del ganglio centin...     None
# ..                                                ...      ...
# 86  Introducción. La propagación del denguese atri...     None
# 87  Introducción. En años recientes, el juegopatol...     None
# 88  En los últimos años, ha aumentado elnúmero de ...     None
# 89                                       Sin resumen.     None
# 90  El Dr. Eduardo Urzaiz Rodríguez es unode esos ...     None
#
#                                         Link Articulo  \
# 0   https://www.revistabiomedica.mx/index.php/revb...
# 1   https://www.revistabiomedica.mx/index.php/revb...
# 2   https://www.revistabiomedica.mx/index.php/revb...
# 3   https://www.revistabiomedica.mx/index.php/revb...
# 4   https://www.revistabiomedica.mx/index.php/revb...
# ..                                                ...
# 86  https://www.revistabiomedica.mx/index.php/revb...
# 87  https://www.revistabiomedica.mx/index.php/revb...
# 88  https://www.revistabiomedica.mx/index.php/revb...
# 89  https://www.revistabiomedica.mx/index.php/revb...
# 90  https://www.revistabiomedica.mx/index.php/revb...
#
#                                              Link PDF
# 0   https://www.revistabiomedica.mx/index.php/revb...
# 1   https://www.revistabiomedica.mx/index.php/revb...
# 2   https://www.revistabiomedica.mx/index.php/revb...
# 3   https://www.revistabiomedica.mx/index.php/revb...
# 4   https://www.revistabiomedica.mx/index.php/revb...
# ..                                                ...
# 86  https://www.revistabiomedica.mx/index.php/revb...
# 87  https://www.revistabiomedica.mx/index.php/revb...
# 88  https://www.revistabiomedica.mx/index.php/revb...
# 89  https://www.revistabiomedica.mx/index.php/revb...
# 90  https://www.revistabiomedica.mx/index.php/revb...
#
# [91 rows x 8 columns]

# %%
df_catalogo.to_csv('Revista181.01.csv', index=False)
