# %%
import requests
import bs4
from bs4 import BeautifulSoup
from urllib.parse import urljoin
import pandas as pd

# %%
url_inicial = 'http://erevistas.uacj.mx/ojs/index.php/noesis/issue/archive'
url_root = 'http://erevistas.uacj.mx/ojs/index.php/noesis/issue/archive'
r=requests.get(url_inicial)

# %%
soup = BeautifulSoup(r.text, 'html.parser')

# %%
box = soup.find('ul', class_='issues_archive')
volumen=box.findAll('div', class_='obj_issue_summary')
vol = [x.find('a').get('href')for x in volumen]
vol=[urljoin(url_root,i) for i in vol]
vol
# Out:
# ['http://erevistas.uacj.mx/ojs/index.php/noesis/issue/view/749',
#  'http://erevistas.uacj.mx/ojs/index.php/noesis/issue/view/724',
#  'http://erevistas.uacj.mx/ojs/index.php/noesis/issue/view/702',
#  'http://erevistas.uacj.mx/ojs/index.php/noesis/issue/view/Enero%20-%20junio%202021',
#  'http://erevistas.uacj.mx/ojs/index.php/noesis/issue/view/675',
#  'http://erevistas.uacj.mx/ojs/index.php/noesis/issue/view/688',
#  'http://erevistas.uacj.mx/ojs/index.php/noesis/issue/view/674',
#  'http://erevistas.uacj.mx/ojs/index.php/noesis/issue/view/577',
#  'http://erevistas.uacj.mx/ojs/index.php/noesis/issue/view/636',
#  'http://erevistas.uacj.mx/ojs/index.php/noesis/issue/view/533',
#  'http://erevistas.uacj.mx/ojs/index.php/noesis/issue/view/523',
#  'http://erevistas.uacj.mx/ojs/index.php/noesis/issue/view/608',
#  'http://erevistas.uacj.mx/ojs/index.php/noesis/issue/view/606',
#  'http://erevistas.uacj.mx/ojs/index.php/noesis/issue/view/522',
# ...

# %%
vol2 =[]
for i in vol: 
    url_inicial1=i 
    r1 = requests.get(url_inicial1)
    soup1 = BeautifulSoup(r1.text, 'html.parser')
    box1 = soup1.find('div', class_='sections') 
    volumen1=box1.findAll('div', class_='obj_article_summary')
    vol1 = [x.find('a').get('href')for x in volumen1]
    vol2+=vol1

# %%
vol2
# Out:
# ['http://erevistas.uacj.mx/ojs/index.php/noesis/article/view/5030',
#  'http://erevistas.uacj.mx/ojs/index.php/noesis/article/view/4148',
#  'http://erevistas.uacj.mx/ojs/index.php/noesis/article/view/4285',
#  'http://erevistas.uacj.mx/ojs/index.php/noesis/article/view/4246',
#  'http://erevistas.uacj.mx/ojs/index.php/noesis/article/view/4239',
#  'http://erevistas.uacj.mx/ojs/index.php/noesis/article/view/4238',
#  'http://erevistas.uacj.mx/ojs/index.php/noesis/article/view/4096',
#  'http://erevistas.uacj.mx/ojs/index.php/noesis/article/view/4168',
#  'http://erevistas.uacj.mx/ojs/index.php/noesis/article/view/4236',
#  'http://erevistas.uacj.mx/ojs/index.php/noesis/article/view/4212',
#  'http://erevistas.uacj.mx/ojs/index.php/noesis/article/view/4121',
#  'http://erevistas.uacj.mx/ojs/index.php/noesis/article/view/4211',
#  'http://erevistas.uacj.mx/ojs/index.php/noesis/article/view/4289',
#  'http://erevistas.uacj.mx/ojs/index.php/noesis/article/view/4273',
# ...

# %%
def get_url_items(sopa,url):
    box1 = soup1.find('div', class_='sections') 
    volumen1=box1.findAll('div', class_='obj_article_summary')
    vol1 = [x.find('a').get('href')for x in volumen1]
    return vol2

# %%
links_items=[]
i=0
while i<1:
    i+=1
    print(f'Estoy en la pagina {url_inicial}')
    r_pag=requests.get(url_inicial)
    s_p=BeautifulSoup(r_pag.text,'html.parser')
    links=get_url_items(s_p, url_inicial)
    links_items.append(links)
# Out:
# Estoy en la pagina http://erevistas.uacj.mx/ojs/index.php/noesis/issue/archive

# %%
list_scraper=[]
for i in links_items:
    for j in i:
        list_scraper.append(j)
len(list_scraper)
# Out:
# 233

# %%
uno=list_scraper[0]
r_item=requests.get(uno)
s_item=BeautifulSoup(r_item.text, 'html.parser')

# %%
#funcion para iniciar el escraper de cada libro
def scraper_book(url):
    content_book={}
    r=requests.get(url)
    tire='Nóesis. Revista de Ciencias Sociales y Humanidades'
    a='V. Ciencias Sociales'
    tem='Ciencias Sociales'
    s_item=BeautifulSoup(r.text,'html.parser')
    #titulo de revista
    try:
        titulo=tire
        content_book['Titulo Revista']=tire
    except AttributeError:
        content_book['Titulo Revista']=None
    #area
    try:
        area=a
        content_book['Area']=a
    except AttributeError:
        content_book['Area']=None
    #tematica
    try:
        tema=tem
        content_book['Tematica']=tem
    except AttributeError:
        content_book['Tematica']=None
    #titulo articulo
    try:
        titu=s_item.find('h1', class_='page_title').get_text(strip=True)
        content_book['Titulo Articulo']=titu
    except AttributeError:
        content_book['Titulo Articulo']=None
    #resumen
    try:
        resu=s_item.find('section', class_='item abstract').find('p').get_text(strip=True)
        content_book['Resumen']=resu.replace("Resumen","")
    except AttributeError:
        content_book['Resumen']=None
    #abstract
    try:
        abst=s_item.find('div', id='item cover_image').get_text(strip=True)
        content_book['Abstract']=abst
    except AttributeError:
        content_book['Abstract']=None
    #Link incial
    try:
        linkart=url
        content_book['Link Articulo']=linkart
    except AttributeError:
        content_book['Link Articulo']=None
    #link articulo
    try:
        link=s_item.find('a', class_='obj_galley_link pdf').get('href')
        content_book['Link PDF']=urljoin(url_root, link)
    except AttributeError:
        content_book['Link PDF']=None
    return content_book

# %%
list_scraper=list_scraper[0:233]
datos_book=[]
for idx, i in enumerate(list_scraper):
    print(f'estas escrapeando la pag {idx}')
    datos_book.append(scraper_book(i))
# Out:
# estas escrapeando la pag 0
# estas escrapeando la pag 1
# estas escrapeando la pag 2
# estas escrapeando la pag 3
# estas escrapeando la pag 4
# estas escrapeando la pag 5
# estas escrapeando la pag 6
# estas escrapeando la pag 7
# estas escrapeando la pag 8
# estas escrapeando la pag 9
# estas escrapeando la pag 10
# estas escrapeando la pag 11
# estas escrapeando la pag 12
# estas escrapeando la pag 13
# estas escrapeando la pag 14
# estas escrapeando la pag 15
# estas escrapeando la pag 16
# estas escrapeando la pag 17
# estas escrapeando la pag 18
# estas escrapeando la pag 19
# estas escrapeando la pag 20
# estas escrapeando la pag 21
# estas escrapeando la pag 22
# estas escrapeando la pag 23
# estas escrapeando la pag 24
# estas escrapeando la pag 25
# estas escrapeando la pag 26
# estas escrapeando la pag 27
# estas escrapeando la pag 28
# estas escrapeando la pag 29
# estas escrapeando la pag 30
# estas escrapeando la pag 31
# estas escrapeando la pag 32
# ...

# %%
df_catalogo=pd.DataFrame(datos_book)
df_catalogo
# Out:
#                                         Titulo Revista                  Area  \
# 0    Nóesis. Revista de Ciencias Sociales y Humanid...  V. Ciencias Sociales
# 1    Nóesis. Revista de Ciencias Sociales y Humanid...  V. Ciencias Sociales
# 2    Nóesis. Revista de Ciencias Sociales y Humanid...  V. Ciencias Sociales
# 3    Nóesis. Revista de Ciencias Sociales y Humanid...  V. Ciencias Sociales
# 4    Nóesis. Revista de Ciencias Sociales y Humanid...  V. Ciencias Sociales
# ..                                                 ...                   ...
# 228  Nóesis. Revista de Ciencias Sociales y Humanid...  V. Ciencias Sociales
# 229  Nóesis. Revista de Ciencias Sociales y Humanid...  V. Ciencias Sociales
# 230  Nóesis. Revista de Ciencias Sociales y Humanid...  V. Ciencias Sociales
# 231  Nóesis. Revista de Ciencias Sociales y Humanid...  V. Ciencias Sociales
# 232  Nóesis. Revista de Ciencias Sociales y Humanid...  V. Ciencias Sociales
#
# ...

# %%
df_catalogo.to_csv('Revista135.01.csv', index=False)
