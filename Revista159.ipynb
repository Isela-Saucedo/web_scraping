# %%
import requests
import bs4
from bs4 import BeautifulSoup
from urllib.parse import urljoin
import pandas as pd

# %%
url_inicial = 'https://revistabiociencias.uan.edu.mx/index.php/BIOCIENCIAS/issue/archive/2'
url_root = 'https://revistabiociencias.uan.edu.mx/index.php/BIOCIENCIAS/issue/archive/2'
r=requests.get(url_inicial)

# %%
soup = BeautifulSoup(r.text, 'html.parser')

# %%
box = soup.find('div', class_='container page-archives')
volumen=box.findAll('div', class_='card issue-summary')
vol = [x.find('a').get('href')for x in volumen]
vol=[urljoin(url_root,i) for i in vol]
vol
# Out:
# ['https://revistabiociencias.uan.edu.mx/index.php/BIOCIENCIAS/issue/view/Vol%203%2C%20No.%202%20Supl',
#  'https://revistabiociencias.uan.edu.mx/index.php/BIOCIENCIAS/issue/view/20',
#  'https://revistabiociencias.uan.edu.mx/index.php/BIOCIENCIAS/issue/view/19',
#  'https://revistabiociencias.uan.edu.mx/index.php/BIOCIENCIAS/issue/view/12',
#  'https://revistabiociencias.uan.edu.mx/index.php/BIOCIENCIAS/issue/view/14',
#  'https://revistabiociencias.uan.edu.mx/index.php/BIOCIENCIAS/issue/view/15',
#  'https://revistabiociencias.uan.edu.mx/index.php/BIOCIENCIAS/issue/view/10',
#  'https://revistabiociencias.uan.edu.mx/index.php/BIOCIENCIAS/issue/view/9',
#  'https://revistabiociencias.uan.edu.mx/index.php/BIOCIENCIAS/issue/view/8',
#  'https://revistabiociencias.uan.edu.mx/index.php/BIOCIENCIAS/issue/view/7',
#  'https://revistabiociencias.uan.edu.mx/index.php/BIOCIENCIAS/issue/view/6',
#  'https://revistabiociencias.uan.edu.mx/index.php/BIOCIENCIAS/issue/view/5',
# ...

# %%
vol2 =[]
for i in vol: 
    url_inicial1=i 
    r1 = requests.get(url_inicial1)
    soup1 = BeautifulSoup(r1.text, 'html.parser')
    box1 = soup1.find('div', class_='issue-toc') 
    volumen1=box1.findAll('div', class_='article-summary')
    vol1 = [x.find('a').get('href')for x in volumen1]
    vol2+=vol1

# %%
vol2
# Out:
# ['https://revistabiociencias.uan.edu.mx/index.php/BIOCIENCIAS/article/view/189',
#  'https://revistabiociencias.uan.edu.mx/index.php/BIOCIENCIAS/article/view/190',
#  'https://revistabiociencias.uan.edu.mx/index.php/BIOCIENCIAS/article/view/191',
#  'https://revistabiociencias.uan.edu.mx/index.php/BIOCIENCIAS/article/view/192',
#  'https://revistabiociencias.uan.edu.mx/index.php/BIOCIENCIAS/article/view/178',
#  'https://revistabiociencias.uan.edu.mx/index.php/BIOCIENCIAS/article/view/167',
#  'https://revistabiociencias.uan.edu.mx/index.php/BIOCIENCIAS/article/view/168',
#  'https://revistabiociencias.uan.edu.mx/index.php/BIOCIENCIAS/article/view/169',
#  'https://revistabiociencias.uan.edu.mx/index.php/BIOCIENCIAS/article/view/170',
#  'https://revistabiociencias.uan.edu.mx/index.php/BIOCIENCIAS/article/view/177',
#  'https://revistabiociencias.uan.edu.mx/index.php/BIOCIENCIAS/article/view/175',
#  'https://revistabiociencias.uan.edu.mx/index.php/BIOCIENCIAS/article/view/176',
# ...

# %%
def get_url_items(sopa,url):
    box1 = soup1.find('div', class_='issue-toc') 
    volumen1=box1.findAll('div', class_='article-summary')
    vol1 = [x.find('a').get('href')for x in volumen1]
    return vol2

# %%
links_items=[]
i=0
while i<1:
    i+=1
    print(f'Estoy en la pagina {url_inicial}')
    r_pag=requests.get(url_inicial)
    s_p=BeautifulSoup(r_pag.text,'html.parser')
    links=get_url_items(s_p, url_inicial)
    links_items.append(links)
# Out:
# Estoy en la pagina https://revistabiociencias.uan.edu.mx/index.php/BIOCIENCIAS/issue/archive/2

# %%
list_scraper=[]
for i in links_items:
    for j in i:
        list_scraper.append(j)
len(list_scraper)
# Out:
# 107

# %%
uno=list_scraper[0]
r_item=requests.get(uno)
s_item=BeautifulSoup(r_item.text, 'html.parser')

# %%
#funcion para iniciar el escraper de cada libro
def scraper_book(url):
    content_book={}
    r=requests.get(url)
    tire='Revista Bio Ciencias'
    a='VI. Biotecnología y Ciencias Agropecuarias'
    tem='Biología y Ciencias Agropecuarias'
    s_item=BeautifulSoup(r.text,'html.parser')
    #titulo de revista
    try:
        titulo=tire
        content_book['Titulo Revista']=tire
    except AttributeError:
        content_book['Titulo Revista']=None
    #area
    try:
        area=a
        content_book['Area']=a
    except AttributeError:
        content_book['Area']=None
    #tematica
    try:
        tema=tem
        content_book['Tematica']=tem
    except AttributeError:
        content_book['Tematica']=None
    #titulo articulo
    try:
        titu=s_item.find('h1', class_='article-details-fulltitle').get_text(strip=True)
        content_book['Titulo Articulo']=titu
    except AttributeError:
        content_book['Titulo Articulo']=None
    #resumen
    try:
        resu=s_item.find('div', class_='article-details-block article-details-abstract').get_text(strip=True)
        content_book['Resumen']=resu.replace("Resumen","")
    except AttributeError:
        content_book['Resumen']=None
    #abstract
    try:
        abst=s_item.find('div', id='item cover_image').get_text(strip=True)
        content_book['Abstract']=abst
    except AttributeError:
        content_book['Abstract']=None
    #Link incial
    try:
        linkart=url
        content_book['Link Articulo']=linkart
    except AttributeError:
        content_book['Link Articulo']=None
    #link articulo
    try:
        link=s_item.find('a', class_='btn btn-primary').get('href')
        content_book['Link PDF']=urljoin(url_root, link)
    except AttributeError:
        content_book['Link PDF']=None
    return content_book

# %%
list_scraper=list_scraper[0:107]
datos_book=[]
for idx, i in enumerate(list_scraper):
    print(f'estas escrapeando la pag {idx}')
    datos_book.append(scraper_book(i))
# Out:
# estas escrapeando la pag 0
# estas escrapeando la pag 1
# estas escrapeando la pag 2
# estas escrapeando la pag 3
# estas escrapeando la pag 4
# estas escrapeando la pag 5
# estas escrapeando la pag 6
# estas escrapeando la pag 7
# estas escrapeando la pag 8
# estas escrapeando la pag 9
# estas escrapeando la pag 10
# estas escrapeando la pag 11
# estas escrapeando la pag 12
# estas escrapeando la pag 13
# estas escrapeando la pag 14
# estas escrapeando la pag 15
# estas escrapeando la pag 16
# estas escrapeando la pag 17
# estas escrapeando la pag 18
# estas escrapeando la pag 19
# estas escrapeando la pag 20
# estas escrapeando la pag 21
# estas escrapeando la pag 22
# estas escrapeando la pag 23
# estas escrapeando la pag 24
# estas escrapeando la pag 25
# estas escrapeando la pag 26
# estas escrapeando la pag 27
# estas escrapeando la pag 28
# estas escrapeando la pag 29
# estas escrapeando la pag 30
# estas escrapeando la pag 31
# estas escrapeando la pag 32
# ...

# %%
df_catalogo=pd.DataFrame(datos_book)
df_catalogo
# Out:
#            Titulo Revista                                        Area  \
# 0    Revista Bio Ciencias  VI. Biotecnología y Ciencias Agropecuarias
# 1    Revista Bio Ciencias  VI. Biotecnología y Ciencias Agropecuarias
# 2    Revista Bio Ciencias  VI. Biotecnología y Ciencias Agropecuarias
# 3    Revista Bio Ciencias  VI. Biotecnología y Ciencias Agropecuarias
# 4    Revista Bio Ciencias  VI. Biotecnología y Ciencias Agropecuarias
# ..                    ...                                         ...
# 102  Revista Bio Ciencias  VI. Biotecnología y Ciencias Agropecuarias
# 103  Revista Bio Ciencias  VI. Biotecnología y Ciencias Agropecuarias
# 104  Revista Bio Ciencias  VI. Biotecnología y Ciencias Agropecuarias
# 105  Revista Bio Ciencias  VI. Biotecnología y Ciencias Agropecuarias
# 106  Revista Bio Ciencias  VI. Biotecnología y Ciencias Agropecuarias
#
#                               Tematica  \
# 0    Biología y Ciencias Agropecuarias
# 1    Biología y Ciencias Agropecuarias
# ...

# %%
df_catalogo.to_csv('Revista159.02.csv', index=False)
