# %%
import requests
import bs4
from bs4 import BeautifulSoup
from urllib.parse import urljoin
import pandas as pd

# %%
url_inicial = 'https://www.pueblosyfronteras.unam.mx/index.php/index.php/pyf/issue/archive'
url_root = 'https://www.pueblosyfronteras.unam.mx/index.php/index.php/pyf/issue/archive'
r=requests.get(url_inicial)

# %%
soup = BeautifulSoup(r.text, 'html.parser')

# %%
lista_articulo = soup.find_all('div', class_='media-body')
links_libros = [x.find('a').get('href') for x in lista_articulo]
links_libros = [urljoin (url_root, i) for i in links_libros]
links_libros
# Out:
# ['https://www.pueblosyfronteras.unam.mx/index.php/index.php/pyf/issue/view/31',
#  'https://www.pueblosyfronteras.unam.mx/index.php/index.php/pyf/issue/view/30',
#  'https://www.pueblosyfronteras.unam.mx/index.php/index.php/pyf/issue/view/29',
#  'https://www.pueblosyfronteras.unam.mx/index.php/index.php/pyf/issue/view/28',
#  'https://www.pueblosyfronteras.unam.mx/index.php/index.php/pyf/issue/view/27',
#  'https://www.pueblosyfronteras.unam.mx/index.php/index.php/pyf/issue/view/26',
#  'https://www.pueblosyfronteras.unam.mx/index.php/index.php/pyf/issue/view/25',
#  'https://www.pueblosyfronteras.unam.mx/index.php/index.php/pyf/issue/view/24',
#  'https://www.pueblosyfronteras.unam.mx/index.php/index.php/pyf/issue/view/23',
#  'https://www.pueblosyfronteras.unam.mx/index.php/index.php/pyf/issue/view/22',
#  'https://www.pueblosyfronteras.unam.mx/index.php/index.php/pyf/issue/view/21',
#  'https://www.pueblosyfronteras.unam.mx/index.php/index.php/pyf/issue/view/20',
# ...

# %%
def get_url_items(soup,url):
    lista_articulo = soup.find_all('div', class_='media-body')
    links_libros = [x.find('a').get('href') for x in lista_articulo]
    links_libros = [urljoin (url_root, i) for i in links_libros]
    return links_libros

# %%
links_items=[]
i=0
while i<1:
    i+=1
    print(f'Estoy en la pagina {url_inicial}')
    r_pag=requests.get(url_inicial)
    s_p=BeautifulSoup(r_pag.text,'html.parser')
    links=get_url_items(s_p, url_inicial)
    links_items.append(links)
# Out:
# Estoy en la pagina https://www.pueblosyfronteras.unam.mx/index.php/index.php/pyf/issue/archive

# %%
list_scraper=[]
for i in links_items:
    for j in i:
        list_scraper.append(j)
len(list_scraper)
# Out:
# 29

# %%
uno=list_scraper[0]
r_item=requests.get(uno)
s_item=BeautifulSoup(r_item.text, 'html.parser')

# %%
#funcion para iniciar el escraper de cada libro
def scraper_book(url):
    content_book={}
    r=requests.get(url)
    tire='Revista Pueblos y Fronteras Digital'
    a='V. Ciencias Sociales'
    tem='Ciencias Sociales'
    url='http://www.pueblosyfronteras.unam.mx/'
    s_item=BeautifulSoup(r.text,'html.parser')
    #titulo de revista
    try:
        titulo=tire
        content_book['Titulo de revista']=tire
    except AttributeError:
        content_book['Titulo de revista']=None
    #area
    try:
        area=a
        content_book['Área']=a
    except AttributeError:
        content_book['Área']=None
    #tematica
    try:
        tema=tem
        content_book['Temática']=tem
    except AttributeError:
        content_book['Temática']=None
    #titulo libro
    try:
        titu=s_item.find('h5', class_='media-heading ').get_text(strip=True)
        content_book['Titulo del libro']=titu
    except AttributeError:
        content_book['Titulo del libro']=None
    #resumen
    try:
        resu=s_item.find('div', class_='itemA1 small').get_text(strip=True)
        content_book['Resumen']=resu
    except AttributeError:
        content_book['Resumen']=None
    #Link incial
    try:
        inicial=url
        content_book['Link inicial']=url
    except AttributeError:
        content_book['Link inicial']=None
    #link articulo
    try:
        link=s_item.find('a', class_='h4').get('href')
        content_book['Link articulo']=urljoin(url_root, link)
    except AttributeError:
        content_book['Link articulo']=None
    return content_book

# %%
list_scraper=list_scraper[0:29]
datos_book=[]
for idx, i in enumerate(list_scraper):
    print(f'estas escrapeando la pag {idx}')
    datos_book.append(scraper_book(i))
# Out:
# estas escrapeando la pag 0
# estas escrapeando la pag 1
# estas escrapeando la pag 2
# estas escrapeando la pag 3
# estas escrapeando la pag 4
# estas escrapeando la pag 5
# estas escrapeando la pag 6
# estas escrapeando la pag 7
# estas escrapeando la pag 8
# estas escrapeando la pag 9
# estas escrapeando la pag 10
# estas escrapeando la pag 11
# estas escrapeando la pag 12
# estas escrapeando la pag 13
# estas escrapeando la pag 14
# estas escrapeando la pag 15
# estas escrapeando la pag 16
# estas escrapeando la pag 17
# estas escrapeando la pag 18
# estas escrapeando la pag 19
# estas escrapeando la pag 20
# estas escrapeando la pag 21
# estas escrapeando la pag 22
# estas escrapeando la pag 23
# estas escrapeando la pag 24
# estas escrapeando la pag 25
# estas escrapeando la pag 26
# estas escrapeando la pag 27
# estas escrapeando la pag 28

# %%
df_catalogo=pd.DataFrame(datos_book)
df_catalogo
# Out:
#                       Titulo de revista                  Área  \
# 0   Revista Pueblos y Fronteras Digital  V. Ciencias Sociales
# 1   Revista Pueblos y Fronteras Digital  V. Ciencias Sociales
# 2   Revista Pueblos y Fronteras Digital  V. Ciencias Sociales
# 3   Revista Pueblos y Fronteras Digital  V. Ciencias Sociales
# 4   Revista Pueblos y Fronteras Digital  V. Ciencias Sociales
# 5   Revista Pueblos y Fronteras Digital  V. Ciencias Sociales
# 6   Revista Pueblos y Fronteras Digital  V. Ciencias Sociales
# 7   Revista Pueblos y Fronteras Digital  V. Ciencias Sociales
# 8   Revista Pueblos y Fronteras Digital  V. Ciencias Sociales
# 9   Revista Pueblos y Fronteras Digital  V. Ciencias Sociales
# 10  Revista Pueblos y Fronteras Digital  V. Ciencias Sociales
# 11  Revista Pueblos y Fronteras Digital  V. Ciencias Sociales
# 12  Revista Pueblos y Fronteras Digital  V. Ciencias Sociales
# 13  Revista Pueblos y Fronteras Digital  V. Ciencias Sociales
# ...

# %%
df_catalogo.to_csv('Revista133.csv', index=False)
