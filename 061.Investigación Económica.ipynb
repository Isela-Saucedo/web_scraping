# %%
import requests
import bs4
from bs4 import BeautifulSoup
from urllib.parse import urljoin
import pandas as pd

# %%
url_inicial = 'http://www.revistas.unam.mx/index.php/rie/issue/archive'
url_root = 'http://www.revistas.unam.mx/index.php/rie/issue/archive'
r=requests.get(url_inicial)

# %%
soup = BeautifulSoup(r.text, 'html.parser')

# %%
box = soup.find('div', id='content')
volumen=box.findAll('h4')
vol = [x.find('a').get('href')for x in volumen]
vol=[urljoin(url_root,i) for i in vol]
vol
# Out:
# ['http://www.revistas.unam.mx/index.php/rie/issue/view/5984',
#  'http://www.revistas.unam.mx/index.php/rie/issue/view/5983',
#  'http://www.revistas.unam.mx/index.php/rie/issue/view/5832',
#  'http://www.revistas.unam.mx/index.php/rie/issue/view/5831',
#  'http://www.revistas.unam.mx/index.php/rie/issue/view/5830',
#  'http://www.revistas.unam.mx/index.php/rie/issue/view/5829',
#  'http://www.revistas.unam.mx/index.php/rie/issue/view/5358',
#  'http://www.revistas.unam.mx/index.php/rie/issue/view/5357',
#  'http://www.revistas.unam.mx/index.php/rie/issue/view/5356',
#  'http://www.revistas.unam.mx/index.php/rie/issue/view/5355',
#  'http://www.revistas.unam.mx/index.php/rie/issue/view/5128',
#  'http://www.revistas.unam.mx/index.php/rie/issue/view/5127',
#  'http://www.revistas.unam.mx/index.php/rie/issue/view/5126',
#  'http://www.revistas.unam.mx/index.php/rie/issue/view/5125',
#  'http://www.revistas.unam.mx/index.php/rie/issue/view/4897',
#  'http://www.revistas.unam.mx/index.php/rie/issue/view/5092',
#  'http://www.revistas.unam.mx/index.php/rie/issue/view/4895',
#  'http://www.revistas.unam.mx/index.php/rie/issue/view/4894',
#  'http://www.revistas.unam.mx/index.php/rie/issue/view/4837',
#  'http://www.revistas.unam.mx/index.php/rie/issue/view/4750',
#  'http://www.revistas.unam.mx/index.php/rie/issue/view/4630',
#  'http://www.revistas.unam.mx/index.php/rie/issue/view/4529',
#  'http://www.revistas.unam.mx/index.php/rie/issue/view/4458',
#  'http://www.revistas.unam.mx/index.php/rie/issue/view/4397',
#  'http://www.revistas.unam.mx/index.php/rie/issue/view/4369',
#  'http://www.revistas.unam.mx/index.php/rie/issue/view/4275',
#  'http://www.revistas.unam.mx/index.php/rie/issue/view/4149',
#  'http://www.revistas.unam.mx/index.php/rie/issue/view/4110',
#  'http://www.revistas.unam.mx/index.php/rie/issue/view/4075',
#  'http://www.revistas.unam.mx/index.php/rie/issue/view/3997',
#  'http://www.revistas.unam.mx/index.php/rie/issue/view/3885',
#  'http://www.revistas.unam.mx/index.php/rie/issue/view/3886',
#  'http://www.revistas.unam.mx/index.php/rie/issue/view/3881',
#  'http://www.revistas.unam.mx/index.php/rie/issue/view/3891',
#  'http://www.revistas.unam.mx/index.php/rie/issue/view/3880',
#  'http://www.revistas.unam.mx/index.php/rie/issue/view/3890',
#  'http://www.revistas.unam.mx/index.php/rie/issue/view/3879',
#  'http://www.revistas.unam.mx/index.php/rie/issue/view/3889',
#  'http://www.revistas.unam.mx/index.php/rie/issue/view/3590',
#  'http://www.revistas.unam.mx/index.php/rie/issue/view/3888',
#  'http://www.revistas.unam.mx/index.php/rie/issue/view/3442',
#  'http://www.revistas.unam.mx/index.php/rie/issue/view/3887',
#  'http://www.revistas.unam.mx/index.php/rie/issue/view/3246',
#  'http://www.revistas.unam.mx/index.php/rie/issue/view/3247',
#  'http://www.revistas.unam.mx/index.php/rie/issue/view/2992',
#  'http://www.revistas.unam.mx/index.php/rie/issue/view/2991',
#  'http://www.revistas.unam.mx/index.php/rie/issue/view/2990',
#  'http://www.revistas.unam.mx/index.php/rie/issue/view/2989',
#  'http://www.revistas.unam.mx/index.php/rie/issue/view/2987',
#  'http://www.revistas.unam.mx/index.php/rie/issue/view/2986',
#  'http://www.revistas.unam.mx/index.php/rie/issue/view/2985',
#  'http://www.revistas.unam.mx/index.php/rie/issue/view/2045',
#  'http://www.revistas.unam.mx/index.php/rie/issue/view/2044',
#  'http://www.revistas.unam.mx/index.php/rie/issue/view/2041',
#  'http://www.revistas.unam.mx/index.php/rie/issue/view/2040',
#  'http://www.revistas.unam.mx/index.php/rie/issue/view/1359',
#  'http://www.revistas.unam.mx/index.php/rie/issue/view/1354',
#  'http://www.revistas.unam.mx/index.php/rie/issue/view/1353',
#  'http://www.revistas.unam.mx/index.php/rie/issue/view/1350',
#  'http://www.revistas.unam.mx/index.php/rie/issue/view/2995',
#  'http://www.revistas.unam.mx/index.php/rie/issue/view/2994']

# %%
def get_url_items(sopa, url): 
    box = soup.find('div', id='content')
    volumen=box.findAll('h4')
    vol = [x.find('a').get('href')for x in volumen]
    vol=[urljoin(url_root,i) for i in vol]
    return vol

# %%
links_items=[]
i=0
while i<1:
    i+=1
    print(f'Estoy en la pagina {url_inicial}')
    r_pag=requests.get(url_inicial)
    s_p=BeautifulSoup(r_pag.text,'html.parser')
    links=get_url_items(s_p, url_inicial)
    links_items.append(links)
# Out:
# Estoy en la pagina http://www.revistas.unam.mx/index.php/rie/issue/archive

# %%
list_scraper=[]
for i in links_items:
    for j in i:
        list_scraper.append(j)
len(list_scraper)
# Out:
# 61

# %%
uno=list_scraper[0]
r_item=requests.get(uno)
s_item=BeautifulSoup(r_item.text, 'html.parser')

# %%
#funcion para iniciar el escraper de cada libro
def scraper_book(url):
    content_book={}
    r=requests.get(url)
    tire='Investigación Económica'
    a='V. Ciencias Sociales'
    tem='Teorías Económicas y su aplicación'
    url='http://www.revistas.unam.mx/index.php/rie'
    s_item=BeautifulSoup(r.text,'html.parser')
    #titulo de revista
    try:
        titulo=tire
        content_book['Titulo de revista']=tire
    except AttributeError:
        content_book['Titulo de revista']=None
    #area
    try:
        area=a
        content_book['Área']=a
    except AttributeError:
        content_book['Área']=None
    #tematica
    try:
        tema=tem
        content_book['Temática']=tem
    except AttributeError:
        content_book['Temática']=None
    #titulo libro
    try:
        titu=s_item.find('div', class_='tocTitle').get_text(strip=True)
        content_book['Titulo del libro']=titu
    except AttributeError:
        content_book['Titulo del libro']=None
    #resumen
    try:
        resu=s_item.find('a', class_='cover').get_text(strip=True)
        content_book['Resumen']=resu
    except AttributeError:
        content_book['Resumen']=None
    #Link incial
    try:
        inicial=url
        content_book['Link inicial']=url
    except AttributeError:
        content_book['Link inicial']=None
    #link articulo
    try:
        link=s_item.find('a', class_='file').get('href')
        content_book['Link articulo']=urljoin(url_root, link)
    except AttributeError:
        content_book['Link articulo']=None
    return content_book

# %%
list_scraper=list_scraper[0:61]
datos_book=[]
for idx, i in enumerate(list_scraper):
    print(f'estas escrapeando la pag {idx}')
    datos_book.append(scraper_book(i))
# Out:
# estas escrapeando la pag 0
# estas escrapeando la pag 1
# estas escrapeando la pag 2
# estas escrapeando la pag 3
# estas escrapeando la pag 4
# estas escrapeando la pag 5
# estas escrapeando la pag 6
# estas escrapeando la pag 7
# estas escrapeando la pag 8
# estas escrapeando la pag 9
# estas escrapeando la pag 10
# estas escrapeando la pag 11
# estas escrapeando la pag 12
# estas escrapeando la pag 13
# estas escrapeando la pag 14
# estas escrapeando la pag 15
# estas escrapeando la pag 16
# estas escrapeando la pag 17
# estas escrapeando la pag 18
# estas escrapeando la pag 19
# estas escrapeando la pag 20
# estas escrapeando la pag 21
# estas escrapeando la pag 22
# estas escrapeando la pag 23
# estas escrapeando la pag 24
# estas escrapeando la pag 25
# estas escrapeando la pag 26
# estas escrapeando la pag 27
# estas escrapeando la pag 28
# estas escrapeando la pag 29
# estas escrapeando la pag 30
# estas escrapeando la pag 31
# estas escrapeando la pag 32
# estas escrapeando la pag 33
# estas escrapeando la pag 34
# estas escrapeando la pag 35
# estas escrapeando la pag 36
# estas escrapeando la pag 37
# estas escrapeando la pag 38
# estas escrapeando la pag 39
# estas escrapeando la pag 40
# estas escrapeando la pag 41
# estas escrapeando la pag 42
# estas escrapeando la pag 43
# estas escrapeando la pag 44
# estas escrapeando la pag 45
# estas escrapeando la pag 46
# estas escrapeando la pag 47
# estas escrapeando la pag 48
# estas escrapeando la pag 49
# estas escrapeando la pag 50
# estas escrapeando la pag 51
# estas escrapeando la pag 52
# estas escrapeando la pag 53
# estas escrapeando la pag 54
# estas escrapeando la pag 55
# estas escrapeando la pag 56
# estas escrapeando la pag 57
# estas escrapeando la pag 58
# estas escrapeando la pag 59
# estas escrapeando la pag 60

# %%
df_catalogo=pd.DataFrame(datos_book)
df_catalogo
# Out:
#           Titulo de revista                  Área  \
# 0   Investigación Económica  V. Ciencias Sociales
# 1   Investigación Económica  V. Ciencias Sociales
# 2   Investigación Económica  V. Ciencias Sociales
# 3   Investigación Económica  V. Ciencias Sociales
# 4   Investigación Económica  V. Ciencias Sociales
# ..                      ...                   ...
# 56  Investigación Económica  V. Ciencias Sociales
# 57  Investigación Económica  V. Ciencias Sociales
# 58  Investigación Económica  V. Ciencias Sociales
# 59  Investigación Económica  V. Ciencias Sociales
# 60  Investigación Económica  V. Ciencias Sociales
#
#                               Temática  \
# 0   Teorías Económicas y su aplicación
# 1   Teorías Económicas y su aplicación
# 2   Teorías Económicas y su aplicación
# 3   Teorías Económicas y su aplicación
# 4   Teorías Económicas y su aplicación
# ..                                 ...
# 56  Teorías Económicas y su aplicación
# 57  Teorías Económicas y su aplicación
# 58  Teorías Económicas y su aplicación
# 59  Teorías Económicas y su aplicación
# 60  Teorías Económicas y su aplicación
#
#                                      Titulo del libro Resumen  \
# 0   A BRIEF NOTE ON PALLEY’S CRITICISM OF NEW DEVE...    None
# 1   CAPITAL THEORY DEBATES: NEW DEVELOPMENTS AND D...    None
# 2   EXOGENOUS INTEREST RATE AND EXCHANGE RATE DYNA...    None
# 3   THE ECONOMICS OF NEW DEVELOPMENTALISM: A CRITI...    None
# 4                           EDITORIAL: 80 ANIVERSARIO    None
# ..                                                ...     ...
# 56                            Introducción del Editor    None
# 57  The backward bending Phillips curves: competin...    None
# 58          La tasa de inflación en México, 2000-2007    None
# 59  A MODIFIED KALDORIAN MODEL OF CUMULATIVE CAUSA...    None
# 60  EFECTOS DE LA LIBERACIÓN COMERCIAL EN EL CRECI...    None
#
#                                  Link inicial  \
# 0   http://www.revistas.unam.mx/index.php/rie
# 1   http://www.revistas.unam.mx/index.php/rie
# 2   http://www.revistas.unam.mx/index.php/rie
# 3   http://www.revistas.unam.mx/index.php/rie
# 4   http://www.revistas.unam.mx/index.php/rie
# ..                                        ...
# 56  http://www.revistas.unam.mx/index.php/rie
# 57  http://www.revistas.unam.mx/index.php/rie
# 58  http://www.revistas.unam.mx/index.php/rie
# 59  http://www.revistas.unam.mx/index.php/rie
# 60  http://www.revistas.unam.mx/index.php/rie
#
#                                         Link articulo
# 0   http://www.revistas.unam.mx/index.php/rie/arti...
# 1   http://www.revistas.unam.mx/index.php/rie/arti...
# 2   http://www.revistas.unam.mx/index.php/rie/arti...
# 3   http://www.revistas.unam.mx/index.php/rie/arti...
# 4   http://www.revistas.unam.mx/index.php/rie/arti...
# ..                                                ...
# 56  http://www.revistas.unam.mx/index.php/rie/arti...
# 57  http://www.revistas.unam.mx/index.php/rie/arti...
# 58  http://www.revistas.unam.mx/index.php/rie/arti...
# 59  http://www.revistas.unam.mx/index.php/rie/arti...
# 60  http://www.revistas.unam.mx/index.php/rie/arti...
#
# [61 rows x 7 columns]

# %%
df_catalogo.to_csv('Revista61.csv', index=False)
