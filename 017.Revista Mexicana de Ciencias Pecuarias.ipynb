# %%
import requests
import bs4
from bs4 import BeautifulSoup
from urllib.parse import urljoin
import pandas as pd

# %%
url_inicial = 'https://cienciaspecuarias.inifap.gob.mx/index.php/Pecuarias/issue/view/542'
url_root = 'https://cienciaspecuarias.inifap.gob.mx/index.php/Pecuarias/issue/view/542'
r=requests.get(url_inicial)

# %%
soup = BeautifulSoup(r.text, 'html.parser')

# %%
lista_articulo = soup.find_all('table', class_='tocArticle')
links_libros = [x.find('a').get('href') for x in lista_articulo]
links_libros = [urljoin (url_root, i) for i in links_libros]
links_libros
# Out:
# ['https://cienciaspecuarias.inifap.gob.mx/index.php/Pecuarias/article/view/4814',
#  'https://cienciaspecuarias.inifap.gob.mx/index.php/Pecuarias/article/view/4740',
#  'https://cienciaspecuarias.inifap.gob.mx/index.php/Pecuarias/article/view/4913',
#  'https://cienciaspecuarias.inifap.gob.mx/index.php/Pecuarias/article/view/4565',
#  'https://cienciaspecuarias.inifap.gob.mx/index.php/Pecuarias/article/view/5226',
#  'https://cienciaspecuarias.inifap.gob.mx/index.php/Pecuarias/article/view/5083',
#  'https://cienciaspecuarias.inifap.gob.mx/index.php/Pecuarias/article/view/4757',
#  'https://cienciaspecuarias.inifap.gob.mx/index.php/Pecuarias/article/view/5018',
#  'https://cienciaspecuarias.inifap.gob.mx/index.php/Pecuarias/article/view/4981',
#  'https://cienciaspecuarias.inifap.gob.mx/index.php/Pecuarias/article/view/4882',
#  'https://cienciaspecuarias.inifap.gob.mx/index.php/Pecuarias/article/view/4998',
# ...

# %%
def get_url_items(sopa,url):
    lista_articulo = soup.find_all('table', class_='tocArticle')
    links_libros = [x.find('a').get('href') for x in lista_articulo]
    links_libros = [urljoin (url_root, i) for i in links_libros]
    return links_libros

# %%
links_items=[]
i = 0
while i<1:
    i+=1
    print(f'Estoy en la pagina {url_inicial}')
    r_pag = requests.get(url_inicial)
    s_p = BeautifulSoup(r_pag.text, 'html.parser')
    links = get_url_items(s_p, url_inicial)
    links_items.append(links)
    #next_a = s_p.select('nav.View additional pages > a')
    #if not next_a or not next_a[0].get('href'):
      #  break
       # url_inicial = urljoin(url_inicial, next_a[0].get('href'))
# Out:
# Estoy en la pagina https://cienciaspecuarias.inifap.gob.mx/index.php/Pecuarias/issue/view/542

# %%
list_scraper=[]
for i in links_items:
    for j in i:
        list_scraper.append(j)
len(list_scraper)
# Out:
# 21

# %%
uno=list_scraper[0]
r_item=requests.get(uno)
s_item=BeautifulSoup(r_item.text, 'html.parser')

# %%
#funcion para iniciar el escraper de cada libro
def scraper_book(url):
    content_book={}
    r=requests.get(url)
    tire='Revista Mexicana de Ciencias Pecuarias'
    a='VI. Biotecnología y Ciencias Agropecuarias'
    tem='Inmunología, Microbiología, Epidemiología, Parasitología, Reproducción, Genética, Nutrición, Apicultura, Socioeconomía, Forrajes y Pastizales, Inocuidad.'
    url='http://cienciaspecuarias.inifap.gob.mx'
    s_item=BeautifulSoup(r.text,'html.parser')
    #titulo de revista
    try:
        titulo=tire
        content_book['Titulo de revista']=tire
    except AttributeError:
        content_book['Titulo de revista']=None
    #area
    try:
        area=a
        content_book['Área']=a
    except AttributeError:
        content_book['Área']=None
    #tematica
    try:
        tema=tem
        content_book['Temática']=tem
    except AttributeError:
        content_book['Temática']=None
    #titulo libro
    try:
        titu=s_item.find('div', id='articleTitle').get_text(strip=True)
        content_book['Titulo del libro']=titu
    except AttributeError:
        content_book['Titulo del libro']=None
    #abstract
    try:
        abst=s_item.find('p').get_text(strip=True)
        content_book['Abstract']=abst
    except AttributeError:
        content_book['Abstract']=None
    #resumen
    try:
        resu=s_item.find('div', id='articleAbstract').get_text(strip=True)
        content_book['Resumen']=resu
    except AttributeError:
        content_book['Resumen']=None
    #Link incial
    try:
        inicial=url
        content_book['Link inicial']=url
    except AttributeError:
        content_book['Link inicial']=None
    #link articulo
    try:
        link=s_item.find('a', class_='file').get('href')
        content_book['Link articulo']=urljoin(url_root, link)
    except AttributeError:
        content_book['Link articulo']=None
    return content_book

# %%
list_scraper=list_scraper[0:30]
datos_book=[]
for idx, i in enumerate(list_scraper):
    print(f'estas escrapeando la pag {idx}')
    datos_book.append(scraper_book(i))
# Out:
# estas escrapeando la pag 0
# estas escrapeando la pag 1
# estas escrapeando la pag 2
# estas escrapeando la pag 3
# estas escrapeando la pag 4
# estas escrapeando la pag 5
# estas escrapeando la pag 6
# estas escrapeando la pag 7
# estas escrapeando la pag 8
# estas escrapeando la pag 9
# estas escrapeando la pag 10
# estas escrapeando la pag 11
# estas escrapeando la pag 12
# estas escrapeando la pag 13
# estas escrapeando la pag 14
# estas escrapeando la pag 15
# estas escrapeando la pag 16
# estas escrapeando la pag 17
# estas escrapeando la pag 18
# estas escrapeando la pag 19
# estas escrapeando la pag 20

# %%
df_catalogo=pd.DataFrame(datos_book)
df_catalogo
# Out:
#                          Titulo de revista  \
# 0   Revista Mexicana de Ciencias Pecuarias
# 1   Revista Mexicana de Ciencias Pecuarias
# 2   Revista Mexicana de Ciencias Pecuarias
# 3   Revista Mexicana de Ciencias Pecuarias
# 4   Revista Mexicana de Ciencias Pecuarias
# 5   Revista Mexicana de Ciencias Pecuarias
# 6   Revista Mexicana de Ciencias Pecuarias
# 7   Revista Mexicana de Ciencias Pecuarias
# 8   Revista Mexicana de Ciencias Pecuarias
# 9   Revista Mexicana de Ciencias Pecuarias
# 10  Revista Mexicana de Ciencias Pecuarias
#
#                                           Área  \
# 0   VI. Biotecnología y Ciencias Agropecuarias
# 1   VI. Biotecnología y Ciencias Agropecuarias
# 2   VI. Biotecnología y Ciencias Agropecuarias
# 3   VI. Biotecnología y Ciencias Agropecuarias
# 4   VI. Biotecnología y Ciencias Agropecuarias
# 5   VI. Biotecnología y Ciencias Agropecuarias
# 6   VI. Biotecnología y Ciencias Agropecuarias
# 7   VI. Biotecnología y Ciencias Agropecuarias
# ...

# %%
df_catalogo.to_csv('Revista17.013.csv', index=False)
