# %%
import requests
import bs4
from bs4 import BeautifulSoup
from urllib.parse import urljoin
import pandas as pd

# %%
url_inicial = 'http://riem.facmed.unam.mx/index.php/riem/issue/archive'
url_root = 'http://riem.facmed.unam.mx/index.php/riem/issue/archive'
r=requests.get(url_inicial)

# %%
soup = BeautifulSoup(r.text, 'html.parser')

# %%
box = soup.find('ul', class_='issues_archive')
volumen=box.findAll('div', class_='obj_issue_summary')
vol = [x.find('a').get('href')for x in volumen]
vol=[urljoin(url_root,i) for i in vol]
vol
# Out:
# ['http://riem.facmed.unam.mx/index.php/riem/issue/view/48',
#  'http://riem.facmed.unam.mx/index.php/riem/issue/view/47',
#  'http://riem.facmed.unam.mx/index.php/riem/issue/view/46',
#  'http://riem.facmed.unam.mx/index.php/riem/issue/view/45',
#  'http://riem.facmed.unam.mx/index.php/riem/issue/view/44',
#  'http://riem.facmed.unam.mx/index.php/riem/issue/view/43',
#  'http://riem.facmed.unam.mx/index.php/riem/issue/view/40',
#  'http://riem.facmed.unam.mx/index.php/riem/issue/view/39',
#  'http://riem.facmed.unam.mx/index.php/riem/issue/view/38',
#  'http://riem.facmed.unam.mx/index.php/riem/issue/view/37',
#  'http://riem.facmed.unam.mx/index.php/riem/issue/view/36',
#  'http://riem.facmed.unam.mx/index.php/riem/issue/view/35',
#  'http://riem.facmed.unam.mx/index.php/riem/issue/view/19',
#  'http://riem.facmed.unam.mx/index.php/riem/issue/view/4',
#  'http://riem.facmed.unam.mx/index.php/riem/issue/view/2',
#  'http://riem.facmed.unam.mx/index.php/riem/issue/view/3',
# ...

# %%
vol2 =[]
for i in vol: 
    url_inicial1=i 
    r1 = requests.get(url_inicial1)
    soup1 = BeautifulSoup(r1.text, 'html.parser')
    box1 = soup1.find('div', class_='sections') 
    volumen1=box1.findAll('div', class_='obj_article_summary')
    vol1 = [x.find('a').get('href')for x in volumen1]
    vol2+=vol1

# %%
vol2
# Out:
# ['http://riem.facmed.unam.mx/index.php/riem/article/view/901',
#  'http://riem.facmed.unam.mx/index.php/riem/article/view/865',
#  'http://riem.facmed.unam.mx/index.php/riem/article/view/866',
#  'http://riem.facmed.unam.mx/index.php/riem/article/view/867',
#  'http://riem.facmed.unam.mx/index.php/riem/article/view/868',
#  'http://riem.facmed.unam.mx/index.php/riem/article/view/871',
#  'http://riem.facmed.unam.mx/index.php/riem/article/view/872',
#  'http://riem.facmed.unam.mx/index.php/riem/article/view/873',
#  'http://riem.facmed.unam.mx/index.php/riem/article/view/874',
#  'http://riem.facmed.unam.mx/index.php/riem/article/view/875',
#  'http://riem.facmed.unam.mx/index.php/riem/article/view/894',
#  'http://riem.facmed.unam.mx/index.php/riem/article/view/895',
#  'http://riem.facmed.unam.mx/index.php/riem/article/view/896',
#  'http://riem.facmed.unam.mx/index.php/riem/article/view/897',
#  'http://riem.facmed.unam.mx/index.php/riem/article/view/903',
# ...

# %%
def get_url_items(sopa,url):
    box1 = soup1.find('div', class_='sections') 
    volumen1=box1.findAll('div', class_='obj_article_summary')
    vol1 = [x.find('a').get('href')for x in volumen1]
    return vol2

# %%
links_items=[]
i=0
while i<1:
    i+=1
    print(f'Estoy en la pagina {url_inicial}')
    r_pag=requests.get(url_inicial)
    s_p=BeautifulSoup(r_pag.text,'html.parser')
    links=get_url_items(s_p, url_inicial)
    links_items.append(links)
# Out:
# Estoy en la pagina http://riem.facmed.unam.mx/index.php/riem/issue/archive

# %%
list_scraper=[]
for i in links_items:
    for j in i:
        list_scraper.append(j)
len(list_scraper)
# Out:
# 432

# %%
uno=list_scraper[0]
r_item=requests.get(uno)
s_item=BeautifulSoup(r_item.text, 'html.parser')

# %%
#funcion para iniciar el escraper de cada libro
def scraper_book(url):
    content_book={}
    r=requests.get(url)
    tire='Investigación en Educación Médica'
    a='III. Medicina y Ciencias de la Salud'
    tem='Educación Médica'
    s_item=BeautifulSoup(r.text,'html.parser')
    #titulo de revista
    try:
        titulo=tire
        content_book['Titulo Revista']=tire
    except AttributeError:
        content_book['Titulo Revista']=None
    #area
    try:
        area=a
        content_book['Area']=a
    except AttributeError:
        content_book['Area']=None
    #tematica
    try:
        tema=tem
        content_book['Tematica']=tem
    except AttributeError:
        content_book['Tematica']=None
    #titulo articulo
    try:
        titu=s_item.find('h1', class_='page_title').get_text(strip=True)
        content_book['Titulo Articulo']=titu
    except AttributeError:
        content_book['Titulo Articulo']=None
    #resumen
    try:
        resu=s_item.find('div', class_='item abstract').get_text(strip=True)
        content_book['Resumen']=resu.replace("Resumen","")
    except AttributeError:
        content_book['Resumen']=None
    #abstract
    try:
        abst=s_item.find('div', id='item cover_image').get_text(strip=True)
        content_book['Abstract']=abst
    except AttributeError:
        content_book['Abstract']=None
    #Link incial
    try:
        linkart=url
        content_book['Link Articulo']=linkart
    except AttributeError:
        content_book['Link Articulo']=None
    #link articulo
    try:
        link=s_item.find('a', class_='obj_galley_link pdf').get('href')
        content_book['Link PDF']=urljoin(url_root, link)
    except AttributeError:
        content_book['Link PDF']=None
    return content_book

# %%
list_scraper=list_scraper[0:432]
datos_book=[]
for idx, i in enumerate(list_scraper):
    print(f'estas escrapeando la pag {idx}')
    datos_book.append(scraper_book(i))
# Out:
# estas escrapeando la pag 0
# estas escrapeando la pag 1
# estas escrapeando la pag 2
# estas escrapeando la pag 3
# estas escrapeando la pag 4
# estas escrapeando la pag 5
# estas escrapeando la pag 6
# estas escrapeando la pag 7
# estas escrapeando la pag 8
# estas escrapeando la pag 9
# estas escrapeando la pag 10
# estas escrapeando la pag 11
# estas escrapeando la pag 12
# estas escrapeando la pag 13
# estas escrapeando la pag 14
# estas escrapeando la pag 15
# estas escrapeando la pag 16
# estas escrapeando la pag 17
# estas escrapeando la pag 18
# estas escrapeando la pag 19
# estas escrapeando la pag 20
# estas escrapeando la pag 21
# estas escrapeando la pag 22
# estas escrapeando la pag 23
# estas escrapeando la pag 24
# estas escrapeando la pag 25
# estas escrapeando la pag 26
# estas escrapeando la pag 27
# estas escrapeando la pag 28
# estas escrapeando la pag 29
# estas escrapeando la pag 30
# estas escrapeando la pag 31
# estas escrapeando la pag 32
# ...

# %%
df_catalogo=pd.DataFrame(datos_book)
df_catalogo
# Out:
#                         Titulo Revista                                  Area  \
# 0    Investigación en Educación Médica  III. Medicina y Ciencias de la Salud
# 1    Investigación en Educación Médica  III. Medicina y Ciencias de la Salud
# 2    Investigación en Educación Médica  III. Medicina y Ciencias de la Salud
# 3    Investigación en Educación Médica  III. Medicina y Ciencias de la Salud
# 4    Investigación en Educación Médica  III. Medicina y Ciencias de la Salud
# ..                                 ...                                   ...
# 427  Investigación en Educación Médica  III. Medicina y Ciencias de la Salud
# 428  Investigación en Educación Médica  III. Medicina y Ciencias de la Salud
# 429  Investigación en Educación Médica  III. Medicina y Ciencias de la Salud
# 430  Investigación en Educación Médica  III. Medicina y Ciencias de la Salud
# 431  Investigación en Educación Médica  III. Medicina y Ciencias de la Salud
#
# ...

# %%
df_catalogo.to_csv('Revista155.01.csv', index=False)
