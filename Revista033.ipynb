# %%
import requests
import bs4
from bs4 import BeautifulSoup
from urllib.parse import urljoin
import pandas as pd

# %%
url_inicial = 'https://estudiosdemograficosyurbanos.colmex.mx/index.php/edu/issue/archive'
url_root = 'https://estudiosdemograficosyurbanos.colmex.mx/index.php/edu/issue/archive'
r=requests.get(url_inicial)

# %%
soup = BeautifulSoup(r.text, 'html.parser')

# %%
box = soup.find('ul', class_='issues_archive')
volumen=box.findAll('div', class_='obj_issue_summary')
vol = [x.find('a').get('href')for x in volumen]
vol
# Out:
# ['https://estudiosdemograficosyurbanos.colmex.mx/index.php/edu/issue/view/173',
#  'https://estudiosdemograficosyurbanos.colmex.mx/index.php/edu/issue/view/172',
#  'https://estudiosdemograficosyurbanos.colmex.mx/index.php/edu/issue/view/171',
#  'https://estudiosdemograficosyurbanos.colmex.mx/index.php/edu/issue/view/170',
#  'https://estudiosdemograficosyurbanos.colmex.mx/index.php/edu/issue/view/169',
#  'https://estudiosdemograficosyurbanos.colmex.mx/index.php/edu/issue/view/168',
#  'https://estudiosdemograficosyurbanos.colmex.mx/index.php/edu/issue/view/167',
#  'https://estudiosdemograficosyurbanos.colmex.mx/index.php/edu/issue/view/166',
#  'https://estudiosdemograficosyurbanos.colmex.mx/index.php/edu/issue/view/164',
#  'https://estudiosdemograficosyurbanos.colmex.mx/index.php/edu/issue/view/163',
#  'https://estudiosdemograficosyurbanos.colmex.mx/index.php/edu/issue/view/161',
#  'https://estudiosdemograficosyurbanos.colmex.mx/index.php/edu/issue/view/160',
# ...

# %%
vol2 =[]
for i in vol: 
    url_inicial1=i 
    r1 = requests.get(url_inicial1)
    soup1 = BeautifulSoup(r1.text, 'html.parser')
    box1 = soup1.find('ul', class_='cmp_article_list articles') 
    volumen1=box1.findAll('div', class_='obj_article_summary')
    vol1 = [x.find('a').get('href')for x in volumen1]
    vol2+=vol1

# %%
vol2
# Out:
# ['https://estudiosdemograficosyurbanos.colmex.mx/index.php/edu/article/view/2057',
#  'https://estudiosdemograficosyurbanos.colmex.mx/index.php/edu/article/view/2053',
#  'https://estudiosdemograficosyurbanos.colmex.mx/index.php/edu/article/view/2049',
#  'https://estudiosdemograficosyurbanos.colmex.mx/index.php/edu/article/view/2015',
#  'https://estudiosdemograficosyurbanos.colmex.mx/index.php/edu/article/view/2083',
#  'https://estudiosdemograficosyurbanos.colmex.mx/index.php/edu/article/view/2052',
#  'https://estudiosdemograficosyurbanos.colmex.mx/index.php/edu/article/view/2028',
#  'https://estudiosdemograficosyurbanos.colmex.mx/index.php/edu/article/view/2029',
#  'https://estudiosdemograficosyurbanos.colmex.mx/index.php/edu/article/view/2018',
#  'https://estudiosdemograficosyurbanos.colmex.mx/index.php/edu/article/view/1924',
#  'https://estudiosdemograficosyurbanos.colmex.mx/index.php/edu/article/view/1966',
# ...

# %%
def get_url_items(sopa,url):
    box1 = soup1.find('ul', class_='cmp_article_list articles') 
    volumen1=box1.findAll('div', class_='obj_article_summary')
    vol1 = [x.find('a').get('href')for x in volumen1]
    return vol2

# %%
links_items=[]
i=0
while i<1:
    i+=1
    print(f'Estoy en la pagina {url_inicial}')
    r_pag=requests.get(url_inicial)
    s_p=BeautifulSoup(r_pag.text,'html.parser')
    links=get_url_items(s_p, url_inicial)
    links_items.append(links) 
    next_a=s_p.select('li.next > a')
    if not next_a or not next_a[0].get('href'):
        break
# Out:
# Estoy en la pagina https://estudiosdemograficosyurbanos.colmex.mx/index.php/edu/issue/archive

# %%
list_scraper=[]
for i in links_items:
    for j in i:
        list_scraper.append(j)
len(list_scraper)
# Out:
# 798

# %%
uno=list_scraper[0]
r_item=requests.get(uno)
s_item=BeautifulSoup(r_item.text, 'html.parser')

# %%
#funcion para iniciar el escraper de cada libro
def scraper_book(url):
    content_book={}
    r=requests.get(url)
    tire='Estudios Demográficos y Urbanos'
    a='V. Ciencias Sociales'
    tem='Demografía; Estudios Urbanos; Estudios Ambientales'
    s_item=BeautifulSoup(r.text,'html.parser')
 #titulo de revista
    try:
        titulo=tire
        content_book['Titulo Revista']=tire
    except AttributeError:
        content_book['Titulo Revista']=None
    #area
    try:
        area=a
        content_book['Area']=a
    except AttributeError:
        content_book['Area']=None
    #tematica
    try:
        tema=tem
        content_book['Tematica']=tem
    except AttributeError:
        content_book['Tematica']=None
    #titulo articulo
    try:
        titu=s_item.find('h1', class_='page_title').get_text(strip=True)
        content_book['Titulo Articulo']=titu
    except AttributeError:
        content_book['Titulo Articulo']=None
    #resumen
    try:
        resu=s_item.find('section', class_='item abstract').find('p').get_text(strip=True)
        content_book['Resumen']=resu
    except AttributeError:
        content_book['Resumen']=None
    #abstract
    try:
        abst=s_item.find('div', class_='item cover_image').get_text(strip=True)
        content_book['Abstract']=abst
    except AttributeError:
        content_book['Abstract']=None
    #Link incial
    try:
        linkart=url
        content_book['Link Articulo']=linkart
    except AttributeError:
        content_book['Link Articulo']=None
    #link articulo
    try:
        link=s_item.find('a', class_='obj_galley_link pdf').get('href')
        content_book['Link PDF']=urljoin(url_root, link)
    except AttributeError:
        content_book['Link PDF']=None
    return content_book

# %%
list_scraper=list_scraper[0:798]
datos_book=[]
for idx, i in enumerate(list_scraper):
    print(f'estas escrapeando la pag {idx}')
    datos_book.append(scraper_book(i))
# Out:
# estas escrapeando la pag 0
# estas escrapeando la pag 1
# estas escrapeando la pag 2
# estas escrapeando la pag 3
# estas escrapeando la pag 4
# estas escrapeando la pag 5
# estas escrapeando la pag 6
# estas escrapeando la pag 7
# estas escrapeando la pag 8
# estas escrapeando la pag 9
# estas escrapeando la pag 10
# estas escrapeando la pag 11
# estas escrapeando la pag 12
# estas escrapeando la pag 13
# estas escrapeando la pag 14
# estas escrapeando la pag 15
# estas escrapeando la pag 16
# estas escrapeando la pag 17
# estas escrapeando la pag 18
# estas escrapeando la pag 19
# estas escrapeando la pag 20
# estas escrapeando la pag 21
# estas escrapeando la pag 22
# estas escrapeando la pag 23
# estas escrapeando la pag 24
# estas escrapeando la pag 25
# estas escrapeando la pag 26
# estas escrapeando la pag 27
# estas escrapeando la pag 28
# estas escrapeando la pag 29
# estas escrapeando la pag 30
# estas escrapeando la pag 31
# estas escrapeando la pag 32
# ...

# %%
df_catalogo=pd.DataFrame(datos_book)
df_catalogo
# Out:
#                       Titulo Revista                  Area  \
# 0    Estudios Demográficos y Urbanos  V. Ciencias Sociales
# 1    Estudios Demográficos y Urbanos  V. Ciencias Sociales
# 2    Estudios Demográficos y Urbanos  V. Ciencias Sociales
# 3    Estudios Demográficos y Urbanos  V. Ciencias Sociales
# 4    Estudios Demográficos y Urbanos  V. Ciencias Sociales
# ..                               ...                   ...
# 793  Estudios Demográficos y Urbanos  V. Ciencias Sociales
# 794  Estudios Demográficos y Urbanos  V. Ciencias Sociales
# 795  Estudios Demográficos y Urbanos  V. Ciencias Sociales
# 796  Estudios Demográficos y Urbanos  V. Ciencias Sociales
# 797  Estudios Demográficos y Urbanos  V. Ciencias Sociales
#
#                                               Tematica  \
# 0    Demografía; Estudios Urbanos; Estudios Ambient...
# 1    Demografía; Estudios Urbanos; Estudios Ambient...
# 2    Demografía; Estudios Urbanos; Estudios Ambient...
# ...

# %%
df_catalogo.to_csv('Revista33.csv', index=False)

# %%
df=df_catalogo.drop(df_catalogo.index[[121,170,171,172,392,399,413,414,415,436,437,485,503,514,525,526,527,528,561,581,656,670,797]])
df
# Out:
#                       Titulo Revista                  Area  \
# 0    Estudios Demográficos y Urbanos  V. Ciencias Sociales
# 1    Estudios Demográficos y Urbanos  V. Ciencias Sociales
# 2    Estudios Demográficos y Urbanos  V. Ciencias Sociales
# 3    Estudios Demográficos y Urbanos  V. Ciencias Sociales
# 4    Estudios Demográficos y Urbanos  V. Ciencias Sociales
# ..                               ...                   ...
# 792  Estudios Demográficos y Urbanos  V. Ciencias Sociales
# 793  Estudios Demográficos y Urbanos  V. Ciencias Sociales
# 794  Estudios Demográficos y Urbanos  V. Ciencias Sociales
# 795  Estudios Demográficos y Urbanos  V. Ciencias Sociales
# 796  Estudios Demográficos y Urbanos  V. Ciencias Sociales
#
#                                               Tematica  \
# 0    Demografía; Estudios Urbanos; Estudios Ambient...
# 1    Demografía; Estudios Urbanos; Estudios Ambient...
# 2    Demografía; Estudios Urbanos; Estudios Ambient...
# ...

# %%
df.to_csv('Revista33.csv', index=False)
