# %%
import requests
import bs4
from bs4 import BeautifulSoup
from urllib.parse import urljoin
import pandas as pd

# %%
url_inicial = 'http://revistamexicanadesociologia.unam.mx/index.php/rms/issue/archive?issuesPage=10#issues'
url_root = 'http://revistamexicanadesociologia.unam.mx/index.php/rms/issue/archive?issuesPage=10#issues'
r=requests.get(url_inicial)

# %%
soup = BeautifulSoup(r.text, 'html.parser')

# %%
box = soup.find('div', id='content')
volumen=box.findAll('h4')
vol = [x.find('a').get('href')for x in volumen]
vol=[urljoin(url_root,i) for i in vol]
vol
# Out:
# ['http://revistamexicanadesociologia.unam.mx/index.php/rms/issue/view/4532',
#  'http://revistamexicanadesociologia.unam.mx/index.php/rms/issue/view/4490',
#  'http://revistamexicanadesociologia.unam.mx/index.php/rms/issue/view/4489',
#  'http://revistamexicanadesociologia.unam.mx/index.php/rms/issue/view/4488',
#  'http://revistamexicanadesociologia.unam.mx/index.php/rms/issue/view/4475',
#  'http://revistamexicanadesociologia.unam.mx/index.php/rms/issue/view/4474',
#  'http://revistamexicanadesociologia.unam.mx/index.php/rms/issue/view/4540',
#  'http://revistamexicanadesociologia.unam.mx/index.php/rms/issue/view/4539',
#  'http://revistamexicanadesociologia.unam.mx/index.php/rms/issue/view/4538',
#  'http://revistamexicanadesociologia.unam.mx/index.php/rms/issue/view/4537',
#  'http://revistamexicanadesociologia.unam.mx/index.php/rms/issue/view/4473',
#  'http://revistamexicanadesociologia.unam.mx/index.php/rms/issue/view/4468']

# %%
def get_url_items(sopa, url): 
    box = soup.find('div', id='content')
    volumen=box.findAll('h4')
    vol = [x.find('a').get('href')for x in volumen]
    vol=[urljoin(url_root,i) for i in vol]
    return vol

# %%
links_items=[]
i=0
while i<1:
    i+=1
    print(f'Estoy en la pagina {url_inicial}')
    r_pag=requests.get(url_inicial)
    s_p=BeautifulSoup(r_pag.text,'html.parser')
    links=get_url_items(s_p, url_inicial)
    links_items.append(links)
# Out:
# Estoy en la pagina http://revistamexicanadesociologia.unam.mx/index.php/rms/issue/archive?issuesPage=10#issues

# %%
list_scraper=[]
for i in links_items:
    for j in i:
        list_scraper.append(j)
len(list_scraper)
# Out:
# 12

# %%
uno=list_scraper[0]
r_item=requests.get(uno)
s_item=BeautifulSoup(r_item.text, 'html.parser')

# %%
#funcion para iniciar el escraper de cada libro
def scraper_book(url):
    content_book={}
    r=requests.get(url)
    tire='Revista Mexicana de Sociología'
    a='V. Ciencias Sociales'
    tem='Sociología, Ciencias Sociales, América Latina, Cultura, Temas de Coyuntura Social.'
    url='http://revistamexicanadesociologia.unam.mx/index.php/rms/issue/view/4457'
    s_item=BeautifulSoup(r.text,'html.parser')
    #titulo de revista
    try:
        titulo=tire
        content_book['Titulo de revista']=tire
    except AttributeError:
        content_book['Titulo de revista']=None
    #area
    try:
        area=a
        content_book['Área']=a
    except AttributeError:
        content_book['Área']=None
    #tematica
    try:
        tema=tem
        content_book['Temática']=tem
    except AttributeError:
        content_book['Temática']=None
    #titulo libro
    try:
        titu=s_item.find('h2').get_text(strip=True)
        content_book['Titulo del libro']=titu
    except AttributeError:
        content_book['Titulo del libro']=None
    #resumen
    try:
        resu=s_item.find('a', class_='cover').get_text(strip=True)
        content_book['Resumen']=resu
    except AttributeError:
        content_book['Resumen']=None
    #Link incial
    try:
        inicial=url
        content_book['Link inicial']=url
    except AttributeError:
        content_book['Link inicial']=None
    #link articulo
    try:
        link=s_item.find('a', id='pub-id::doi').get('href')
        content_book['Link articulo']=urljoin(url_root, link)
    except AttributeError:
        content_book['Link articulo']=None
    return content_book

# %%
list_scraper=list_scraper[0:12]
datos_book=[]
for idx, i in enumerate(list_scraper):
    print(f'estas escrapeando la pag {idx}')
    datos_book.append(scraper_book(i))
# Out:
# estas escrapeando la pag 0
# estas escrapeando la pag 1
# estas escrapeando la pag 2
# estas escrapeando la pag 3
# estas escrapeando la pag 4
# estas escrapeando la pag 5
# estas escrapeando la pag 6
# estas escrapeando la pag 7
# estas escrapeando la pag 8
# estas escrapeando la pag 9
# estas escrapeando la pag 10
# estas escrapeando la pag 11

# %%
df_catalogo=pd.DataFrame(datos_book)
df_catalogo
# Out:
#                  Titulo de revista                  Área  \
# 0   Revista Mexicana de Sociología  V. Ciencias Sociales
# 1   Revista Mexicana de Sociología  V. Ciencias Sociales
# 2   Revista Mexicana de Sociología  V. Ciencias Sociales
# 3   Revista Mexicana de Sociología  V. Ciencias Sociales
# 4   Revista Mexicana de Sociología  V. Ciencias Sociales
# 5   Revista Mexicana de Sociología  V. Ciencias Sociales
# 6   Revista Mexicana de Sociología  V. Ciencias Sociales
# 7   Revista Mexicana de Sociología  V. Ciencias Sociales
# 8   Revista Mexicana de Sociología  V. Ciencias Sociales
# 9   Revista Mexicana de Sociología  V. Ciencias Sociales
# 10  Revista Mexicana de Sociología  V. Ciencias Sociales
# 11  Revista Mexicana de Sociología  V. Ciencias Sociales
#
#                                              Temática  \
# 0   Sociología, Ciencias Sociales, América Latina,...
# 1   Sociología, Ciencias Sociales, América Latina,...
# 2   Sociología, Ciencias Sociales, América Latina,...
# ...

# %%
df_catalogo.to_csv('Revista83.10.csv', index=False)
