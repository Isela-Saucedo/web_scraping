# %%
import requests
import bs4
from bs4 import BeautifulSoup
from urllib.parse import urljoin
import pandas as pd

# %%
url_inicial = 'http://cienciasagricolas.inifap.gob.mx/index.php/agricolas/issue/archive/4'
url_root = 'http://cienciasagricolas.inifap.gob.mx/index.php/agricolas/issue/archive/4'
r=requests.get(url_inicial)

# %%
soup = BeautifulSoup(r.text, 'html.parser')

# %%
box = soup.find('ul', class_='issues_archive')
volumen=box.findAll('div', class_='obj_issue_summary')
vol = [x.find('a').get('href')for x in volumen]
vol=[urljoin(url_root,i) for i in vol]
vol
# Out:
# ['http://cienciasagricolas.inifap.gob.mx/index.php/agricolas/issue/view/51',
#  'http://cienciasagricolas.inifap.gob.mx/index.php/agricolas/issue/view/52',
#  'http://cienciasagricolas.inifap.gob.mx/index.php/agricolas/issue/view/53',
#  'http://cienciasagricolas.inifap.gob.mx/index.php/agricolas/issue/view/55',
#  'http://cienciasagricolas.inifap.gob.mx/index.php/agricolas/issue/view/56',
#  'http://cienciasagricolas.inifap.gob.mx/index.php/agricolas/issue/view/57',
#  'http://cienciasagricolas.inifap.gob.mx/index.php/agricolas/issue/view/58',
#  'http://cienciasagricolas.inifap.gob.mx/index.php/agricolas/issue/view/59',
#  'http://cienciasagricolas.inifap.gob.mx/index.php/agricolas/issue/view/60',
#  'http://cienciasagricolas.inifap.gob.mx/index.php/agricolas/issue/view/61',
#  'http://cienciasagricolas.inifap.gob.mx/index.php/agricolas/issue/view/62',
#  'http://cienciasagricolas.inifap.gob.mx/index.php/agricolas/issue/view/64',
# ...

# %%
def get_url_items(sopa, url): 
    box = soup.find('ul', class_='issues_archive')
    volumen=box.findAll('div', class_='obj_issue_summary')
    vol = [x.find('a').get('href')for x in volumen]
    vol=[urljoin(url_root,i) for i in vol]
    return vol

# %%
links_items=[]
i=0
while i<1:
    i+=1
    print(f'Estoy en la pagina {url_inicial}')
    r_pag=requests.get(url_inicial)
    s_p=BeautifulSoup(r_pag.text,'html.parser')
    links=get_url_items(s_p, url_inicial)
    links_items.append(links)
# Out:
# Estoy en la pagina http://cienciasagricolas.inifap.gob.mx/index.php/agricolas/issue/archive/4

# %%
list_scraper=[]
for i in links_items:
    for j in i:
        list_scraper.append(j)
len(list_scraper)
# Out:
# 18

# %%
uno=list_scraper[0]
r_item=requests.get(uno)
s_item=BeautifulSoup(r_item.text, 'html.parser')

# %%
#funcion para iniciar el escraper de cada libro
def scraper_book(url):
    content_book={}
    r=requests.get(url)
    tire='Revista Mexicana de Ciencias Agrícolas'
    a='VI. Biotecnología y Ciencias Agropecuarias'
    tem='Agricultura y Ciencias Biológicas'
    url='http://cienciasagricolas.inifap.gob.mx'
    s_item=BeautifulSoup(r.text,'html.parser')
    #titulo de revista
    try:
        titulo=tire
        content_book['Titulo de revista']=tire
    except AttributeError:
        content_book['Titulo de revista']=None
    #area
    try:
        area=a
        content_book['Área']=a
    except AttributeError:
        content_book['Área']=None
    #tematica
    try:
        tema=tem
        content_book['Temática']=tem
    except AttributeError:
        content_book['Temática']=None
    #titulo libro
    try:
        titu=s_item.find('h3', class_='title').get_text(strip=True)
        content_book['Titulo del libro']=titu
    except AttributeError:
        content_book['Titulo del libro']=None
    #resumen
    try:
        resu=s_item.find('a', class_='cover').get_text(strip=True)
        content_book['Resumen']=resu
    except AttributeError:
        content_book['Resumen']=None
    #Link incial
    try:
        inicial=url
        content_book['Link inicial']=url
    except AttributeError:
        content_book['Link inicial']=None
    #link articulo
    try:
        link=s_item.find('a', class_='obj_galley_link pdf').get('href')
        content_book['Link articulo']=urljoin(url_root, link)
    except AttributeError:
        content_book['Link articulo']=None
    return content_book

# %%
list_scraper=list_scraper[0:30]
datos_book=[]
for idx, i in enumerate(list_scraper):
    print(f'estas escrapeando la pag {idx}')
    datos_book.append(scraper_book(i))
# Out:
# estas escrapeando la pag 0
# estas escrapeando la pag 1
# estas escrapeando la pag 2
# estas escrapeando la pag 3
# estas escrapeando la pag 4
# estas escrapeando la pag 5
# estas escrapeando la pag 6
# estas escrapeando la pag 7
# estas escrapeando la pag 8
# estas escrapeando la pag 9
# estas escrapeando la pag 10
# estas escrapeando la pag 11
# estas escrapeando la pag 12
# estas escrapeando la pag 13
# estas escrapeando la pag 14
# estas escrapeando la pag 15
# estas escrapeando la pag 16
# estas escrapeando la pag 17

# %%
df_catalogo=pd.DataFrame(datos_book)
df_catalogo
# Out:
#                          Titulo de revista  \
# 0   Revista Mexicana de Ciencias Agrícolas
# 1   Revista Mexicana de Ciencias Agrícolas
# 2   Revista Mexicana de Ciencias Agrícolas
# 3   Revista Mexicana de Ciencias Agrícolas
# 4   Revista Mexicana de Ciencias Agrícolas
# 5   Revista Mexicana de Ciencias Agrícolas
# 6   Revista Mexicana de Ciencias Agrícolas
# 7   Revista Mexicana de Ciencias Agrícolas
# 8   Revista Mexicana de Ciencias Agrícolas
# 9   Revista Mexicana de Ciencias Agrícolas
# 10  Revista Mexicana de Ciencias Agrícolas
# 11  Revista Mexicana de Ciencias Agrícolas
# 12  Revista Mexicana de Ciencias Agrícolas
# 13  Revista Mexicana de Ciencias Agrícolas
# 14  Revista Mexicana de Ciencias Agrícolas
# 15  Revista Mexicana de Ciencias Agrícolas
# 16  Revista Mexicana de Ciencias Agrícolas
# 17  Revista Mexicana de Ciencias Agrícolas
#
#                                           Área  \
# 0   VI. Biotecnología y Ciencias Agropecuarias
# ...

# %%
df_catalogo.to_csv('Revista141.04.csv', index=False)
